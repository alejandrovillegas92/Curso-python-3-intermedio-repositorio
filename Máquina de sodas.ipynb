# %% [markdown]
# Maquina de sodas

# %%
#Maquina de sodas compleja
Coca_Cola= 18
Sprite = 18
Fanta = 18
Jumex_Durazno = 20
Jumex_Naranja = 20
Agua_Ciel = 14
Sidral_Mundet = 20
Fresca = 20
Pepsi = 18
Sevenup = 18
saldo=0

while True:
  opcion =int(input("""Bienvenido a la máquina Maxi Sodas
             ¿Que deseas beber hoy?:
            1: Coca Cola 600 ml $18
            2: Sprite 600 ml $18
            3: Fanta 600 ml $18
            4: Jugo Jumex Durazno $20
            5: Jugo Jumez Naranga $20
            6: Agua Ciel 1 lt $14
            7: Sidral Mundet 600ml $20
            8: Fresca toronja 600ml $20
            9: Pepsi 600ml $18
           10: 7up 600ml $18
           11: Salir
                                  """))

  if opcion == 1:
    print('Has elegido una Coca Cola')
    while saldo<Coca_Cola:
      #Mostrar monto adeudado
      print('Tu monto adeudado es: $',Coca_Cola-saldo,'pesos',)
      #Solicitar ingresar moneda
      dinero=int(input('Ingresa una moneda, solo acepto monedas de $1, $2, $5 y $10 pesos: '))
        #verificar validez de la moneda
      if dinero==1:
        saldo+=dinero
      if dinero==2:
        saldo+=dinero
      if dinero==5:
        saldo+=dinero
      if dinero==10:
        saldo+=dinero
    print('Tu monto adeudado es $0 pesos')
      #Salida del programa
    print('Aquí tienes tu bebida, tu cambio es: $',saldo-Coca_Cola,'pesos, gracias vuelva pronto')
    break


  elif opcion == 2:
    print('Has elegido una Sprite')
    while saldo<Sprite:
      #Mostrar monto adeudado
      print('Tu monto adeudado es: $',Sprite-saldo,'pesos',)
      #Solicitar ingresar moneda
      dinero=int(input('Ingresa una moneda, solo acepto monedas de $1, $2, $5 y $10 pesos: '))
        #verificar validez de la moneda
      if dinero==1:
        saldo+=dinero
      if dinero==2:
        saldo+=dinero
      if dinero==5:
        saldo+=dinero
      if dinero==10:
        saldo+=dinero
    print('Tu monto adeudado es $0 pesos')
      #Salida del programa
    print('Aquí tienes tu bebida, tu cambio es: $',saldo-Sprite,'pesos, gracias vuelva pronto')
    break


  elif opcion == 3:
    print('Has elegido una Fanta')
    while saldo<Fanta:
      #Mostrar monto adeudado
      print('Tu monto adeudado es: $',Fanta-saldo,'pesos',)
      #Solicitar ingresar moneda
      dinero=int(input('Ingresa una moneda, solo acepto monedas de $1, $2, $5 y $10 pesos: '))
        #verificar validez de la moneda
      if dinero==1:
        saldo+=dinero
      if dinero==2:
        saldo+=dinero
      if dinero==5:
        saldo+=dinero
      if dinero==10:
        saldo+=dinero
    print('Tu monto adeudado es $0 pesos')
      #Salida del programa
    print('Aquí tienes tu bebida, tu cambio es: $',saldo-Fanta,'pesos, gracias vuelva pronto')
    break


  elif opcion == 4:
    print('Has elegido un Jumex de Durazno')
    while saldo<Jumex_Durazno:
      #Mostrar monto adeudado
      print('Tu monto adeudado es: $',Jumex_Durazno-saldo,'pesos',)
      #Solicitar ingresar moneda
      dinero=int(input('Ingresa una moneda, solo acepto monedas de $1, $2, $5 y $10 pesos: '))
        #verificar validez de la moneda
      if dinero==1:
        saldo+=dinero
      if dinero==2:
        saldo+=dinero
      if dinero==5:
        saldo+=dinero
      if dinero==10:
        saldo+=dinero
    print('Tu monto adeudado es $0 pesos')
      #Salida del programa
    print('Aquí tienes tu bebida, tu cambio es: $',saldo-Jumex_Durazno,'pesos, gracias vuelva pronto')
    break


  elif opcion == 5:
    print('Has elegido un Jumex de Naranja')
    while saldo<Jumex_Naranja:
      #Mostrar monto adeudado
      print('Tu monto adeudado es: $',Jumex_Naranja-saldo,'pesos',)
      #Solicitar ingresar moneda
      dinero=int(input('Ingresa una moneda, solo acepto monedas de $1, $2, $5 y $10 pesos: '))
        #verificar validez de la moneda
      if dinero==1:
        saldo+=dinero
      if dinero==2:
        saldo+=dinero
      if dinero==5:
        saldo+=dinero
      if dinero==10:
        saldo+=dinero
    print('Tu monto adeudado es $0 pesos')
      #Salida del programa
    print('Aquí tienes tu bebida, tu cambio es: $',saldo-Jumex_Naranja,'pesos, gracias vuelva pronto')
    break


  elif opcion == 6:
    print('Has elegido un Agua Ciel')
    while saldo<Agua_Ciel:
      #Mostrar monto adeudado
      print('Tu monto adeudado es: $',Agua_Ciel-saldo,'pesos',)
      #Solicitar ingresar moneda
      dinero=int(input('Ingresa una moneda, solo acepto monedas de $1, $2, $5 y $10 pesos: '))
        #verificar validez de la moneda
      if dinero==1:
        saldo+=dinero
      if dinero==2:
        saldo+=dinero
      if dinero==5:
        saldo+=dinero
      if dinero==10:
        saldo+=dinero
    print('Tu monto adeudado es $0 pesos')
      #Salida del programa
    print('Aquí tienes tu bebida, tu cambio es: $',saldo-Agua_Ciel,'pesos, gracias vuelva pronto')
    break


  elif opcion == 7:
    print('Has elegido una Sidral Mundet')
    while saldo<Sidral_Mundet:
      #Mostrar monto adeudado
      print('Tu monto adeudado es: $',Sidral_Mundet-saldo,'pesos',)
      #Solicitar ingresar moneda
      dinero=int(input('Ingresa una moneda, solo acepto monedas de $1, $2, $5 y $10 pesos: '))
        #verificar validez de la moneda
      if dinero==1:
        saldo+=dinero
      if dinero==2:
        saldo+=dinero
      if dinero==5:
        saldo+=dinero
      if dinero==10:
        saldo+=dinero
    print('Tu monto adeudado es $0 pesos')
      #Salida del programa
    print('Aquí tienes tu bebida, tu cambio es: $',saldo-Sidral_Mundet,'pesos, gracias vuelva pronto')
    break


  elif opcion == 8:
    print('Has elegido una Fresca')
    while saldo<Fresca:
      #Mostrar monto adeudado
      print('Tu monto adeudado es: $',Fresca-saldo,'pesos',)
      #Solicitar ingresar moneda
      dinero=int(input('Ingresa una moneda, solo acepto monedas de $1, $2, $5 y $10 pesos: '))
        #verificar validez de la moneda
      if dinero==1:
        saldo+=dinero
      if dinero==2:
        saldo+=dinero
      if dinero==5:
        saldo+=dinero
      if dinero==10:
        saldo+=dinero
    print('Tu monto adeudado es $0 pesos')
      #Salida del programa
    print('Aquí tienes tu bebida, tu cambio es: $',saldo-Fresca,'pesos, gracias vuelva pronto')
    break


  elif opcion == 9:
    print('Has elegido una Pepsi')
    while saldo<Pepsi:
      #Mostrar monto adeudado
      print('Tu monto adeudado es: $',Pepsi-saldo,'pesos',)
      #Solicitar ingresar moneda
      dinero=int(input('Ingresa una moneda, solo acepto monedas de $1, $2, $5 y $10 pesos: '))
        #verificar validez de la moneda
      if dinero==1:
        saldo+=dinero
      if dinero==2:
        saldo+=dinero
      if dinero==5:
        saldo+=dinero
      if dinero==10:
        saldo+=dinero
    print('Tu monto adeudado es $0 pesos')
      #Salida del programa
    print('Aquí tienes tu bebida, tu cambio es: $',saldo-Pepsi,'pesos, gracias vuelva pronto')
    break


  elif opcion == 10:
    print('Has elegido una 7up')
    while saldo<Sevenup:
      #Mostrar monto adeudado
      print('Tu monto adeudado es: $',Sevenup-saldo,'pesos',)
      #Solicitar ingresar moneda
      dinero=int(input('Ingresa una moneda, solo acepto monedas de $1, $2, $5 y $10 pesos: '))
        #verificar validez de la moneda
      if dinero==1:
        saldo+=dinero
      if dinero==2:
        saldo+=dinero
      if dinero==5:
        saldo+=dinero
      if dinero==10:
        saldo+=dinero
    print('Tu monto adeudado es $0 pesos')
      #Salida del programa
    print('Aquí tienes tu bebida, tu cambio es: $',saldo-Sevenup,'pesos, gracias vuelva pronto')
    break
  
  elif opcion == 11:
    print("Gracias vuelva pronto")
    break

  else:
    print("Opción invalida, por favor ingrese una opción valida")
