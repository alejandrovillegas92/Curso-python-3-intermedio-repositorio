# %% [markdown]
# Web scrapping con BeautifulSoup

# %% [markdown]
# 1.Instalar e importar librerias

# %%
pip install requests
# Out:
# Collecting requestsNote: you may need to restart the kernel to use updated packages.
#   Downloading requests-2.31.0-py3-none-any.whl (62 kB)
# Collecting charset-normalizer<4,>=2
# WARNING: Value for scheme.headers does not match. Please report this to <https://github.com/pypa/pip/issues/9617>
# distutils: c:\Users\cross\AppData\Local\Programs\Python\Python39\Include\UNKNOWN
# sysconfig: c:\Users\cross\AppData\Local\Programs\Python\Python39\Include
# WARNING: Additional context:
# user = False
# home = None
# root = None
# prefix = None
# WARNING: Value for scheme.headers does not match. Please report this to <https://github.com/pypa/pip/issues/9617>
# distutils: c:\Users\cross\AppData\Local\Programs\Python\Python39\Include\UNKNOWN
# sysconfig: c:\Users\cross\AppData\Local\Programs\Python\Python39\Include
# WARNING: Additional context:
# user = False
# home = None
# root = None
# prefix = None
# WARNING: You are using pip version 21.1; however, version 23.1.2 is available.
# You should consider upgrading via the 'c:\Users\cross\AppData\Local\Programs\Python\Python39\python.exe -m pip install --upgrade pip' command.
#   Downloading charset_normalizer-3.2.0-cp39-cp39-win_amd64.whl (96 kB)
# Collecting urllib3<3,>=1.21.1
#   Downloading urllib3-2.0.4-py3-none-any.whl (123 kB)
# Collecting certifi>=2017.4.17
#   Downloading certifi-2023.5.7-py3-none-any.whl (156 kB)
# Collecting idna<4,>=2.5
#   Downloading idna-3.4-py3-none-any.whl (61 kB)
# Installing collected packages: urllib3, idna, charset-normalizer, certifi, requests
# Successfully installed certifi-2023.5.7 charset-normalizer-3.2.0 idna-3.4 requests-2.31.0 urllib3-2.0.4

# %%
pip install beautifulsoup4
# Out:
# Collecting beautifulsoup4
#   Downloading beautifulsoup4-4.12.2-py3-none-any.whl (142 kB)
# Collecting soupsieve>1.2
#   Downloading soupsieve-2.4.1-py3-none-any.whl (36 kB)
# Installing collected packages: soupsieve, beautifulsoup4
# Successfully installed beautifulsoup4-4.12.2 soupsieve-2.4.1
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Value for scheme.headers does not match. Please report this to <https://github.com/pypa/pip/issues/9617>
# distutils: c:\Users\cross\AppData\Local\Programs\Python\Python39\Include\UNKNOWN
# sysconfig: c:\Users\cross\AppData\Local\Programs\Python\Python39\Include
# WARNING: Additional context:
# user = False
# home = None
# root = None
# prefix = None
# WARNING: Value for scheme.headers does not match. Please report this to <https://github.com/pypa/pip/issues/9617>
# distutils: c:\Users\cross\AppData\Local\Programs\Python\Python39\Include\UNKNOWN
# sysconfig: c:\Users\cross\AppData\Local\Programs\Python\Python39\Include
# WARNING: Additional context:
# user = False
# home = None
# root = None
# prefix = None
# WARNING: You are using pip version 21.1; however, version 23.1.2 is available.
# You should consider upgrading via the 'c:\Users\cross\AppData\Local\Programs\Python\Python39\python.exe -m pip install --upgrade pip' command.

# %%
import requests

from bs4 import BeautifulSoup

# %% [markdown]
# 2. Enviar peticion HTTP para extraer codigo fuente de la pagina web

# %%
pagina_web = requests.get('http://books.toscrape.com/asasasas') #De esta forma hacemos la peticion a la pagina web que deseemos

print(pagina_web)#Cuando exista algun error en la pagina habra un error 404 que es not found
# Out:
# <Response [404]>

# %%
pagina_web = requests.get('http://books.toscrape.com/index.html') #De esta forma hacemos la peticion a la pagina web que deseemos

print(pagina_web) #Se obtendra como resultado un responde 200 que representa 'Todo esta bien' 'Fue aceptada'

soup = BeautifulSoup(pagina_web.text,'html.parser') #Creamos el objeto Soup que toma a Beutiful soup como clase, y ahora 
                                                    #Ponemos nuestra pagina web con el atributo texto y definimos un analizador que es el parser

print(soup.prettify())#con este metodo se imprime el codigo fuente a manera de texto
# Out:
# <Response [200]>
# <!DOCTYPE html>
# <!--[if lt IE 7]>      <html lang="en-us" class="no-js lt-ie9 lt-ie8 lt-ie7"> <![endif]-->
# <!--[if IE 7]>         <html lang="en-us" class="no-js lt-ie9 lt-ie8"> <![endif]-->
# <!--[if IE 8]>         <html lang="en-us" class="no-js lt-ie9"> <![endif]-->
# <!--[if gt IE 8]><!-->
# <html class="no-js" lang="en-us">
#  <!--<![endif]-->
#  <head>
#   <title>
#    All products | Books to Scrape - Sandbox
#   </title>
#   <meta content="text/html; charset=utf-8" http-equiv="content-type"/>
#   <meta content="24th Jun 2016 09:29" name="created"/>
#   <meta content="" name="description"/>
#   <meta content="width=device-width" name="viewport"/>
#   <meta content="NOARCHIVE,NOCACHE" name="robots"/>
#   <!-- Le HTML5 shim, for IE6-8 support of HTML elements -->
#   <!--[if lt IE 9]>
#         <script src="//html5shim.googlecode.com/svn/trunk/html5.js"></script>
#         <![endif]-->
#   <link href="static/oscar/favicon.ico" rel="shortcut icon"/>
#   <link href="static/oscar/css/styles.css" rel="stylesheet" type="text/css"/>
#   <link href="static/oscar/js/bootstrap-datetimepicker/bootstrap-datetimepicker.css" rel="stylesheet"/>
#   <link href="static/oscar/css/datetimepicker.css" rel="stylesheet" type="text/css"/>
#  </head>
#  <body class="default" id="default">
#   <header class="header container-fluid">
#    <div class="page_inner">
#     <div class="row">
#      <div class="col-sm-8 h1">
#       <a href="index.html">
#        Books to Scrape
#       </a>
#       <small>
#        We love being scraped!
#       </small>
#      </div>
#     </div>
#    </div>
#   </header>
#   <div class="container-fluid page">
#    <div class="page_inner">
#     <ul class="breadcrumb">
#      <li>
#       <a href="index.html">
#        Home
#       </a>
#      </li>
#      <li class="active">
#       All products
#      </li>
#     </ul>
#     <div class="row">
#      <aside class="sidebar col-sm-4 col-md-3">
#       <div id="promotions_left">
#       </div>
#       <div class="side_categories">
#        <ul class="nav nav-list">
#         <li>
#          <a href="catalogue/category/books_1/index.html">
#           Books
#          </a>
#          <ul>
#           <li>
#            <a href="catalogue/category/books/travel_2/index.html">
#             Travel
#            </a>
#           </li>
#           <li>
#            <a href="catalogue/category/books/mystery_3/index.html">
#             Mystery
#            </a>
#           </li>
#           <li>
#            <a href="catalogue/category/books/historical-fiction_4/index.html">
#             Historical Fiction
#            </a>
#           </li>
#           <li>
#            <a href="catalogue/category/books/sequential-art_5/index.html">
#             Sequential Art
#            </a>
#           </li>
#           <li>
#            <a href="catalogue/category/books/classics_6/index.html">
#             Classics
#            </a>
#           </li>
#           <li>
#            <a href="catalogue/category/books/philosophy_7/index.html">
#             Philosophy
#            </a>
#           </li>
#           <li>
#            <a href="catalogue/category/books/romance_8/index.html">
#             Romance
#            </a>
#           </li>
#           <li>
#            <a href="catalogue/category/books/womens-fiction_9/index.html">
#             Womens Fiction
#            </a>
#           </li>
#           <li>
#            <a href="catalogue/category/books/fiction_10/index.html">
#             Fiction
#            </a>
#           </li>
#           <li>
#            <a href="catalogue/category/books/childrens_11/index.html">
#             Childrens
#            </a>
#           </li>
#           <li>
#            <a href="catalogue/category/books/religion_12/index.html">
#             Religion
#            </a>
#           </li>
#           <li>
#            <a href="catalogue/category/books/nonfiction_13/index.html">
#             Nonfiction
#            </a>
#           </li>
#           <li>
#            <a href="catalogue/category/books/music_14/index.html">
#             Music
#            </a>
#           </li>
#           <li>
#            <a href="catalogue/category/books/default_15/index.html">
#             Default
#            </a>
#           </li>
#           <li>
#            <a href="catalogue/category/books/science-fiction_16/index.html">
#             Science Fiction
#            </a>
#           </li>
#           <li>
#            <a href="catalogue/category/books/sports-and-games_17/index.html">
#             Sports and Games
#            </a>
#           </li>
#           <li>
#            <a href="catalogue/category/books/add-a-comment_18/index.html">
#             Add a comment
#            </a>
#           </li>
#           <li>
#            <a href="catalogue/category/books/fantasy_19/index.html">
#             Fantasy
#            </a>
#           </li>
#           <li>
#            <a href="catalogue/category/books/new-adult_20/index.html">
#             New Adult
#            </a>
#           </li>
#           <li>
#            <a href="catalogue/category/books/young-adult_21/index.html">
#             Young Adult
#            </a>
#           </li>
#           <li>
#            <a href="catalogue/category/books/science_22/index.html">
#             Science
#            </a>
#           </li>
#           <li>
#            <a href="catalogue/category/books/poetry_23/index.html">
#             Poetry
#            </a>
#           </li>
#           <li>
#            <a href="catalogue/category/books/paranormal_24/index.html">
#             Paranormal
#            </a>
#           </li>
#           <li>
#            <a href="catalogue/category/books/art_25/index.html">
#             Art
#            </a>
#           </li>
#           <li>
#            <a href="catalogue/category/books/psychology_26/index.html">
#             Psychology
#            </a>
#           </li>
#           <li>
#            <a href="catalogue/category/books/autobiography_27/index.html">
#             Autobiography
#            </a>
#           </li>
#           <li>
#            <a href="catalogue/category/books/parenting_28/index.html">
#             Parenting
#            </a>
#           </li>
#           <li>
#            <a href="catalogue/category/books/adult-fiction_29/index.html">
#             Adult Fiction
#            </a>
#           </li>
#           <li>
#            <a href="catalogue/category/books/humor_30/index.html">
#             Humor
#            </a>
#           </li>
#           <li>
#            <a href="catalogue/category/books/horror_31/index.html">
#             Horror
#            </a>
#           </li>
#           <li>
#            <a href="catalogue/category/books/history_32/index.html">
#             History
#            </a>
#           </li>
#           <li>
#            <a href="catalogue/category/books/food-and-drink_33/index.html">
#             Food and Drink
#            </a>
#           </li>
#           <li>
#            <a href="catalogue/category/books/christian-fiction_34/index.html">
#             Christian Fiction
#            </a>
#           </li>
#           <li>
#            <a href="catalogue/category/books/business_35/index.html">
#             Business
#            </a>
#           </li>
#           <li>
#            <a href="catalogue/category/books/biography_36/index.html">
#             Biography
#            </a>
#           </li>
#           <li>
#            <a href="catalogue/category/books/thriller_37/index.html">
#             Thriller
#            </a>
#           </li>
#           <li>
#            <a href="catalogue/category/books/contemporary_38/index.html">
#             Contemporary
#            </a>
#           </li>
#           <li>
#            <a href="catalogue/category/books/spirituality_39/index.html">
#             Spirituality
#            </a>
#           </li>
#           <li>
#            <a href="catalogue/category/books/academic_40/index.html">
#             Academic
#            </a>
#           </li>
#           <li>
#            <a href="catalogue/category/books/self-help_41/index.html">
#             Self Help
#            </a>
#           </li>
#           <li>
#            <a href="catalogue/category/books/historical_42/index.html">
#             Historical
#            </a>
#           </li>
#           <li>
#            <a href="catalogue/category/books/christian_43/index.html">
#             Christian
#            </a>
#           </li>
#           <li>
#            <a href="catalogue/category/books/suspense_44/index.html">
#             Suspense
#            </a>
#           </li>
#           <li>
#            <a href="catalogue/category/books/short-stories_45/index.html">
#             Short Stories
#            </a>
#           </li>
#           <li>
#            <a href="catalogue/category/books/novels_46/index.html">
#             Novels
#            </a>
#           </li>
#           <li>
#            <a href="catalogue/category/books/health_47/index.html">
#             Health
#            </a>
#           </li>
#           <li>
#            <a href="catalogue/category/books/politics_48/index.html">
#             Politics
#            </a>
#           </li>
#           <li>
#            <a href="catalogue/category/books/cultural_49/index.html">
#             Cultural
#            </a>
#           </li>
#           <li>
#            <a href="catalogue/category/books/erotica_50/index.html">
#             Erotica
#            </a>
#           </li>
#           <li>
#            <a href="catalogue/category/books/crime_51/index.html">
#             Crime
#            </a>
#           </li>
#          </ul>
#         </li>
#        </ul>
#       </div>
#      </aside>
#      <div class="col-sm-8 col-md-9">
#       <div class="page-header action">
#        <h1>
#         All products
#        </h1>
#       </div>
#       <div id="messages">
#       </div>
#       <div id="promotions">
#       </div>
#       <form class="form-horizontal" method="get">
#        <div style="display:none">
#        </div>
#        <strong>
#         1000
#        </strong>
#        results - showing
#        <strong>
#         1
#        </strong>
#        to
#        <strong>
#         20
#        </strong>
#        .
#       </form>
#       <section>
#        <div class="alert alert-warning" role="alert">
#         <strong>
#          Warning!
#         </strong>
#         This is a demo website for web scraping purposes. Prices and ratings here were randomly assigned and have no real meaning.
#        </div>
#        <div>
#         <ol class="row">
#          <li class="col-xs-6 col-sm-4 col-md-3 col-lg-3">
#           <article class="product_pod">
#            <div class="image_container">
#             <a href="catalogue/a-light-in-the-attic_1000/index.html">
#              <img alt="A Light in the Attic" class="thumbnail" src="media/cache/2c/da/2cdad67c44b002e7ead0cc35693c0e8b.jpg"/>
#             </a>
#            </div>
#            <p class="star-rating Three">
#             <i class="icon-star">
#             </i>
#             <i class="icon-star">
#             </i>
#             <i class="icon-star">
#             </i>
#             <i class="icon-star">
#             </i>
#             <i class="icon-star">
#             </i>
#            </p>
#            <h3>
#             <a href="catalogue/a-light-in-the-attic_1000/index.html" title="A Light in the Attic">
#              A Light in the ...
#             </a>
#            </h3>
#            <div class="product_price">
#             <p class="price_color">
#              Â£51.77
#             </p>
#             <p class="instock availability">
#              <i class="icon-ok">
#              </i>
#              In stock
#             </p>
#             <form>
#              <button class="btn btn-primary btn-block" data-loading-text="Adding..." type="submit">
#               Add to basket
#              </button>
#             </form>
#            </div>
#           </article>
#          </li>
#          <li class="col-xs-6 col-sm-4 col-md-3 col-lg-3">
#           <article class="product_pod">
#            <div class="image_container">
#             <a href="catalogue/tipping-the-velvet_999/index.html">
#              <img alt="Tipping the Velvet" class="thumbnail" src="media/cache/26/0c/260c6ae16bce31c8f8c95daddd9f4a1c.jpg"/>
#             </a>
#            </div>
#            <p class="star-rating One">
#             <i class="icon-star">
#             </i>
#             <i class="icon-star">
#             </i>
#             <i class="icon-star">
#             </i>
#             <i class="icon-star">
#             </i>
#             <i class="icon-star">
#             </i>
#            </p>
#            <h3>
#             <a href="catalogue/tipping-the-velvet_999/index.html" title="Tipping the Velvet">
#              Tipping the Velvet
#             </a>
#            </h3>
#            <div class="product_price">
#             <p class="price_color">
#              Â£53.74
#             </p>
#             <p class="instock availability">
#              <i class="icon-ok">
#              </i>
#              In stock
#             </p>
#             <form>
#              <button class="btn btn-primary btn-block" data-loading-text="Adding..." type="submit">
#               Add to basket
#              </button>
#             </form>
#            </div>
#           </article>
#          </li>
#          <li class="col-xs-6 col-sm-4 col-md-3 col-lg-3">
#           <article class="product_pod">
#            <div class="image_container">
#             <a href="catalogue/soumission_998/index.html">
#              <img alt="Soumission" class="thumbnail" src="media/cache/3e/ef/3eef99c9d9adef34639f510662022830.jpg"/>
#             </a>
#            </div>
#            <p class="star-rating One">
#             <i class="icon-star">
#             </i>
#             <i class="icon-star">
#             </i>
#             <i class="icon-star">
#             </i>
#             <i class="icon-star">
#             </i>
#             <i class="icon-star">
#             </i>
#            </p>
#            <h3>
#             <a href="catalogue/soumission_998/index.html" title="Soumission">
#              Soumission
#             </a>
#            </h3>
#            <div class="product_price">
#             <p class="price_color">
#              Â£50.10
#             </p>
#             <p class="instock availability">
#              <i class="icon-ok">
#              </i>
#              In stock
#             </p>
#             <form>
#              <button class="btn btn-primary btn-block" data-loading-text="Adding..." type="submit">
#               Add to basket
#              </button>
#             </form>
#            </div>
#           </article>
#          </li>
#          <li class="col-xs-6 col-sm-4 col-md-3 col-lg-3">
#           <article class="product_pod">
#            <div class="image_container">
#             <a href="catalogue/sharp-objects_997/index.html">
#              <img alt="Sharp Objects" class="thumbnail" src="media/cache/32/51/3251cf3a3412f53f339e42cac2134093.jpg"/>
#             </a>
#            </div>
#            <p class="star-rating Four">
#             <i class="icon-star">
#             </i>
#             <i class="icon-star">
#             </i>
#             <i class="icon-star">
#             </i>
#             <i class="icon-star">
#             </i>
#             <i class="icon-star">
#             </i>
#            </p>
#            <h3>
#             <a href="catalogue/sharp-objects_997/index.html" title="Sharp Objects">
#              Sharp Objects
#             </a>
#            </h3>
#            <div class="product_price">
#             <p class="price_color">
#              Â£47.82
#             </p>
#             <p class="instock availability">
#              <i class="icon-ok">
#              </i>
#              In stock
#             </p>
#             <form>
#              <button class="btn btn-primary btn-block" data-loading-text="Adding..." type="submit">
#               Add to basket
#              </button>
#             </form>
#            </div>
#           </article>
#          </li>
#          <li class="col-xs-6 col-sm-4 col-md-3 col-lg-3">
#           <article class="product_pod">
#            <div class="image_container">
#             <a href="catalogue/sapiens-a-brief-history-of-humankind_996/index.html">
#              <img alt="Sapiens: A Brief History of Humankind" class="thumbnail" src="media/cache/be/a5/bea5697f2534a2f86a3ef27b5a8c12a6.jpg"/>
#             </a>
#            </div>
#            <p class="star-rating Five">
#             <i class="icon-star">
#             </i>
#             <i class="icon-star">
#             </i>
#             <i class="icon-star">
#             </i>
#             <i class="icon-star">
#             </i>
#             <i class="icon-star">
#             </i>
#            </p>
#            <h3>
#             <a href="catalogue/sapiens-a-brief-history-of-humankind_996/index.html" title="Sapiens: A Brief History of Humankind">
#              Sapiens: A Brief History ...
#             </a>
#            </h3>
#            <div class="product_price">
#             <p class="price_color">
#              Â£54.23
#             </p>
#             <p class="instock availability">
#              <i class="icon-ok">
#              </i>
#              In stock
#             </p>
#             <form>
#              <button class="btn btn-primary btn-block" data-loading-text="Adding..." type="submit">
#               Add to basket
#              </button>
#             </form>
#            </div>
#           </article>
#          </li>
#          <li class="col-xs-6 col-sm-4 col-md-3 col-lg-3">
#           <article class="product_pod">
#            <div class="image_container">
#             <a href="catalogue/the-requiem-red_995/index.html">
#              <img alt="The Requiem Red" class="thumbnail" src="media/cache/68/33/68339b4c9bc034267e1da611ab3b34f8.jpg"/>
#             </a>
#            </div>
#            <p class="star-rating One">
#             <i class="icon-star">
#             </i>
#             <i class="icon-star">
#             </i>
#             <i class="icon-star">
#             </i>
#             <i class="icon-star">
#             </i>
#             <i class="icon-star">
#             </i>
#            </p>
#            <h3>
#             <a href="catalogue/the-requiem-red_995/index.html" title="The Requiem Red">
#              The Requiem Red
#             </a>
#            </h3>
#            <div class="product_price">
#             <p class="price_color">
#              Â£22.65
#             </p>
#             <p class="instock availability">
#              <i class="icon-ok">
#              </i>
#              In stock
#             </p>
#             <form>
#              <button class="btn btn-primary btn-block" data-loading-text="Adding..." type="submit">
#               Add to basket
#              </button>
#             </form>
#            </div>
#           </article>
#          </li>
#          <li class="col-xs-6 col-sm-4 col-md-3 col-lg-3">
#           <article class="product_pod">
#            <div class="image_container">
#             <a href="catalogue/the-dirty-little-secrets-of-getting-your-dream-job_994/index.html">
#              <img alt="The Dirty Little Secrets of Getting Your Dream Job" class="thumbnail" src="media/cache/92/27/92274a95b7c251fea59a2b8a78275ab4.jpg"/>
#             </a>
#            </div>
#            <p class="star-rating Four">
#             <i class="icon-star">
#             </i>
#             <i class="icon-star">
#             </i>
#             <i class="icon-star">
#             </i>
#             <i class="icon-star">
#             </i>
#             <i class="icon-star">
#             </i>
#            </p>
#            <h3>
#             <a href="catalogue/the-dirty-little-secrets-of-getting-your-dream-job_994/index.html" title="The Dirty Little Secrets of Getting Your Dream Job">
#              The Dirty Little Secrets ...
#             </a>
#            </h3>
#            <div class="product_price">
#             <p class="price_color">
#              Â£33.34
#             </p>
#             <p class="instock availability">
#              <i class="icon-ok">
#              </i>
#              In stock
#             </p>
#             <form>
#              <button class="btn btn-primary btn-block" data-loading-text="Adding..." type="submit">
#               Add to basket
#              </button>
#             </form>
#            </div>
#           </article>
#          </li>
#          <li class="col-xs-6 col-sm-4 col-md-3 col-lg-3">
#           <article class="product_pod">
#            <div class="image_container">
#             <a href="catalogue/the-coming-woman-a-novel-based-on-the-life-of-the-infamous-feminist-victoria-woodhull_993/index.html">
#              <img alt="The Coming Woman: A Novel Based on the Life of the Infamous Feminist, Victoria Woodhull" class="thumbnail" src="media/cache/3d/54/3d54940e57e662c4dd1f3ff00c78cc64.jpg"/>
#             </a>
#            </div>
#            <p class="star-rating Three">
#             <i class="icon-star">
#             </i>
#             <i class="icon-star">
#             </i>
#             <i class="icon-star">
#             </i>
#             <i class="icon-star">
#             </i>
#             <i class="icon-star">
#             </i>
#            </p>
#            <h3>
#             <a href="catalogue/the-coming-woman-a-novel-based-on-the-life-of-the-infamous-feminist-victoria-woodhull_993/index.html" title="The Coming Woman: A Novel Based on the Life of the Infamous Feminist, Victoria Woodhull">
#              The Coming Woman: A ...
#             </a>
#            </h3>
#            <div class="product_price">
#             <p class="price_color">
#              Â£17.93
#             </p>
#             <p class="instock availability">
#              <i class="icon-ok">
#              </i>
#              In stock
#             </p>
#             <form>
#              <button class="btn btn-primary btn-block" data-loading-text="Adding..." type="submit">
#               Add to basket
#              </button>
#             </form>
#            </div>
#           </article>
#          </li>
#          <li class="col-xs-6 col-sm-4 col-md-3 col-lg-3">
#           <article class="product_pod">
#            <div class="image_container">
#             <a href="catalogue/the-boys-in-the-boat-nine-americans-and-their-epic-quest-for-gold-at-the-1936-berlin-olympics_992/index.html">
#              <img alt="The Boys in the Boat: Nine Americans and Their Epic Quest for Gold at the 1936 Berlin Olympics" class="thumbnail" src="media/cache/66/88/66883b91f6804b2323c8369331cb7dd1.jpg"/>
#             </a>
#            </div>
#            <p class="star-rating Four">
#             <i class="icon-star">
#             </i>
#             <i class="icon-star">
#             </i>
#             <i class="icon-star">
#             </i>
#             <i class="icon-star">
#             </i>
#             <i class="icon-star">
#             </i>
#            </p>
#            <h3>
#             <a href="catalogue/the-boys-in-the-boat-nine-americans-and-their-epic-quest-for-gold-at-the-1936-berlin-olympics_992/index.html" title="The Boys in the Boat: Nine Americans and Their Epic Quest for Gold at the 1936 Berlin Olympics">
#              The Boys in the ...
#             </a>
#            </h3>
#            <div class="product_price">
#             <p class="price_color">
#              Â£22.60
#             </p>
#             <p class="instock availability">
#              <i class="icon-ok">
#              </i>
#              In stock
#             </p>
#             <form>
#              <button class="btn btn-primary btn-block" data-loading-text="Adding..." type="submit">
#               Add to basket
#              </button>
#             </form>
#            </div>
#           </article>
#          </li>
#          <li class="col-xs-6 col-sm-4 col-md-3 col-lg-3">
#           <article class="product_pod">
#            <div class="image_container">
#             <a href="catalogue/the-black-maria_991/index.html">
#              <img alt="The Black Maria" class="thumbnail" src="media/cache/58/46/5846057e28022268153beff6d352b06c.jpg"/>
#             </a>
#            </div>
#            <p class="star-rating One">
#             <i class="icon-star">
#             </i>
#             <i class="icon-star">
#             </i>
#             <i class="icon-star">
#             </i>
#             <i class="icon-star">
#             </i>
#             <i class="icon-star">
#             </i>
#            </p>
#            <h3>
#             <a href="catalogue/the-black-maria_991/index.html" title="The Black Maria">
#              The Black Maria
#             </a>
#            </h3>
#            <div class="product_price">
#             <p class="price_color">
#              Â£52.15
#             </p>
#             <p class="instock availability">
#              <i class="icon-ok">
#              </i>
#              In stock
#             </p>
#             <form>
#              <button class="btn btn-primary btn-block" data-loading-text="Adding..." type="submit">
#               Add to basket
#              </button>
#             </form>
#            </div>
#           </article>
#          </li>
#          <li class="col-xs-6 col-sm-4 col-md-3 col-lg-3">
#           <article class="product_pod">
#            <div class="image_container">
#             <a href="catalogue/starving-hearts-triangular-trade-trilogy-1_990/index.html">
#              <img alt="Starving Hearts (Triangular Trade Trilogy, #1)" class="thumbnail" src="media/cache/be/f4/bef44da28c98f905a3ebec0b87be8530.jpg"/>
#             </a>
#            </div>
#            <p class="star-rating Two">
#             <i class="icon-star">
#             </i>
#             <i class="icon-star">
#             </i>
#             <i class="icon-star">
#             </i>
#             <i class="icon-star">
#             </i>
#             <i class="icon-star">
#             </i>
#            </p>
#            <h3>
#             <a href="catalogue/starving-hearts-triangular-trade-trilogy-1_990/index.html" title="Starving Hearts (Triangular Trade Trilogy, #1)">
#              Starving Hearts (Triangular Trade ...
#             </a>
#            </h3>
#            <div class="product_price">
#             <p class="price_color">
#              Â£13.99
#             </p>
#             <p class="instock availability">
#              <i class="icon-ok">
#              </i>
#              In stock
#             </p>
#             <form>
#              <button class="btn btn-primary btn-block" data-loading-text="Adding..." type="submit">
#               Add to basket
#              </button>
#             </form>
#            </div>
#           </article>
#          </li>
#          <li class="col-xs-6 col-sm-4 col-md-3 col-lg-3">
#           <article class="product_pod">
#            <div class="image_container">
#             <a href="catalogue/shakespeares-sonnets_989/index.html">
#              <img alt="Shakespeare's Sonnets" class="thumbnail" src="media/cache/10/48/1048f63d3b5061cd2f424d20b3f9b666.jpg"/>
#             </a>
#            </div>
#            <p class="star-rating Four">
#             <i class="icon-star">
#             </i>
#             <i class="icon-star">
#             </i>
#             <i class="icon-star">
#             </i>
#             <i class="icon-star">
#             </i>
#             <i class="icon-star">
#             </i>
#            </p>
#            <h3>
#             <a href="catalogue/shakespeares-sonnets_989/index.html" title="Shakespeare's Sonnets">
#              Shakespeare's Sonnets
#             </a>
#            </h3>
#            <div class="product_price">
#             <p class="price_color">
#              Â£20.66
#             </p>
#             <p class="instock availability">
#              <i class="icon-ok">
#              </i>
#              In stock
#             </p>
#             <form>
#              <button class="btn btn-primary btn-block" data-loading-text="Adding..." type="submit">
#               Add to basket
#              </button>
#             </form>
#            </div>
#           </article>
#          </li>
#          <li class="col-xs-6 col-sm-4 col-md-3 col-lg-3">
#           <article class="product_pod">
#            <div class="image_container">
#             <a href="catalogue/set-me-free_988/index.html">
#              <img alt="Set Me Free" class="thumbnail" src="media/cache/5b/88/5b88c52633f53cacf162c15f4f823153.jpg"/>
#             </a>
#            </div>
#            <p class="star-rating Five">
#             <i class="icon-star">
#             </i>
#             <i class="icon-star">
#             </i>
#             <i class="icon-star">
#             </i>
#             <i class="icon-star">
#             </i>
#             <i class="icon-star">
#             </i>
#            </p>
#            <h3>
#             <a href="catalogue/set-me-free_988/index.html" title="Set Me Free">
#              Set Me Free
#             </a>
#            </h3>
#            <div class="product_price">
#             <p class="price_color">
#              Â£17.46
#             </p>
#             <p class="instock availability">
#              <i class="icon-ok">
#              </i>
#              In stock
#             </p>
#             <form>
#              <button class="btn btn-primary btn-block" data-loading-text="Adding..." type="submit">
#               Add to basket
#              </button>
#             </form>
#            </div>
#           </article>
#          </li>
#          <li class="col-xs-6 col-sm-4 col-md-3 col-lg-3">
#           <article class="product_pod">
#            <div class="image_container">
#             <a href="catalogue/scott-pilgrims-precious-little-life-scott-pilgrim-1_987/index.html">
#              <img alt="Scott Pilgrim's Precious Little Life (Scott Pilgrim #1)" class="thumbnail" src="media/cache/94/b1/94b1b8b244bce9677c2f29ccc890d4d2.jpg"/>
#             </a>
#            </div>
#            <p class="star-rating Five">
#             <i class="icon-star">
#             </i>
#             <i class="icon-star">
#             </i>
#             <i class="icon-star">
#             </i>
#             <i class="icon-star">
#             </i>
#             <i class="icon-star">
#             </i>
#            </p>
#            <h3>
#             <a href="catalogue/scott-pilgrims-precious-little-life-scott-pilgrim-1_987/index.html" title="Scott Pilgrim's Precious Little Life (Scott Pilgrim #1)">
#              Scott Pilgrim's Precious Little ...
#             </a>
#            </h3>
#            <div class="product_price">
#             <p class="price_color">
#              Â£52.29
#             </p>
#             <p class="instock availability">
#              <i class="icon-ok">
#              </i>
#              In stock
#             </p>
#             <form>
#              <button class="btn btn-primary btn-block" data-loading-text="Adding..." type="submit">
#               Add to basket
#              </button>
#             </form>
#            </div>
#           </article>
#          </li>
#          <li class="col-xs-6 col-sm-4 col-md-3 col-lg-3">
#           <article class="product_pod">
#            <div class="image_container">
#             <a href="catalogue/rip-it-up-and-start-again_986/index.html">
#              <img alt="Rip it Up and Start Again" class="thumbnail" src="media/cache/81/c4/81c4a973364e17d01f217e1188253d5e.jpg"/>
#             </a>
#            </div>
#            <p class="star-rating Five">
#             <i class="icon-star">
#             </i>
#             <i class="icon-star">
#             </i>
#             <i class="icon-star">
#             </i>
#             <i class="icon-star">
#             </i>
#             <i class="icon-star">
#             </i>
#            </p>
#            <h3>
#             <a href="catalogue/rip-it-up-and-start-again_986/index.html" title="Rip it Up and Start Again">
#              Rip it Up and ...
#             </a>
#            </h3>
#            <div class="product_price">
#             <p class="price_color">
#              Â£35.02
#             </p>
#             <p class="instock availability">
#              <i class="icon-ok">
#              </i>
#              In stock
#             </p>
#             <form>
#              <button class="btn btn-primary btn-block" data-loading-text="Adding..." type="submit">
#               Add to basket
#              </button>
#             </form>
#            </div>
#           </article>
#          </li>
#          <li class="col-xs-6 col-sm-4 col-md-3 col-lg-3">
#           <article class="product_pod">
#            <div class="image_container">
#             <a href="catalogue/our-band-could-be-your-life-scenes-from-the-american-indie-underground-1981-1991_985/index.html">
#              <img alt="Our Band Could Be Your Life: Scenes from the American Indie Underground, 1981-1991" class="thumbnail" src="media/cache/54/60/54607fe8945897cdcced0044103b10b6.jpg"/>
#             </a>
#            </div>
#            <p class="star-rating Three">
#             <i class="icon-star">
#             </i>
#             <i class="icon-star">
#             </i>
#             <i class="icon-star">
#             </i>
#             <i class="icon-star">
#             </i>
#             <i class="icon-star">
#             </i>
#            </p>
#            <h3>
#             <a href="catalogue/our-band-could-be-your-life-scenes-from-the-american-indie-underground-1981-1991_985/index.html" title="Our Band Could Be Your Life: Scenes from the American Indie Underground, 1981-1991">
#              Our Band Could Be ...
#             </a>
#            </h3>
#            <div class="product_price">
#             <p class="price_color">
#              Â£57.25
#             </p>
#             <p class="instock availability">
#              <i class="icon-ok">
#              </i>
#              In stock
#             </p>
#             <form>
#              <button class="btn btn-primary btn-block" data-loading-text="Adding..." type="submit">
#               Add to basket
#              </button>
#             </form>
#            </div>
#           </article>
#          </li>
#          <li class="col-xs-6 col-sm-4 col-md-3 col-lg-3">
#           <article class="product_pod">
#            <div class="image_container">
#             <a href="catalogue/olio_984/index.html">
#              <img alt="Olio" class="thumbnail" src="media/cache/55/33/553310a7162dfbc2c6d19a84da0df9e1.jpg"/>
#             </a>
#            </div>
#            <p class="star-rating One">
#             <i class="icon-star">
#             </i>
#             <i class="icon-star">
#             </i>
#             <i class="icon-star">
#             </i>
#             <i class="icon-star">
#             </i>
#             <i class="icon-star">
#             </i>
#            </p>
#            <h3>
#             <a href="catalogue/olio_984/index.html" title="Olio">
#              Olio
#             </a>
#            </h3>
#            <div class="product_price">
#             <p class="price_color">
#              Â£23.88
#             </p>
#             <p class="instock availability">
#              <i class="icon-ok">
#              </i>
#              In stock
#             </p>
#             <form>
#              <button class="btn btn-primary btn-block" data-loading-text="Adding..." type="submit">
#               Add to basket
#              </button>
#             </form>
#            </div>
#           </article>
#          </li>
#          <li class="col-xs-6 col-sm-4 col-md-3 col-lg-3">
#           <article class="product_pod">
#            <div class="image_container">
#             <a href="catalogue/mesaerion-the-best-science-fiction-stories-1800-1849_983/index.html">
#              <img alt="Mesaerion: The Best Science Fiction Stories 1800-1849" class="thumbnail" src="media/cache/09/a3/09a3aef48557576e1a85ba7efea8ecb7.jpg"/>
#             </a>
#            </div>
#            <p class="star-rating One">
#             <i class="icon-star">
#             </i>
#             <i class="icon-star">
#             </i>
#             <i class="icon-star">
#             </i>
#             <i class="icon-star">
#             </i>
#             <i class="icon-star">
#             </i>
#            </p>
#            <h3>
#             <a href="catalogue/mesaerion-the-best-science-fiction-stories-1800-1849_983/index.html" title="Mesaerion: The Best Science Fiction Stories 1800-1849">
#              Mesaerion: The Best Science ...
#             </a>
#            </h3>
#            <div class="product_price">
#             <p class="price_color">
#              Â£37.59
#             </p>
#             <p class="instock availability">
#              <i class="icon-ok">
#              </i>
#              In stock
#             </p>
#             <form>
#              <button class="btn btn-primary btn-block" data-loading-text="Adding..." type="submit">
#               Add to basket
#              </button>
#             </form>
#            </div>
#           </article>
#          </li>
#          <li class="col-xs-6 col-sm-4 col-md-3 col-lg-3">
#           <article class="product_pod">
#            <div class="image_container">
#             <a href="catalogue/libertarianism-for-beginners_982/index.html">
#              <img alt="Libertarianism for Beginners" class="thumbnail" src="media/cache/0b/bc/0bbcd0a6f4bcd81ccb1049a52736406e.jpg"/>
#             </a>
#            </div>
#            <p class="star-rating Two">
#             <i class="icon-star">
#             </i>
#             <i class="icon-star">
#             </i>
#             <i class="icon-star">
#             </i>
#             <i class="icon-star">
#             </i>
#             <i class="icon-star">
#             </i>
#            </p>
#            <h3>
#             <a href="catalogue/libertarianism-for-beginners_982/index.html" title="Libertarianism for Beginners">
#              Libertarianism for Beginners
#             </a>
#            </h3>
#            <div class="product_price">
#             <p class="price_color">
#              Â£51.33
#             </p>
#             <p class="instock availability">
#              <i class="icon-ok">
#              </i>
#              In stock
#             </p>
#             <form>
#              <button class="btn btn-primary btn-block" data-loading-text="Adding..." type="submit">
#               Add to basket
#              </button>
#             </form>
#            </div>
#           </article>
#          </li>
#          <li class="col-xs-6 col-sm-4 col-md-3 col-lg-3">
#           <article class="product_pod">
#            <div class="image_container">
#             <a href="catalogue/its-only-the-himalayas_981/index.html">
#              <img alt="It's Only the Himalayas" class="thumbnail" src="media/cache/27/a5/27a53d0bb95bdd88288eaf66c9230d7e.jpg"/>
#             </a>
#            </div>
#            <p class="star-rating Two">
#             <i class="icon-star">
#             </i>
#             <i class="icon-star">
#             </i>
#             <i class="icon-star">
#             </i>
#             <i class="icon-star">
#             </i>
#             <i class="icon-star">
#             </i>
#            </p>
#            <h3>
#             <a href="catalogue/its-only-the-himalayas_981/index.html" title="It's Only the Himalayas">
#              It's Only the Himalayas
#             </a>
#            </h3>
#            <div class="product_price">
#             <p class="price_color">
#              Â£45.17
#             </p>
#             <p class="instock availability">
#              <i class="icon-ok">
#              </i>
#              In stock
#             </p>
#             <form>
#              <button class="btn btn-primary btn-block" data-loading-text="Adding..." type="submit">
#               Add to basket
#              </button>
#             </form>
#            </div>
#           </article>
#          </li>
#         </ol>
#         <div>
#          <ul class="pager">
#           <li class="current">
#            Page 1 of 50
#           </li>
#           <li class="next">
#            <a href="catalogue/page-2.html">
#             next
#            </a>
#           </li>
#          </ul>
#         </div>
#        </div>
#       </section>
#      </div>
#     </div>
#     <!-- /row -->
#    </div>
#    <!-- /page_inner -->
#   </div>
#   <!-- /container-fluid -->
#   <footer class="footer container-fluid">
#   </footer>
#   <!-- jQuery -->
#   <script src="http://ajax.googleapis.com/ajax/libs/jquery/1.9.1/jquery.min.js">
#   </script>
#   <script>
#    window.jQuery || document.write('<script src="static/oscar/js/jquery/jquery-1.9.1.min.js"><\/script>')
#   </script>
#   <!-- Twitter Bootstrap -->
#   <script src="static/oscar/js/bootstrap3/bootstrap.min.js" type="text/javascript">
#   </script>
#   <!-- Oscar -->
#   <script charset="utf-8" src="static/oscar/js/oscar/ui.js" type="text/javascript">
#   </script>
#   <script charset="utf-8" src="static/oscar/js/bootstrap-datetimepicker/bootstrap-datetimepicker.js" type="text/javascript">
#   </script>
#   <script charset="utf-8" src="static/oscar/js/bootstrap-datetimepicker/locales/bootstrap-datetimepicker.all.js" type="text/javascript">
#   </script>
#   <script type="text/javascript">
#    $(function() {
#
#
#
#     oscar.init();
#
#     oscar.search.init();
#
#             });
#   </script>
#   <!-- Version: N/A -->
#  </body>
# </html>

# %%
pagina_web2 = requests.get('http://books.toscrape.com/catalogue/category/books/fiction_10/index.html')

soup = BeautifulSoup(pagina_web2.text,'html.parser') 

print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <!--[if lt IE 7]>      <html lang="en-us" class="no-js lt-ie9 lt-ie8 lt-ie7"> <![endif]-->
# <!--[if IE 7]>         <html lang="en-us" class="no-js lt-ie9 lt-ie8"> <![endif]-->
# <!--[if IE 8]>         <html lang="en-us" class="no-js lt-ie9"> <![endif]-->
# <!--[if gt IE 8]><!-->
# <html class="no-js" lang="en-us">
#  <!--<![endif]-->
#  <head>
#   <title>
#    Fiction |
#      Books to Scrape - Sandbox
#   </title>
#   <meta content="text/html; charset=utf-8" http-equiv="content-type"/>
#   <meta content="24th Jun 2016 09:29" name="created"/>
#   <meta content="
#
# " name="description"/>
#   <meta content="width=device-width" name="viewport"/>
#   <meta content="NOARCHIVE,NOCACHE" name="robots"/>
#   <!-- Le HTML5 shim, for IE6-8 support of HTML elements -->
#   <!--[if lt IE 9]>
#         <script src="//html5shim.googlecode.com/svn/trunk/html5.js"></script>
#         <![endif]-->
#   <link href="../../../../static/oscar/favicon.ico" rel="shortcut icon"/>
#   <link href="../../../../static/oscar/css/styles.css" rel="stylesheet" type="text/css"/>
#   <link href="../../../../static/oscar/js/bootstrap-datetimepicker/bootstrap-datetimepicker.css" rel="stylesheet"/>
#   <link href="../../../../static/oscar/css/datetimepicker.css" rel="stylesheet" type="text/css"/>
#  </head>
#  <body class="default" id="default">
#   <header class="header container-fluid">
#    <div class="page_inner">
#     <div class="row">
#      <div class="col-sm-8 h1">
#       <a href="../../../../index.html">
#        Books to Scrape
#       </a>
#       <small>
#        We love being scraped!
#       </small>
#      </div>
#     </div>
#    </div>
#   </header>
#   <div class="container-fluid page">
#    <div class="page_inner">
#     <ul class="breadcrumb">
#      <li>
#       <a href="../../../../index.html">
#        Home
#       </a>
#      </li>
#      <li>
#       <a href="../../books_1/index.html">
#        Books
#       </a>
#      </li>
#      <li class="active">
#       Fiction
#      </li>
#     </ul>
#     <div class="row">
#      <aside class="sidebar col-sm-4 col-md-3">
#       <div id="promotions_left">
#       </div>
#       <div class="side_categories">
#        <ul class="nav nav-list">
#         <li>
#          <a href="../../books_1/index.html">
#           Books
#          </a>
#          <ul>
#           <li>
#            <a href="../travel_2/index.html">
#             Travel
#            </a>
#           </li>
#           <li>
#            <a href="../mystery_3/index.html">
#             Mystery
#            </a>
#           </li>
#           <li>
#            <a href="../historical-fiction_4/index.html">
#             Historical Fiction
#            </a>
#           </li>
#           <li>
#            <a href="../sequential-art_5/index.html">
#             Sequential Art
#            </a>
#           </li>
#           <li>
#            <a href="../classics_6/index.html">
#             Classics
#            </a>
#           </li>
#           <li>
#            <a href="../philosophy_7/index.html">
#             Philosophy
#            </a>
#           </li>
#           <li>
#            <a href="../romance_8/index.html">
#             Romance
#            </a>
#           </li>
#           <li>
#            <a href="../womens-fiction_9/index.html">
#             Womens Fiction
#            </a>
#           </li>
#           <li>
#            <a href="index.html">
#             <strong>
#              Fiction
#             </strong>
#            </a>
#           </li>
#           <li>
#            <a href="../childrens_11/index.html">
#             Childrens
#            </a>
#           </li>
#           <li>
#            <a href="../religion_12/index.html">
#             Religion
#            </a>
#           </li>
#           <li>
#            <a href="../nonfiction_13/index.html">
#             Nonfiction
#            </a>
#           </li>
#           <li>
#            <a href="../music_14/index.html">
#             Music
#            </a>
#           </li>
#           <li>
#            <a href="../default_15/index.html">
#             Default
#            </a>
#           </li>
#           <li>
#            <a href="../science-fiction_16/index.html">
#             Science Fiction
#            </a>
#           </li>
#           <li>
#            <a href="../sports-and-games_17/index.html">
#             Sports and Games
#            </a>
#           </li>
#           <li>
#            <a href="../add-a-comment_18/index.html">
#             Add a comment
#            </a>
#           </li>
#           <li>
#            <a href="../fantasy_19/index.html">
#             Fantasy
#            </a>
#           </li>
#           <li>
#            <a href="../new-adult_20/index.html">
#             New Adult
#            </a>
#           </li>
#           <li>
#            <a href="../young-adult_21/index.html">
#             Young Adult
#            </a>
#           </li>
#           <li>
#            <a href="../science_22/index.html">
#             Science
#            </a>
#           </li>
#           <li>
#            <a href="../poetry_23/index.html">
#             Poetry
#            </a>
#           </li>
#           <li>
#            <a href="../paranormal_24/index.html">
#             Paranormal
#            </a>
#           </li>
#           <li>
#            <a href="../art_25/index.html">
#             Art
#            </a>
#           </li>
#           <li>
#            <a href="../psychology_26/index.html">
#             Psychology
#            </a>
#           </li>
#           <li>
#            <a href="../autobiography_27/index.html">
#             Autobiography
#            </a>
#           </li>
#           <li>
#            <a href="../parenting_28/index.html">
#             Parenting
#            </a>
#           </li>
#           <li>
#            <a href="../adult-fiction_29/index.html">
#             Adult Fiction
#            </a>
#           </li>
#           <li>
#            <a href="../humor_30/index.html">
#             Humor
#            </a>
#           </li>
#           <li>
#            <a href="../horror_31/index.html">
#             Horror
#            </a>
#           </li>
#           <li>
#            <a href="../history_32/index.html">
#             History
#            </a>
#           </li>
#           <li>
#            <a href="../food-and-drink_33/index.html">
#             Food and Drink
#            </a>
#           </li>
#           <li>
#            <a href="../christian-fiction_34/index.html">
#             Christian Fiction
#            </a>
#           </li>
#           <li>
#            <a href="../business_35/index.html">
#             Business
#            </a>
#           </li>
#           <li>
#            <a href="../biography_36/index.html">
#             Biography
#            </a>
#           </li>
#           <li>
#            <a href="../thriller_37/index.html">
#             Thriller
#            </a>
#           </li>
#           <li>
#            <a href="../contemporary_38/index.html">
#             Contemporary
#            </a>
#           </li>
#           <li>
#            <a href="../spirituality_39/index.html">
#             Spirituality
#            </a>
#           </li>
#           <li>
#            <a href="../academic_40/index.html">
#             Academic
#            </a>
#           </li>
#           <li>
#            <a href="../self-help_41/index.html">
#             Self Help
#            </a>
#           </li>
#           <li>
#            <a href="../historical_42/index.html">
#             Historical
#            </a>
#           </li>
#           <li>
#            <a href="../christian_43/index.html">
#             Christian
#            </a>
#           </li>
#           <li>
#            <a href="../suspense_44/index.html">
#             Suspense
#            </a>
#           </li>
#           <li>
#            <a href="../short-stories_45/index.html">
#             Short Stories
#            </a>
#           </li>
#           <li>
#            <a href="../novels_46/index.html">
#             Novels
#            </a>
#           </li>
#           <li>
#            <a href="../health_47/index.html">
#             Health
#            </a>
#           </li>
#           <li>
#            <a href="../politics_48/index.html">
#             Politics
#            </a>
#           </li>
#           <li>
#            <a href="../cultural_49/index.html">
#             Cultural
#            </a>
#           </li>
#           <li>
#            <a href="../erotica_50/index.html">
#             Erotica
#            </a>
#           </li>
#           <li>
#            <a href="../crime_51/index.html">
#             Crime
#            </a>
#           </li>
#          </ul>
#         </li>
#        </ul>
#       </div>
#      </aside>
#      <div class="col-sm-8 col-md-9">
#       <div class="page-header action">
#        <h1>
#         Fiction
#        </h1>
#       </div>
#       <div id="messages">
#       </div>
#       <div id="promotions">
#       </div>
#       <form class="form-horizontal" method="get">
#        <div style="display:none">
#        </div>
#        <strong>
#         65
#        </strong>
#        results - showing
#        <strong>
#         1
#        </strong>
#        to
#        <strong>
#         20
#        </strong>
#        .
#       </form>
#       <section>
#        <div class="alert alert-warning" role="alert">
#         <strong>
#          Warning!
#         </strong>
#         This is a demo website for web scraping purposes. Prices and ratings here were randomly assigned and have no real meaning.
#        </div>
#        <div>
#         <ol class="row">
#          <li class="col-xs-6 col-sm-4 col-md-3 col-lg-3">
#           <article class="product_pod">
#            <div class="image_container">
#             <a href="../../../soumission_998/index.html">
#              <img alt="Soumission" class="thumbnail" src="../../../../media/cache/3e/ef/3eef99c9d9adef34639f510662022830.jpg"/>
#             </a>
#            </div>
#            <p class="star-rating One">
#             <i class="icon-star">
#             </i>
#             <i class="icon-star">
#             </i>
#             <i class="icon-star">
#             </i>
#             <i class="icon-star">
#             </i>
#             <i class="icon-star">
#             </i>
#            </p>
#            <h3>
#             <a href="../../../soumission_998/index.html" title="Soumission">
#              Soumission
#             </a>
#            </h3>
#            <div class="product_price">
#             <p class="price_color">
#              Â£50.10
#             </p>
#             <p class="instock availability">
#              <i class="icon-ok">
#              </i>
#              In stock
#             </p>
#             <form>
#              <button class="btn btn-primary btn-block" data-loading-text="Adding..." type="submit">
#               Add to basket
#              </button>
#             </form>
#            </div>
#           </article>
#          </li>
#          <li class="col-xs-6 col-sm-4 col-md-3 col-lg-3">
#           <article class="product_pod">
#            <div class="image_container">
#             <a href="../../../private-paris-private-10_958/index.html">
#              <img alt="Private Paris (Private #10)" class="thumbnail" src="../../../../media/cache/9d/05/9d0533bae1578846d728a82913b95c26.jpg"/>
#             </a>
#            </div>
#            <p class="star-rating Five">
#             <i class="icon-star">
#             </i>
#             <i class="icon-star">
#             </i>
#             <i class="icon-star">
#             </i>
#             <i class="icon-star">
#             </i>
#             <i class="icon-star">
#             </i>
#            </p>
#            <h3>
#             <a href="../../../private-paris-private-10_958/index.html" title="Private Paris (Private #10)">
#              Private Paris (Private #10)
#             </a>
#            </h3>
#            <div class="product_price">
#             <p class="price_color">
#              Â£47.61
#             </p>
#             <p class="instock availability">
#              <i class="icon-ok">
#              </i>
#              In stock
#             </p>
#             <form>
#              <button class="btn btn-primary btn-block" data-loading-text="Adding..." type="submit">
#               Add to basket
#              </button>
#             </form>
#            </div>
#           </article>
#          </li>
#          <li class="col-xs-6 col-sm-4 col-md-3 col-lg-3">
#           <article class="product_pod">
#            <div class="image_container">
#             <a href="../../../we-love-you-charlie-freeman_954/index.html">
#              <img alt="We Love You, Charlie Freeman" class="thumbnail" src="../../../../media/cache/5f/15/5f152afdbc42356ecba02f61058a7e5b.jpg"/>
#             </a>
#            </div>
#            <p class="star-rating Five">
#             <i class="icon-star">
#             </i>
#             <i class="icon-star">
#             </i>
#             <i class="icon-star">
#             </i>
#             <i class="icon-star">
#             </i>
#             <i class="icon-star">
#             </i>
#            </p>
#            <h3>
#             <a href="../../../we-love-you-charlie-freeman_954/index.html" title="We Love You, Charlie Freeman">
#              We Love You, Charlie ...
#             </a>
#            </h3>
#            <div class="product_price">
#             <p class="price_color">
#              Â£50.27
#             </p>
#             <p class="instock availability">
#              <i class="icon-ok">
#              </i>
#              In stock
#             </p>
#             <form>
#              <button class="btn btn-primary btn-block" data-loading-text="Adding..." type="submit">
#               Add to basket
#              </button>
#             </form>
#            </div>
#           </article>
#          </li>
#          <li class="col-xs-6 col-sm-4 col-md-3 col-lg-3">
#           <article class="product_pod">
#            <div class="image_container">
#             <a href="../../../thirst_946/index.html">
#              <img alt="Thirst" class="thumbnail" src="../../../../media/cache/c4/0a/c40a64f59e7487b1a80a049f6ceb2ba5.jpg"/>
#             </a>
#            </div>
#            <p class="star-rating Five">
#             <i class="icon-star">
#             </i>
#             <i class="icon-star">
#             </i>
#             <i class="icon-star">
#             </i>
#             <i class="icon-star">
#             </i>
#             <i class="icon-star">
#             </i>
#            </p>
#            <h3>
#             <a href="../../../thirst_946/index.html" title="Thirst">
#              Thirst
#             </a>
#            </h3>
#            <div class="product_price">
#             <p class="price_color">
#              Â£17.27
#             </p>
#             <p class="instock availability">
#              <i class="icon-ok">
#              </i>
#              In stock
#             </p>
#             <form>
#              <button class="btn btn-primary btn-block" data-loading-text="Adding..." type="submit">
#               Add to basket
#              </button>
#             </form>
#            </div>
#           </article>
#          </li>
#          <li class="col-xs-6 col-sm-4 col-md-3 col-lg-3">
#           <article class="product_pod">
#            <div class="image_container">
#             <a href="../../../the-murder-that-never-was-forensic-instincts-5_939/index.html">
#              <img alt="The Murder That Never Was (Forensic Instincts #5)" class="thumbnail" src="../../../../media/cache/dc/44/dc44f8e2aebac48ca8553814d9b021a8.jpg"/>
#             </a>
#            </div>
#            <p class="star-rating Three">
#             <i class="icon-star">
#             </i>
#             <i class="icon-star">
#             </i>
#             <i class="icon-star">
#             </i>
#             <i class="icon-star">
#             </i>
#             <i class="icon-star">
#             </i>
#            </p>
#            <h3>
#             <a href="../../../the-murder-that-never-was-forensic-instincts-5_939/index.html" title="The Murder That Never Was (Forensic Instincts #5)">
#              The Murder That Never ...
#             </a>
#            </h3>
#            <div class="product_price">
#             <p class="price_color">
#              Â£54.11
#             </p>
#             <p class="instock availability">
#              <i class="icon-ok">
#              </i>
#              In stock
#             </p>
#             <form>
#              <button class="btn btn-primary btn-block" data-loading-text="Adding..." type="submit">
#               Add to basket
#              </button>
#             </form>
#            </div>
#           </article>
#          </li>
#          <li class="col-xs-6 col-sm-4 col-md-3 col-lg-3">
#           <article class="product_pod">
#            <div class="image_container">
#             <a href="../../../tuesday-nights-in-1980_870/index.html">
#              <img alt="Tuesday Nights in 1980" class="thumbnail" src="../../../../media/cache/6b/da/6bdae061cb92c32b0b83cda8dd10275d.jpg"/>
#             </a>
#            </div>
#            <p class="star-rating Two">
#             <i class="icon-star">
#             </i>
#             <i class="icon-star">
#             </i>
#             <i class="icon-star">
#             </i>
#             <i class="icon-star">
#             </i>
#             <i class="icon-star">
#             </i>
#            </p>
#            <h3>
#             <a href="../../../tuesday-nights-in-1980_870/index.html" title="Tuesday Nights in 1980">
#              Tuesday Nights in 1980
#             </a>
#            </h3>
#            <div class="product_price">
#             <p class="price_color">
#              Â£21.04
#             </p>
#             <p class="instock availability">
#              <i class="icon-ok">
#              </i>
#              In stock
#             </p>
#             <form>
#              <button class="btn btn-primary btn-block" data-loading-text="Adding..." type="submit">
#               Add to basket
#              </button>
#             </form>
#            </div>
#           </article>
#          </li>
#          <li class="col-xs-6 col-sm-4 col-md-3 col-lg-3">
#           <article class="product_pod">
#            <div class="image_container">
#             <a href="../../../the-vacationers_863/index.html">
#              <img alt="The Vacationers" class="thumbnail" src="../../../../media/cache/37/25/372578cc073efae80cf284b56040a488.jpg"/>
#             </a>
#            </div>
#            <p class="star-rating Four">
#             <i class="icon-star">
#             </i>
#             <i class="icon-star">
#             </i>
#             <i class="icon-star">
#             </i>
#             <i class="icon-star">
#             </i>
#             <i class="icon-star">
#             </i>
#            </p>
#            <h3>
#             <a href="../../../the-vacationers_863/index.html" title="The Vacationers">
#              The Vacationers
#             </a>
#            </h3>
#            <div class="product_price">
#             <p class="price_color">
#              Â£42.15
#             </p>
#             <p class="instock availability">
#              <i class="icon-ok">
#              </i>
#              In stock
#             </p>
#             <form>
#              <button class="btn btn-primary btn-block" data-loading-text="Adding..." type="submit">
#               Add to basket
#              </button>
#             </form>
#            </div>
#           </article>
#          </li>
#          <li class="col-xs-6 col-sm-4 col-md-3 col-lg-3">
#           <article class="product_pod">
#            <div class="image_container">
#             <a href="../../../the-regional-office-is-under-attack_858/index.html">
#              <img alt="The Regional Office Is Under Attack!" class="thumbnail" src="../../../../media/cache/f8/31/f8314c7fdaa79fb7191a583e9a852db8.jpg"/>
#             </a>
#            </div>
#            <p class="star-rating Five">
#             <i class="icon-star">
#             </i>
#             <i class="icon-star">
#             </i>
#             <i class="icon-star">
#             </i>
#             <i class="icon-star">
#             </i>
#             <i class="icon-star">
#             </i>
#            </p>
#            <h3>
#             <a href="../../../the-regional-office-is-under-attack_858/index.html" title="The Regional Office Is Under Attack!">
#              The Regional Office Is ...
#             </a>
#            </h3>
#            <div class="product_price">
#             <p class="price_color">
#              Â£51.36
#             </p>
#             <p class="instock availability">
#              <i class="icon-ok">
#              </i>
#              In stock
#             </p>
#             <form>
#              <button class="btn btn-primary btn-block" data-loading-text="Adding..." type="submit">
#               Add to basket
#              </button>
#             </form>
#            </div>
#           </article>
#          </li>
#          <li class="col-xs-6 col-sm-4 col-md-3 col-lg-3">
#           <article class="product_pod">
#            <div class="image_container">
#             <a href="../../../finders-keepers-bill-hodges-trilogy-2_807/index.html">
#              <img alt="Finders Keepers (Bill Hodges Trilogy #2)" class="thumbnail" src="../../../../media/cache/6a/81/6a81103b1c01a3f6c56e5718a838a4c8.jpg"/>
#             </a>
#            </div>
#            <p class="star-rating Five">
#             <i class="icon-star">
#             </i>
#             <i class="icon-star">
#             </i>
#             <i class="icon-star">
#             </i>
#             <i class="icon-star">
#             </i>
#             <i class="icon-star">
#             </i>
#            </p>
#            <h3>
#             <a href="../../../finders-keepers-bill-hodges-trilogy-2_807/index.html" title="Finders Keepers (Bill Hodges Trilogy #2)">
#              Finders Keepers (Bill Hodges ...
#             </a>
#            </h3>
#            <div class="product_price">
#             <p class="price_color">
#              Â£53.53
#             </p>
#             <p class="instock availability">
#              <i class="icon-ok">
#              </i>
#              In stock
#             </p>
#             <form>
#              <button class="btn btn-primary btn-block" data-loading-text="Adding..." type="submit">
#               Add to basket
#              </button>
#             </form>
#            </div>
#           </article>
#          </li>
#          <li class="col-xs-6 col-sm-4 col-md-3 col-lg-3">
#           <article class="product_pod">
#            <div class="image_container">
#             <a href="../../../the-time-keeper_766/index.html">
#              <img alt="The Time Keeper" class="thumbnail" src="../../../../media/cache/8f/f8/8ff8680dde59ea739d6978a01e4d7fe5.jpg"/>
#             </a>
#            </div>
#            <p class="star-rating Five">
#             <i class="icon-star">
#             </i>
#             <i class="icon-star">
#             </i>
#             <i class="icon-star">
#             </i>
#             <i class="icon-star">
#             </i>
#             <i class="icon-star">
#             </i>
#            </p>
#            <h3>
#             <a href="../../../the-time-keeper_766/index.html" title="The Time Keeper">
#              The Time Keeper
#             </a>
#            </h3>
#            <div class="product_price">
#             <p class="price_color">
#              Â£27.88
#             </p>
#             <p class="instock availability">
#              <i class="icon-ok">
#              </i>
#              In stock
#             </p>
#             <form>
#              <button class="btn btn-primary btn-block" data-loading-text="Adding..." type="submit">
#               Add to basket
#              </button>
#             </form>
#            </div>
#           </article>
#          </li>
#          <li class="col-xs-6 col-sm-4 col-md-3 col-lg-3">
#           <article class="product_pod">
#            <div class="image_container">
#             <a href="../../../the-testament-of-mary_765/index.html">
#              <img alt="The Testament of Mary" class="thumbnail" src="../../../../media/cache/83/05/8305154438c91a02cefacf4ec8b53393.jpg"/>
#             </a>
#            </div>
#            <p class="star-rating Four">
#             <i class="icon-star">
#             </i>
#             <i class="icon-star">
#             </i>
#             <i class="icon-star">
#             </i>
#             <i class="icon-star">
#             </i>
#             <i class="icon-star">
#             </i>
#            </p>
#            <h3>
#             <a href="../../../the-testament-of-mary_765/index.html" title="The Testament of Mary">
#              The Testament of Mary
#             </a>
#            </h3>
#            <div class="product_price">
#             <p class="price_color">
#              Â£52.67
#             </p>
#             <p class="instock availability">
#              <i class="icon-ok">
#              </i>
#              In stock
#             </p>
#             <form>
#              <button class="btn btn-primary btn-block" data-loading-text="Adding..." type="submit">
#               Add to basket
#              </button>
#             </form>
#            </div>
#           </article>
#          </li>
#          <li class="col-xs-6 col-sm-4 col-md-3 col-lg-3">
#           <article class="product_pod">
#            <div class="image_container">
#             <a href="../../../the-first-hostage-jb-collins-2_749/index.html">
#              <img alt="The First Hostage (J.B. Collins #2)" class="thumbnail" src="../../../../media/cache/38/34/3834572e651cdc14b18d348fa4875aa9.jpg"/>
#             </a>
#            </div>
#            <p class="star-rating Three">
#             <i class="icon-star">
#             </i>
#             <i class="icon-star">
#             </i>
#             <i class="icon-star">
#             </i>
#             <i class="icon-star">
#             </i>
#             <i class="icon-star">
#             </i>
#            </p>
#            <h3>
#             <a href="../../../the-first-hostage-jb-collins-2_749/index.html" title="The First Hostage (J.B. Collins #2)">
#              The First Hostage (J.B. ...
#             </a>
#            </h3>
#            <div class="product_price">
#             <p class="price_color">
#              Â£25.85
#             </p>
#             <p class="instock availability">
#              <i class="icon-ok">
#              </i>
#              In stock
#             </p>
#             <form>
#              <button class="btn btn-primary btn-block" data-loading-text="Adding..." type="submit">
#               Add to basket
#              </button>
#             </form>
#            </div>
#           </article>
#          </li>
#          <li class="col-xs-6 col-sm-4 col-md-3 col-lg-3">
#           <article class="product_pod">
#            <div class="image_container">
#             <a href="../../../take-me-with-you_741/index.html">
#              <img alt="Take Me with You" class="thumbnail" src="../../../../media/cache/d8/a4/d8a44eda7cbe7bd1207f868e9adc06f3.jpg"/>
#             </a>
#            </div>
#            <p class="star-rating Three">
#             <i class="icon-star">
#             </i>
#             <i class="icon-star">
#             </i>
#             <i class="icon-star">
#             </i>
#             <i class="icon-star">
#             </i>
#             <i class="icon-star">
#             </i>
#            </p>
#            <h3>
#             <a href="../../../take-me-with-you_741/index.html" title="Take Me with You">
#              Take Me with You
#             </a>
#            </h3>
#            <div class="product_price">
#             <p class="price_color">
#              Â£45.21
#             </p>
#             <p class="instock availability">
#              <i class="icon-ok">
#              </i>
#              In stock
#             </p>
#             <form>
#              <button class="btn btn-primary btn-block" data-loading-text="Adding..." type="submit">
#               Add to basket
#              </button>
#             </form>
#            </div>
#           </article>
#          </li>
#          <li class="col-xs-6 col-sm-4 col-md-3 col-lg-3">
#           <article class="product_pod">
#            <div class="image_container">
#             <a href="../../../still-life-with-bread-crumbs_738/index.html">
#              <img alt="Still Life with Bread Crumbs" class="thumbnail" src="../../../../media/cache/8e/c7/8ec7f310b74ddd7ec3c859e9b0da7389.jpg"/>
#             </a>
#            </div>
#            <p class="star-rating Three">
#             <i class="icon-star">
#             </i>
#             <i class="icon-star">
#             </i>
#             <i class="icon-star">
#             </i>
#             <i class="icon-star">
#             </i>
#             <i class="icon-star">
#             </i>
#            </p>
#            <h3>
#             <a href="../../../still-life-with-bread-crumbs_738/index.html" title="Still Life with Bread Crumbs">
#              Still Life with Bread ...
#             </a>
#            </h3>
#            <div class="product_price">
#             <p class="price_color">
#              Â£26.41
#             </p>
#             <p class="instock availability">
#              <i class="icon-ok">
#              </i>
#              In stock
#             </p>
#             <form>
#              <button class="btn btn-primary btn-block" data-loading-text="Adding..." type="submit">
#               Add to basket
#              </button>
#             </form>
#            </div>
#           </article>
#          </li>
#          <li class="col-xs-6 col-sm-4 col-md-3 col-lg-3">
#           <article class="product_pod">
#            <div class="image_container">
#             <a href="../../../shtum_733/index.html">
#              <img alt="Shtum" class="thumbnail" src="../../../../media/cache/03/16/0316bb6f4785ac69c0643109201bad5d.jpg"/>
#             </a>
#            </div>
#            <p class="star-rating Four">
#             <i class="icon-star">
#             </i>
#             <i class="icon-star">
#             </i>
#             <i class="icon-star">
#             </i>
#             <i class="icon-star">
#             </i>
#             <i class="icon-star">
#             </i>
#            </p>
#            <h3>
#             <a href="../../../shtum_733/index.html" title="Shtum">
#              Shtum
#             </a>
#            </h3>
#            <div class="product_price">
#             <p class="price_color">
#              Â£55.84
#             </p>
#             <p class="instock availability">
#              <i class="icon-ok">
#              </i>
#              In stock
#             </p>
#             <form>
#              <button class="btn btn-primary btn-block" data-loading-text="Adding..." type="submit">
#               Add to basket
#              </button>
#             </form>
#            </div>
#           </article>
#          </li>
#          <li class="col-xs-6 col-sm-4 col-md-3 col-lg-3">
#           <article class="product_pod">
#            <div class="image_container">
#             <a href="../../../my-name-is-lucy-barton_720/index.html">
#              <img alt="My Name Is Lucy Barton" class="thumbnail" src="../../../../media/cache/ca/b1/cab150e556b5fab663a9fec00ed97943.jpg"/>
#             </a>
#            </div>
#            <p class="star-rating One">
#             <i class="icon-star">
#             </i>
#             <i class="icon-star">
#             </i>
#             <i class="icon-star">
#             </i>
#             <i class="icon-star">
#             </i>
#             <i class="icon-star">
#             </i>
#            </p>
#            <h3>
#             <a href="../../../my-name-is-lucy-barton_720/index.html" title="My Name Is Lucy Barton">
#              My Name Is Lucy ...
#             </a>
#            </h3>
#            <div class="product_price">
#             <p class="price_color">
#              Â£41.56
#             </p>
#             <p class="instock availability">
#              <i class="icon-ok">
#              </i>
#              In stock
#             </p>
#             <form>
#              <button class="btn btn-primary btn-block" data-loading-text="Adding..." type="submit">
#               Add to basket
#              </button>
#             </form>
#            </div>
#           </article>
#          </li>
#          <li class="col-xs-6 col-sm-4 col-md-3 col-lg-3">
#           <article class="product_pod">
#            <div class="image_container">
#             <a href="../../../my-mrs-brown_719/index.html">
#              <img alt="My Mrs. Brown" class="thumbnail" src="../../../../media/cache/e0/79/e07906c1e507055da9a2260a74f58273.jpg"/>
#             </a>
#            </div>
#            <p class="star-rating Three">
#             <i class="icon-star">
#             </i>
#             <i class="icon-star">
#             </i>
#             <i class="icon-star">
#             </i>
#             <i class="icon-star">
#             </i>
#             <i class="icon-star">
#             </i>
#            </p>
#            <h3>
#             <a href="../../../my-mrs-brown_719/index.html" title="My Mrs. Brown">
#              My Mrs. Brown
#             </a>
#            </h3>
#            <div class="product_price">
#             <p class="price_color">
#              Â£24.48
#             </p>
#             <p class="instock availability">
#              <i class="icon-ok">
#              </i>
#              In stock
#             </p>
#             <form>
#              <button class="btn btn-primary btn-block" data-loading-text="Adding..." type="submit">
#               Add to basket
#              </button>
#             </form>
#            </div>
#           </article>
#          </li>
#          <li class="col-xs-6 col-sm-4 col-md-3 col-lg-3">
#           <article class="product_pod">
#            <div class="image_container">
#             <a href="../../../mr-mercedes-bill-hodges-trilogy-1_717/index.html">
#              <img alt="Mr. Mercedes (Bill Hodges Trilogy #1)" class="thumbnail" src="../../../../media/cache/a7/f0/a7f092a7b79f848df0226f808fed489b.jpg"/>
#             </a>
#            </div>
#            <p class="star-rating One">
#             <i class="icon-star">
#             </i>
#             <i class="icon-star">
#             </i>
#             <i class="icon-star">
#             </i>
#             <i class="icon-star">
#             </i>
#             <i class="icon-star">
#             </i>
#            </p>
#            <h3>
#             <a href="../../../mr-mercedes-bill-hodges-trilogy-1_717/index.html" title="Mr. Mercedes (Bill Hodges Trilogy #1)">
#              Mr. Mercedes (Bill Hodges ...
#             </a>
#            </h3>
#            <div class="product_price">
#             <p class="price_color">
#              Â£28.90
#             </p>
#             <p class="instock availability">
#              <i class="icon-ok">
#              </i>
#              In stock
#             </p>
#             <form>
#              <button class="btn btn-primary btn-block" data-loading-text="Adding..." type="submit">
#               Add to basket
#              </button>
#             </form>
#            </div>
#           </article>
#          </li>
#          <li class="col-xs-6 col-sm-4 col-md-3 col-lg-3">
#           <article class="product_pod">
#            <div class="image_container">
#             <a href="../../../i-am-pilgrim-pilgrim-1_703/index.html">
#              <img alt="I Am Pilgrim (Pilgrim #1)" class="thumbnail" src="../../../../media/cache/ed/07/ed07c9e7c53d4f33a6eb7d41eb0e6d4a.jpg"/>
#             </a>
#            </div>
#            <p class="star-rating Four">
#             <i class="icon-star">
#             </i>
#             <i class="icon-star">
#             </i>
#             <i class="icon-star">
#             </i>
#             <i class="icon-star">
#             </i>
#             <i class="icon-star">
#             </i>
#            </p>
#            <h3>
#             <a href="../../../i-am-pilgrim-pilgrim-1_703/index.html" title="I Am Pilgrim (Pilgrim #1)">
#              I Am Pilgrim (Pilgrim ...
#             </a>
#            </h3>
#            <div class="product_price">
#             <p class="price_color">
#              Â£10.60
#             </p>
#             <p class="instock availability">
#              <i class="icon-ok">
#              </i>
#              In stock
#             </p>
#             <form>
#              <button class="btn btn-primary btn-block" data-loading-text="Adding..." type="submit">
#               Add to basket
#              </button>
#             </form>
#            </div>
#           </article>
#          </li>
#          <li class="col-xs-6 col-sm-4 col-md-3 col-lg-3">
#           <article class="product_pod">
#            <div class="image_container">
#             <a href="../../../eligible-the-austen-project-4_692/index.html">
#              <img alt="Eligible (The Austen Project #4)" class="thumbnail" src="../../../../media/cache/26/3b/263bf5d128bf18553ea8da8bb19e9a0c.jpg"/>
#             </a>
#            </div>
#            <p class="star-rating Three">
#             <i class="icon-star">
#             </i>
#             <i class="icon-star">
#             </i>
#             <i class="icon-star">
#             </i>
#             <i class="icon-star">
#             </i>
#             <i class="icon-star">
#             </i>
#            </p>
#            <h3>
#             <a href="../../../eligible-the-austen-project-4_692/index.html" title="Eligible (The Austen Project #4)">
#              Eligible (The Austen Project ...
#             </a>
#            </h3>
#            <div class="product_price">
#             <p class="price_color">
#              Â£27.09
#             </p>
#             <p class="instock availability">
#              <i class="icon-ok">
#              </i>
#              In stock
#             </p>
#             <form>
#              <button class="btn btn-primary btn-block" data-loading-text="Adding..." type="submit">
#               Add to basket
#              </button>
#             </form>
#            </div>
#           </article>
#          </li>
#         </ol>
#         <div>
#          <ul class="pager">
#           <li class="current">
#            Page 1 of 4
#           </li>
#           <li class="next">
#            <a href="page-2.html">
#             next
#            </a>
#           </li>
#          </ul>
#         </div>
#        </div>
#       </section>
#      </div>
#     </div>
#     <!-- /row -->
#    </div>
#    <!-- /page_inner -->
#   </div>
#   <!-- /container-fluid -->
#   <footer class="footer container-fluid">
#   </footer>
#   <!-- jQuery -->
#   <script src="http://ajax.googleapis.com/ajax/libs/jquery/1.9.1/jquery.min.js">
#   </script>
#   <script>
#    window.jQuery || document.write('<script src="../../../../static/oscar/js/jquery/jquery-1.9.1.min.js"><\/script>')
#   </script>
#   <!-- Twitter Bootstrap -->
#   <script src="../../../../static/oscar/js/bootstrap3/bootstrap.min.js" type="text/javascript">
#   </script>
#   <!-- Oscar -->
#   <script charset="utf-8" src="../../../../static/oscar/js/oscar/ui.js" type="text/javascript">
#   </script>
#   <script charset="utf-8" src="../../../../static/oscar/js/bootstrap-datetimepicker/bootstrap-datetimepicker.js" type="text/javascript">
#   </script>
#   <script charset="utf-8" src="../../../../static/oscar/js/bootstrap-datetimepicker/locales/bootstrap-datetimepicker.all.js" type="text/javascript">
#   </script>
#   <script type="text/javascript">
#    $(function() {
#
#
#
#     oscar.init();
#
#     oscar.search.init();
#
#             });
#   </script>
#   <!-- Version: N/A -->
#  </body>
# </html>

# %%
titulo_item = soup.find('a') #Regresa la primera etiqueta o articulo con el valor asignado

print(titulo_item)
# Out:
# <a href="../../../../index.html">Books to Scrape</a>

# %%
titulo_items = soup.find_all('a') #Regresa todas las etiquetas que empiecen con esa letra y lo devuelve en forma de arreglo

print(titulo_items)
# Out:
# [<a href="../../../../index.html">Books to Scrape</a>, <a href="../../../../index.html">Home</a>, <a href="../../books_1/index.html">Books</a>, <a href="../../books_1/index.html">
#
#                                 Books
#
#                         </a>, <a href="../travel_2/index.html">
#
#                                 Travel
#
#                         </a>, <a href="../mystery_3/index.html">
#
#                                 Mystery
#
#                         </a>, <a href="../historical-fiction_4/index.html">
#
#                                 Historical Fiction
#
#                         </a>, <a href="../sequential-art_5/index.html">
#
#                                 Sequential Art
#
#                         </a>, <a href="../classics_6/index.html">
#
#                                 Classics
#
#                         </a>, <a href="../philosophy_7/index.html">
#
#                                 Philosophy
#
#                         </a>, <a href="../romance_8/index.html">
#
#                                 Romance
#
#                         </a>, <a href="../womens-fiction_9/index.html">
#
#                                 Womens Fiction
#
#                         </a>, <a href="index.html">
# <strong>Fiction</strong>
# </a>, <a href="../childrens_11/index.html">
#
#                                 Childrens
#
#                         </a>, <a href="../religion_12/index.html">
#
#                                 Religion
#
#                         </a>, <a href="../nonfiction_13/index.html">
#
#                                 Nonfiction
#
#                         </a>, <a href="../music_14/index.html">
#
#                                 Music
#
#                         </a>, <a href="../default_15/index.html">
#
#                                 Default
#
#                         </a>, <a href="../science-fiction_16/index.html">
#
#                                 Science Fiction
#
#                         </a>, <a href="../sports-and-games_17/index.html">
#
#                                 Sports and Games
#
#                         </a>, <a href="../add-a-comment_18/index.html">
#
#                                 Add a comment
#
#                         </a>, <a href="../fantasy_19/index.html">
#
#                                 Fantasy
#
#                         </a>, <a href="../new-adult_20/index.html">
#
#                                 New Adult
#
#                         </a>, <a href="../young-adult_21/index.html">
#
#                                 Young Adult
#
#                         </a>, <a href="../science_22/index.html">
#
#                                 Science
#
#                         </a>, <a href="../poetry_23/index.html">
#
#                                 Poetry
#
#                         </a>, <a href="../paranormal_24/index.html">
#
#                                 Paranormal
#
#                         </a>, <a href="../art_25/index.html">
#
#                                 Art
#
#                         </a>, <a href="../psychology_26/index.html">
#
#                                 Psychology
#
#                         </a>, <a href="../autobiography_27/index.html">
#
#                                 Autobiography
#
#                         </a>, <a href="../parenting_28/index.html">
#
#                                 Parenting
#
#                         </a>, <a href="../adult-fiction_29/index.html">
#
#                                 Adult Fiction
#
#                         </a>, <a href="../humor_30/index.html">
#
#                                 Humor
#
#                         </a>, <a href="../horror_31/index.html">
#
#                                 Horror
#
#                         </a>, <a href="../history_32/index.html">
#
#                                 History
#
#                         </a>, <a href="../food-and-drink_33/index.html">
#
#                                 Food and Drink
#
#                         </a>, <a href="../christian-fiction_34/index.html">
#
#                                 Christian Fiction
#
#                         </a>, <a href="../business_35/index.html">
#
#                                 Business
#
#                         </a>, <a href="../biography_36/index.html">
#
#                                 Biography
#
#                         </a>, <a href="../thriller_37/index.html">
#
#                                 Thriller
#
#                         </a>, <a href="../contemporary_38/index.html">
#
#                                 Contemporary
#
#                         </a>, <a href="../spirituality_39/index.html">
#
#                                 Spirituality
#
#                         </a>, <a href="../academic_40/index.html">
#
#                                 Academic
#
#                         </a>, <a href="../self-help_41/index.html">
#
#                                 Self Help
#
#                         </a>, <a href="../historical_42/index.html">
#
#                                 Historical
#
#                         </a>, <a href="../christian_43/index.html">
#
#                                 Christian
#
#                         </a>, <a href="../suspense_44/index.html">
#
#                                 Suspense
#
#                         </a>, <a href="../short-stories_45/index.html">
#
#                                 Short Stories
#
#                         </a>, <a href="../novels_46/index.html">
#
#                                 Novels
#
#                         </a>, <a href="../health_47/index.html">
#
#                                 Health
#
#                         </a>, <a href="../politics_48/index.html">
#
#                                 Politics
#
#                         </a>, <a href="../cultural_49/index.html">
#
#                                 Cultural
#
#                         </a>, <a href="../erotica_50/index.html">
#
#                                 Erotica
#
#                         </a>, <a href="../crime_51/index.html">
#
#                                 Crime
#
#                         </a>, <a href="../../../soumission_998/index.html"><img alt="Soumission" class="thumbnail" src="../../../../media/cache/3e/ef/3eef99c9d9adef34639f510662022830.jpg"/></a>, <a href="../../../soumission_998/index.html" title="Soumission">Soumission</a>, <a href="../../../private-paris-private-10_958/index.html"><img alt="Private Paris (Private #10)" class="thumbnail" src="../../../../media/cache/9d/05/9d0533bae1578846d728a82913b95c26.jpg"/></a>, <a href="../../../private-paris-private-10_958/index.html" title="Private Paris (Private #10)">Private Paris (Private #10)</a>, <a href="../../../we-love-you-charlie-freeman_954/index.html"><img alt="We Love You, Charlie Freeman" class="thumbnail" src="../../../../media/cache/5f/15/5f152afdbc42356ecba02f61058a7e5b.jpg"/></a>, <a href="../../../we-love-you-charlie-freeman_954/index.html" title="We Love You, Charlie Freeman">We Love You, Charlie ...</a>, <a href="../../../thirst_946/index.html"><img alt="Thirst" class="thumbnail" src="../../../../media/cache/c4/0a/c40a64f59e7487b1a80a049f6ceb2ba5.jpg"/></a>, <a href="../../../thirst_946/index.html" title="Thirst">Thirst</a>, <a href="../../../the-murder-that-never-was-forensic-instincts-5_939/index.html"><img alt="The Murder That Never Was (Forensic Instincts #5)" class="thumbnail" src="../../../../media/cache/dc/44/dc44f8e2aebac48ca8553814d9b021a8.jpg"/></a>, <a href="../../../the-murder-that-never-was-forensic-instincts-5_939/index.html" title="The Murder That Never Was (Forensic Instincts #5)">The Murder That Never ...</a>, <a href="../../../tuesday-nights-in-1980_870/index.html"><img alt="Tuesday Nights in 1980" class="thumbnail" src="../../../../media/cache/6b/da/6bdae061cb92c32b0b83cda8dd10275d.jpg"/></a>, <a href="../../../tuesday-nights-in-1980_870/index.html" title="Tuesday Nights in 1980">Tuesday Nights in 1980</a>, <a href="../../../the-vacationers_863/index.html"><img alt="The Vacationers" class="thumbnail" src="../../../../media/cache/37/25/372578cc073efae80cf284b56040a488.jpg"/></a>, <a href="../../../the-vacationers_863/index.html" title="The Vacationers">The Vacationers</a>, <a href="../../../the-regional-office-is-under-attack_858/index.html"><img alt="The Regional Office Is Under Attack!" class="thumbnail" src="../../../../media/cache/f8/31/f8314c7fdaa79fb7191a583e9a852db8.jpg"/></a>, <a href="../../../the-regional-office-is-under-attack_858/index.html" title="The Regional Office Is Under Attack!">The Regional Office Is ...</a>, <a href="../../../finders-keepers-bill-hodges-trilogy-2_807/index.html"><img alt="Finders Keepers (Bill Hodges Trilogy #2)" class="thumbnail" src="../../../../media/cache/6a/81/6a81103b1c01a3f6c56e5718a838a4c8.jpg"/></a>, <a href="../../../finders-keepers-bill-hodges-trilogy-2_807/index.html" title="Finders Keepers (Bill Hodges Trilogy #2)">Finders Keepers (Bill Hodges ...</a>, <a href="../../../the-time-keeper_766/index.html"><img alt="The Time Keeper" class="thumbnail" src="../../../../media/cache/8f/f8/8ff8680dde59ea739d6978a01e4d7fe5.jpg"/></a>, <a href="../../../the-time-keeper_766/index.html" title="The Time Keeper">The Time Keeper</a>, <a href="../../../the-testament-of-mary_765/index.html"><img alt="The Testament of Mary" class="thumbnail" src="../../../../media/cache/83/05/8305154438c91a02cefacf4ec8b53393.jpg"/></a>, <a href="../../../the-testament-of-mary_765/index.html" title="The Testament of Mary">The Testament of Mary</a>, <a href="../../../the-first-hostage-jb-collins-2_749/index.html"><img alt="The First Hostage (J.B. Collins #2)" class="thumbnail" src="../../../../media/cache/38/34/3834572e651cdc14b18d348fa4875aa9.jpg"/></a>, <a href="../../../the-first-hostage-jb-collins-2_749/index.html" title="The First Hostage (J.B. Collins #2)">The First Hostage (J.B. ...</a>, <a href="../../../take-me-with-you_741/index.html"><img alt="Take Me with You" class="thumbnail" src="../../../../media/cache/d8/a4/d8a44eda7cbe7bd1207f868e9adc06f3.jpg"/></a>, <a href="../../../t ...

# %%
titulo_items = soup.find_all('h3') #Regresa todas las etiquetas que empiecen con esa letra y lo devuelve en forma de arreglo

for item in titulo_items:
    titulo = item.a #De esta manera regresa la etiqueta a

    print(titulo)
# Out:
# <a href="../../../soumission_998/index.html" title="Soumission">Soumission</a>
# <a href="../../../private-paris-private-10_958/index.html" title="Private Paris (Private #10)">Private Paris (Private #10)</a>
# <a href="../../../we-love-you-charlie-freeman_954/index.html" title="We Love You, Charlie Freeman">We Love You, Charlie ...</a>
# <a href="../../../thirst_946/index.html" title="Thirst">Thirst</a>
# <a href="../../../the-murder-that-never-was-forensic-instincts-5_939/index.html" title="The Murder That Never Was (Forensic Instincts #5)">The Murder That Never ...</a>
# <a href="../../../tuesday-nights-in-1980_870/index.html" title="Tuesday Nights in 1980">Tuesday Nights in 1980</a>
# <a href="../../../the-vacationers_863/index.html" title="The Vacationers">The Vacationers</a>
# <a href="../../../the-regional-office-is-under-attack_858/index.html" title="The Regional Office Is Under Attack!">The Regional Office Is ...</a>
# <a href="../../../finders-keepers-bill-hodges-trilogy-2_807/index.html" title="Finders Keepers (Bill Hodges Trilogy #2)">Finders Keepers (Bill Hodges ...</a>
# <a href="../../../the-time-keeper_766/index.html" title="The Time Keeper">The Time Keeper</a>
# <a href="../../../the-testament-of-mary_765/index.html" title="The Testament of Mary">The Testament of Mary</a>
# <a href="../../../the-first-hostage-jb-collins-2_749/index.html" title="The First Hostage (J.B. Collins #2)">The First Hostage (J.B. ...</a>
# <a href="../../../take-me-with-you_741/index.html" title="Take Me with You">Take Me with You</a>
# <a href="../../../still-life-with-bread-crumbs_738/index.html" title="Still Life with Bread Crumbs">Still Life with Bread ...</a>
# <a href="../../../shtum_733/index.html" title="Shtum">Shtum</a>
# <a href="../../../my-name-is-lucy-barton_720/index.html" title="My Name Is Lucy Barton">My Name Is Lucy ...</a>
# <a href="../../../my-mrs-brown_719/index.html" title="My Mrs. Brown">My Mrs. Brown</a>
# <a href="../../../mr-mercedes-bill-hodges-trilogy-1_717/index.html" title="Mr. Mercedes (Bill Hodges Trilogy #1)">Mr. Mercedes (Bill Hodges ...</a>
# <a href="../../../i-am-pilgrim-pilgrim-1_703/index.html" title="I Am Pilgrim (Pilgrim #1)">I Am Pilgrim (Pilgrim ...</a>
# <a href="../../../eligible-the-austen-project-4_692/index.html" title="Eligible (The Austen Project #4)">Eligible (The Austen Project ...</a>

# %%
titulo_items = soup.find_all('h3') 

for item in titulo_items:
    titulo = item.a 

    print(titulo.attrs) #Devuelve el artibuto href y el titulo, attrs significa atributo
# Out:
# {'href': '../../../soumission_998/index.html', 'title': 'Soumission'}
# {'href': '../../../private-paris-private-10_958/index.html', 'title': 'Private Paris (Private #10)'}
# {'href': '../../../we-love-you-charlie-freeman_954/index.html', 'title': 'We Love You, Charlie Freeman'}
# {'href': '../../../thirst_946/index.html', 'title': 'Thirst'}
# {'href': '../../../the-murder-that-never-was-forensic-instincts-5_939/index.html', 'title': 'The Murder That Never Was (Forensic Instincts #5)'}
# {'href': '../../../tuesday-nights-in-1980_870/index.html', 'title': 'Tuesday Nights in 1980'}
# {'href': '../../../the-vacationers_863/index.html', 'title': 'The Vacationers'}
# {'href': '../../../the-regional-office-is-under-attack_858/index.html', 'title': 'The Regional Office Is Under Attack!'}
# {'href': '../../../finders-keepers-bill-hodges-trilogy-2_807/index.html', 'title': 'Finders Keepers (Bill Hodges Trilogy #2)'}
# {'href': '../../../the-time-keeper_766/index.html', 'title': 'The Time Keeper'}
# {'href': '../../../the-testament-of-mary_765/index.html', 'title': 'The Testament of Mary'}
# {'href': '../../../the-first-hostage-jb-collins-2_749/index.html', 'title': 'The First Hostage (J.B. Collins #2)'}
# {'href': '../../../take-me-with-you_741/index.html', 'title': 'Take Me with You'}
# {'href': '../../../still-life-with-bread-crumbs_738/index.html', 'title': 'Still Life with Bread Crumbs'}
# {'href': '../../../shtum_733/index.html', 'title': 'Shtum'}
# {'href': '../../../my-name-is-lucy-barton_720/index.html', 'title': 'My Name Is Lucy Barton'}
# {'href': '../../../my-mrs-brown_719/index.html', 'title': 'My Mrs. Brown'}
# {'href': '../../../mr-mercedes-bill-hodges-trilogy-1_717/index.html', 'title': 'Mr. Mercedes (Bill Hodges Trilogy #1)'}
# {'href': '../../../i-am-pilgrim-pilgrim-1_703/index.html', 'title': 'I Am Pilgrim (Pilgrim #1)'}
# {'href': '../../../eligible-the-austen-project-4_692/index.html', 'title': 'Eligible (The Austen Project #4)'}

# %%
titulos = [] #Aqui se guardan los titulos ya limpios sin el resto del codigo

titulo_items = soup.find_all('h3') 

for item in titulo_items:
    titulo = item.a
    titulos.append(titulo['title']) 

    print(titulo['title']) #Devuelve el titulo ya limpio
# Out:
# Soumission
# Private Paris (Private #10)
# We Love You, Charlie Freeman
# Thirst
# The Murder That Never Was (Forensic Instincts #5)
# Tuesday Nights in 1980
# The Vacationers
# The Regional Office Is Under Attack!
# Finders Keepers (Bill Hodges Trilogy #2)
# The Time Keeper
# The Testament of Mary
# The First Hostage (J.B. Collins #2)
# Take Me with You
# Still Life with Bread Crumbs
# Shtum
# My Name Is Lucy Barton
# My Mrs. Brown
# Mr. Mercedes (Bill Hodges Trilogy #1)
# I Am Pilgrim (Pilgrim #1)
# Eligible (The Austen Project #4)

# %%
titulos
# Out:
# ['Soumission',
#  'Private Paris (Private #10)',
#  'We Love You, Charlie Freeman',
#  'Thirst',
#  'The Murder That Never Was (Forensic Instincts #5)',
#  'Tuesday Nights in 1980',
#  'The Vacationers',
#  'The Regional Office Is Under Attack!',
#  'Finders Keepers (Bill Hodges Trilogy #2)',
#  'The Time Keeper',
#  'The Testament of Mary',
#  'The First Hostage (J.B. Collins #2)',
#  'Take Me with You',
#  'Still Life with Bread Crumbs',
#  'Shtum',
#  'My Name Is Lucy Barton',
#  'My Mrs. Brown',
#  'Mr. Mercedes (Bill Hodges Trilogy #1)',
#  'I Am Pilgrim (Pilgrim #1)',
#  'Eligible (The Austen Project #4)']

# %%
precio = []

precio_items = soup.find_all('p',class_="price_color")

print(precio_items)
# Out:
# [<p class="price_color">Â£50.10</p>, <p class="price_color">Â£47.61</p>, <p class="price_color">Â£50.27</p>, <p class="price_color">Â£17.27</p>, <p class="price_color">Â£54.11</p>, <p class="price_color">Â£21.04</p>, <p class="price_color">Â£42.15</p>, <p class="price_color">Â£51.36</p>, <p class="price_color">Â£53.53</p>, <p class="price_color">Â£27.88</p>, <p class="price_color">Â£52.67</p>, <p class="price_color">Â£25.85</p>, <p class="price_color">Â£45.21</p>, <p class="price_color">Â£26.41</p>, <p class="price_color">Â£55.84</p>, <p class="price_color">Â£41.56</p>, <p class="price_color">Â£24.48</p>, <p class="price_color">Â£28.90</p>, <p class="price_color">Â£10.60</p>, <p class="price_color">Â£27.09</p>]

# %%
precios = [] 

precio_items = soup.find_all('p',class_="price_color") 

for item in precio_items:
    precio = item.text
    precios.append(precio) 

    print(precios)
# Out:
# ['Â£50.10', 'Â£47.61', 'Â£50.27', 'Â£17.27', 'Â£54.11', 'Â£21.04', 'Â£42.15', 'Â£51.36', 'Â£53.53', 'Â£27.88', 'Â£52.67', 'Â£25.85', 'Â£45.21', 'Â£26.41', 'Â£55.84', 'Â£41.56', 'Â£24.48', 'Â£28.90', 'Â£10.60', 'Â£27.09']

# %%
precios
# Out:
# ['Â£50.10',
#  'Â£47.61',
#  'Â£50.27',
#  'Â£17.27',
#  'Â£54.11',
#  'Â£21.04',
#  'Â£42.15',
#  'Â£51.36',
#  'Â£53.53',
#  'Â£27.88',
#  'Â£52.67',
#  'Â£25.85',
#  'Â£45.21',
#  'Â£26.41',
#  'Â£55.84',
#  'Â£41.56',
#  'Â£24.48',
#  'Â£28.90',
#  'Â£10.60',
#  'Â£27.09']

# %%
existencias = []

existencia_items = soup.find_all('p',class_="instock availability")

for item in existencia_items:
    existencia = item.text
    existencias.append(existencia)

# %%
existencias
# Out:
# ['\n\n    \n        In stock\n    \n',
#  '\n\n    \n        In stock\n    \n',
#  '\n\n    \n        In stock\n    \n',
#  '\n\n    \n        In stock\n    \n',
#  '\n\n    \n        In stock\n    \n',
#  '\n\n    \n        In stock\n    \n',
#  '\n\n    \n        In stock\n    \n',
#  '\n\n    \n        In stock\n    \n',
#  '\n\n    \n        In stock\n    \n',
#  '\n\n    \n        In stock\n    \n',
#  '\n\n    \n        In stock\n    \n',
#  '\n\n    \n        In stock\n    \n',
#  '\n\n    \n        In stock\n    \n',
#  '\n\n    \n        In stock\n    \n',
#  '\n\n    \n        In stock\n    \n',
#  '\n\n    \n        In stock\n    \n',
#  '\n\n    \n        In stock\n    \n',
#  '\n\n    \n        In stock\n    \n',
#  '\n\n    \n        In stock\n    \n',
#  '\n\n    \n        In stock\n    \n']

# %%
ratings = []

rating_items =  soup.find_all('p', class_='star-rating')

print(rating_items)
# Out:
# [<p class="star-rating One">
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# </p>, <p class="star-rating Five">
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# </p>, <p class="star-rating Five">
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# </p>, <p class="star-rating Five">
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# </p>, <p class="star-rating Three">
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# </p>, <p class="star-rating Two">
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# </p>, <p class="star-rating Four">
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# </p>, <p class="star-rating Five">
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# </p>, <p class="star-rating Five">
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# </p>, <p class="star-rating Five">
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# </p>, <p class="star-rating Four">
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# </p>, <p class="star-rating Three">
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# </p>, <p class="star-rating Three">
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# </p>, <p class="star-rating Three">
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# </p>, <p class="star-rating Four">
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# </p>, <p class="star-rating One">
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# </p>, <p class="star-rating Three">
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# </p>, <p class="star-rating One">
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# </p>, <p class="star-rating Four">
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# </p>, <p class="star-rating Three">
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# </p>]

# %%
ratings = []

rating_items =  soup.find_all('p', class_='star-rating')

for item in rating_items:
    rating =item['class'][1] #Este arreglo es que por cada item que exista en rating items va a devolver class o clase el primer valor o sea 1 que da el
                             #el numero de estrellas
    ratings.append(rating)

# %%
ratings
# Out:
# ['One',
#  'Five',
#  'Five',
#  'Five',
#  'Three',
#  'Two',
#  'Four',
#  'Five',
#  'Five',
#  'Five',
#  'Four',
#  'Three',
#  'Three',
#  'Three',
#  'Four',
#  'One',
#  'Three',
#  'One',
#  'Four',
#  'Three']

# %%
import pandas as pd 

data = {'Titulo': titulos, 
        'Precio': precio, 
        'Rating': ratings, 
        'En existencia': existencias
        }

df =pd.DataFrame(data) #Ya podemos convertir los datos en un dataframe

# %%
df
# Out:
#                                                Titulo   Precio Rating  \
# 0                                          Soumission  Â£27.09    One
# 1                         Private Paris (Private #10)  Â£27.09   Five
# 2                        We Love You, Charlie Freeman  Â£27.09   Five
# 3                                              Thirst  Â£27.09   Five
# 4   The Murder That Never Was (Forensic Instincts #5)  Â£27.09  Three
# 5                              Tuesday Nights in 1980  Â£27.09    Two
# 6                                     The Vacationers  Â£27.09   Four
# 7                The Regional Office Is Under Attack!  Â£27.09   Five
# 8            Finders Keepers (Bill Hodges Trilogy #2)  Â£27.09   Five
# 9                                     The Time Keeper  Â£27.09   Five
# 10                              The Testament of Mary  Â£27.09   Four
# 11                The First Hostage (J.B. Collins #2)  Â£27.09  Three
# 12                                   Take Me with You  Â£27.09  Three
# 13                       Still Life with Bread Crumbs  Â£27.09  Three
# 14                                              Shtum  Â£27.09   Four
# 15                             My Name Is Lucy Barton  Â£27.09    One
# 16                                      My Mrs. Brown  Â£27.09  Three
# 17              Mr. Mercedes (Bill Hodges Trilogy #1)  Â£27.09    One
# 18                          I Am Pilgrim (Pilgrim #1)  Â£27.09   Four
# 19                   Eligible (The Austen Project #4)  Â£27.09  Three
#
#                          En existencia
# 0   \n\n    \n        In stock\n    \n
# 1   \n\n    \n        In stock\n    \n
# 2   \n\n    \n        In stock\n    \n
# 3   \n\n    \n        In stock\n    \n
# 4   \n\n    \n        In stock\n    \n
# 5   \n\n    \n        In stock\n    \n
# 6   \n\n    \n        In stock\n    \n
# 7   \n\n    \n        In stock\n    \n
# 8   \n\n    \n        In stock\n    \n
# 9   \n\n    \n        In stock\n    \n
# 10  \n\n    \n        In stock\n    \n
# 11  \n\n    \n        In stock\n    \n
# 12  \n\n    \n        In stock\n    \n
# 13  \n\n    \n        In stock\n    \n
# 14  \n\n    \n        In stock\n    \n
# 15  \n\n    \n        In stock\n    \n
# 16  \n\n    \n        In stock\n    \n
# 17  \n\n    \n        In stock\n    \n
# 18  \n\n    \n        In stock\n    \n
# 19  \n\n    \n        In stock\n    \n

# %% [markdown]
# 2. Enviar solicitud HTTP

# %%
pagina_web = requests.get('http://books.toscrape.com/') #Esto es para hacer lapeticion a la pagina web

travel_page =  requests.get('http://books.toscrape.com/catalogue/category/books_1/index.html')

soup = BeautifulSoup(pagina_web.text, 'html.parser')

soup2 = BeautifulSoup(travel_page.text, 'html.parser')

print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <!--[if lt IE 7]>      <html lang="en-us" class="no-js lt-ie9 lt-ie8 lt-ie7"> <![endif]-->
# <!--[if IE 7]>         <html lang="en-us" class="no-js lt-ie9 lt-ie8"> <![endif]-->
# <!--[if IE 8]>         <html lang="en-us" class="no-js lt-ie9"> <![endif]-->
# <!--[if gt IE 8]><!-->
# <html class="no-js" lang="en-us">
#  <!--<![endif]-->
#  <head>
#   <title>
#    All products | Books to Scrape - Sandbox
#   </title>
#   <meta content="text/html; charset=utf-8" http-equiv="content-type"/>
#   <meta content="24th Jun 2016 09:29" name="created"/>
#   <meta content="" name="description"/>
#   <meta content="width=device-width" name="viewport"/>
#   <meta content="NOARCHIVE,NOCACHE" name="robots"/>
#   <!-- Le HTML5 shim, for IE6-8 support of HTML elements -->
#   <!--[if lt IE 9]>
#         <script src="//html5shim.googlecode.com/svn/trunk/html5.js"></script>
#         <![endif]-->
#   <link href="static/oscar/favicon.ico" rel="shortcut icon"/>
#   <link href="static/oscar/css/styles.css" rel="stylesheet" type="text/css"/>
#   <link href="static/oscar/js/bootstrap-datetimepicker/bootstrap-datetimepicker.css" rel="stylesheet"/>
#   <link href="static/oscar/css/datetimepicker.css" rel="stylesheet" type="text/css"/>
#  </head>
#  <body class="default" id="default">
#   <header class="header container-fluid">
#    <div class="page_inner">
#     <div class="row">
#      <div class="col-sm-8 h1">
#       <a href="index.html">
#        Books to Scrape
#       </a>
#       <small>
#        We love being scraped!
#       </small>
#      </div>
#     </div>
#    </div>
#   </header>
#   <div class="container-fluid page">
#    <div class="page_inner">
#     <ul class="breadcrumb">
#      <li>
#       <a href="index.html">
#        Home
#       </a>
#      </li>
#      <li class="active">
#       All products
#      </li>
#     </ul>
#     <div class="row">
#      <aside class="sidebar col-sm-4 col-md-3">
#       <div id="promotions_left">
#       </div>
#       <div class="side_categories">
#        <ul class="nav nav-list">
#         <li>
#          <a href="catalogue/category/books_1/index.html">
#           Books
#          </a>
#          <ul>
#           <li>
#            <a href="catalogue/category/books/travel_2/index.html">
#             Travel
#            </a>
#           </li>
#           <li>
#            <a href="catalogue/category/books/mystery_3/index.html">
#             Mystery
#            </a>
#           </li>
#           <li>
#            <a href="catalogue/category/books/historical-fiction_4/index.html">
#             Historical Fiction
#            </a>
#           </li>
#           <li>
#            <a href="catalogue/category/books/sequential-art_5/index.html">
#             Sequential Art
#            </a>
#           </li>
#           <li>
#            <a href="catalogue/category/books/classics_6/index.html">
#             Classics
#            </a>
#           </li>
#           <li>
#            <a href="catalogue/category/books/philosophy_7/index.html">
#             Philosophy
#            </a>
#           </li>
#           <li>
#            <a href="catalogue/category/books/romance_8/index.html">
#             Romance
#            </a>
#           </li>
#           <li>
#            <a href="catalogue/category/books/womens-fiction_9/index.html">
#             Womens Fiction
#            </a>
#           </li>
#           <li>
#            <a href="catalogue/category/books/fiction_10/index.html">
#             Fiction
#            </a>
#           </li>
#           <li>
#            <a href="catalogue/category/books/childrens_11/index.html">
#             Childrens
#            </a>
#           </li>
#           <li>
#            <a href="catalogue/category/books/religion_12/index.html">
#             Religion
#            </a>
#           </li>
#           <li>
#            <a href="catalogue/category/books/nonfiction_13/index.html">
#             Nonfiction
#            </a>
#           </li>
#           <li>
#            <a href="catalogue/category/books/music_14/index.html">
#             Music
#            </a>
#           </li>
#           <li>
#            <a href="catalogue/category/books/default_15/index.html">
#             Default
#            </a>
#           </li>
#           <li>
#            <a href="catalogue/category/books/science-fiction_16/index.html">
#             Science Fiction
#            </a>
#           </li>
#           <li>
#            <a href="catalogue/category/books/sports-and-games_17/index.html">
#             Sports and Games
#            </a>
#           </li>
#           <li>
#            <a href="catalogue/category/books/add-a-comment_18/index.html">
#             Add a comment
#            </a>
#           </li>
#           <li>
#            <a href="catalogue/category/books/fantasy_19/index.html">
#             Fantasy
#            </a>
#           </li>
#           <li>
#            <a href="catalogue/category/books/new-adult_20/index.html">
#             New Adult
#            </a>
#           </li>
#           <li>
#            <a href="catalogue/category/books/young-adult_21/index.html">
#             Young Adult
#            </a>
#           </li>
#           <li>
#            <a href="catalogue/category/books/science_22/index.html">
#             Science
#            </a>
#           </li>
#           <li>
#            <a href="catalogue/category/books/poetry_23/index.html">
#             Poetry
#            </a>
#           </li>
#           <li>
#            <a href="catalogue/category/books/paranormal_24/index.html">
#             Paranormal
#            </a>
#           </li>
#           <li>
#            <a href="catalogue/category/books/art_25/index.html">
#             Art
#            </a>
#           </li>
#           <li>
#            <a href="catalogue/category/books/psychology_26/index.html">
#             Psychology
#            </a>
#           </li>
#           <li>
#            <a href="catalogue/category/books/autobiography_27/index.html">
#             Autobiography
#            </a>
#           </li>
#           <li>
#            <a href="catalogue/category/books/parenting_28/index.html">
#             Parenting
#            </a>
#           </li>
#           <li>
#            <a href="catalogue/category/books/adult-fiction_29/index.html">
#             Adult Fiction
#            </a>
#           </li>
#           <li>
#            <a href="catalogue/category/books/humor_30/index.html">
#             Humor
#            </a>
#           </li>
#           <li>
#            <a href="catalogue/category/books/horror_31/index.html">
#             Horror
#            </a>
#           </li>
#           <li>
#            <a href="catalogue/category/books/history_32/index.html">
#             History
#            </a>
#           </li>
#           <li>
#            <a href="catalogue/category/books/food-and-drink_33/index.html">
#             Food and Drink
#            </a>
#           </li>
#           <li>
#            <a href="catalogue/category/books/christian-fiction_34/index.html">
#             Christian Fiction
#            </a>
#           </li>
#           <li>
#            <a href="catalogue/category/books/business_35/index.html">
#             Business
#            </a>
#           </li>
#           <li>
#            <a href="catalogue/category/books/biography_36/index.html">
#             Biography
#            </a>
#           </li>
#           <li>
#            <a href="catalogue/category/books/thriller_37/index.html">
#             Thriller
#            </a>
#           </li>
#           <li>
#            <a href="catalogue/category/books/contemporary_38/index.html">
#             Contemporary
#            </a>
#           </li>
#           <li>
#            <a href="catalogue/category/books/spirituality_39/index.html">
#             Spirituality
#            </a>
#           </li>
#           <li>
#            <a href="catalogue/category/books/academic_40/index.html">
#             Academic
#            </a>
#           </li>
#           <li>
#            <a href="catalogue/category/books/self-help_41/index.html">
#             Self Help
#            </a>
#           </li>
#           <li>
#            <a href="catalogue/category/books/historical_42/index.html">
#             Historical
#            </a>
#           </li>
#           <li>
#            <a href="catalogue/category/books/christian_43/index.html">
#             Christian
#            </a>
#           </li>
#           <li>
#            <a href="catalogue/category/books/suspense_44/index.html">
#             Suspense
#            </a>
#           </li>
#           <li>
#            <a href="catalogue/category/books/short-stories_45/index.html">
#             Short Stories
#            </a>
#           </li>
#           <li>
#            <a href="catalogue/category/books/novels_46/index.html">
#             Novels
#            </a>
#           </li>
#           <li>
#            <a href="catalogue/category/books/health_47/index.html">
#             Health
#            </a>
#           </li>
#           <li>
#            <a href="catalogue/category/books/politics_48/index.html">
#             Politics
#            </a>
#           </li>
#           <li>
#            <a href="catalogue/category/books/cultural_49/index.html">
#             Cultural
#            </a>
#           </li>
#           <li>
#            <a href="catalogue/category/books/erotica_50/index.html">
#             Erotica
#            </a>
#           </li>
#           <li>
#            <a href="catalogue/category/books/crime_51/index.html">
#             Crime
#            </a>
#           </li>
#          </ul>
#         </li>
#        </ul>
#       </div>
#      </aside>
#      <div class="col-sm-8 col-md-9">
#       <div class="page-header action">
#        <h1>
#         All products
#        </h1>
#       </div>
#       <div id="messages">
#       </div>
#       <div id="promotions">
#       </div>
#       <form class="form-horizontal" method="get">
#        <div style="display:none">
#        </div>
#        <strong>
#         1000
#        </strong>
#        results - showing
#        <strong>
#         1
#        </strong>
#        to
#        <strong>
#         20
#        </strong>
#        .
#       </form>
#       <section>
#        <div class="alert alert-warning" role="alert">
#         <strong>
#          Warning!
#         </strong>
#         This is a demo website for web scraping purposes. Prices and ratings here were randomly assigned and have no real meaning.
#        </div>
#        <div>
#         <ol class="row">
#          <li class="col-xs-6 col-sm-4 col-md-3 col-lg-3">
#           <article class="product_pod">
#            <div class="image_container">
#             <a href="catalogue/a-light-in-the-attic_1000/index.html">
#              <img alt="A Light in the Attic" class="thumbnail" src="media/cache/2c/da/2cdad67c44b002e7ead0cc35693c0e8b.jpg"/>
#             </a>
#            </div>
#            <p class="star-rating Three">
#             <i class="icon-star">
#             </i>
#             <i class="icon-star">
#             </i>
#             <i class="icon-star">
#             </i>
#             <i class="icon-star">
#             </i>
#             <i class="icon-star">
#             </i>
#            </p>
#            <h3>
#             <a href="catalogue/a-light-in-the-attic_1000/index.html" title="A Light in the Attic">
#              A Light in the ...
#             </a>
#            </h3>
#            <div class="product_price">
#             <p class="price_color">
#              Â£51.77
#             </p>
#             <p class="instock availability">
#              <i class="icon-ok">
#              </i>
#              In stock
#             </p>
#             <form>
#              <button class="btn btn-primary btn-block" data-loading-text="Adding..." type="submit">
#               Add to basket
#              </button>
#             </form>
#            </div>
#           </article>
#          </li>
#          <li class="col-xs-6 col-sm-4 col-md-3 col-lg-3">
#           <article class="product_pod">
#            <div class="image_container">
#             <a href="catalogue/tipping-the-velvet_999/index.html">
#              <img alt="Tipping the Velvet" class="thumbnail" src="media/cache/26/0c/260c6ae16bce31c8f8c95daddd9f4a1c.jpg"/>
#             </a>
#            </div>
#            <p class="star-rating One">
#             <i class="icon-star">
#             </i>
#             <i class="icon-star">
#             </i>
#             <i class="icon-star">
#             </i>
#             <i class="icon-star">
#             </i>
#             <i class="icon-star">
#             </i>
#            </p>
#            <h3>
#             <a href="catalogue/tipping-the-velvet_999/index.html" title="Tipping the Velvet">
#              Tipping the Velvet
#             </a>
#            </h3>
#            <div class="product_price">
#             <p class="price_color">
#              Â£53.74
#             </p>
#             <p class="instock availability">
#              <i class="icon-ok">
#              </i>
#              In stock
#             </p>
#             <form>
#              <button class="btn btn-primary btn-block" data-loading-text="Adding..." type="submit">
#               Add to basket
#              </button>
#             </form>
#            </div>
#           </article>
#          </li>
#          <li class="col-xs-6 col-sm-4 col-md-3 col-lg-3">
#           <article class="product_pod">
#            <div class="image_container">
#             <a href="catalogue/soumission_998/index.html">
#              <img alt="Soumission" class="thumbnail" src="media/cache/3e/ef/3eef99c9d9adef34639f510662022830.jpg"/>
#             </a>
#            </div>
#            <p class="star-rating One">
#             <i class="icon-star">
#             </i>
#             <i class="icon-star">
#             </i>
#             <i class="icon-star">
#             </i>
#             <i class="icon-star">
#             </i>
#             <i class="icon-star">
#             </i>
#            </p>
#            <h3>
#             <a href="catalogue/soumission_998/index.html" title="Soumission">
#              Soumission
#             </a>
#            </h3>
#            <div class="product_price">
#             <p class="price_color">
#              Â£50.10
#             </p>
#             <p class="instock availability">
#              <i class="icon-ok">
#              </i>
#              In stock
#             </p>
#             <form>
#              <button class="btn btn-primary btn-block" data-loading-text="Adding..." type="submit">
#               Add to basket
#              </button>
#             </form>
#            </div>
#           </article>
#          </li>
#          <li class="col-xs-6 col-sm-4 col-md-3 col-lg-3">
#           <article class="product_pod">
#            <div class="image_container">
#             <a href="catalogue/sharp-objects_997/index.html">
#              <img alt="Sharp Objects" class="thumbnail" src="media/cache/32/51/3251cf3a3412f53f339e42cac2134093.jpg"/>
#             </a>
#            </div>
#            <p class="star-rating Four">
#             <i class="icon-star">
#             </i>
#             <i class="icon-star">
#             </i>
#             <i class="icon-star">
#             </i>
#             <i class="icon-star">
#             </i>
#             <i class="icon-star">
#             </i>
#            </p>
#            <h3>
#             <a href="catalogue/sharp-objects_997/index.html" title="Sharp Objects">
#              Sharp Objects
#             </a>
#            </h3>
#            <div class="product_price">
#             <p class="price_color">
#              Â£47.82
#             </p>
#             <p class="instock availability">
#              <i class="icon-ok">
#              </i>
#              In stock
#             </p>
#             <form>
#              <button class="btn btn-primary btn-block" data-loading-text="Adding..." type="submit">
#               Add to basket
#              </button>
#             </form>
#            </div>
#           </article>
#          </li>
#          <li class="col-xs-6 col-sm-4 col-md-3 col-lg-3">
#           <article class="product_pod">
#            <div class="image_container">
#             <a href="catalogue/sapiens-a-brief-history-of-humankind_996/index.html">
#              <img alt="Sapiens: A Brief History of Humankind" class="thumbnail" src="media/cache/be/a5/bea5697f2534a2f86a3ef27b5a8c12a6.jpg"/>
#             </a>
#            </div>
#            <p class="star-rating Five">
#             <i class="icon-star">
#             </i>
#             <i class="icon-star">
#             </i>
#             <i class="icon-star">
#             </i>
#             <i class="icon-star">
#             </i>
#             <i class="icon-star">
#             </i>
#            </p>
#            <h3>
#             <a href="catalogue/sapiens-a-brief-history-of-humankind_996/index.html" title="Sapiens: A Brief History of Humankind">
#              Sapiens: A Brief History ...
#             </a>
#            </h3>
#            <div class="product_price">
#             <p class="price_color">
#              Â£54.23
#             </p>
#             <p class="instock availability">
#              <i class="icon-ok">
#              </i>
#              In stock
#             </p>
#             <form>
#              <button class="btn btn-primary btn-block" data-loading-text="Adding..." type="submit">
#               Add to basket
#              </button>
#             </form>
#            </div>
#           </article>
#          </li>
#          <li class="col-xs-6 col-sm-4 col-md-3 col-lg-3">
#           <article class="product_pod">
#            <div class="image_container">
#             <a href="catalogue/the-requiem-red_995/index.html">
#              <img alt="The Requiem Red" class="thumbnail" src="media/cache/68/33/68339b4c9bc034267e1da611ab3b34f8.jpg"/>
#             </a>
#            </div>
#            <p class="star-rating One">
#             <i class="icon-star">
#             </i>
#             <i class="icon-star">
#             </i>
#             <i class="icon-star">
#             </i>
#             <i class="icon-star">
#             </i>
#             <i class="icon-star">
#             </i>
#            </p>
#            <h3>
#             <a href="catalogue/the-requiem-red_995/index.html" title="The Requiem Red">
#              The Requiem Red
#             </a>
#            </h3>
#            <div class="product_price">
#             <p class="price_color">
#              Â£22.65
#             </p>
#             <p class="instock availability">
#              <i class="icon-ok">
#              </i>
#              In stock
#             </p>
#             <form>
#              <button class="btn btn-primary btn-block" data-loading-text="Adding..." type="submit">
#               Add to basket
#              </button>
#             </form>
#            </div>
#           </article>
#          </li>
#          <li class="col-xs-6 col-sm-4 col-md-3 col-lg-3">
#           <article class="product_pod">
#            <div class="image_container">
#             <a href="catalogue/the-dirty-little-secrets-of-getting-your-dream-job_994/index.html">
#              <img alt="The Dirty Little Secrets of Getting Your Dream Job" class="thumbnail" src="media/cache/92/27/92274a95b7c251fea59a2b8a78275ab4.jpg"/>
#             </a>
#            </div>
#            <p class="star-rating Four">
#             <i class="icon-star">
#             </i>
#             <i class="icon-star">
#             </i>
#             <i class="icon-star">
#             </i>
#             <i class="icon-star">
#             </i>
#             <i class="icon-star">
#             </i>
#            </p>
#            <h3>
#             <a href="catalogue/the-dirty-little-secrets-of-getting-your-dream-job_994/index.html" title="The Dirty Little Secrets of Getting Your Dream Job">
#              The Dirty Little Secrets ...
#             </a>
#            </h3>
#            <div class="product_price">
#             <p class="price_color">
#              Â£33.34
#             </p>
#             <p class="instock availability">
#              <i class="icon-ok">
#              </i>
#              In stock
#             </p>
#             <form>
#              <button class="btn btn-primary btn-block" data-loading-text="Adding..." type="submit">
#               Add to basket
#              </button>
#             </form>
#            </div>
#           </article>
#          </li>
#          <li class="col-xs-6 col-sm-4 col-md-3 col-lg-3">
#           <article class="product_pod">
#            <div class="image_container">
#             <a href="catalogue/the-coming-woman-a-novel-based-on-the-life-of-the-infamous-feminist-victoria-woodhull_993/index.html">
#              <img alt="The Coming Woman: A Novel Based on the Life of the Infamous Feminist, Victoria Woodhull" class="thumbnail" src="media/cache/3d/54/3d54940e57e662c4dd1f3ff00c78cc64.jpg"/>
#             </a>
#            </div>
#            <p class="star-rating Three">
#             <i class="icon-star">
#             </i>
#             <i class="icon-star">
#             </i>
#             <i class="icon-star">
#             </i>
#             <i class="icon-star">
#             </i>
#             <i class="icon-star">
#             </i>
#            </p>
#            <h3>
#             <a href="catalogue/the-coming-woman-a-novel-based-on-the-life-of-the-infamous-feminist-victoria-woodhull_993/index.html" title="The Coming Woman: A Novel Based on the Life of the Infamous Feminist, Victoria Woodhull">
#              The Coming Woman: A ...
#             </a>
#            </h3>
#            <div class="product_price">
#             <p class="price_color">
#              Â£17.93
#             </p>
#             <p class="instock availability">
#              <i class="icon-ok">
#              </i>
#              In stock
#             </p>
#             <form>
#              <button class="btn btn-primary btn-block" data-loading-text="Adding..." type="submit">
#               Add to basket
#              </button>
#             </form>
#            </div>
#           </article>
#          </li>
#          <li class="col-xs-6 col-sm-4 col-md-3 col-lg-3">
#           <article class="product_pod">
#            <div class="image_container">
#             <a href="catalogue/the-boys-in-the-boat-nine-americans-and-their-epic-quest-for-gold-at-the-1936-berlin-olympics_992/index.html">
#              <img alt="The Boys in the Boat: Nine Americans and Their Epic Quest for Gold at the 1936 Berlin Olympics" class="thumbnail" src="media/cache/66/88/66883b91f6804b2323c8369331cb7dd1.jpg"/>
#             </a>
#            </div>
#            <p class="star-rating Four">
#             <i class="icon-star">
#             </i>
#             <i class="icon-star">
#             </i>
#             <i class="icon-star">
#             </i>
#             <i class="icon-star">
#             </i>
#             <i class="icon-star">
#             </i>
#            </p>
#            <h3>
#             <a href="catalogue/the-boys-in-the-boat-nine-americans-and-their-epic-quest-for-gold-at-the-1936-berlin-olympics_992/index.html" title="The Boys in the Boat: Nine Americans and Their Epic Quest for Gold at the 1936 Berlin Olympics">
#              The Boys in the ...
#             </a>
#            </h3>
#            <div class="product_price">
#             <p class="price_color">
#              Â£22.60
#             </p>
#             <p class="instock availability">
#              <i class="icon-ok">
#              </i>
#              In stock
#             </p>
#             <form>
#              <button class="btn btn-primary btn-block" data-loading-text="Adding..." type="submit">
#               Add to basket
#              </button>
#             </form>
#            </div>
#           </article>
#          </li>
#          <li class="col-xs-6 col-sm-4 col-md-3 col-lg-3">
#           <article class="product_pod">
#            <div class="image_container">
#             <a href="catalogue/the-black-maria_991/index.html">
#              <img alt="The Black Maria" class="thumbnail" src="media/cache/58/46/5846057e28022268153beff6d352b06c.jpg"/>
#             </a>
#            </div>
#            <p class="star-rating One">
#             <i class="icon-star">
#             </i>
#             <i class="icon-star">
#             </i>
#             <i class="icon-star">
#             </i>
#             <i class="icon-star">
#             </i>
#             <i class="icon-star">
#             </i>
#            </p>
#            <h3>
#             <a href="catalogue/the-black-maria_991/index.html" title="The Black Maria">
#              The Black Maria
#             </a>
#            </h3>
#            <div class="product_price">
#             <p class="price_color">
#              Â£52.15
#             </p>
#             <p class="instock availability">
#              <i class="icon-ok">
#              </i>
#              In stock
#             </p>
#             <form>
#              <button class="btn btn-primary btn-block" data-loading-text="Adding..." type="submit">
#               Add to basket
#              </button>
#             </form>
#            </div>
#           </article>
#          </li>
#          <li class="col-xs-6 col-sm-4 col-md-3 col-lg-3">
#           <article class="product_pod">
#            <div class="image_container">
#             <a href="catalogue/starving-hearts-triangular-trade-trilogy-1_990/index.html">
#              <img alt="Starving Hearts (Triangular Trade Trilogy, #1)" class="thumbnail" src="media/cache/be/f4/bef44da28c98f905a3ebec0b87be8530.jpg"/>
#             </a>
#            </div>
#            <p class="star-rating Two">
#             <i class="icon-star">
#             </i>
#             <i class="icon-star">
#             </i>
#             <i class="icon-star">
#             </i>
#             <i class="icon-star">
#             </i>
#             <i class="icon-star">
#             </i>
#            </p>
#            <h3>
#             <a href="catalogue/starving-hearts-triangular-trade-trilogy-1_990/index.html" title="Starving Hearts (Triangular Trade Trilogy, #1)">
#              Starving Hearts (Triangular Trade ...
#             </a>
#            </h3>
#            <div class="product_price">
#             <p class="price_color">
#              Â£13.99
#             </p>
#             <p class="instock availability">
#              <i class="icon-ok">
#              </i>
#              In stock
#             </p>
#             <form>
#              <button class="btn btn-primary btn-block" data-loading-text="Adding..." type="submit">
#               Add to basket
#              </button>
#             </form>
#            </div>
#           </article>
#          </li>
#          <li class="col-xs-6 col-sm-4 col-md-3 col-lg-3">
#           <article class="product_pod">
#            <div class="image_container">
#             <a href="catalogue/shakespeares-sonnets_989/index.html">
#              <img alt="Shakespeare's Sonnets" class="thumbnail" src="media/cache/10/48/1048f63d3b5061cd2f424d20b3f9b666.jpg"/>
#             </a>
#            </div>
#            <p class="star-rating Four">
#             <i class="icon-star">
#             </i>
#             <i class="icon-star">
#             </i>
#             <i class="icon-star">
#             </i>
#             <i class="icon-star">
#             </i>
#             <i class="icon-star">
#             </i>
#            </p>
#            <h3>
#             <a href="catalogue/shakespeares-sonnets_989/index.html" title="Shakespeare's Sonnets">
#              Shakespeare's Sonnets
#             </a>
#            </h3>
#            <div class="product_price">
#             <p class="price_color">
#              Â£20.66
#             </p>
#             <p class="instock availability">
#              <i class="icon-ok">
#              </i>
#              In stock
#             </p>
#             <form>
#              <button class="btn btn-primary btn-block" data-loading-text="Adding..." type="submit">
#               Add to basket
#              </button>
#             </form>
#            </div>
#           </article>
#          </li>
#          <li class="col-xs-6 col-sm-4 col-md-3 col-lg-3">
#           <article class="product_pod">
#            <div class="image_container">
#             <a href="catalogue/set-me-free_988/index.html">
#              <img alt="Set Me Free" class="thumbnail" src="media/cache/5b/88/5b88c52633f53cacf162c15f4f823153.jpg"/>
#             </a>
#            </div>
#            <p class="star-rating Five">
#             <i class="icon-star">
#             </i>
#             <i class="icon-star">
#             </i>
#             <i class="icon-star">
#             </i>
#             <i class="icon-star">
#             </i>
#             <i class="icon-star">
#             </i>
#            </p>
#            <h3>
#             <a href="catalogue/set-me-free_988/index.html" title="Set Me Free">
#              Set Me Free
#             </a>
#            </h3>
#            <div class="product_price">
#             <p class="price_color">
#              Â£17.46
#             </p>
#             <p class="instock availability">
#              <i class="icon-ok">
#              </i>
#              In stock
#             </p>
#             <form>
#              <button class="btn btn-primary btn-block" data-loading-text="Adding..." type="submit">
#               Add to basket
#              </button>
#             </form>
#            </div>
#           </article>
#          </li>
#          <li class="col-xs-6 col-sm-4 col-md-3 col-lg-3">
#           <article class="product_pod">
#            <div class="image_container">
#             <a href="catalogue/scott-pilgrims-precious-little-life-scott-pilgrim-1_987/index.html">
#              <img alt="Scott Pilgrim's Precious Little Life (Scott Pilgrim #1)" class="thumbnail" src="media/cache/94/b1/94b1b8b244bce9677c2f29ccc890d4d2.jpg"/>
#             </a>
#            </div>
#            <p class="star-rating Five">
#             <i class="icon-star">
#             </i>
#             <i class="icon-star">
#             </i>
#             <i class="icon-star">
#             </i>
#             <i class="icon-star">
#             </i>
#             <i class="icon-star">
#             </i>
#            </p>
#            <h3>
#             <a href="catalogue/scott-pilgrims-precious-little-life-scott-pilgrim-1_987/index.html" title="Scott Pilgrim's Precious Little Life (Scott Pilgrim #1)">
#              Scott Pilgrim's Precious Little ...
#             </a>
#            </h3>
#            <div class="product_price">
#             <p class="price_color">
#              Â£52.29
#             </p>
#             <p class="instock availability">
#              <i class="icon-ok">
#              </i>
#              In stock
#             </p>
#             <form>
#              <button class="btn btn-primary btn-block" data-loading-text="Adding..." type="submit">
#               Add to basket
#              </button>
#             </form>
#            </div>
#           </article>
#          </li>
#          <li class="col-xs-6 col-sm-4 col-md-3 col-lg-3">
#           <article class="product_pod">
#            <div class="image_container">
#             <a href="catalogue/rip-it-up-and-start-again_986/index.html">
#              <img alt="Rip it Up and Start Again" class="thumbnail" src="media/cache/81/c4/81c4a973364e17d01f217e1188253d5e.jpg"/>
#             </a>
#            </div>
#            <p class="star-rating Five">
#             <i class="icon-star">
#             </i>
#             <i class="icon-star">
#             </i>
#             <i class="icon-star">
#             </i>
#             <i class="icon-star">
#             </i>
#             <i class="icon-star">
#             </i>
#            </p>
#            <h3>
#             <a href="catalogue/rip-it-up-and-start-again_986/index.html" title="Rip it Up and Start Again">
#              Rip it Up and ...
#             </a>
#            </h3>
#            <div class="product_price">
#             <p class="price_color">
#              Â£35.02
#             </p>
#             <p class="instock availability">
#              <i class="icon-ok">
#              </i>
#              In stock
#             </p>
#             <form>
#              <button class="btn btn-primary btn-block" data-loading-text="Adding..." type="submit">
#               Add to basket
#              </button>
#             </form>
#            </div>
#           </article>
#          </li>
#          <li class="col-xs-6 col-sm-4 col-md-3 col-lg-3">
#           <article class="product_pod">
#            <div class="image_container">
#             <a href="catalogue/our-band-could-be-your-life-scenes-from-the-american-indie-underground-1981-1991_985/index.html">
#              <img alt="Our Band Could Be Your Life: Scenes from the American Indie Underground, 1981-1991" class="thumbnail" src="media/cache/54/60/54607fe8945897cdcced0044103b10b6.jpg"/>
#             </a>
#            </div>
#            <p class="star-rating Three">
#             <i class="icon-star">
#             </i>
#             <i class="icon-star">
#             </i>
#             <i class="icon-star">
#             </i>
#             <i class="icon-star">
#             </i>
#             <i class="icon-star">
#             </i>
#            </p>
#            <h3>
#             <a href="catalogue/our-band-could-be-your-life-scenes-from-the-american-indie-underground-1981-1991_985/index.html" title="Our Band Could Be Your Life: Scenes from the American Indie Underground, 1981-1991">
#              Our Band Could Be ...
#             </a>
#            </h3>
#            <div class="product_price">
#             <p class="price_color">
#              Â£57.25
#             </p>
#             <p class="instock availability">
#              <i class="icon-ok">
#              </i>
#              In stock
#             </p>
#             <form>
#              <button class="btn btn-primary btn-block" data-loading-text="Adding..." type="submit">
#               Add to basket
#              </button>
#             </form>
#            </div>
#           </article>
#          </li>
#          <li class="col-xs-6 col-sm-4 col-md-3 col-lg-3">
#           <article class="product_pod">
#            <div class="image_container">
#             <a href="catalogue/olio_984/index.html">
#              <img alt="Olio" class="thumbnail" src="media/cache/55/33/553310a7162dfbc2c6d19a84da0df9e1.jpg"/>
#             </a>
#            </div>
#            <p class="star-rating One">
#             <i class="icon-star">
#             </i>
#             <i class="icon-star">
#             </i>
#             <i class="icon-star">
#             </i>
#             <i class="icon-star">
#             </i>
#             <i class="icon-star">
#             </i>
#            </p>
#            <h3>
#             <a href="catalogue/olio_984/index.html" title="Olio">
#              Olio
#             </a>
#            </h3>
#            <div class="product_price">
#             <p class="price_color">
#              Â£23.88
#             </p>
#             <p class="instock availability">
#              <i class="icon-ok">
#              </i>
#              In stock
#             </p>
#             <form>
#              <button class="btn btn-primary btn-block" data-loading-text="Adding..." type="submit">
#               Add to basket
#              </button>
#             </form>
#            </div>
#           </article>
#          </li>
#          <li class="col-xs-6 col-sm-4 col-md-3 col-lg-3">
#           <article class="product_pod">
#            <div class="image_container">
#             <a href="catalogue/mesaerion-the-best-science-fiction-stories-1800-1849_983/index.html">
#              <img alt="Mesaerion: The Best Science Fiction Stories 1800-1849" class="thumbnail" src="media/cache/09/a3/09a3aef48557576e1a85ba7efea8ecb7.jpg"/>
#             </a>
#            </div>
#            <p class="star-rating One">
#             <i class="icon-star">
#             </i>
#             <i class="icon-star">
#             </i>
#             <i class="icon-star">
#             </i>
#             <i class="icon-star">
#             </i>
#             <i class="icon-star">
#             </i>
#            </p>
#            <h3>
#             <a href="catalogue/mesaerion-the-best-science-fiction-stories-1800-1849_983/index.html" title="Mesaerion: The Best Science Fiction Stories 1800-1849">
#              Mesaerion: The Best Science ...
#             </a>
#            </h3>
#            <div class="product_price">
#             <p class="price_color">
#              Â£37.59
#             </p>
#             <p class="instock availability">
#              <i class="icon-ok">
#              </i>
#              In stock
#             </p>
#             <form>
#              <button class="btn btn-primary btn-block" data-loading-text="Adding..." type="submit">
#               Add to basket
#              </button>
#             </form>
#            </div>
#           </article>
#          </li>
#          <li class="col-xs-6 col-sm-4 col-md-3 col-lg-3">
#           <article class="product_pod">
#            <div class="image_container">
#             <a href="catalogue/libertarianism-for-beginners_982/index.html">
#              <img alt="Libertarianism for Beginners" class="thumbnail" src="media/cache/0b/bc/0bbcd0a6f4bcd81ccb1049a52736406e.jpg"/>
#             </a>
#            </div>
#            <p class="star-rating Two">
#             <i class="icon-star">
#             </i>
#             <i class="icon-star">
#             </i>
#             <i class="icon-star">
#             </i>
#             <i class="icon-star">
#             </i>
#             <i class="icon-star">
#             </i>
#            </p>
#            <h3>
#             <a href="catalogue/libertarianism-for-beginners_982/index.html" title="Libertarianism for Beginners">
#              Libertarianism for Beginners
#             </a>
#            </h3>
#            <div class="product_price">
#             <p class="price_color">
#              Â£51.33
#             </p>
#             <p class="instock availability">
#              <i class="icon-ok">
#              </i>
#              In stock
#             </p>
#             <form>
#              <button class="btn btn-primary btn-block" data-loading-text="Adding..." type="submit">
#               Add to basket
#              </button>
#             </form>
#            </div>
#           </article>
#          </li>
#          <li class="col-xs-6 col-sm-4 col-md-3 col-lg-3">
#           <article class="product_pod">
#            <div class="image_container">
#             <a href="catalogue/its-only-the-himalayas_981/index.html">
#              <img alt="It's Only the Himalayas" class="thumbnail" src="media/cache/27/a5/27a53d0bb95bdd88288eaf66c9230d7e.jpg"/>
#             </a>
#            </div>
#            <p class="star-rating Two">
#             <i class="icon-star">
#             </i>
#             <i class="icon-star">
#             </i>
#             <i class="icon-star">
#             </i>
#             <i class="icon-star">
#             </i>
#             <i class="icon-star">
#             </i>
#            </p>
#            <h3>
#             <a href="catalogue/its-only-the-himalayas_981/index.html" title="It's Only the Himalayas">
#              It's Only the Himalayas
#             </a>
#            </h3>
#            <div class="product_price">
#             <p class="price_color">
#              Â£45.17
#             </p>
#             <p class="instock availability">
#              <i class="icon-ok">
#              </i>
#              In stock
#             </p>
#             <form>
#              <button class="btn btn-primary btn-block" data-loading-text="Adding..." type="submit">
#               Add to basket
#              </button>
#             </form>
#            </div>
#           </article>
#          </li>
#         </ol>
#         <div>
#          <ul class="pager">
#           <li class="current">
#            Page 1 of 50
#           </li>
#           <li class="next">
#            <a href="catalogue/page-2.html">
#             next
#            </a>
#           </li>
#          </ul>
#         </div>
#        </div>
#       </section>
#      </div>
#     </div>
#     <!-- /row -->
#    </div>
#    <!-- /page_inner -->
#   </div>
#   <!-- /container-fluid -->
#   <footer class="footer container-fluid">
#   </footer>
#   <!-- jQuery -->
#   <script src="http://ajax.googleapis.com/ajax/libs/jquery/1.9.1/jquery.min.js">
#   </script>
#   <script>
#    window.jQuery || document.write('<script src="static/oscar/js/jquery/jquery-1.9.1.min.js"><\/script>')
#   </script>
#   <!-- Twitter Bootstrap -->
#   <script src="static/oscar/js/bootstrap3/bootstrap.min.js" type="text/javascript">
#   </script>
#   <!-- Oscar -->
#   <script charset="utf-8" src="static/oscar/js/oscar/ui.js" type="text/javascript">
#   </script>
#   <script charset="utf-8" src="static/oscar/js/bootstrap-datetimepicker/bootstrap-datetimepicker.js" type="text/javascript">
#   </script>
#   <script charset="utf-8" src="static/oscar/js/bootstrap-datetimepicker/locales/bootstrap-datetimepicker.all.js" type="text/javascript">
#   </script>
#   <script type="text/javascript">
#    $(function() {
#
#
#
#     oscar.init();
#
#     oscar.search.init();
#
#             });
#   </script>
#   <!-- Version: N/A -->
#  </body>
# </html>

# %%
imagenes_items = soup.find_all('img', class_='thumbnail')



print(imagenes_items)
# Out:
# [<img alt="A Light in the Attic" class="thumbnail" src="media/cache/2c/da/2cdad67c44b002e7ead0cc35693c0e8b.jpg"/>, <img alt="Tipping the Velvet" class="thumbnail" src="media/cache/26/0c/260c6ae16bce31c8f8c95daddd9f4a1c.jpg"/>, <img alt="Soumission" class="thumbnail" src="media/cache/3e/ef/3eef99c9d9adef34639f510662022830.jpg"/>, <img alt="Sharp Objects" class="thumbnail" src="media/cache/32/51/3251cf3a3412f53f339e42cac2134093.jpg"/>, <img alt="Sapiens: A Brief History of Humankind" class="thumbnail" src="media/cache/be/a5/bea5697f2534a2f86a3ef27b5a8c12a6.jpg"/>, <img alt="The Requiem Red" class="thumbnail" src="media/cache/68/33/68339b4c9bc034267e1da611ab3b34f8.jpg"/>, <img alt="The Dirty Little Secrets of Getting Your Dream Job" class="thumbnail" src="media/cache/92/27/92274a95b7c251fea59a2b8a78275ab4.jpg"/>, <img alt="The Coming Woman: A Novel Based on the Life of the Infamous Feminist, Victoria Woodhull" class="thumbnail" src="media/cache/3d/54/3d54940e57e662c4dd1f3ff00c78cc64.jpg"/>, <img alt="The Boys in the Boat: Nine Americans and Their Epic Quest for Gold at the 1936 Berlin Olympics" class="thumbnail" src="media/cache/66/88/66883b91f6804b2323c8369331cb7dd1.jpg"/>, <img alt="The Black Maria" class="thumbnail" src="media/cache/58/46/5846057e28022268153beff6d352b06c.jpg"/>, <img alt="Starving Hearts (Triangular Trade Trilogy, #1)" class="thumbnail" src="media/cache/be/f4/bef44da28c98f905a3ebec0b87be8530.jpg"/>, <img alt="Shakespeare's Sonnets" class="thumbnail" src="media/cache/10/48/1048f63d3b5061cd2f424d20b3f9b666.jpg"/>, <img alt="Set Me Free" class="thumbnail" src="media/cache/5b/88/5b88c52633f53cacf162c15f4f823153.jpg"/>, <img alt="Scott Pilgrim's Precious Little Life (Scott Pilgrim #1)" class="thumbnail" src="media/cache/94/b1/94b1b8b244bce9677c2f29ccc890d4d2.jpg"/>, <img alt="Rip it Up and Start Again" class="thumbnail" src="media/cache/81/c4/81c4a973364e17d01f217e1188253d5e.jpg"/>, <img alt="Our Band Could Be Your Life: Scenes from the American Indie Underground, 1981-1991" class="thumbnail" src="media/cache/54/60/54607fe8945897cdcced0044103b10b6.jpg"/>, <img alt="Olio" class="thumbnail" src="media/cache/55/33/553310a7162dfbc2c6d19a84da0df9e1.jpg"/>, <img alt="Mesaerion: The Best Science Fiction Stories 1800-1849" class="thumbnail" src="media/cache/09/a3/09a3aef48557576e1a85ba7efea8ecb7.jpg"/>, <img alt="Libertarianism for Beginners" class="thumbnail" src="media/cache/0b/bc/0bbcd0a6f4bcd81ccb1049a52736406e.jpg"/>, <img alt="It's Only the Himalayas" class="thumbnail" src="media/cache/27/a5/27a53d0bb95bdd88288eaf66c9230d7e.jpg"/>]

# %%
images = []
images_items = soup.find_all('img', class_='thumbnail')

for item in images_items:
    image =  item['src']
    images.append(image)
print(images)
# Out:
# ['media/cache/2c/da/2cdad67c44b002e7ead0cc35693c0e8b.jpg', 'media/cache/26/0c/260c6ae16bce31c8f8c95daddd9f4a1c.jpg', 'media/cache/3e/ef/3eef99c9d9adef34639f510662022830.jpg', 'media/cache/32/51/3251cf3a3412f53f339e42cac2134093.jpg', 'media/cache/be/a5/bea5697f2534a2f86a3ef27b5a8c12a6.jpg', 'media/cache/68/33/68339b4c9bc034267e1da611ab3b34f8.jpg', 'media/cache/92/27/92274a95b7c251fea59a2b8a78275ab4.jpg', 'media/cache/3d/54/3d54940e57e662c4dd1f3ff00c78cc64.jpg', 'media/cache/66/88/66883b91f6804b2323c8369331cb7dd1.jpg', 'media/cache/58/46/5846057e28022268153beff6d352b06c.jpg', 'media/cache/be/f4/bef44da28c98f905a3ebec0b87be8530.jpg', 'media/cache/10/48/1048f63d3b5061cd2f424d20b3f9b666.jpg', 'media/cache/5b/88/5b88c52633f53cacf162c15f4f823153.jpg', 'media/cache/94/b1/94b1b8b244bce9677c2f29ccc890d4d2.jpg', 'media/cache/81/c4/81c4a973364e17d01f217e1188253d5e.jpg', 'media/cache/54/60/54607fe8945897cdcced0044103b10b6.jpg', 'media/cache/55/33/553310a7162dfbc2c6d19a84da0df9e1.jpg', 'media/cache/09/a3/09a3aef48557576e1a85ba7efea8ecb7.jpg', 'media/cache/0b/bc/0bbcd0a6f4bcd81ccb1049a52736406e.jpg', 'media/cache/27/a5/27a53d0bb95bdd88288eaf66c9230d7e.jpg']

# %%
images = []
images_items = soup.find_all('img', class_='thumbnail')

for item in images_items:
    image =  item['src']
    images.append('http://books.toscrape.com/' + image) #De esta manera nos da los hipervinculos y podemos almacenar los archivos multimedia
print(images)
# Out:
# ['http://books.toscrape.com/media/cache/2c/da/2cdad67c44b002e7ead0cc35693c0e8b.jpg', 'http://books.toscrape.com/media/cache/26/0c/260c6ae16bce31c8f8c95daddd9f4a1c.jpg', 'http://books.toscrape.com/media/cache/3e/ef/3eef99c9d9adef34639f510662022830.jpg', 'http://books.toscrape.com/media/cache/32/51/3251cf3a3412f53f339e42cac2134093.jpg', 'http://books.toscrape.com/media/cache/be/a5/bea5697f2534a2f86a3ef27b5a8c12a6.jpg', 'http://books.toscrape.com/media/cache/68/33/68339b4c9bc034267e1da611ab3b34f8.jpg', 'http://books.toscrape.com/media/cache/92/27/92274a95b7c251fea59a2b8a78275ab4.jpg', 'http://books.toscrape.com/media/cache/3d/54/3d54940e57e662c4dd1f3ff00c78cc64.jpg', 'http://books.toscrape.com/media/cache/66/88/66883b91f6804b2323c8369331cb7dd1.jpg', 'http://books.toscrape.com/media/cache/58/46/5846057e28022268153beff6d352b06c.jpg', 'http://books.toscrape.com/media/cache/be/f4/bef44da28c98f905a3ebec0b87be8530.jpg', 'http://books.toscrape.com/media/cache/10/48/1048f63d3b5061cd2f424d20b3f9b666.jpg', 'http://books.toscrape.com/media/cache/5b/88/5b88c52633f53cacf162c15f4f823153.jpg', 'http://books.toscrape.com/media/cache/94/b1/94b1b8b244bce9677c2f29ccc890d4d2.jpg', 'http://books.toscrape.com/media/cache/81/c4/81c4a973364e17d01f217e1188253d5e.jpg', 'http://books.toscrape.com/media/cache/54/60/54607fe8945897cdcced0044103b10b6.jpg', 'http://books.toscrape.com/media/cache/55/33/553310a7162dfbc2c6d19a84da0df9e1.jpg', 'http://books.toscrape.com/media/cache/09/a3/09a3aef48557576e1a85ba7efea8ecb7.jpg', 'http://books.toscrape.com/media/cache/0b/bc/0bbcd0a6f4bcd81ccb1049a52736406e.jpg', 'http://books.toscrape.com/media/cache/27/a5/27a53d0bb95bdd88288eaf66c9230d7e.jpg']

# %%
images
# Out:
# ['http://books.toscrape.com/media/cache/2c/da/2cdad67c44b002e7ead0cc35693c0e8b.jpg',
#  'http://books.toscrape.com/media/cache/26/0c/260c6ae16bce31c8f8c95daddd9f4a1c.jpg',
#  'http://books.toscrape.com/media/cache/3e/ef/3eef99c9d9adef34639f510662022830.jpg',
#  'http://books.toscrape.com/media/cache/32/51/3251cf3a3412f53f339e42cac2134093.jpg',
#  'http://books.toscrape.com/media/cache/be/a5/bea5697f2534a2f86a3ef27b5a8c12a6.jpg',
#  'http://books.toscrape.com/media/cache/68/33/68339b4c9bc034267e1da611ab3b34f8.jpg',
#  'http://books.toscrape.com/media/cache/92/27/92274a95b7c251fea59a2b8a78275ab4.jpg',
#  'http://books.toscrape.com/media/cache/3d/54/3d54940e57e662c4dd1f3ff00c78cc64.jpg',
#  'http://books.toscrape.com/media/cache/66/88/66883b91f6804b2323c8369331cb7dd1.jpg',
#  'http://books.toscrape.com/media/cache/58/46/5846057e28022268153beff6d352b06c.jpg',
#  'http://books.toscrape.com/media/cache/be/f4/bef44da28c98f905a3ebec0b87be8530.jpg',
#  'http://books.toscrape.com/media/cache/10/48/1048f63d3b5061cd2f424d20b3f9b666.jpg',
#  'http://books.toscrape.com/media/cache/5b/88/5b88c52633f53cacf162c15f4f823153.jpg',
#  'http://books.toscrape.com/media/cache/94/b1/94b1b8b244bce9677c2f29ccc890d4d2.jpg',
#  'http://books.toscrape.com/media/cache/81/c4/81c4a973364e17d01f217e1188253d5e.jpg',
#  'http://books.toscrape.com/media/cache/54/60/54607fe8945897cdcced0044103b10b6.jpg',
#  'http://books.toscrape.com/media/cache/55/33/553310a7162dfbc2c6d19a84da0df9e1.jpg',
#  'http://books.toscrape.com/media/cache/09/a3/09a3aef48557576e1a85ba7efea8ecb7.jpg',
#  'http://books.toscrape.com/media/cache/0b/bc/0bbcd0a6f4bcd81ccb1049a52736406e.jpg',
#  'http://books.toscrape.com/media/cache/27/a5/27a53d0bb95bdd88288eaf66c9230d7e.jpg']

# %% [markdown]
# paginacion

# %%
import requests

from bs4 import BeautifulSoup

# %%
def obtener_contenido_pagina(url):
    reponse = requests.get(url)
    return reponse.content

# %%
def analizar_contenido_html(html):
    return BeautifulSoup(html, 'html.parser')

# %%
data = []

def procesar_pagina(soup):
    titulos = []
    ratings = []
    existencias = []
    links = []

    titulo_items = soup.find_all('h3')
    for items in titulo_items:
        titulo = items.a
        titulos.append(titulo['title'])
        links.append(titulo['href'])

    rating_items = soup.find_all('p', class_='star-rating')
    for item in rating_items:
        rating = item['class'][1]
        ratings.append(rating)
    
    existencia_items = soup.find_all('p', class_='instock availability')
    for item in existencia_items:
        existencia =  item.text.strip()
        existencias.append(existencia)
    
    for i in range(len(titulos)):
        data.append({
            "titulo":titulos[i],
            "Rating":ratings[i],
            "Existencia":existencias[i]
        })

# %%
def manejar_paginacion(url_base, num_paginas):
    for i in range(1, num_paginas + 1):
        url =  url_base + '/page-' + str(i) + '.html'
        contenido_pagina = obtener_contenido_pagina(url)
        soup = analizar_contenido_html(contenido_pagina)
        procesar_pagina(soup)

# %%
url_base = 'http://books.toscrape.com/catalogue/'

num_paginas = 50

manejar_paginacion(url_base, num_paginas)

# %%
data
# Out:
# [{'titulo': 'A Light in the Attic',
#   'Rating': 'Three',
#   'Existencia': 'In stock'},
#  {'titulo': 'Tipping the Velvet', 'Rating': 'One', 'Existencia': 'In stock'},
#  {'titulo': 'Soumission', 'Rating': 'One', 'Existencia': 'In stock'},
#  {'titulo': 'Sharp Objects', 'Rating': 'Four', 'Existencia': 'In stock'},
#  {'titulo': 'Sapiens: A Brief History of Humankind',
#   'Rating': 'Five',
#   'Existencia': 'In stock'},
#  {'titulo': 'The Requiem Red', 'Rating': 'One', 'Existencia': 'In stock'},
#  {'titulo': 'The Dirty Little Secrets of Getting Your Dream Job',
#   'Rating': 'Four',
#   'Existencia': 'In stock'},
#  {'titulo': 'The Coming Woman: A Novel Based on the Life of the Infamous Feminist, Victoria Woodhull',
#   'Rating': 'Three',
#   'Existencia': 'In stock'},
#  {'titulo': 'The Boys in the Boat: Nine Americans and Their Epic Quest for Gold at the 1936 Berlin Olympics',
#   'Rating': 'Four',
#   'Existencia': 'In stock'},
#  {'titulo': 'The Black Maria', 'Rating': 'One', 'Existencia': 'In stock'},
#  {'titulo': 'Starving Hearts (Triangular Trade Trilogy, #1)',
#   'Rating': 'Two',
#   'Existencia': 'In stock'},
#  {'titulo': "Shakespeare's Sonnets",
#   'Rating': 'Four',
#   'Existencia': 'In stock'},
#  {'titulo': 'Set Me Free', 'Rating': 'Five', 'Existencia': 'In stock'},
#  {'titulo': "Scott Pilgrim's Precious Little Life (Scott Pilgrim #1)",
#   'Rating': 'Five',
#   'Existencia': 'In stock'},
#  {'titulo': 'Rip it Up and Start Again',
#   'Rating': 'Five',
#   'Existencia': 'In stock'},
#  {'titulo': 'Our Band Could Be Your Life: Scenes from the American Indie Underground, 1981-1991',
#   'Rating': 'Three',
#   'Existencia': 'In stock'},
#  {'titulo': 'Olio', 'Rating': 'One', 'Existencia': 'In stock'},
#  {'titulo': 'Mesaerion: The Best Science Fiction Stories 1800-1849',
#   'Rating': 'One',
#   'Existencia': 'In stock'},
#  {'titulo': 'Libertarianism for Beginners',
#   'Rating': 'Two',
#   'Existencia': 'In stock'},
#  {'titulo': "It's Only the Himalayas",
#   'Rating': 'Two',
#   'Existencia': 'In stock'},
#  {'titulo': 'In Her Wake', 'Rating': 'One', 'Existencia': 'In stock'},
#  {'titulo': 'How Music Works', 'Rating': 'Two', 'Existencia': 'In stock'},
#  {'titulo': 'Foolproof Preserving: A Guide to Small Batch Jams, Jellies, Pickles, Condiments, and More: A Foolproof Guide to Making Small Batch Jams, Jellies, Pickles, Condiments, and More',
#   'Rating': 'Three',
#   'Existencia': 'In stock'},
#  {'titulo': 'Chase Me (Paris Nights #2)',
#   'Rating': 'Five',
#   'Existencia': 'In stock'},
#  {'titulo': 'Black Dust', 'Rating': 'Five', 'Existencia': 'In stock'},
#  {'titulo': 'Birdsong: A Story in Pictures',
#   'Rating': 'Three',
#   'Existencia': 'In stock'},
#  {'titulo': "America's Cradle of Quarterbacks: Western Pennsylvania's Football Factory from Johnny Unitas to Joe Montana",
#   'Rating': 'Three',
#   'Existencia': 'In stock'},
#  {'titulo': 'Aladdin and His Wonderful Lamp',
#   'Rating': 'Three',
#   'Existencia': 'In stock'},
#  {'titulo': 'Worlds Elsewhere: Journeys Around Shakespeare’s Globe',
#   'Rating': 'Five',
#   'Existencia': 'In stock'},
#  {'titulo': 'Wall and Piece', 'Rating': 'Four', 'Existencia': 'In stock'},
#  {'titulo': 'The Four Agreements: A Practical Guide to Personal Freedom',
#   'Rating': 'Five',
#   'Existencia': 'In stock'},
#  {'titulo': 'The Five Love Languages: How to Express Heartfelt Commitment to Your Mate',
#   'Rating': 'Three',
#   'Existencia': 'In stock'},
#  {'titulo': 'The Elephant Tree', 'Rating': 'Five', 'Existencia': 'In stock'},
#  {'titulo': 'The Bear and the Piano',
#   'Rating': 'One',
#   'Existencia': 'In stock'},
#  {'titulo': "Sophie's World", 'Rating': 'Five', 'Existencia': 'In stock'},
#  {'titulo': 'Penny Maybe', 'Rating': 'Three', 'Existencia': 'In stock'},
#  {'titulo': 'Maude (1883-1993):She Grew Up with the country',
#   'Rating': 'Two',
#   'Existencia': 'In stock'},
#  {'titulo': 'In a Dark, Dark Wood', 'Rating': 'One', 'Existencia': 'In stock'},
#  {'titulo': 'Behind Closed Doors', 'Rating': 'Four', 'Existencia': 'In stock'},
#  {'titulo': "You can't bury them all: Poems",
#   'Rating': 'Two',
#   'Existencia': 'In stock'},
#  {'titulo': 'Slow States of Collapse: Poems',
#   'Rating': 'Three',
#   'Existencia': 'In stock'},
#  {'titulo': 'Reasons to Stay Alive',
#   'Rating': 'Two',
#   'Existencia': 'In stock'},
#  {'titulo': 'Private Paris (Private #10)',
#   'Rating': 'Five',
#   'Existencia': 'In stock'},
#  {'titulo': '#HigherSelfie: Wake Up Your Life. Free Your Soul. Find Your Tribe.',
#   'Rating': 'Five',
#   'Existencia': 'In stock'},
#  {'titulo': 'Without Borders (Wanderlove #1)',
#   'Rating': 'Two',
#   'Existencia': 'In stock'},
#  {'titulo': 'When We Collided', 'Rating': 'One', 'Existencia': 'In stock'},
#  {'titulo': 'We Love You, Charlie Freeman',
#   'Rating': 'Five',
#   'Existencia': 'In stock'},
#  {'titulo': 'Untitled Collection: Sabbath Poems 2014',
#   'Rating': 'Four',
#   'Existencia': 'In stock'},
#  {'titulo': 'Unseen City: The Majesty of Pigeons, the Discreet Charm of Snails & Other Wonders of the Urban Wilderness',
#   'Rating': 'Four',
#   'Existencia': 'In stock'},
#  {'titulo': 'Unicorn Tracks', 'Rating': 'Three', 'Existencia': 'In stock'},
#  {'titulo': 'Unbound: How Eight Technologies Made Us Human, Transformed Society, and Brought Our World to the Brink',
#   'Rating': 'One',
#   'Existencia': 'In stock'},
#  {'titulo': 'Tsubasa: WoRLD CHRoNiCLE 2 (Tsubasa WoRLD CHRoNiCLE #2)',
#   'Rating': 'One',
#   'Existencia': 'In stock'},
#  {'titulo': 'Throwing Rocks at the Google Bus: How Growth Became the Enemy of Prosperity',
#   'Rating': 'Three',
#   'Existencia': 'In stock'},
#  {'titulo': 'This One Summer', 'Rating': 'Four', 'Existencia': 'In stock'},
#  {'titulo': 'Thirst', 'Rating': 'Five', 'Existencia': 'In stock'},
#  {'titulo': 'The Torch Is Passed: A Harding Family Story',
#   'Rating': 'One',
#   'Existencia': 'In stock'},
#  {'titulo': 'The Secret of Dreadwillow Carse',
#   'Rating': 'One',
#   'Existencia': 'In stock'},
#  {'titulo': 'The Pioneer Woman Cooks: Dinnertime: Comfort Classics, Freezer Food, 16-Minute Meals, and Other Delicious Ways to Solve Supper!',
#   'Rating': 'One',
#   'Existencia': 'In stock'},
#  {'titulo': 'The Past Never Ends', 'Rating': 'Four', 'Existencia': 'In stock'},
#  {'titulo': 'The Natural History of Us (The Fine Art of Pretending #2)',
#   'Rating': 'Three',
#   'Existencia': 'In stock'},
#  {'titulo': 'The Nameless City (The Nameless City #1)',
#   'Rating': 'Four',
#   'Existencia': 'In stock'},
#  {'titulo': 'The Murder That Never Was (Forensic Instincts #5)',
#   'Rating': 'Three',
#   'Existencia': 'In stock'},
#  {'titulo': "The Most Perfect Thing: Inside (and Outside) a Bird's Egg",
#   'Rating': 'Four',
#   'Existencia': 'In stock'},
#  {'titulo': 'The Mindfulness and Acceptance Workbook for Anxiety: A Guide to Breaking Free from Anxiety, Phobias, and Worry Using Acceptance and Commitment Therapy',
#   'Rating': 'Four',
#   'Existencia': 'In stock'},
#  {'titulo': 'The Life-Changing Magic of Tidying Up: The Japanese Art of Decluttering and Organizing',
#   'Rating': 'Three',
#   'Existencia': 'In stock'},
#  {'titulo': 'The Inefficiency Assassin: Time Management Tactics for Working Smarter, Not Longer',
#   'Rating': 'Five',
#   'Existencia': 'In stock'},
#  {'titulo': 'The Gutsy Girl: Escapades for Your Life of Epic Adventure',
#   'Rating': 'One',
#   'Existencia': 'In stock'},
#  {'titulo': 'The Electric Pencil: Drawings from Inside State Hospital No. 3',
#   'Rating': 'One',
#   'Existencia': 'In stock'},
#  {'titulo': 'The Death of Humanity: and the Case for Life',
#   'Rating': 'Four',
#   'Existencia': 'In stock'},
#  {'titulo': 'The Bulletproof Diet: Lose up to a Pound a Day, Reclaim Energy and Focus, Upgrade Your Life',
#   'Rating': 'Three',
#   'Existencia': 'In stock'},
#  {'titulo': 'The Art Forger', 'Rating': 'Three', 'Existencia': 'In stock'},
#  {'titulo': 'The Age of Genius: The Seventeenth Century and the Birth of the Modern Mind',
#   'Rating': 'One',
#   'Existencia': 'In stock'},
#  {'titulo': "The Activist's Tao Te Ching: Ancient Advice for a Modern Revolution",
#   'Rating': 'Five',
#   'Existencia': 'In stock'},
#  {'titulo': 'Spark Joy: An Illustrated Master Class on the Art of Organizing and Tidying Up',
#   'Rating': 'Four',
#   'Existencia': 'In stock'},
#  {'titulo': 'Soul Reader', 'Rating': 'Two', 'Existencia': 'In stock'},
#  {'titulo': 'Security', 'Rating': 'Two', 'Existencia': 'In stock'},
#  {'titulo': 'Saga, Volume 6 (Saga (Collected Editions) #6)',
#   'Rating': 'Three',
#   'Existencia': 'In stock'},
#  {'titulo': 'Saga, Volume 5 (Saga (Collected Editions) #5)',
#   'Rating': 'Two',
#   'Existencia': 'In stock'},
#  {'titulo': 'Reskilling America: Learning to Labor in the Twenty-First Century',
#   'Rating': 'Two',
#   'Existencia': 'In stock'},
#  {'titulo': 'Rat Queens, Vol. 3: Demons (Rat Queens (Collected Editions) #11-15)',
#   'Rating': 'Three',
#   'Existencia': 'In stock'},
#  {'titulo': 'Princess Jellyfish 2-in-1 Omnibus, Vol. 01 (Princess Jellyfish 2-in-1 Omnibus #1)',
#   'Rating': 'Five',
#   'Existencia': 'In stock'},
#  {'titulo': 'Princess Between Worlds (Wide-Awake Princess #5)',
#   'Rating': 'Five',
#   'Existencia': 'In stock'},
#  {'titulo': 'Pop Gun War, Volume 1: Gift',
#   'Rating': 'One',
#   'Existencia': 'In stock'},
#  {'titulo': 'Political Suicide: Missteps, Peccadilloes, Bad Calls, Backroom Hijinx, Sordid Pasts, Rotten Breaks, and Just Plain Dumb Mistakes in the Annals of American Politics',
#   'Rating': 'Two',
#   'Existencia': 'In stock'},
#  {'titulo': 'Patience', 'Rating': 'Three', 'Existencia': 'In stock'},
#  {'titulo': 'Outcast, Vol. 1: A Darkness Surrounds Him (Outcast #1)',
#   'Rating': 'Four',
#   'Existencia': 'In stock'},
#  {'titulo': 'orange: The Complete Collection 1 (orange: The Complete Collection #1)',
#   'Rating': 'One',
#   'Existencia': 'In stock'},
#  {'titulo': 'Online Marketing for Busy Authors: A Step-By-Step Guide',
#   'Rating': 'One',
#   'Existencia': 'In stock'},
#  {'titulo': 'On a Midnight Clear',
#   'Rating': 'Three',
#   'Existencia': 'In stock'},
#  {'titulo': 'Obsidian (Lux #1)', 'Rating': 'Two', 'Existencia': 'In stock'},
#  {'titulo': 'My Paris Kitchen: Recipes and Stories',
#   'Rating': 'Two',
#   'Existencia': 'In stock'},
#  {'titulo': 'Masks and Shadows', 'Rating': 'Two', 'Existencia': 'In stock'},
#  {'titulo': 'Mama Tried: Traditional Italian Cooking for the Screwed, Crude, Vegan, and Tattooed',
#   'Rating': 'Four',
#   'Existencia': 'In stock'},
#  {'titulo': 'Lumberjanes, Vol. 2: Friendship to the Max (Lumberjanes #5-8)',
#   'Rating': 'Two',
#   'Existencia': 'In stock'},
#  {'titulo': 'Lumberjanes, Vol. 1: Beware the Kitten Holy (Lumberjanes #1-4)',
#   'Rating': 'Three',
#   'Existencia': 'In stock'},
#  {'titulo': 'Lumberjanes Vol. 3: A Terrible Plan (Lumberjanes #9-12)',
#   'Rating': 'Two',
#   'Existencia': 'In stock'},
#  {'titulo': 'Layered: Baking, Building, and Styling Spectacular Cakes',
#   'Rating': 'One',
#   'Existencia': 'In stock'},
#  {'titulo': 'Judo: Seven Steps to Black Belt (an Introductory Guide for Beginners)',
#   'Rating': 'Two',
#   'Existencia': 'In stock'},
#  {'titulo': 'Join', 'Rating': 'Five', 'Existencia': 'In stock'},
#  {'titulo': 'In the Country We Love: My Family Divided',
#   'Rating': 'Four',
#   'Existencia': 'In stock'},
#  {'titulo': 'Immunity: How Elie Metchnikoff Changed the Course of Modern Medicine',
#   'Rating': 'Five',
#   'Existencia': 'In stock'},
#  {'titulo': 'I Hate Fairyland, Vol. 1: Madly Ever After (I Hate Fairyland (Compilations) #1-5)',
#   'Rating': 'Two',
#   'Existencia': 'In stock'},
#  {'titulo': 'I am a Hero Omnibus Volume 1',
#   'Rating': 'Three',
#   'Existencia': 'In stock'},
#  {'titulo': 'How to Be Miserable: 40 Strategies You Already Use',
#   'Rating': 'One',
#   'Existencia': 'In stock'},
#  {'titulo': 'Her Backup Boyfriend (The Sorensen Family #1)',
#   'Rating': 'One',
#   'Existencia': 'In stock'},
#  {'titulo': 'Giant Days, Vol. 2 (Giant Days #5-8)',
#   'Rating': 'Two',
#   'Existencia': 'In stock'},
#  {'titulo': 'Forever and Forever: The Courtship of Henry Longfellow and Fanny Appleton',
#   'Rating': 'Three',
#   'Existencia': 'In stock'},
#  {'titulo': 'First and First (Five Boroughs #3)',
#   'Rating': 'Four',
#   'Existencia': 'In stock'},
#  {'titulo': 'Fifty Shades Darker (Fifty Shades #2)',
#   'Rating': 'One',
#   'Existencia': 'In stock'},
#  {'titulo': 'Everydata: The Misinformation Hidden in the Little Data You Consume Every Day',
#   'Rating': 'Two',
#   'Existencia': 'In stock'},
#  {'titulo': "Don't Be a Jerk: And Other Practical Advice from Dogen, Japan's Greatest Zen Master",
#   'Rating': 'Two',
#   'Existencia': 'In stock'},
#  {'titulo': 'Danganronpa Volume 1',
#   'Rating': 'Four',
#   'Existencia': 'In stock'},
#  {'titulo': 'Crown of Midnight (Throne of Glass #2)',
#   'Rating': 'Three',
#   'Existencia': 'In stock'},
#  {'titulo': 'Codename Baboushka, Volume 1: The Conclave of Death',
#   'Rating': 'Four',
#   'Existencia': 'In stock'},
#  {'titulo': 'Camp Midnight', 'Rating': 'Four', 'Existencia': 'In stock'},
#  {'titulo': 'Call the Nurse: True Stories of a Country Nurse on a Scottish Isle',
#   'Rating': 'Five',
#   'Existencia': 'In stock'},
#  {'titulo': 'Burning', 'Rating': 'Three', 'Existencia': 'In stock'},
#  {'titulo': 'Bossypants', 'Rating': 'Two', 'Existencia': 'In stock'},
#  {'titulo': 'Bitch Planet, Vol. 1: Extraordinary Machine (Bitch Planet (Collected Editions))',
#   'Rating': 'Two',
#   'Existencia': 'In stock'},
#  {'titulo': 'Avatar: The Last Airbender: Smoke and Shadow, Part 3 (Smoke and Shadow #3)',
#   'Rating': 'Two',
#   'Existencia': 'In stock'},
#  {'titulo': 'Algorithms to Live By: The Computer Science of Human Decisions',
#   'Rating': 'One',
#   'Existencia': 'In stock'},
#  {'titulo': 'A World of Flavor: Your Gluten Free Passport',
#   'Rating': 'One',
#   'Existencia': 'In stock'},
#  {'titulo': 'A Piece of Sky, a Grain of Rice: A Memoir in Four Meditations',
#   'Rating': 'Five',
#   'Existencia': 'In stock'},
#  {'titulo': 'A Murder in Time', 'Rating': 'One', 'Existencia': 'In stock'},
#  {'titulo': 'A Flight of Arrows (The Pathfinders #2)',
#   'Rating': 'Five',
#   'Existencia': 'In stock'},
#  {'titulo': 'A Fierce and Subtle Poison',
#   'Rating': 'Four',
#   'Existencia': 'In stock'},
#  {'titulo': 'A Court of Thorns and Roses (A Court of Thorns and Roses #1)',
#   'Rating': 'One',
#   'Existencia': 'In stock'},
#  {'titulo': '(Un)Qualified: How God Uses Broken People to Do Big Things',
#   'Rating': 'Five',
#   'Existencia': 'In stock'},
#  {'titulo': 'You Are What You Love: The Spiritual Power of Habit',
#   'Rating': 'Four',
#   'Existencia': 'In stock'},
#  {'titulo': "William Shakespeare's Star Wars: Verily, A New Hope (William Shakespeare's Star Wars #4)",
#   'Rating': 'Four',
#   'Existencia': 'In stock'},
#  {'titulo': 'Tuesday Nights in 1980',
#   'Rating': 'Two',
#   'Existencia': 'In stock'},
#  {'titulo': 'Tracing Numbers on a Train',
#   'Rating': 'Three',
#   'Existencia': 'In stock'},
#  {'titulo': 'Throne of Glass (Throne of Glass #1)',
#   'Rating': 'Three',
#   'Existencia': 'In stock'},
#  {'titulo': 'Thomas Jefferson and the Tripoli Pirates: The Forgotten War That Changed American History',
#   'Rating': 'One',
#   'Existencia': 'In stock'},
#  {'titulo': 'Thirteen Reasons Why', 'Rating': 'One', 'Existencia': 'In stock'},
#  {'titulo': 'The White Cat and the Monk: A Retelling of the Poem “Pangur Bán”',
#   'Rating': 'Four',
#   'Existencia': 'In stock'},
#  {'titulo': 'The Wedding Dress', 'Rating': 'One', 'Existencia': 'In stock'},
#  {'titulo': 'The Vacationers', 'Rating': 'Four', 'Existencia': 'In stock'},
#  {'titulo': 'The Third Wave: An Entrepreneur’s Vision of the Future',
#   'Rating': 'Five',
#   'Existencia': 'In stock'},
#  {'titulo': 'The Stranger', 'Rating': 'Four', 'Existencia': 'In stock'},
#  {'titulo': 'The Shadow Hero (The Shadow Hero)',
#   'Rating': 'One',
#   'Existencia': 'In stock'},
#  {'titulo': 'The Secret (The Secret #1)',
#   'Rating': 'Four',
#   'Existencia': 'In stock'},
#  {'titulo': 'The Regional Office Is Under Attack!',
#   'Rating': 'Five',
#   'Existencia': 'In stock'},
#  {'titulo': 'The Psychopath Test: A Journey Through the Madness Industry',
#   'Rating': 'Two',
#   'Existencia': 'In stock'},
#  {'titulo': 'The Project', 'Rating': 'One', 'Existencia': 'In stock'},
#  {'titulo': 'The Power of Now: A Guide to Spiritual Enlightenment',
#   'Rating': 'Two',
#   'Existencia': 'In stock'},
#  {'titulo': "The Omnivore's Dilemma: A Natural History of Four Meals",
#   'Rating': 'Two',
#   'Existencia': 'In stock'},
#  {'titulo': 'The Nerdy Nummies Cookbook: Sweet Treats for the Geek in All of Us',
#   'Rating': 'Five',
#   'Existencia': 'In stock'},
#  {'titulo': 'The Murder of Roger Ackroyd (Hercule Poirot #4)',
#   'Rating': 'Four',
#   'Existencia': 'In stock'},
#  {'titulo': 'The Mistake (Off-Campus #2)',
#   'Rating': 'Three',
#   'Existencia': 'In stock'},
#  {'titulo': "The Matchmaker's Playbook (Wingmen Inc. #1)",
#   'Rating': 'One',
#   'Existencia': 'In stock'},
#  {'titulo': 'The Love and Lemons Cookbook: An Apple-to-Zucchini Celebration of Impromptu Cooking',
#   'Rating': 'Two',
#   'Existencia': 'In stock'},
#  {'titulo': 'The Long Shadow of Small Ghosts: Murder and Memory in an American City',
#   'Rating': 'One',
#   'Existencia': 'In stock'},
#  {'titulo': 'The Kite Runner', 'Rating': 'Four', 'Existencia': 'In stock'},
#  {'titulo': 'The House by the Lake',
#   'Rating': 'One',
#   'Existencia': 'In stock'},
#  {'titulo': 'The Glittering Court (The Glittering Court #1)',
#   'Rating': 'One',
#   'Existencia': 'In stock'},
#  {'titulo': 'The Girl on the Train',
#   'Rating': 'Two',
#   'Existencia': 'In stock'},
#  {'titulo': 'The Genius of Birds', 'Rating': 'One', 'Existencia': 'In stock'},
#  {'titulo': 'The Emerald Mystery', 'Rating': 'Two', 'Existencia': 'In stock'},
#  {'titulo': 'The Cookies & Cups Cookbook: 125+ sweet & savory recipes reminding you to Always Eat Dessert First',
#   'Rating': 'One',
#   'Existencia': 'In stock'},
#  {'titulo': "The Bridge to Consciousness: I'm Writing the Bridge Between Science and Our Old and New Beliefs.",
#   'Rating': 'Three',
#   'Existencia': 'In stock'},
#  {'titulo': "The Artist's Way: A Spiritual Path to Higher Creativity",
#   'Rating': 'Five',
#   'Existencia': 'In stock'},
#  {'titulo': 'The Art of War', 'Rating': 'Five', 'Existencia': 'In stock'},
#  {'titulo': 'The Argonauts', 'Rating': 'Two', 'Existencia': 'In stock'},
#  {'titulo': 'The 10% Entrepreneur: Live Your Startup Dream Without Quitting Your Day Job',
#   'Rating': 'Three',
#   'Existencia': 'In stock'},
#  {'titulo': 'Suddenly in Love (Lake Haven #1)',
#   'Rating': 'Two',
#   'Existencia': 'In stock'},
#  {'titulo': 'Something More Than This',
#   'Rating': 'Four',
#   'Existencia': 'In stock'},
#  {'titulo': 'Soft Apocalypse', 'Rating': 'Two', 'Existencia': 'In stock'},
#  {'titulo': "So You've Been Publicly Shamed",
#   'Rating': 'Two',
#   'Existencia': 'In stock'},
#  {'titulo': 'Shoe Dog: A Memoir by the Creator of NIKE',
#   'Rating': 'Two',
#   'Existencia': 'In stock'},
#  {'titulo': 'Shobu Samurai, Project Aryoku (#3)',
#   'Rating': 'Three',
#   'Existencia': 'In stock'},
#  {'titulo': 'Secrets and Lace (Fatal Hearts #1)',
#   'Rating': 'One',
#   'Existencia': 'In stock'},
#  {'titulo': 'Scarlett Epstein Hates It Here',
#   'Rating': 'Five',
#   'Existencia': 'In stock'},
#  {'titulo': 'Romero and Juliet: A Tragic Tale of Love and Zombies',
#   'Rating': 'One',
#   'Existencia': 'In stock'},
#  {'titulo': 'Redeeming Love', 'Rating': 'Five', 'Existencia': 'In stock'},
#  {'titulo': 'Poses for Artists Volume 1 - Dynamic and Sitting Poses: An Essential Reference for Figure Drawing and the Human Form',
#   'Rating': 'One',
#   'Existencia': 'In stock'},
#  {'titulo': 'Poems That Make Grown Women Cry',
#   'Rating': 'Four',
#   'Existencia': 'In stock'},
#  {'titulo': 'Nightingale, Sing', 'Rating': 'One', 'Existencia': 'In stock'},
#  {'titulo': 'Night Sky with Exit Wounds',
#   'Rating': 'One',
#   'Existencia': 'In stock'},
#  {'titulo': 'Mrs. Houdini', 'Rating': 'Five', 'Existencia': 'In stock'},
#  {'titulo': 'Modern Romance', 'Rating': 'Five', 'Existencia': 'In stock'},
#  {'titulo': 'Miss Peregrine’s Home for Peculiar Children (Miss Peregrine’s Peculiar Children #1)',
#   'Rating': 'One',
#   'Existencia': 'In stock'},
#  {'titulo': 'Louisa: The Extraordinary Life of Mrs. Adams',
#   'Rating': 'Two',
#   'Existencia': 'In stock'},
#  {'titulo': 'Little Red', 'Rating': 'Three', 'Existencia': 'In stock'},
#  {'titulo': 'Library of Souls (Miss Peregrine’s Peculiar Children #3)',
#   'Rating': 'Five',
#   'Existencia': 'In stock'},
#  {'titulo': 'Large Print Heart of the Pride',
#   'Rating': 'Two',
#   'Existencia': 'In stock'},
#  {'titulo': 'I Had a Nice Time And Other Lies...: How to find love & sh*t like that',
#   'Rating': 'Four',
#   'Existencia': 'In stock'},
#  {'titulo': 'Hollow City (Miss Peregrine’s Peculiar Children #2)',
#   'Rating': 'One',
#   'Existencia': 'In stock'},
#  {'titulo': 'Grumbles', 'Rating': 'Two', 'Existencia': 'In stock'},
#  {'titulo': 'Full Moon over Noah’s Ark: An Odyssey to Mount Ararat and Beyond',
#   'Rating': 'Four',
#   'Existencia': 'In stock'},
#  {'titulo': 'Frostbite (Vampire Academy #2)',
#   'Rating': 'Five',
#   'Existencia': 'In stock'},
#  {'titulo': 'Follow You Home', 'Rating': 'One', 'Existencia': 'In stock'},
#  {'titulo': 'First Steps for New Christians (Print Edition)',
#   'Rating': 'One',
#   'Existencia': 'In stock'},
#  {'titulo': 'Finders Keepers (Bill Hodges Trilogy #2)',
#   'Rating': 'Five',
#   'Existencia': 'In stock'},
#  {'titulo': 'Fables, Vol. 1: Legends in Exile (Fables #1)',
#   'Rating': 'Four',
#   'Existencia': 'In stock'},
#  {'titulo': 'Eureka Trivia 6.0', 'Rating': 'Four', 'Existencia': 'In stock'},
#  {'titulo': 'Drive: The Surprising Truth About What Motivates Us',
#   'Rating': 'Four',
#   'Existencia': 'In stock'},
#  {'titulo': 'Done Rubbed Out (Reightman & Bailey #1)',
#   'Rating': 'Five',
#   'Existencia': 'In stock'},
#  {'titulo': 'Doing It Over (Most Likely To #1)',
#   'Rating': 'Three',
#   'Existencia': 'In stock'},
#  {'titulo': 'Deliciously Ella Every Day: Quick and Easy Recipes for Gluten-Free Snacks, Packed Lunches, and Simple Meals',
#   'Rating': 'Three',
#   'Existencia': 'In stock'},
#  {'titulo': 'Dark Notes', 'Rating': 'Five', 'Existencia': 'In stock'},
#  {'titulo': 'Daring Greatly: How the Courage to Be Vulnerable Transforms the Way We Live, Love, Parent, and Lead',
#   'Rating': 'Three',
#   'Existencia': 'In stock'},
#  {'titulo': 'Close to You', 'Rating': 'Four', 'Existencia': 'In stock'},
#  {'titulo': 'Chasing Heaven: What Dying Taught Me About Living',
#   'Rating': 'Two',
#   'Existencia': 'In stock'},
#  {'titulo': 'Big Magic: Creative Living Beyond Fear',
#   'Rating': 'Three',
#   'Existencia': 'In stock'},
#  {'titulo': 'Becoming Wise: An Inquiry into the Mystery and Art of Living',
#   'Rating': 'Two',
#   'Existencia': 'In stock'},
#  {'titulo': 'Beauty Restored (Riley Family Legacy Novellas #3)',
#   'Rating': 'Two',
#   'Existencia': 'In stock'},
#  {'titulo': 'Batman: The Long Halloween (Batman)',
#   'Rating': 'Two',
#   'Existencia': 'In stock'},
#  {'titulo': 'Batman: The Dark Knight Returns (Batman)',
#   'Rating': 'Five',
#   'Existencia': 'In stock'},
#  {'titulo': "Ayumi's Violin", 'Rating': 'Two', 'Existencia': 'In stock'},
#  {'titulo': 'Anonymous', 'Rating': 'Four', 'Existencia': 'In stock'},
#  {'titulo': 'Amy Meets the Saints and Sages',
#   'Rating': 'Three',
#   'Existencia': 'In stock'},
#  {'titulo': 'Amid the Chaos', 'Rating': 'One', 'Existencia': 'In stock'},
#  {'titulo': 'Amatus', 'Rating': 'Five', 'Existencia': 'In stock'},
#  {'titulo': 'Agnostic: A Spirited Manifesto',
#   'Rating': 'Five',
#   'Existencia': 'In stock'},
#  {'titulo': 'Zealot: The Life and Times of Jesus of Nazareth',
#   'Rating': 'Three',
#   'Existencia': 'In stock'},
#  {'titulo': 'You (You #1)', 'Rating': 'Five', 'Existencia': 'In stock'},
#  {'titulo': 'Wonder Woman: Earth One, Volume One (Wonder Woman: Earth One #1)',
#   'Rating': 'Four',
#   'Existencia': 'In stock'},
#  {'titulo': 'Wild Swans', 'Rating': 'Two', 'Existencia': 'In stock'},
#  {'titulo': 'Why the Right Went Wrong: Conservatism--From Goldwater to the Tea Party and Beyond',
#   'Rating': 'Four',
#   'Existencia': 'In stock'},
#  {'titulo': 'Whole Lotta Creativity Going On: 60 Fun and Unusual Exercises to Awaken and Strengthen Your Creativity',
#   'Rating': 'Four',
#   'Existencia': 'In stock'},
#  {'titulo': "What's It Like in Space?: Stories from Astronauts Who've Been There",
#   'Rating': 'Two',
#   'Existencia': 'In stock'},
#  {'titulo': 'We Are Robin, Vol. 1: The Vigilante Business (We Are Robin #1)',
#   'Rating': 'One',
#   'Existencia': 'In stock'},
#  {'titulo': "Walt Disney's Alice in Wonderland",
#   'Rating': 'Five',
#   'Existencia': 'In stock'},
#  {'titulo': 'V for Vendetta (V for Vendetta Complete)',
#   'Rating': 'Four',
#   'Existencia': 'In stock'},
#  {'titulo': 'Until Friday Night (The Field Party #1)',
#   'Rating': 'Two',
#   'Existencia': 'In stock'},
#  {'titulo': 'Unbroken: A World War II Story of Survival, Resilience, and Redemption',
#   'Rating': 'Two',
#   'Existencia': 'In stock'},
#  {'titulo': 'Twenty Yawns', 'Rating': 'Two', 'Existencia': 'In stock'},
#  {'titulo': 'Through the Woods', 'Rating': 'Two', 'Existencia': 'In stock'},
#  {'titulo': 'This Is Where It Ends',
#   'Rating': 'Two',
#   'Existencia': 'In stock'},
#  {'titulo': 'The Year of Magical Thinking',
#   'Rating': 'Two',
#   'Existencia': 'In stock'},
#  {'titulo': 'The Wright Brothers', 'Rating': 'Four', 'Existencia': 'In stock'},
#  {'titulo': "The White Queen (The Cousins' War #1)",
#   'Rating': 'Five',
#   'Existencia': 'In stock'},
#  {'titulo': "The Wedding Pact (The O'Malleys #2)",
#   'Rating': 'Three',
#   'Existencia': 'In stock'},
#  {'titulo': 'The Time Keeper', 'Rating': 'Five', 'Existencia': 'In stock'},
#  {'titulo': 'The Testament of Mary',
#   'Rating': 'Four',
#   'Existencia': 'In stock'},
#  {'titulo': 'The Star-Touched Queen',
#   'Rating': 'Five',
#   'Existencia': 'In stock'},
#  {'titulo': 'The Songs of the Gods',
#   'Rating': 'Five',
#   'Existencia': 'In stock'},
#  {'titulo': 'The Song of Achilles',
#   'Rating': 'Five',
#   'Existencia': 'In stock'},
#  {'titulo': 'The Rosie Project (Don Tillman #1)',
#   'Rating': 'One',
#   'Existencia': 'In stock'},
#  {'titulo': 'The Power of Habit: Why We Do What We Do in Life and Business',
#   'Rating': 'Three',
#   'Existencia': 'In stock'},
#  {'titulo': 'The Marriage of Opposites',
#   'Rating': 'Four',
#   'Existencia': 'In stock'},
#  {'titulo': 'The Lucifer Effect: Understanding How Good People Turn Evil',
#   'Rating': 'One',
#   'Existencia': 'In stock'},
#  {'titulo': 'The Long Haul (Diary of a Wimpy Kid #9)',
#   'Rating': 'One',
#   'Existencia': 'In stock'},
#  {'titulo': 'The Loney', 'Rating': 'One', 'Existencia': 'In stock'},
#  {'titulo': 'The Literature Book (Big Ideas Simply Explained)',
#   'Rating': 'Three',
#   'Existencia': 'In stock'},
#  {'titulo': 'The Last Mile (Amos Decker #2)',
#   'Rating': 'Two',
#   'Existencia': 'In stock'},
#  {'titulo': 'The Immortal Life of Henrietta Lacks',
#   'Rating': 'Two',
#   'Existencia': 'In stock'},
#  {'titulo': 'The Hidden Oracle (The Trials of Apollo #1)',
#   'Rating': 'Two',
#   'Existencia': 'In stock'},
#  {'titulo': 'The Help Yourself Cookbook for Kids: 60 Easy Plant-Based Recipes Kids Can Make to Stay Healthy and Save the Earth',
#   'Rating': 'Three',
#   'Existencia': 'In stock'},
#  {'titulo': 'The Guilty (Will Robie #4)',
#   'Rating': 'Two',
#   'Existencia': 'In stock'},
#  {'titulo': 'The First Hostage (J.B. Collins #2)',
#   'Rating': 'Three',
#   'Existencia': 'In stock'},
#  {'titulo': 'The Dovekeepers', 'Rating': 'One', 'Existencia': 'In stock'},
#  {'titulo': 'The Darkest Lie', 'Rating': 'Five', 'Existencia': 'In stock'},
#  {'titulo': 'The Bane Chronicles (The Bane Chronicles #1-11)',
#   'Rating': 'Four',
#   'Existencia': 'In stock'},
#  {'titulo': 'The Bad-Ass Librarians of Timbuktu: And Their Race to Save the World’s Most Precious Manuscripts',
#   'Rating': 'One',
#   'Existencia': 'In stock'},
#  {'titulo': 'The 14th Colony (Cotton Malone #11)',
#   'Rating': 'One',
#   'Existencia': 'In stock'},
#  {'titulo': 'That Darkness (Gardiner and Renner #1)',
#   'Rating': 'One',
#   'Existencia': 'In stock'},
#  {'titulo': 'Tastes Like Fear (DI Marnie Rome #3)',
#   'Rating': 'One',
#   'Existencia': 'In stock'},
#  {'titulo': 'Take Me with You', 'Rating': 'Three', 'Existencia': 'In stock'},
#  {'titulo': 'Swell: A Year of Waves',
#   'Rating': 'One',
#   'Existencia': 'In stock'},
#  {'titulo': 'Superman Vol. 1: Before Truth (Superman by Gene Luen Yang #1)',
#   'Rating': 'Five',
#   'Existencia': 'In stock'},
#  {'titulo': 'Still Life with Bread Crumbs',
#   'Rating': 'Three',
#   'Existencia': 'In stock'},
#  {'titulo': 'Steve Jobs', 'Rating': 'Five', 'Existencia': 'In stock'},
#  {'titulo': 'Sorting the Beef from the Bull: The Science of Food Fraud Forensics',
#   'Rating': 'Four',
#   'Existencia': 'In stock'},
#  {'titulo': 'Someone Like You (The Harrisons #2)',
#   'Rating': 'Five',
#   'Existencia': 'In stock'},
#  {'titulo': 'So Cute It Hurts!!, Vol. 6 (So Cute It Hurts!! #6)',
#   'Rating': 'Four',
#   'Existencia': 'In stock'},
#  {'titulo': 'Shtum', 'Rating': 'Four', 'Existencia': 'In stock'},
#  {'titulo': 'See America: A Celebration of Our National Parks & Treasured Sites',
#   'Rating': 'Three',
#   'Existencia': 'In stock'},
#  {'titulo': 'salt.', 'Rating': 'Four', 'Existencia': 'In stock'},
#  {'titulo': 'Robin War', 'Rating': 'Three', 'Existencia': 'In stock'},
#  {'titulo': 'Red Hood/Arsenal, Vol. 1: Open for Business (Red Hood/Arsenal #1)',
#   'Rating': 'Two',
#   'Existencia': 'In stock'},
#  {'titulo': 'Rain Fish', 'Rating': 'Three', 'Existencia': 'In stock'},
#  {'titulo': 'Quarter Life Poetry: Poems for the Young, Broke and Hangry',
#   'Rating': 'Five',
#   'Existencia': 'In stock'},
#  {'titulo': 'Pet Sematary', 'Rating': 'Three', 'Existencia': 'In stock'},
#  {'titulo': 'Overload: How to Unplug, Unwind, and Unleash Yourself from the Pressure of Stress',
#   'Rating': 'Three',
#   'Existencia': 'In stock'},
#  {'titulo': 'Once Was a Time', 'Rating': 'Two', 'Existencia': 'In stock'},
#  {'titulo': 'Old School (Diary of a Wimpy Kid #10)',
#   'Rating': 'Five',
#   'Existencia': 'In stock'},
#  {'titulo': 'No Dream Is Too High: Life Lessons From a Man Who Walked on the Moon',
#   'Rating': 'Two',
#   'Existencia': 'In stock'},
#  {'titulo': 'Naruto (3-in-1 Edition), Vol. 14: Includes Vols. 40, 41 & 42 (Naruto: Omnibus #14)',
#   'Rating': 'Two',
#   'Existencia': 'In stock'},
#  {'titulo': 'My Name Is Lucy Barton',
#   'Rating': 'One',
#   'Existencia': 'In stock'},
#  {'titulo': 'My Mrs. Brown', 'Rating': 'Three', 'Existencia': 'In stock'},
#  {'titulo': 'My Kind of Crazy', 'Rating': 'One', 'Existencia': 'In stock'},
#  {'titulo': 'Mr. Mercedes (Bill Hodges Trilogy #1)',
#   'Rating': 'One',
#   'Existencia': 'In stock'},
#  {'titulo': 'More Than Music (Chasing the Dream #1)',
#   'Rating': 'Two',
#   'Existencia': 'In stock'},
#  {'titulo': 'Made to Stick: Why Some Ideas Survive and Others Die',
#   'Rating': 'Five',
#   'Existencia': 'In stock'},
#  {'titulo': 'Luis Paints the World',
#   'Rating': 'Three',
#   'Existencia': 'In stock'},
#  {'titulo': 'Luckiest Girl Alive',
#   'Rating': 'Three',
#   'Existencia': 'In stock'},
#  {'titulo': 'Lowriders to the Center of the Earth (Lowriders in Space #2)',
#   'Rating': 'Two',
#   'Existencia': 'In stock'},
#  {'titulo': 'Love Is a Mix Tape (Music #1)',
#   'Rating': 'One',
#   'Existencia': 'In stock'},
#  {'titulo': 'Looking for Lovely: Collecting the Moments that Matter',
#   'Rating': 'Five',
#   'Existencia': 'In stock'},
#  {'titulo': 'Living Leadership by Insight: A Good Leader Achieves, a Great Leader Builds Monuments',
#   'Rating': 'Four',
#   'Existencia': 'In stock'},
#  {'titulo': 'Let It Out: A Journey Through Journaling',
#   'Rating': 'Five',
#   'Existencia': 'In stock'},
#  {'titulo': 'Lady Midnight (The Dark Artifices #1)',
#   'Rating': 'Five',
#   'Existencia': 'In stock'},
#  {'titulo': "It's All Easy: Healthy, Delicious Weeknight Meals in under 30 Minutes",
#   'Rating': 'One',
#   'Existencia': 'In stock'},
#  {'titulo': 'Island of Dragons (Unwanteds #7)',
#   'Rating': 'One',
#   'Existencia': 'In stock'},
#  {'titulo': "I Know What I'm Doing -- and Other Lies I Tell Myself: Dispatches from a Life Under Construction",
#   'Rating': 'Four',
#   'Existencia': 'In stock'},
#  {'titulo': 'I Am Pilgrim (Pilgrim #1)',
#   'Rating': 'Four',
#   'Existencia': 'In stock'},
#  {'titulo': 'Hyperbole and a Half: Unfortunate Situations, Flawed Coping Mechanisms, Mayhem, and Other Things That Happened',
#   'Rating': 'Five',
#   'Existencia': 'In stock'},
#  {'titulo': 'Hush, Hush (Hush, Hush #1)',
#   'Rating': 'Three',
#   'Existencia': 'In stock'},
#  {'titulo': 'Hold Your Breath (Search and Rescue #1)',
#   'Rating': 'One',
#   'Existencia': 'In stock'},
#  {'titulo': 'Hamilton: The Revolution',
#   'Rating': 'Three',
#   'Existencia': 'In stock'},
#  {'titulo': 'Greek Mythic History',
#   'Rating': 'Five',
#   'Existencia': 'In stock'},
#  {'titulo': 'God: The Most Unpleasant Character in All Fiction',
#   'Rating': 'Five',
#   'Existencia': 'In stock'},
#  {'titulo': 'Glory over Everything: Beyond The Kitchen House',
#   'Rating': 'Three',
#   'Existencia': 'In stock'},
#  {'titulo': 'Feathers: Displays of Brilliant Plumage',
#   'Rating': 'Three',
#   'Existencia': 'In stock'},
#  {'titulo': 'Far & Away: Places on the Brink of Change: Seven Continents, Twenty-Five Years',
#   'Rating': 'Four',
#   'Existencia': 'In stock'},
#  {'titulo': 'Every Last Word', 'Rating': 'Three', 'Existencia': 'In stock'},
#  {'titulo': 'Eligible (The Austen Project #4)',
#   'Rating': 'Three',
#   'Existencia': 'In stock'},
#  {'titulo': 'El Deafo', 'Rating': 'Five', 'Existencia': 'In stock'},
#  {'titulo': 'Eight Hundred Grapes',
#   'Rating': 'Four',
#   'Existencia': 'In stock'},
#  {'titulo': 'Eaternity: More than 150 Deliciously Easy Vegan Recipes for a Long, Healthy, Satisfied, Joyful Life',
#   'Rating': 'Five',
#   'Existencia': 'In stock'},
#  {'titulo': 'Eat Fat, Get Thin', 'Rating': 'Two', 'Existencia': 'In stock'},
#  {'titulo': "Don't Get Caught", 'Rating': 'One', 'Existencia': 'In stock'},
#  {'titulo': 'Doctor Sleep (The Shining #2)',
#   'Rating': 'Two',
#   'Existencia': 'In stock'},
#  {'titulo': 'Demigods & Magicians: Percy and Annabeth Meet the Kanes (Percy Jackson & Kane Chronicles Crossover #1-3)',
#   'Rating': 'Five',
#   'Existencia': 'In stock'},
#  {'titulo': 'Dear Mr. Knightley', 'Rating': 'Five', 'Existencia': 'In stock'},
#  {'titulo': 'Daily Fantasy Sports', 'Rating': 'One', 'Existencia': 'In stock'},
#  {'titulo': 'Crazy Love: Overwhelmed by a Relentless God',
#   'Rating': 'Two',
#   'Existencia': 'In stock'},
#  {'titulo': 'Cometh the Hour (The Clifton Chronicles #6)',
#   'Rating': 'Three',
#   'Existencia': 'In stock'},
#  {'titulo': 'Code Name Verity (Code Name Verity #1)',
#   'Rating': 'Four',
#   'Existencia': 'In stock'},
#  {'titulo': 'Clockwork Angel (The Infernal Devices #1)',
#   'Rating': 'One',
#   'Existencia': 'In stock'},
#  {'titulo': 'City of Glass (The Mortal Instruments #3)',
#   'Rating': 'Four',
#   'Existencia': 'In stock'},
#  {'titulo': 'City of Fallen Angels (The Mortal Instruments #4)',
#   'Rating': 'Four',
#   'Existencia': 'In stock'},
#  {'titulo': 'City of Bones (The Mortal Instruments #1)',
#   'Rating': 'One',
#   'Existencia': 'In stock'},
#  {'titulo': 'City of Ashes (The Mortal Instruments #2)',
#   'Rating': 'One',
#   'Existencia': 'In stock'},
#  {'titulo': 'Cell', 'Rating': 'Four', 'Existencia': 'In stock'},
#  {'titulo': 'Catching Jordan (Hundred Oaks)',
#   'Rating': 'Three',
#   'Existencia': 'In stock'},
#  {'titulo': 'Carry On, Warrior: Thoughts on Life Unarmed',
#   'Rating': 'Three',
#   'Existencia': 'In stock'},
#  {'titulo': 'Carrie', 'Rating': 'Two', 'Existencia': 'In stock'},
#  {'titulo': 'Buying In: The Secret Dialogue Between What We Buy and Who We Are',
#   'Rating': 'Four',
#   'Existencia': 'In stock'},
#  {'titulo': 'Brain on Fire: My Month of Madness',
#   'Rating': 'Five',
#   'Existencia': 'In stock'},
#  {'titulo': 'Batman: Europa', 'Rating': 'Two', 'Existencia': 'In stock'},
#  {'titulo': 'Barefoot Contessa Back to Basics',
#   'Rating': 'One',
#   'Existencia': 'In stock'},
#  {'titulo': "Barefoot Contessa at Home: Everyday Recipes You'll Make Over and Over Again",
#   'Rating': 'Five',
#   'Existencia': 'In stock'},
#  {'titulo': 'Balloon Animals', 'Rating': 'Three', 'Existencia': 'In stock'},
#  {'titulo': 'Art Ops Vol. 1', 'Rating': 'Three', 'Existencia': 'In stock'},
#  {'titulo': 'Aristotle and Dante Discover the Secrets of the Universe (Aristotle and Dante Discover the Secrets of the Universe #1)',
#   'Rating': 'Four',
#   'Existencia': 'In stock'},
#  {'titulo': 'Angels Walking (Angels Walking #1)',
#   'Rating': 'Two',
#   'Existencia': 'In stock'},
#  {'titulo': 'Angels & Demons (Robert Langdon #1)',
#   'Rating': 'Three',
#   'Existencia': 'In stock'},
#  {'titulo': 'All the Light We Cannot See',
#   'Rating': 'Five',
#   'Existencia': 'In stock'},
#  {'titulo': 'Adulthood Is a Myth: A "Sarah\'s Scribbles" Collection',
#   'Rating': 'Two',
#   'Existencia': 'In stock'},
#  {'titulo': 'Abstract City', 'Rating': 'Five', 'Existencia': 'In stock'},
#  {'titulo': 'A Time of Torment (Charlie Parker #14)',
#   'Rating': 'Five',
#   'Existencia': 'In stock'},
#  {'titulo': 'A Study in Scarlet (Sherlock Holmes #1)',
#   'Rating': 'Two',
#   'Existencia': 'In stock'},
#  {'titulo': 'A Series of Catastrophes and Miracles: A True Story of Love, Science, and Cancer',
#   'Rating': 'Two',
#   'Existencia': 'In stock'},
#  {'titulo': "A People's History of the United States",
#   'Rating': 'Two',
#   'Existencia': 'In stock'},
#  {'titulo': 'A Man Called Ove', 'Rating': 'One', 'Existencia': 'In stock'},
#  {'titulo': 'A Distant Mirror: The Calamitous 14th Century',
#   'Rating': 'Three',
#   'Existencia': 'In stock'},
#  {'titulo': 'A Brush of Wings (Angels Walking #3)',
#   'Rating': 'One',
#   'Existencia': 'In stock'},
#  {'titulo': '1491: New Revelations of the Americas Before Columbus',
#   'Rating': 'Three',
#   'Existencia': 'In stock'},
#  {'titulo': 'The Three Searches, Meaning, and the Story',
#   'Rating': 'Three',
#   'Existencia': 'In stock'},
#  {'titulo': 'Searching for Meaning in Gailana',
#   'Rating': 'One',
#   'Existencia': 'In stock'},
#  {'titulo': 'Rook', 'Rating': 'Four', 'Existencia': 'In stock'},
#  {'titulo': 'My Kitchen Year: 136 Recipes That Saved My Life',
#   'Rating': 'Two',
#   'Existencia': 'In stock'},
#  {'titulo': '13 Hours: The Inside Account of What Really Happened In Benghazi',
#   'Rating': 'One',
#   'Existencia': 'In stock'},
#  {'titulo': "Will You Won't You Want Me?",
#   'Rating': 'Three',
#   'Existencia': 'In stock'},
#  {'titulo': 'Tipping Point for Planet Earth: How Close Are We to the Edge?',
#   'Rating': 'One',
#   'Existencia': 'In stock'},
#  {'titulo': 'The Star-Touched Queen',
#   'Rating': 'Five',
#   'Existencia': 'In stock'},
#  {'titulo': 'The Silent Sister (Riley MacPherson #1)',
#   'Rating': 'Five',
#   'Existencia': 'In stock'},
#  {'titulo': 'The Midnight Watch: A Novel of the Titanic and the Californian',
#   'Rating': 'One',
#   'Existencia': 'In stock'},
#  {'titulo': 'The Lonely City: Adventures in the Art of Being Alone',
#   'Rating': 'Two',
#   'Existencia': 'In stock'},
#  {'titulo': 'The Gray Rhino: How to Recognize and Act on the Obvious Dangers We Ignore',
#   'Rating': 'Four',
#   'Existencia': 'In stock'},
#  {'titulo': 'The Golden Condom: And Other Essays on Love Lost and Found',
#   'Rating': 'One',
#   'Existencia': 'In stock'},
#  {'titulo': 'The Epidemic (The Program 0.6)',
#   'Rating': 'Five',
#   'Existencia': 'In stock'},
#  {'titulo': 'The Dinner Party', 'Rating': 'Two', 'Existencia': 'In stock'},
#  {'titulo': 'The Diary of a Young Girl',
#   'Rating': 'Three',
#   'Existencia': 'In stock'},
#  {'titulo': 'The Children', 'Rating': 'Three', 'Existencia': 'In stock'},
#  {'titulo': 'Stars Above (The Lunar Chronicles #4.5)',
#   'Rating': 'Two',
#   'Existencia': 'In stock'},
#  {'titulo': 'Snatched: How A Drug Queen Went Undercover for the DEA and Was Kidnapped By Colombian Guerillas',
#   'Rating': 'Three',
#   'Existencia': 'In stock'},
#  {'titulo': 'Raspberry Pi Electronics Projects for the Evil Genius',
#   'Rating': 'Four',
#   'Existencia': 'In stock'},
#  {'titulo': 'Quench Your Own Thirst: Business Lessons Learned Over a Beer or Two',
#   'Rating': 'One',
#   'Existencia': 'In stock'},
#  {'titulo': 'Psycho: Sanitarium (Psycho #1.5)',
#   'Rating': 'Five',
#   'Existencia': 'In stock'},
#  {'titulo': 'Poisonous (Max Revere Novels #3)',
#   'Rating': 'Three',
#   'Existencia': 'In stock'},
#  {'titulo': 'One with You (Crossfire #5)',
#   'Rating': 'Four',
#   'Existencia': 'In stock'},
#  {'titulo': 'No Love Allowed (Dodge Cove #1)',
#   'Rating': 'Four',
#   'Existencia': 'In stock'},
#  {'titulo': 'Murder at the 42nd Street Library (Raymond Ambler #1)',
#   'Rating': 'Four',
#   'Existencia': 'In stock'},
#  {'titulo': 'Most Wanted', 'Rating': 'Three', 'Existencia': 'In stock'},
#  {'titulo': 'Love, Lies and Spies', 'Rating': 'Two', 'Existencia': 'In stock'},
#  {'titulo': 'How to Speak Golf: An Illustrated Guide to Links Lingo',
#   'Rating': 'Five',
#   'Existencia': 'In stock'},
#  {'titulo': 'Hide Away (Eve Duncan #20)',
#   'Rating': 'One',
#   'Existencia': 'In stock'},
#  {'titulo': 'Furiously Happy: A Funny Book About Horrible Things',
#   'Rating': 'Four',
#   'Existencia': 'In stock'},
#  {'titulo': 'Everyday Italian: 125 Simple and Delicious Recipes',
#   'Rating': 'Five',
#   'Existencia': 'In stock'},
#  {'titulo': "Equal Is Unfair: America's Misguided Fight Against Income Inequality",
#   'Rating': 'One',
#   'Existencia': 'In stock'},
#  {'titulo': 'Eleanor & Park', 'Rating': 'Five', 'Existencia': 'In stock'},
#  {'titulo': 'Dirty (Dive Bar #1)', 'Rating': 'Four', 'Existencia': 'In stock'},
#  {'titulo': 'Can You Keep a Secret? (Fear Street Relaunch #4)',
#   'Rating': 'One',
#   'Existencia': 'In stock'},
#  {'titulo': 'Boar Island (Anna Pigeon #19)',
#   'Rating': 'Three',
#   'Existencia': 'In stock'},
#  {'titulo': 'A Paris Apartment', 'Rating': 'Four', 'Existencia': 'In stock'},
#  {'titulo': 'A la Mode: 120 Recipes in 60 Pairings: Pies, Tarts, Cakes, Crisps, and More Topped with Ice Cream, Gelato, Frozen Custard, and More',
#   'Rating': 'One',
#   'Existencia': 'In stock'},
#  {'titulo': 'Troublemaker: Surviving Hollywood and Scientology',
#   'Rating': 'Two',
#   'Existencia': 'In stock'},
#  {'titulo': 'The Widow', 'Rating': 'Two', 'Existencia': 'In stock'},
#  {'titulo': 'The Sleep Revolution: Transforming Your Life, One Night at a Time',
#   'Rating': 'Four',
#   'Existencia': 'In stock'},
#  {'titulo': 'The Improbability of Love',
#   'Rating': 'One',
#   'Existencia': 'In stock'},
#  {'titulo': 'The Art of Startup Fundraising',
#   'Rating': 'Three',
#   'Existencia': 'In stock'},
#  {'titulo': 'Take Me Home Tonight (Rock Star Romance #3)',
#   'Rating': 'Three',
#   'Existencia': 'In stock'},
#  {'titulo': 'Sleeping Giants (Themis Files #1)',
#   'Rating': 'One',
#   'Existencia': 'In stock'},
#  {'titulo': 'Setting the World on Fire: The Brief, Astonishing Life of St. Catherine of Siena',
#   'Rating': 'Two',
#   'Existencia': 'In stock'},
#  {'titulo': 'Playing with Fire', 'Rating': 'Three', 'Existencia': 'In stock'},
#  {'titulo': 'Off the Hook (Fishing for Trouble #1)',
#   'Rating': 'Three',
#   'Existencia': 'In stock'},
#  {'titulo': 'Mothering Sunday', 'Rating': 'Two', 'Existencia': 'In stock'},
#  {'titulo': 'Mother, Can You Not?',
#   'Rating': 'Five',
#   'Existencia': 'In stock'},
#  {'titulo': 'M Train', 'Rating': 'One', 'Existencia': 'In stock'},
#  {'titulo': 'Lilac Girls', 'Rating': 'Two', 'Existencia': 'In stock'},
#  {'titulo': 'Lies and Other Acts of Love',
#   'Rating': 'One',
#   'Existencia': 'In stock'},
#  {'titulo': 'Lab Girl', 'Rating': 'One', 'Existencia': 'In stock'},
#  {'titulo': 'Keep Me Posted', 'Rating': 'Four', 'Existencia': 'In stock'},
#  {'titulo': "It Didn't Start with You: How Inherited Family Trauma Shapes Who We Are and How to End the Cycle",
#   'Rating': 'Three',
#   'Existencia': 'In stock'},
#  {'titulo': 'Grey (Fifty Shades #4)',
#   'Rating': 'Four',
#   'Existencia': 'In stock'},
#  {'titulo': 'Exit, Pursued by a Bear',
#   'Rating': 'Four',
#   'Existencia': 'In stock'},
#  {'titulo': 'Daredevils', 'Rating': 'Three', 'Existencia': 'In stock'},
#  {'titulo': 'Cravings: Recipes for What You Want to Eat',
#   'Rating': 'Three',
#   'Existencia': 'In stock'},
#  {'titulo': 'Born for This: How to Find the Work You Were Meant to Do',
#   'Rating': 'Five',
#   'Existencia': 'In stock'},
#  {'titulo': 'Arena', 'Rating': 'Four', 'Existencia': 'In stock'},
#  {'titulo': 'Adultery', 'Rating': 'Five', 'Existencia': 'In stock'},
#  {'titulo': "A Mother's Reckoning: Living in the Aftermath of Tragedy",
#   'Rating': 'Three',
#   'Existencia': 'In stock'},
#  {'titulo': "A Gentleman's Position (Society of Gentlemen #3)",
#   'Rating': 'Five',
#   'Existencia': 'In stock'},
#  {'titulo': '11/22/63', 'Rating': 'Three', 'Existencia': 'In stock'},
#  {'titulo': '10% Happier: How I Tamed the Voice in My Head, Reduced Stress Without Losing My Edge, and Found Self-Help That Actually Works',
#   'Rating': 'Two',
#   'Existencia': 'In stock'},
#  {'titulo': '10-Day Green Smoothie Cleanse: Lose Up to 15 Pounds in 10 Days!',
#   'Rating': 'Five',
#   'Existencia': 'In stock'},
#  {'titulo': 'Without Shame', 'Rating': 'Five', 'Existencia': 'In stock'},
#  {'titulo': 'Watchmen', 'Rating': 'Four', 'Existencia': 'In stock'},
#  {'titulo': 'Unlimited Intuition Now',
#   'Rating': 'Four',
#   'Existencia': 'In stock'},
#  {'titulo': 'Underlying Notes', 'Rating': 'Two', 'Existencia': 'In stock'},
#  {'titulo': 'The Shack', 'Rating': 'One', 'Existencia': 'In stock'},
#  {'titulo': 'The New Brand You: Your New Image Makes the Sale for You',
#   'Rating': 'Five',
#   'Existencia': 'In stock'},
#  {'titulo': 'The Moosewood Cookbook: Recipes from Moosewood Restaurant, Ithaca, New York',
#   'Rating': 'Four',
#   'Existencia': 'In stock'},
#  {'titulo': 'The Flowers Lied', 'Rating': 'Two', 'Existencia': 'In stock'},
#  {'titulo': 'The Fabric of the Cosmos: Space, Time, and the Texture of Reality',
#   'Rating': 'One',
#   'Existencia': 'In stock'},
#  {'titulo': 'The Book of Mormon', 'Rating': 'Three', 'Existencia': 'In stock'},
#  {'titulo': 'The Art and Science of Low Carbohydrate Living',
#   'Rating': 'Five',
#   'Existencia': 'In stock'},
#  {'titulo': 'The Alien Club', 'Rating': 'One', 'Existencia': 'In stock'},
#  {'titulo': 'Suzie Snowflake: One beautiful flake (a self-esteem story)',
#   'Rating': 'Five',
#   'Existencia': 'In stock'},
#  {'titulo': 'Nap-a-Roo', 'Rating': 'One', 'Existencia': 'In stock'},
#  {'titulo': 'NaNo What Now? Finding your editing process, revising your NaNoWriMo book and building a writing career through publishing and beyond',
#   'Rating': 'Four',
#   'Existencia': 'In stock'},
#  {'titulo': 'Modern Day Fables', 'Rating': 'Two', 'Existencia': 'In stock'},
#  {'titulo': "If I Gave You God's Phone Number....: Searching for Spirituality in America",
#   'Rating': 'One',
#   'Existencia': 'In stock'},
#  {'titulo': 'Fruits Basket, Vol. 9 (Fruits Basket #9)',
#   'Rating': 'Four',
#   'Existencia': 'In stock'},
#  {'titulo': 'Dress Your Family in Corduroy and Denim',
#   'Rating': 'Three',
#   'Existencia': 'In stock'},
#  {'titulo': "Don't Forget Steven", 'Rating': 'One', 'Existencia': 'In stock'},
#  {'titulo': "Chernobyl 01:23:40: The Incredible True Story of the World's Worst Nuclear Disaster",
#   'Rating': 'Two',
#   'Existencia': 'In stock'},
#  {'titulo': 'Art and Fear: Observations on the Perils (and Rewards) of Artmaking',
#   'Rating': 'Four',
#   'Existencia': 'In stock'},
#  {'titulo': 'A Shard of Ice (The Black Symphony Saga #1)',
#   'Rating': 'Three',
#   'Existencia': 'In stock'},
#  {'titulo': "A Hero's Curse (The Unseen Chronicles #1)",
#   'Rating': 'Three',
#   'Existencia': 'In stock'},
#  {'titulo': '23 Degrees South: A Tropical Tale of Changing Whether...',
#   'Rating': 'Two',
#   'Existencia': 'In stock'},
#  {'titulo': 'Zero to One: Notes on Startups, or How to Build the Future',
#   'Rating': 'Three',
#   'Existencia': 'In stock'},
#  {'titulo': 'Why Not Me?', 'Rating': 'One', 'Existencia': 'In stock'},
#  {'titulo': 'When Breath Becomes Air',
#   'Rating': 'Two',
#   'Existencia': 'In stock'},
#  {'titulo': 'Vagabonding: An Uncommon Guide to the Art of Long-Term World Travel',
#   'Rating': 'Two',
#   'Existencia': 'In stock'},
#  {'titulo': 'The Unlikely Pilgrimage of Harold Fry (Harold Fry #1)',
#   'Rating': 'Five',
#   'Existencia': 'In stock'},
#  {'titulo': 'The New Drawing on the Right Side of the Brain',
#   'Rating': 'Three',
#   'Existencia': 'In stock'},
#  {'titulo': "The Midnight Assassin: Panic, Scandal, and the Hunt for America's First Serial Killer",
#   'Rating': 'Four',
#   'Existencia': 'In stock'},
#  {'titulo': 'The Martian (The Martian #1)',
#   'Rating': 'Two',
#   'Existencia': 'In stock'},
#  {'titulo': 'The High Mountains of Portugal',
#   'Rating': 'One',
#   'Existencia': 'In stock'},
#  {'titulo': 'The Grownup', 'Rating': 'One', 'Existencia': 'In stock'},
# ...
#   'Existencia': 'In stock'},
#  {'titulo': 'House of Leaves', 'Rating': 'One', 'Existencia': 'In stock'},
#  {'titulo': 'Horrible Bear!', 'Rating': 'Two', 'Existencia': 'In stock'},
#  {'titulo': 'Holidays on Ice', 'Rating': 'Two', 'Existencia': 'In stock'},
#  {'titulo': 'Heir to the Sky', 'Rating': 'Four', 'Existencia': 'In stock'},
#  {'titulo': 'Green Eggs and Ham (Beginner Books B-16)',
#   'Rating': 'Four',
#   'Existencia': 'In stock'},
#  {'titulo': 'Grayson, Vol 3: Nemesis (Grayson #3)',
#   'Rating': 'One',
#   'Existencia': 'In stock'},
#  {'titulo': 'Gratitude', 'Rating': 'Five', 'Existencia': 'In stock'},
#  {'titulo': 'Gone Girl', 'Rating': 'Five', 'Existencia': 'In stock'},
#  {'titulo': 'Golden (Heart of Dread #3)',
#   'Rating': 'Four',
#   'Existencia': 'In stock'},
#  {'titulo': 'Girl in the Blue Coat',
#   'Rating': 'Two',
#   'Existencia': 'In stock'},
#  {'titulo': 'Fruits Basket, Vol. 3 (Fruits Basket #3)',
#   'Rating': 'Two',
#   'Existencia': 'In stock'},
#  {'titulo': 'Friday Night Lights: A Town, a Team, and a Dream',
#   'Rating': 'Three',
#   'Existencia': 'In stock'},
#  {'titulo': 'Fire Bound (Sea Haven/Sisters of the Heart #5)',
#   'Rating': 'Four',
#   'Existencia': 'In stock'},
#  {'titulo': 'Fifty Shades Freed (Fifty Shades #3)',
#   'Rating': 'Five',
#   'Existencia': 'In stock'},
#  {'titulo': 'Fellside', 'Rating': 'One', 'Existencia': 'In stock'},
#  {'titulo': 'Extreme Prey (Lucas Davenport #26)',
#   'Rating': 'Three',
#   'Existencia': 'In stock'},
#  {'titulo': 'Eragon (The Inheritance Cycle #1)',
#   'Rating': 'Three',
#   'Existencia': 'In stock'},
#  {'titulo': 'Eclipse (Twilight #3)',
#   'Rating': 'One',
#   'Existencia': 'In stock'},
#  {'titulo': 'Dune (Dune #1)', 'Rating': 'One', 'Existencia': 'In stock'},
#  {'titulo': 'Dracula', 'Rating': 'Three', 'Existencia': 'In stock'},
#  {'titulo': 'Do Androids Dream of Electric Sheep? (Blade Runner #1)',
#   'Rating': 'One',
#   'Existencia': 'In stock'},
#  {'titulo': 'Disrupted: My Misadventure in the Start-Up Bubble',
#   'Rating': 'Five',
#   'Existencia': 'In stock'},
#  {'titulo': 'Dead Wake: The Last Crossing of the Lusitania',
#   'Rating': 'Five',
#   'Existencia': 'In stock'},
#  {'titulo': 'David and Goliath: Underdogs, Misfits, and the Art of Battling Giants',
#   'Rating': 'One',
#   'Existencia': 'In stock'},
#  {'titulo': 'Darkfever (Fever #1)', 'Rating': 'One', 'Existencia': 'In stock'},
#  {'titulo': 'Dark Places', 'Rating': 'Five', 'Existencia': 'In stock'},
#  {'titulo': 'Crazy Rich Asians (Crazy Rich Asians #1)',
#   'Rating': 'Five',
#   'Existencia': 'In stock'},
#  {'titulo': 'Counting Thyme', 'Rating': 'One', 'Existencia': 'In stock'},
#  {'titulo': 'Cosmos', 'Rating': 'Two', 'Existencia': 'In stock'},
#  {'titulo': 'Civilization and Its Discontents',
#   'Rating': 'Two',
#   'Existencia': 'In stock'},
#  {'titulo': 'Cinder (The Lunar Chronicles #1)',
#   'Rating': 'One',
#   'Existencia': 'In stock'},
#  {'titulo': "Catastrophic Happiness: Finding Joy in Childhood's Messy Years",
#   'Rating': 'Two',
#   'Existencia': 'In stock'},
#  {'titulo': 'Career of Evil (Cormoran Strike #3)',
#   'Rating': 'Two',
#   'Existencia': 'In stock'},
#  {'titulo': 'Breaking Dawn (Twilight #4)',
#   'Rating': 'Five',
#   'Existencia': 'In stock'},
#  {'titulo': 'Brave Enough', 'Rating': 'Five', 'Existencia': 'In stock'},
#  {'titulo': 'Boy Meets Boy', 'Rating': 'Three', 'Existencia': 'In stock'},
#  {'titulo': 'Born to Run: A Hidden Tribe, Superathletes, and the Greatest Race the World Has Never Seen',
#   'Rating': 'Two',
#   'Existencia': 'In stock'},
#  {'titulo': 'Blink: The Power of Thinking Without Thinking',
#   'Rating': 'Five',
#   'Existencia': 'In stock'},
#  {'titulo': 'Black Flags: The Rise of ISIS',
#   'Rating': 'One',
#   'Existencia': 'In stock'},
#  {'titulo': 'Black Butler, Vol. 1 (Black Butler #1)',
#   'Rating': 'One',
#   'Existencia': 'In stock'},
#  {'titulo': 'Big Little Lies', 'Rating': 'One', 'Existencia': 'In stock'},
#  {'titulo': 'Between Shades of Gray',
#   'Rating': 'Five',
#   'Existencia': 'In stock'},
#  {'titulo': "Best of My Love (Fool's Gold #20)",
#   'Rating': 'Two',
#   'Existencia': 'In stock'},
#  {'titulo': 'Beowulf', 'Rating': 'Two', 'Existencia': 'In stock'},
#  {'titulo': 'Beautiful Creatures (Caster Chronicles #1)',
#   'Rating': 'Five',
#   'Existencia': 'In stock'},
#  {'titulo': 'Awkward', 'Rating': 'Two', 'Existencia': 'In stock'},
#  {'titulo': 'Ash', 'Rating': 'Four', 'Existencia': 'In stock'},
#  {'titulo': 'Are We There Yet?', 'Rating': 'Three', 'Existencia': 'In stock'},
#  {'titulo': 'Are We Smart Enough to Know How Smart Animals Are?',
#   'Rating': 'One',
#   'Existencia': 'In stock'},
#  {'titulo': 'Annie on My Mind', 'Rating': 'Five', 'Existencia': 'In stock'},
#  {'titulo': 'And Then There Were None',
#   'Rating': 'Two',
#   'Existencia': 'In stock'},
#  {'titulo': 'A Walk in the Woods: Rediscovering America on the Appalachian Trail',
#   'Rating': 'Four',
#   'Existencia': 'In stock'},
#  {'titulo': 'A Visit from the Goon Squad',
#   'Rating': 'Five',
#   'Existencia': 'In stock'},
#  {'titulo': 'A Storm of Swords (A Song of Ice and Fire #3)',
#   'Rating': 'Two',
#   'Existencia': 'In stock'},
#  {'titulo': 'A Heartbreaking Work of Staggering Genius',
#   'Rating': 'Five',
#   'Existencia': 'In stock'},
#  {'titulo': '8 Keys to Mental Health Through Exercise',
#   'Rating': 'One',
#   'Existencia': 'In stock'},
#  {'titulo': '#GIRLBOSS', 'Rating': 'One', 'Existencia': 'In stock'},
#  {'titulo': 'The Suffragettes (Little Black Classics, #96)',
#   'Rating': 'Two',
#   'Existencia': 'In stock'},
#  {'titulo': 'The Sense of an Ending',
#   'Rating': 'Three',
#   'Existencia': 'In stock'},
#  {'titulo': "The Sandman, Vol. 2: The Doll's House (The Sandman (volumes) #2)",
#   'Rating': 'One',
#   'Existencia': 'In stock'},
#  {'titulo': 'The Course of Love', 'Rating': 'Three', 'Existencia': 'In stock'},
#  {'titulo': 'Sugar Rush (Offensive Line #2)',
#   'Rating': 'One',
#   'Existencia': 'In stock'},
#  {'titulo': 'Saga, Volume 2 (Saga (Collected Editions) #2)',
#   'Rating': 'Three',
#   'Existencia': 'In stock'},
#  {'titulo': 'Run, Spot, Run: The Ethics of Keeping Pets',
#   'Rating': 'One',
#   'Existencia': 'In stock'},
#  {'titulo': 'New Moon (Twilight #2)',
#   'Rating': 'Four',
#   'Existencia': 'In stock'},
#  {'titulo': 'Life', 'Rating': 'Five', 'Existencia': 'In stock'},
#  {'titulo': "Kindle Paperwhite User's Guide",
#   'Rating': 'Three',
#   'Existencia': 'In stock'},
#  {'titulo': 'H is for Hawk', 'Rating': 'Five', 'Existencia': 'In stock'},
#  {'titulo': 'Girl Online On Tour (Girl Online #2)',
#   'Rating': 'One',
#   'Existencia': 'In stock'},
#  {'titulo': 'Fruits Basket, Vol. 2 (Fruits Basket #2)',
#   'Rating': 'Five',
#   'Existencia': 'In stock'},
#  {'titulo': 'Diary of a Minecraft Zombie Book 1: A Scare of a Dare (An Unofficial Minecraft Book)',
#   'Rating': 'Four',
#   'Existencia': 'In stock'},
#  {'titulo': 'Y: The Last Man, Vol. 1: Unmanned (Y: The Last Man #1)',
#   'Rating': 'Four',
#   'Existencia': 'In stock'},
#  {'titulo': 'While You Were Mine', 'Rating': 'Five', 'Existencia': 'In stock'},
#  {'titulo': 'Where Lightning Strikes (Bleeding Stars #3)',
#   'Rating': 'Three',
#   'Existencia': 'In stock'},
#  {'titulo': "When I'm Gone", 'Rating': 'Three', 'Existencia': 'In stock'},
#  {'titulo': 'Ways of Seeing', 'Rating': 'Five', 'Existencia': 'In stock'},
#  {'titulo': 'Vampire Knight, Vol. 1 (Vampire Knight #1)',
#   'Rating': 'One',
#   'Existencia': 'In stock'},
#  {'titulo': 'Vampire Girl (Vampire Girl #1)',
#   'Rating': 'Two',
#   'Existencia': 'In stock'},
#  {'titulo': 'Twenty Love Poems and a Song of Despair',
#   'Rating': 'Four',
#   'Existencia': 'In stock'},
#  {'titulo': 'Travels with Charley: In Search of America',
#   'Rating': 'Five',
#   'Existencia': 'In stock'},
#  {'titulo': 'Three Wishes (River of Time: California #1)',
#   'Rating': 'Two',
#   'Existencia': 'In stock'},
#  {'titulo': 'This One Moment (Pushing Limits #1)',
#   'Rating': 'One',
#   'Existencia': 'In stock'},
#  {'titulo': 'The Zombie Room', 'Rating': 'Five', 'Existencia': 'In stock'},
#  {'titulo': 'The Wicked + The Divine, Vol. 1: The Faust Act (The Wicked + The Divine)',
#   'Rating': 'Two',
#   'Existencia': 'In stock'},
#  {'titulo': 'The Tumor', 'Rating': 'Five', 'Existencia': 'In stock'},
#  {'titulo': 'The Story of Hong Gildong',
#   'Rating': 'Four',
#   'Existencia': 'In stock'},
#  {'titulo': 'The Silent Wife', 'Rating': 'Five', 'Existencia': 'In stock'},
#  {'titulo': 'The Silent Twin (Detective Jennifer Knight #3)',
#   'Rating': 'Three',
#   'Existencia': 'In stock'},
#  {'titulo': 'The Selfish Gene', 'Rating': 'One', 'Existencia': 'In stock'},
#  {'titulo': 'The Secret Healer', 'Rating': 'Three', 'Existencia': 'In stock'},
#  {'titulo': 'The Sandman, Vol. 1: Preludes and Nocturnes (The Sandman (volumes) #1)',
#   'Rating': 'Three',
#   'Existencia': 'In stock'},
#  {'titulo': 'The Republic', 'Rating': 'Three', 'Existencia': 'In stock'},
#  {'titulo': 'The Odyssey', 'Rating': 'Three', 'Existencia': 'In stock'},
#  {'titulo': "The No. 1 Ladies' Detective Agency (No. 1 Ladies' Detective Agency #1)",
#   'Rating': 'Four',
#   'Existencia': 'In stock'},
#  {'titulo': 'The Nicomachean Ethics',
#   'Rating': 'One',
#   'Existencia': 'In stock'},
#  {'titulo': 'The Name of the Wind (The Kingkiller Chronicle #1)',
#   'Rating': 'Three',
#   'Existencia': 'In stock'},
#  {'titulo': 'The Mirror & the Maze (The Wrath and the Dawn #1.5)',
#   'Rating': 'One',
#   'Existencia': 'In stock'},
#  {'titulo': 'The Little Prince', 'Rating': 'Two', 'Existencia': 'In stock'},
#  {'titulo': 'The Light of the Fireflies',
#   'Rating': 'One',
#   'Existencia': 'In stock'},
#  {'titulo': 'The Last Girl (The Dominion Trilogy #1)',
#   'Rating': 'Two',
#   'Existencia': 'In stock'},
#  {'titulo': 'The Iliad', 'Rating': 'One', 'Existencia': 'In stock'},
#  {'titulo': 'The Hook Up (Game On #1)',
#   'Rating': 'Five',
#   'Existencia': 'In stock'},
#  {'titulo': 'The Haters', 'Rating': 'Five', 'Existencia': 'In stock'},
#  {'titulo': 'The Girl You Lost', 'Rating': 'Five', 'Existencia': 'In stock'},
#  {'titulo': 'The Girl In The Ice (DCI Erika Foster #1)',
#   'Rating': 'Three',
#   'Existencia': 'In stock'},
#  {'titulo': 'The End of the Jesus Era (An Investigation #1)',
#   'Rating': 'One',
#   'Existencia': 'In stock'},
#  {'titulo': 'The Edge of Reason (Bridget Jones #2)',
#   'Rating': 'Four',
#   'Existencia': 'In stock'},
#  {'titulo': 'The Complete Maus (Maus #1-2)',
#   'Rating': 'Three',
#   'Existencia': 'In stock'},
#  {'titulo': 'The Communist Manifesto',
#   'Rating': 'Three',
#   'Existencia': 'In stock'},
#  {'titulo': 'The Bhagavad Gita', 'Rating': 'Three', 'Existencia': 'In stock'},
#  {'titulo': 'The Bette Davis Club',
#   'Rating': 'Three',
#   'Existencia': 'In stock'},
#  {'titulo': 'The Art of Not Breathing',
#   'Rating': 'Four',
#   'Existencia': 'In stock'},
#  {'titulo': 'Taking Shots (Assassins #1)',
#   'Rating': 'Two',
#   'Existencia': 'In stock'},
#  {'titulo': 'Starlark', 'Rating': 'Three', 'Existencia': 'In stock'},
#  {'titulo': 'Skip Beat!, Vol. 01 (Skip Beat! #1)',
#   'Rating': 'Three',
#   'Existencia': 'In stock'},
#  {'titulo': 'Sister Sable (The Mad Queen #1)',
#   'Rating': 'Three',
#   'Existencia': 'In stock'},
#  {'titulo': 'Shatter Me (Shatter Me #1)',
#   'Rating': 'One',
#   'Existencia': 'In stock'},
#  {'titulo': 'Shameless', 'Rating': 'Three', 'Existencia': 'In stock'},
#  {'titulo': 'Shadow Rites (Jane Yellowrock #10)',
#   'Rating': 'Four',
#   'Existencia': 'In stock'},
#  {'titulo': 'Settling the Score (The Summer Games #1)',
#   'Rating': 'Two',
#   'Existencia': 'In stock'},
#  {'titulo': 'Sense and Sensibility',
#   'Rating': 'One',
#   'Existencia': 'In stock'},
#  {'titulo': 'Saga, Volume 1 (Saga (Collected Editions) #1)',
#   'Rating': 'One',
#   'Existencia': 'In stock'},
#  {'titulo': 'Rhythm, Chord & Malykhin',
#   'Rating': 'Two',
#   'Existencia': 'In stock'},
#  {'titulo': 'Rat Queens, Vol. 1: Sass & Sorcery (Rat Queens (Collected Editions) #1-5)',
#   'Rating': 'Five',
#   'Existencia': 'In stock'},
#  {'titulo': 'Paradise Lost (Paradise #1)',
#   'Rating': 'One',
#   'Existencia': 'In stock'},
#  {'titulo': 'Paper Girls, Vol. 1 (Paper Girls #1-5)',
#   'Rating': 'Four',
#   'Existencia': 'In stock'},
#  {'titulo': 'Ouran High School Host Club, Vol. 1 (Ouran High School Host Club #1)',
#   'Rating': 'Three',
#   'Existencia': 'In stock'},
#  {'titulo': 'Origins (Alphas 0.5)', 'Rating': 'One', 'Existencia': 'In stock'},
#  {'titulo': 'One Second (Seven #7)',
#   'Rating': 'Two',
#   'Existencia': 'In stock'},
#  {'titulo': 'On the Road (Duluoz Legend)',
#   'Rating': 'Three',
#   'Existencia': 'In stock'},
#  {'titulo': "Old Records Never Die: One Man's Quest for His Vinyl and His Past",
#   'Rating': 'Two',
#   'Existencia': 'In stock'},
#  {'titulo': 'Off Sides (Off #1)', 'Rating': 'Five', 'Existencia': 'In stock'},
#  {'titulo': 'Of Mice and Men', 'Rating': 'Two', 'Existencia': 'In stock'},
#  {'titulo': 'Myriad (Prentor #1)', 'Rating': 'Four', 'Existencia': 'In stock'},
#  {'titulo': 'My Perfect Mistake (Over the Top #1)',
#   'Rating': 'Two',
#   'Existencia': 'In stock'},
#  {'titulo': 'Ms. Marvel, Vol. 1: No Normal (Ms. Marvel (2014-2015) #1)',
#   'Rating': 'Four',
#   'Existencia': 'In stock'},
#  {'titulo': 'Meditations', 'Rating': 'Two', 'Existencia': 'In stock'},
#  {'titulo': 'Matilda', 'Rating': 'One', 'Existencia': 'In stock'},
#  {'titulo': 'Lost Among the Living',
#   'Rating': 'Four',
#   'Existencia': 'In stock'},
#  {'titulo': 'Lord of the Flies', 'Rating': 'Three', 'Existencia': 'In stock'},
#  {'titulo': 'Listen to Me (Fusion #1)',
#   'Rating': 'Three',
#   'Existencia': 'In stock'},
#  {'titulo': 'Kitchens of the Great Midwest',
#   'Rating': 'Five',
#   'Existencia': 'In stock'},
#  {'titulo': 'Jane Eyre', 'Rating': 'Five', 'Existencia': 'In stock'},
#  {'titulo': 'Imperfect Harmony', 'Rating': 'Four', 'Existencia': 'In stock'},
#  {'titulo': 'Icing (Aces Hockey #2)',
#   'Rating': 'Four',
#   'Existencia': 'In stock'},
#  {'titulo': 'Hawkeye, Vol. 1: My Life as a Weapon (Hawkeye #1)',
#   'Rating': 'Three',
#   'Existencia': 'In stock'},
#  {'titulo': "Having the Barbarian's Baby (Ice Planet Barbarians #7.5)",
#   'Rating': 'Four',
#   'Existencia': 'In stock'},
#  {'titulo': 'Giant Days, Vol. 1 (Giant Days #1-4)',
#   'Rating': 'Four',
#   'Existencia': 'In stock'},
#  {'titulo': 'Fruits Basket, Vol. 1 (Fruits Basket #1)',
#   'Rating': 'Five',
#   'Existencia': 'In stock'},
#  {'titulo': 'Frankenstein', 'Rating': 'Two', 'Existencia': 'In stock'},
#  {'titulo': 'Forever Rockers (The Rocker #12)',
#   'Rating': 'Three',
#   'Existencia': 'In stock'},
#  {'titulo': 'Fighting Fate (Fighting #6)',
#   'Rating': 'Three',
#   'Existencia': 'In stock'},
#  {'titulo': 'Emma', 'Rating': 'Two', 'Existencia': 'In stock'},
#  {'titulo': 'Eat, Pray, Love', 'Rating': 'Three', 'Existencia': 'In stock'},
#  {'titulo': 'Deep Under (Walker Security #1)',
#   'Rating': 'Five',
#   'Existencia': 'In stock'},
#  {'titulo': "Choosing Our Religion: The Spiritual Lives of America's Nones",
#   'Rating': 'Four',
#   'Existencia': 'In stock'},
#  {'titulo': 'Charlie and the Chocolate Factory (Charlie Bucket #1)',
#   'Rating': 'Three',
#   'Existencia': 'In stock'},
#  {'titulo': "Charity's Cross (Charles Towne Belles #4)",
#   'Rating': 'One',
#   'Existencia': 'In stock'},
#  {'titulo': 'Bright Lines', 'Rating': 'Five', 'Existencia': 'In stock'},
#  {'titulo': "Bridget Jones's Diary (Bridget Jones #1)",
#   'Rating': 'One',
#   'Existencia': 'In stock'},
#  {'titulo': 'Bounty (Colorado Mountain #7)',
#   'Rating': 'Four',
#   'Existencia': 'In stock'},
#  {'titulo': 'Blood Defense (Samantha Brinkman #1)',
#   'Rating': 'Three',
#   'Existencia': 'In stock'},
#  {'titulo': 'Bleach, Vol. 1: Strawberry and the Soul Reapers (Bleach #1)',
#   'Rating': 'Five',
#   'Existencia': 'In stock'},
#  {'titulo': 'Beyond Good and Evil', 'Rating': 'One', 'Existencia': 'In stock'},
#  {'titulo': "Alice in Wonderland (Alice's Adventures in Wonderland #1)",
#   'Rating': 'One',
#   'Existencia': 'In stock'},
#  {'titulo': 'Ajin: Demi-Human, Volume 1 (Ajin: Demi-Human #1)',
#   'Rating': 'Four',
#   'Existencia': 'In stock'},
#  {'titulo': "A Spy's Devotion (The Regency Spies of London #1)",
#   'Rating': 'Five',
#   'Existencia': 'In stock'},
#  {'titulo': "1st to Die (Women's Murder Club #1)",
#   'Rating': 'One',
#   'Existencia': 'In stock'},
#  {'titulo': '1,000 Places to See Before You Die',
#   'Rating': 'Five',
#   'Existencia': 'In stock'}]

# %%
len(data)
# Out:
# 1000

# %%
import pandas as pd

df = pd.DataFrame(data)

# %%
df
# Out:
#                                                 titulo Rating Existencia
# 0                                 A Light in the Attic  Three   In stock
# 1                                   Tipping the Velvet    One   In stock
# 2                                           Soumission    One   In stock
# 3                                        Sharp Objects   Four   In stock
# 4                Sapiens: A Brief History of Humankind   Five   In stock
# ..                                                 ...    ...        ...
# 995  Alice in Wonderland (Alice's Adventures in Won...    One   In stock
# 996   Ajin: Demi-Human, Volume 1 (Ajin: Demi-Human #1)   Four   In stock
# 997  A Spy's Devotion (The Regency Spies of London #1)   Five   In stock
# 998                1st to Die (Women's Murder Club #1)    One   In stock
# 999                 1,000 Places to See Before You Die   Five   In stock
#
# [1000 rows x 3 columns]

# %% [markdown]
# Expresiones regulares

# %%
html = requests.get('http://books.toscrape.com/')

soup = BeautifulSoup(html.text, 'html.parser')

# %%
import re

# %%
item = soup.select_one('li.current')

patron = r'Page (\d+) of (\d+)'

match = re.search(patron, html.text)

print(match)

if match:
    page_number = int(match.group(1))
    total_pages = int(match.group(2))
    print(page_number, total_pages)
# Out:
# <re.Match object; span=(49748, 49760), match='Page 1 of 50'>
# 1 50

# %%
import re

patron = r'.*+[aeiou]?{n}(ab)+^$\d'

# %%
import re

texto = 'Hola, mi numero de telefono es 614-189-6685. Necesitas contactarme? Llamame'

patron = r'\d{3}-\d{3}-\d{4}'

resultado_search = re.search(patron, texto)

if resultado_search:
    print('Numero de telefono encontrado',resultado_search.group())
else:
    print('Numero de telefono no encontrado')
# Out:
# Numero de telefono encontrado 614-189-6685

# %% [markdown]
# Ejercicio cyberpuerta
# 1. Entrar  a la pagina cyberpuerta  y buscar una categoria
# 2. Realizar las peticiones HTTP pertinentes para obtener  el codigo fuente  de la pagina
# 3. Analizar las paginas web  para identificar los elementos relevantes
# 4. Extraer los elementos relevantes  de las paginas web
# 5. Generar un dataframe con los datos obtenidos
# 6. Generar una grafica para visualizar datos

# %%
import requests

from bs4 import BeautifulSoup

# %%
pagina_web = requests.get('https://www.cyberpuerta.mx/Computadoras/Laptops/') #Solo manejar un tipo de pagina no la travel page


soup = BeautifulSoup(pagina_web.text, 'html.parser')


print(soup.prettify())
# Out:
# <!DOCTYPE HTML>
# <html lang="es">
#  <head>
#   <link href="https://www.cyberpuerta.mx/out/generated/cms-pages.css?1593624763" rel="stylesheet" type="text/css"/>
#   <link href="https://www.cyberpuerta.mx/out/cyberpuertaV5/src/css/em.selectbox.css?1690397509" rel="stylesheet" type="text/css"/>
#   <link href="https://www.cyberpuerta.mx/out/cyberpuertaV5/src/css/oxwidget_headerlogin.css?1690397509" rel="stylesheet" type="text/css"/>
#   <link href="https://www.cyberpuerta.mx/out/cyberpuertaV5/src/css/oxwidget_headernotice.css?1690397509" rel="stylesheet" type="text/css"/>
#   <link href="https://www.cyberpuerta.mx/out/cyberpuertaV5/src/css/oxwidget_headercompare.css?1690397509" rel="stylesheet" type="text/css"/>
#   <link href="https://www.cyberpuerta.mx/out/cyberpuertaV5/src/css/oxwidget_headerhelp.css?1690397509" rel="stylesheet" type="text/css"/>
#   <link href="https://www.cyberpuerta.mx/out/cyberpuertaV5/src/css/oxwidget_headerminibasket.css?1690397509" rel="stylesheet" type="text/css"/>
#   <link data-cp-orig="cdn.Swiper.css" href="https://cdnjs.cloudflare.com/ajax/libs/Swiper/4.3.5/css/swiper.min.css" rel="stylesheet" type="text/css"/>
#   <link data-cp-orig="cp.app.legacy.css" href="https://www.cyberpuerta.mx/out/dist/cp.app.legacy.c6cd68cd7a9e818b946e.g.css" rel="stylesheet" type="text/css"/>
#   <link data-cp-orig="cp.app.foundation.css" href="https://www.cyberpuerta.mx/out/dist/cp.app.foundation.e29b346a69794f0187d9.g.css" rel="stylesheet" type="text/css"/>
#   <link data-cp-orig="cp.app.css" href="https://www.cyberpuerta.mx/out/dist/cp.app.2597a5763d93a7d4fff0.g.css" rel="stylesheet" type="text/css"/>
#   <link data-cp-orig="vendors~cp.app.css" href="https://www.cyberpuerta.mx/out/dist/vendors~cp.app.f79cffac28db61b5a671.g.css" rel="stylesheet" type="text/css"/>
#   <link data-cp-orig="cdn.material-icons.css" href="https://fonts.googleapis.com/icon?family=Material+Icons" rel="stylesheet" type="text/css"/>
#   <link data-cp-orig="cdn.open-sans.css" href="https://fonts.googleapis.com/css?family=Open+Sans:400,700&amp;display=swap" rel="stylesheet" type="text/css"/>
#   <script>
#    window.dataLayer = window.dataLayer || [];
#         let loginCookieMatch = document.cookie.match(/\bcpcautologin=([^;]+)/);
#         let loginCookie = loginCookieMatch ? loginCookieMatch[1] : null;
#
#         // gtm Cookie to be sent to get prediction from Google Recommendations AI
#         let gtmCookie = null;
#         function getCookie(cName) {
#           const name = cName + "=";
#           const cDecoded = decodeURIComponent(document.cookie); //to be careful
#           const cArr = cDecoded.split('; ');
#           let res;
#           cArr.forEach(val => {
#             if (val.indexOf(name) === 0) res = val.substring(name.length);
#           })
#           return res
#         }
#
#         window.onload = function() {
#             gtmCookie = getCookie("_ga");
#         };
#
#         // If in the query string is utm_campaign, set it in a cookie
#
#         // section to define variable to send information to another project "CP Cyberpuerta production"
#         var _gre = _gre || [];
#         // Credentials for project.
#         _gre.push(['apiKey', 'AIzaSyAOwVGpimHdB81KmBDgnKta0wxX9RqszKE']);
#         _gre.push(['projectId', 'cyberpuerta-144818']);
#         _gre.push(['locationId', 'global']);
#         _gre.push(['catalogId', 'default_catalog']);
#
#         let justOne = true;
#
#         window.onload = function() {
#             if ( justOne ) {
#                 var gre = document.createElement('script'); gre.type = 'text/javascript'; gre.async = true;
#                 gre.src = 'https://www.gstatic.com/retail/v2_event.js';
#                 var s = document.getElementsByTagName('script')[0]; s.parentNode.insertBefore(gre, s);
#                 justOne = false;
#             }
#         };
#
#                     dataLayer.push(
#                 {"shop_cl":"alist"}
#             );
#                     dataLayer.push(
#                 {"ab1047_pixel":0}
#             );
#                     dataLayer.push(
#                 {"sess_tk":"3467432F"}
#             );
#                     dataLayer.push(
#                 {"internal_user":0}
#             );
#                     dataLayer.push(
#                 {"rai_active":true}
#             );
#                     dataLayer.push(
#                 {"new_customer":false}
#             );
#                     dataLayer.push(
#                 {"fresh":{"tags":["laptops"]}}
#             );
#
#         dataLayer.push({
#             api_version: 'v0.1'
#         })
#
#
#                                                     dataLayer.push({'Referer':'(direct)'});
#                 dataLayer.push({'firstaccess':'y'});
#
#                             // If is a search page or is a category/manufacturer page but comes from a search
#                             dataLayer.push({'pageview': '/alist - Computadoras/Laptops'});
#
#
#
#
#
#                             dataLayer.push({
#                 'ecomm_prodid': '',
#                 'ecomm_totalvalue': 0,
#                 'nl': 'n'
#             });
#
#             //IT-3502
#             //todo: implement for CP mobile, currently we dont send articles
#             //from cpfacebookpixel_category.tpl
#
#
#
#
#
#
#
#
#
#
#
#
#             window.dataLayer.push({
#                     'category': {
#                         'products': ['82RB00PBLM','82LM00SLLM','7E3H1LT','20W1S03300','7E3H3LT','5U0S5LT','6K710LT','81X700EGLM','7E3H6LT','82KC0084LM'],                         'path': 'Inicio>Computadoras>Laptops',
#                         'name': 'Laptops'
#                     }
#             });
#             //In CP mobile we send the event after get articles(ajax)
#                                             //IT-4010 ask for an eventId
#                                 window.dataLayer.push({
#                     'event': 'categoryPageView',
#                     'fbCategoryId': 'catman64c17905b83ec3.49510789'
#                 });
#
#                 /** GA4Event */
#                 dataLayer.push({
#                     'event': 'view_item_list',
#                     'ecommerce': {
#                         'items': [
#                                                             {
#                                     'item_name': 'Laptop Gamer Lenovo Legion 5 15IAH7H 15.6\" Full HD, Intel Core i5-12500H 3.30GHz, 8GB, 1TB SSD, NVIDIA GeForce RTX 3060, Windows 11 Home 64-bits, Español, Gris',
#                                     'item_id': '82RB00PBLM',
#                                     'price': 22339,
#                                                                         'item_brand': 'LENOVO',
#                                                                                                                                                                                                                                             'item_category': 'Computadoras',
#                                                                                                                                 'item_category2': 'Laptops',
#                                                                                                                                                             'item_list_name': 'category',
#                                     'item_variant': 'NA',
#                                     'index': 1
#                                 },
#                                                             {
#                                     'item_name': 'Laptop Lenovo IdeaPad 5-14ALC05 14\" Full HD, AMD Ryzen 5 5500U 2.10GHz, 8GB, 256GB SSD, Windows 11 Home 64-bit, Español, Platino',
#                                     'item_id': '82LM00SLLM',
#                                     'price': 9549,
#                                                                         'item_brand': 'LENOVO',
#                                                                                                                                                                                                                                             'item_category': 'Computadoras',
#                                                                                                                                 'item_category2': 'Laptops',
#                                                                                                                                                             'item_list_name': 'category',
#                                     'item_variant': 'NA',
#                                     'index': 2
#                                 },
#                                                             {
#                                     'item_name': 'Laptop HP 245 G9 14\" HD, AMD Ryzen 3 5425U 2.70GHz, 8GB, 512GB SSD, Windows 11 Home 64-bit, Español, Negro',
#                                     'item_id': '7E3H1LT',
#                                     'price': 9909,
#                                                                         'item_brand': 'HP',
#                                                                                                                                                                                                                                             'item_category': 'Computadoras',
#                                                                                                                                 'item_category2': 'Laptops',
#                                                                                                                                                             'item_list_name': 'category',
#                                     'item_variant': 'NA',
#                                     'index': 3
#                                 },
#                                                             {
#                                     'item_name': 'Laptop Lenovo Thinkpad T14 Gen2 14\" Full HD, Intel Core i5-1135G7 2.40GHz, 8GB, 256GB SSD, Windows 10 Pro 64-bit, Español, Negro',
#                                     'item_id': '20W1S03300',
#                                     'price': 16459,
#                                                                         'item_brand': 'LENOVO',
#                                                                                                                                                                                                                                             'item_category': 'Computadoras',
#                                                                                                                                 'item_category2': 'Laptops',
#                                                                                                                                                             'item_list_name': 'category',
#                                     'item_variant': 'NA',
#                                     'index': 4
#                                 },
#                                                             {
#                                     'item_name': 'Laptop HP 245 G9 14\" HD, AMD Ryzen 3 5425U 2.70GHz, 8GB, 512GB SSD, Windows 11 Pro 64-bit, Español, Gris',
#                                     'item_id': '7E3H3LT',
#                                     'price': 12409,
#                                                                         'item_brand': 'HP',
#                                                                                                                                                                                                                                             'item_category': 'Computadoras',
#                                                                                                                                 'item_category2': 'Laptops',
#                                                                                                                                                             'item_list_name': 'category',
#                                     'item_variant': 'NA',
#                                     'index': 5
#                                 },
#                                                             {
#                                     'item_name': 'Laptop HP 240 G8 14\" HD, Intel Core i5-1135G7 2.40GHz, 8GB, 512GB SSD, Windows 11 Pro 64-bit, Español, Negro',
#                                     'item_id': '5U0S5LT',
#                                     'price': 12929,
#                                                                         'item_brand': 'HP',
#                                                                                                                                                                                                                                             'item_category': 'Computadoras',
#                                                                                                                                 'item_category2': 'Laptops',
#                                                                                                                                                             'item_list_name': 'category',
#                                     'item_variant': 'NA',
#                                     'index': 6
#                                 },
#                                                             {
#                                     'item_name': 'Laptop HP 240 G8 14\" HD, Intel Core i3-1115G4 1.70GHz, 8GB, 512GB SSD, Windows 11 Pro 64-bit, Español, Negro',
#                                     'item_id': '6K710LT',
#                                     'price': 11019,
#                                                                         'item_brand': 'HP',
#                                                                                                                                                                                                                                             'item_category': 'Computadoras',
#                                                                                                                                 'item_category2': 'Laptops',
#                                                                                                                                                             'item_list_name': 'category',
#                                     'item_variant': 'NA',
#                                     'index': 7
#                                 },
#                                                             {
#                                     'item_name': 'Laptop Lenovo IdeaPad 3 14ITL05 14\" HD, Intel Core i3-1115G4 3GHz, 8GB, 512GB SSD, Windows 11 Home 64-bit, Español, Plata',
#                                     'item_id': '81X700EGLM',
#                                     'price': 8889,
#                                                                         'item_brand': 'LENOVO',
#                                                                                                                                                                                                                                             'item_category': 'Computadoras',
#                                                                                                                                 'item_category2': 'Laptops',
#                                                                                                                                                             'item_list_name': 'category',
#                                     'item_variant': 'NA',
#                                     'index': 8
#                                 },
#                                                             {
#                                     'item_name': 'Laptop HP 245 G9 14\" HD, AMD Ryzen 5 5625U 2.30GHz, 8GB, 256GB SSD, Windows 11 Pro 64-bit, Español, Plata',
#                                     'item_id': '7E3H6LT',
#                                     'price': 13079,
#                                                                         'item_brand': 'HP',
#                                                                                                                                                                                                                                             'item_category': 'Computadoras',
#                                                                                                                                 'item_category2': 'Laptops',
#                                                                                                                                                             'item_list_name': 'category',
#                                     'item_variant': 'NA',
#                                     'index': 9
#                                 },
#                                                             {
#                                     'item_name': 'Laptop Lenovo V14 G2 ALC 14\" HD, AMD Ryzen 7 5700U 1.80GHz, 16GB, 512GB SSD, Windows 10 Pro 64-bit, Español, Gris',
#                                     'item_id': '82KC0084LM',
#                                     'price': 17549,
#                                                                         'item_brand': 'LENOVO',
#                                                                                                                                                                                                                                             'item_category': 'Computadoras',
#                                                                                                                                 'item_category2': 'Laptops',
#                                                                                                                                                             'item_list_name': 'category',
#                                     'item_variant': 'NA',
#                                     'index': 10
#                                 },
#                                                             {
#                                     'item_name': 'Laptop Lenovo ThinkBook 14s G2 ITL 14\" Full HD, Intel Core i5-1135G7 2.40GHz, 16GB, 256GB SSD, Windows 10 Pro 64-bit, Español, Gris',
#                                     'item_id': '20VA0031LM',
#                                     'price': 18489,
#                                                                         'item_brand': 'LENOVO',
#                                                                                                                                                                                                                                             'item_category': 'Computadoras',
#                                                                                                                                 'item_category2': 'Laptops',
#                                                                                                                                                             'item_list_name': 'category',
#                                     'item_variant': 'NA',
#                                     'index': 11
#                                 },
#                                                             {
#                                     'item_name': 'Laptop ASUS ExpertBook B1400 14\" Full HD, Intel Core i5-1135G7 2.40GHz, 8GB, 512GB SSD, Windows 10 Pro 64-bit, Español, Negro',
#                                     'item_id': 'B1400CEAE-I58G512-P2',
#                                     'price': 17489,
#                                                                         'item_brand': 'ASUS',
#                                                                                                                                                                                                                                             'item_category': 'Computadoras',
#                                                                                                                                 'item_category2': 'Laptops',
#                                                                                                                                                             'item_list_name': 'category',
#                                     'item_variant': 'NA',
#                                     'index': 12
#                                 },
#                                                             {
#                                     'item_name': 'Laptop Gamer ASUS TUF Dash F15 15.6\" Full HD, Intel Core i7-12650H 2.30GHz, 16GB, 512GB SSD, NVIDIA GeForce RTX 3070, Windows 11 Home 64-bit, Inglés, Negro',
#                                     'item_id': '90NR0AV3-M001V0',
#                                     'price': 24169,
#                                                                         'item_brand': 'ASUS',
#                                                                                                                                                                                                                                             'item_category': 'Computadoras',
#                                                                                                                                 'item_category2': 'Laptops',
#                                                                                                                                                             'item_list_name': 'category',
#                                     'item_variant': 'NA',
#                                     'index': 13
#                                 },
#                                                             {
#                                     'item_name': 'Laptop HP 250 G9 15.6\" HD, Intel Core i7-1255U 3.50GHz, 8GB, 512GB SSD, Windows 11 Pro 64-bit, Español, Gris',
#                                     'item_id': '7H6B6LA',
#                                     'price': 18209,
#                                                                         'item_brand': 'HP',
#                                                                                                                                                                                                                                             'item_category': 'Computadoras',
#                                                                                                                                 'item_category2': 'Laptops',
#                                                                                                                                                             'item_list_name': 'category',
#                                     'item_variant': 'NA',
#                                     'index': 14
#                                 },
#                                                             {
#                                     'item_name': 'Laptop Gamer Alienware M15 R7 15.6\" Full HD, Intel Core i7-12700H 3.50GHz, 16GB, 512GB SSD, NVIDIA GeForce RTX 3060, Windows 11 Home 64-bit, Español, Negro',
#                                     'item_id': 'AM15R7_FI7165123060BW11S_123',
#                                     'price': 37069,
#                                                                         'item_brand': 'ALIENWARE',
#                                                                                                                                                                                                                                             'item_category': 'Computadoras',
#                                                                                                                                 'item_category2': 'Laptops',
#                                                                                                                                                             'item_list_name': 'category',
#                                     'item_variant': 'NA',
#                                     'index': 15
#                                 },
#                                                             {
#                                     'item_name': 'Laptop HP 245 G9 14\" HD, AMD Ryzen 5 5625U 2.30GHz, 8GB, 512GB SSD, Windows 11 Pro 64-bit, Español, Plata',
#                                     'item_id': '7E3H7LT',
#                                     'price': 12929,
#                                                                         'item_brand': 'HP',
#                                                                                                                                                                                                                                             'item_category': 'Computadoras',
#                                                                                                                                 'item_category2': 'Laptops',
#                                                                                                                                                             'item_list_name': 'category',
#                                     'item_variant': 'NA',
#                                     'index': 16
#                                 },
#                                                     ]
#                     }
#                 });
#
#
#                 if (window.cpGa && window.cpGa.ecProdImp && window.cpGa.ecProdImp.length > 0) {
#             dataLayer.push({
#                 'ecommerce': {
#                     'impressions': window.cpGa.ecProdImp
#                 }
#             });
#         }
#   </script>
#   <!-- Google Tag Manager -->
#   <script>
#    (function(w,d,s,l,i){
#             w[l]=w[l]||[];w[l].push({
#                 'gtm.start': new Date().getTime(),'event':'gtm.js'
#             });
#             var f=d.getElementsByTagName(s)[0],
#                 j=d.createElement(s),
#                 dl=l!='dataLayer'?'&l='+l:'';
#             j.async=true;
#             j.src='//www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
#         })(window, document, 'script', 'dataLayer', 'GTM-TZF4FD');
#
#
#
#
#                                 let addToCart=null;
#
#
#             // If request isn't from a search, registry eventType as category-page-view
#                             //Google Recommendations AI category-page-view
#                 const categoryPageView = {
#                     'cloud_retail': {
#                         'eventType': 'category-page-view',
#                         //Removes starting and ending '/' and replaces inner '/' with ' > '
#                         'pageCategories': [window.location.pathname.replace(/^\/|\/$/g, '').replace(/\//g, ' > ')],
#                     }
#                 };
#
#                 categoryPageView.cloud_retail.visitorId = gtmCookie ? gtmCookie : loginCookie;
#                 dataLayer.push(categoryPageView);
#
#                 categoryPageView.cloud_retail.visitorId = getCookie("_ga");
#
#                 if ( !categoryPageView.cloud_retail.visitorId ) {
#                     categoryPageView.cloud_retail.visitorId = "GA1.2.1758256664.1659050322";
#                 }
#
#                 _gre.push(['logEvent', categoryPageView.cloud_retail]);
#
#             dataLayer.push({
#                 'event': 'track_content_group',
#                 'content_group': 'Listing'
#             });
#
#
#
#
#         //criteo pixel $oxcmp_utils->emcriteo_active()
#                     dataLayer.push({
#                 'criteo_data': [{"event":"setAccount","account":6218},{"event":"setSiteType","type":"d"},{"event":"setHashedEmail","email":""},{"event":"viewList","item":["82RB00PBLM","82LM00SLLM","7E3H1LT","20W1S03300"]}]
#             })
#   </script>
#   <!-- End Google Tag Manager -->
#   <script id="cp-category-view-data" type="application/json">
#    {"id":"2f60c37a62c2a35200a845c09a3e8bf9","type":"cat","articleList":null,"linkToCompare":{"id":null,"title":"Comparaci\u00f3n de producto","url":"https://www.cyberpuerta.mx/index.php?cl=compare","image":null},"categoryAncestors":["4fe38c01729fc","2f60c37a62c2a35200a845c09a3e8bf9"],"listMode":null,"pageSize":null,"page":0,"cpsp":{}}
#   </script>
#   <script id="cp-user-info-view-data" type="application/json">
#    {"isLoggedIn":false,"isBaseLogin":false,"picture":"https:\/\/www.cyberpuerta.mx\/out\/cyberpuertaV5\/img\/userblank.png","name":null,"nameAccount":null,"accountUrls":[],"defaultPicture":null,"email":null,"id":null,"saldo":{"active":false,"amount":0,"minimumOrderValue":0},"clientReference":null,"anonId":null,"zip":null,"emailActivation":true,"salesman":null,"isProcurement":null,"extraData":null,"identityVerificationStatus":null}
#   </script>
#   <meta content="width=device-width,initial-scale=1.0" name="viewport"/>
#   <title>
#    Venta de Laptops de Dell, HP, Acer y Lenovo y más marcas | Cyberpuerta.mx
#   </title>
#   <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
#   <meta content="IE=Edge" http-equiv="X-UA-Compatible"/>
#   <script type="text/javascript">
#    (window.NREUM||(NREUM={})).init={ajax:{deny_list:["bam.nr-data.net"]}};(window.NREUM||(NREUM={})).loader_config={licenseKey:"4879248977",applicationID:"66344412"};;/*! For license information please see nr-loader-rum-1.236.0.min.js.LICENSE.txt */
# (()=>{"use strict";var e,t,n={5763:(e,t,n)=>{n.d(t,{P_:()=>f,Mt:()=>p,C5:()=>s,DL:()=>m,OP:()=>_,lF:()=>E,Yu:()=>y,Dg:()=>g,CX:()=>c,GE:()=>b,sU:()=>j});var r=n(8632),i=n(9567);const o={beacon:r.ce.beacon,errorBeacon:r.ce.errorBeacon,licenseKey:void 0,applicationID:void 0,sa:void 0,queueTime:void 0,applicationTime:void 0,ttGuid:void 0,user:void 0,account:void 0,product:void 0,extra:void 0,jsAttributes:{},userAttributes:void 0,atts:void 0,transactionName:void 0,tNamePlain:void 0},a={};function s(e){if(!e)throw new Error("All info objects require an agent identifier!");if(!a[e])throw new Error("Info for ".concat(e," was never set"));return a[e]}function c(e,t){if(!e)throw new Error("All info objects require an agent identifier!");a[e]=(0,i.D)(t,o),(0,r.Qy)(e,a[e],"info")}var d=n(7056);const u=()=>{const e={blockSelector:"[data-nr-block]",maskInputOptions:{password:!0}};return{allow_bfcache:!0,privacy:{cookies_enabled:!0},ajax:{deny_list:void 0,enabled:!0,harvestTimeSeconds:10},distributed_tracing:{enabled:void 0,exclude_newrelic_header:void 0,cors_use_newrelic_header:void 0,cors_use_tracecontext_headers:void 0,allowed_origins:void 0},session:{domain:void 0,expiresMs:d.oD,inactiveMs:d.Hb},ssl:void 0,obfuscate:void 0,jserrors:{enabled:!0,harvestTimeSeconds:10},metrics:{enabled:!0},page_action:{enabled:!0,harvestTimeSeconds:30},page_view_event:{enabled:!0},page_view_timing:{enabled:!0,harvestTimeSeconds:30,long_task:!1},session_trace:{enabled:!0,harvestTimeSeconds:10},harvest:{tooManyRequestsDelay:60},session_replay:{enabled:!1,harvestTimeSeconds:60,sampleRate:.1,errorSampleRate:.1,maskTextSelector:"*",maskAllInputs:!0,get blockClass(){return"nr-block"},get ignoreClass(){return"nr-ignore"},get maskTextClass(){return"nr-mask"},get blockSelector(){return e.blockSelector},set blockSelector(t){e.blockSelector+=",".concat(t)},get maskInputOptions(){return e.maskInputOptions},set maskInputOptions(t){e.maskInputOptions={...t,password:!0}}},spa:{enabled:!0,harvestTimeSeconds:10}}},l={};function f(e){if(!e)throw new Error("All configuration objects require an agent identifier!");if(!l[e])throw new Error("Configuration for ".concat(e," was never set"));return l[e]}function g(e,t){if(!e)throw new Error("All configuration objects require an agent identifier!");l[e]=(0,i.D)(t,u()),(0,r.Qy)(e,l[e],"config")}function p(e,t){if(!e)throw new Error("All configuration objects require an agent identifier!");var n=f(e);if(n){for(var r=t.split("."),i=0;i<r.length-1;i++)if("object"!=typeof(n=n[r[i]]))return;n=n[r[r.length-1]]}return n}const h={accountID:void 0,trustKey:void 0,agentID:void 0,licenseKey:void 0,applicationID:void 0,xpid:void 0},v={};function m(e){if(!e)throw new Error("All loader-config objects require an agent identifier!");if(!v[e])throw new Error("LoaderConfig for ".concat(e," was never set"));return v[e]}function b(e,t){if(!e)throw new Error("All loader-config objects require an agent identifier!");v[e]=(0,i.D)(t,h),(0,r.Qy)(e,v[e],"loader_config")}const y=(0,r.mF)().o;var w=n(385),A=n(6818);const x={buildEnv:A.Re,bytesSent:{},queryBytesSent:{},customTransaction:void 0,disabled:!1,distMethod:A.gF,isolatedBacklog:!1,loaderType:void 0,maxBytes:3e4,offset:Math.floor(w._A?.performance?.timeOrigin||w._A?.performance?.timing?.navigationStart||Date.now()),onerror:void 0,origin:""+w._A.location,ptid:void 0,releaseIds:{},session:void 0,xhrWrappable:"function"==typeof w._A.XMLHttpRequest?.prototype?.addEventListener,version:A.q4},D={};function _(e){if(!e)throw new Error("All runtime objects require an agent identifier!");if(!D[e])throw new Error("Runtime for ".concat(e," was never set"));return D[e]}function j(e,t){if(!e)throw new Error("All runtime objects require an agent identifier!");D[e]=(0,i.D)(t,x),(0,r.Qy)(e,D[e],"runtime")}function E(e){return function(e){try{const t=s(e);return!!t.licenseKey&&!!t.errorBeacon&&!!t.applicationID}catch(e){return!1}}(e)}},9567:(e,t,n)=>{n.d(t,{D:()=>i});var r=n(50);function i(e,t){try{if(!e||"object"!=typeo ...
#   </script>
#   <meta content="Venta del mejor catalogo de Laptops con las marcas LENOVO, DELL, HP y mas. Al mejor precio del mercado, 100% seguro." name="description"/>
#   <meta content="Computadoras - Laptops." name="keywords"/>
#   <link href="https://www.cyberpuerta.mx/Computadoras/Laptops/" rel="canonical"/>
#   <link href="https://www.cyberpuerta.mx/out/cyberpuertaV5/img/favicon.ico" rel="shortcut icon"/>
#   <script id="cp-env-data" type="application/json">
#    {"cl":"alist","isMobile":false,"isCpx":false,"enableCpNotify":false,"shopUrl":"https:\/\/www.cyberpuerta.mx","enableBanners":1690351200,"bannersFindUrl":"https:\/\/us-central1-cyberpuerta-144818.cloudfunctions.net\/cp-banner-find","bannersExpires":1690399955,"bannerPlaces":["list-main","left-top","side-left","side-right","page-top","list-main","list-left-top","side-left","side-right","page-top"],"bannerContext":[{"name":"path","value":["4fe38c01729fc","2f60c37a62c2a35200a845c09a3e8bf9"]},{"name":"id","value":"2f60c37a62c2a35200a845c09a3e8bf9"},{"name":"man","value":[]},{"name":"cklist","value":[]},{"name":"search","value":""}],"baseApiData":"*,*,4f1f198301cd6","shopPrefix":"cp","env":"prod","restrictionGroup":"1","restrictionGroupName":"Cyberpuerta","sessionToken":"","sessionId":null,"apiVersion":"v0.1","etaCalculatorUri":"https:\/\/cp-eta-calculator-e346qjngfq-uc.a.run.app","etaCalculatorExpires":1690285903,"additional":null,"noSpa":false,"showVat":true,"rai":false,"fid":{"enabled":true,"gsi_clientId":"1044917490556-kg2simrb5fm8ml0s0uubmgeri9rrfhf1.apps.googleusercontent.com","gsi_clientId_android":"1044917490556-9kvrnb85iao90rr8ejf6l4ksd5idut33.apps.googleusercontent.com","gsi_clientId_ios":"1044917490556-nqt66sdvhcel94loopng83jvjle8g4va.apps.googleusercontent.com","apple_clientId":"mx.cyberpuerta","autoLink":false,"autoRegister":true,"canAddPasswordAgain":true,"requirePasswordToLink":false},"cpAdditionalTaxInfo":true,"catalogExpires":"20230725131258"}
#   </script>
#   <script id="cp-layout-view-data" type="application/json">
#    {"initialCategories":[{"id":"99748977a0a9f40e2.09126772","title":"C\u00f3mputo (Hardware)","link":"https://www.cyberpuerta.mx/Computo-Hardware/","image":"cp-menu-icon1","parentId":"","subCategories":[],"path":[],"hasSubCategories":true},{"id":"07a49b1b2f27967a1.24876408","title":"Impresi\u00f3n y Copiado","link":"https://www.cyberpuerta.mx/Impresion-y-Copiado/","image":"cp-menu-icon2","parentId":"","subCategories":[],"path":[],"hasSubCategories":true},{"id":"4fe38c01729fc","title":"Computadoras","link":"https://www.cyberpuerta.mx/Computadoras/","image":"cp-menu-icon6","parentId":"","subCategories":[],"path":[],"hasSubCategories":true},{"id":"4fe353e55a8d4","title":"Audio y Video","link":"https://www.cyberpuerta.mx/Audio-y-Video/","image":"cp-menu-icon4","parentId":"","subCategories":[],"path":[],"hasSubCategories":true},{"id":"5e8f92ef7a3a3","title":"Home Office","link":"https://www.cyberpuerta.mx/Home-Office/","image":"cp-menu-icon9","parentId":"","subCategories":[],"path":[],"hasSubCategories":true}],"moreCategoriesUrl":"https://www.cyberpuerta.mx/out/generated/main-menu/6-oxrootid-1689996556.json","menuUrl":"https://www.cyberpuerta.mx/out/generated/main-menu/main-1689996524.json","basket":{"empty":true,"articles":[],"linkNextStep":null,"numberOfItems":null,"savedItems":[],"numberOfSavedArticles":null,"linkToOffers":null,"saldoData":null,"messagesValidation":null,"errors":null,"forceOpen":null,"msiData":null,"summary":null,"paymentMethods":[],"CheckedPaymentId":""},"beforeCategories":[{"title":"Inicio","icon":"cp-menu-home-image","href":"https://www.cyberpuerta.mx/","template":""},{"title":"Mi cuenta","icon":"cp-menu-icon5","href":"","template":"cp-ko-user-menu"}],"afterCategories":[{"title":"Otras\u003Cbr\u003Ecategor\u00edas","icon":"cp-menu-icon7","href":"","template":"cp-ko-category-menu2"},{"title":"M\u00e1s\u003Cbr\u003Einformaci\u00f3n","icon":"cp-menu-icon3","href":"","template":"cp-ko-moreinfo-menu"}],"simpleHeader":false,"noHeader":false,"accountUrls":[{"url":"https://www.cyberpuerta.mx/mi-cuenta/","lang":"Mi cuenta"},{"url":"https://www.cyberpuerta.mx/historial-de-pedidos/","lang":"Historial de pedidos"},{"url":"https://www.cyberpuerta.mx/mis-direcciones/","lang":"Datos de env\u00edo, pago y facturaci\u00f3n"},{"url":"https://www.cyberpuerta.mx/mis-favoritos/","lang":"Mis favoritos"},{"url":"https://www.cyberpuerta.mx/mis-opiniones/","lang":"Mis opiniones"},{"url":"https://www.cyberpuerta.mx/mis-preguntas/","lang":"Mis preguntas"},{"url":"https://www.cyberpuerta.mx/mis-respuestas/","lang":"Mis respuestas"},{"url":"https://www.cyberpuerta.mx/mi-contrasena/","lang":"Configuraci\u00f3n de cuenta"},{"url":"https://www.cyberpuerta.mx/preferencias-de-correo/","lang":"Suscripciones"},{"url":"js-dynamic","lang":""},{"url":"#user-form=logout","lang":"Salir de cuenta","class":"button primary hollow expanded"}],"loginOptions":{"activeClass":"alist","navParams":"\u003Cinput type=\"hidden\" name=\"cnid\" value=\"2f60c37a62c2a35200a845c09a3e8bf9\" /\u003E\n\u003Cinput type=\"hidden\" name=\"actcontrol\" value=\"alist\" /\u003E\n","action":"https://www.cyberpuerta.mx/index.php?","errors":[],"sizeOptions":[],"loginLink":"https://www.cyberpuerta.mx/web/account/login","logoutLink":"https://www.cyberpuerta.mx/web/account/logout","createAccountLink":"https://www.cyberpuerta.mx/crear-cuenta/","forgotPasswordLink":"https://www.cyberpuerta.mx/olvide-mi-contrasena/"},"cmsUrls":[],"basketUrl":"https://www.cyberpuerta.mx/carrito-de-compras/","homeLink":"https://www.cyberpuerta.mx/","actionLink":"https://www.cyberpuerta.mx/","searchParam":"","fidLink":null}
#   </script>
#   <script id="cp-view-data" type="application/json">
#    {"id":"2f60c37a62c2a35200a845c09a3e8bf9","type":"cat","articleList":null,"linkToCompare":{"id":null,"title":"Comparaci\u00f3n de producto","url":"https://www.cyberpuerta.mx/index.php?cl=compare","image":null},"categoryAncestors":["4fe38c01729fc","2f60c37a62c2a35200a845c09a3e8bf9"],"listMode":null,"pageSize":null,"page":0,"cpsp":{}}
#   </script>
#   <script data-cp-lang="" type="application/json">
#    {"cpx-compare":"Comparar","cpx-offer":"Oferta","cpx-new":"Nuevo","cpx-just-today":"\u00a1S\u00f3lo hoy!","cpx-from":"Desde","cpx-pcs":"Pza.|Pzs.","cpx-pcs-stock1":"Pieza en|Piezas en","cpx-pcs-stock2":"bodega|bodegas","cpx-shipping":"Env\u00edo","cpx-free-signs":"\u00a1Gratis!","cpx-out-of-stock":"Agotado","cpx-create-alert":"Crear alerta","cpx-see-more":"Ver m\u00e1s","cpx-add-to-cart":"Agregar a carrito","cpx-high-eta":"+%d d\u00edas","cpx-sku":"SKU","cpx-in-existence":"En existencia","cpx-show-all-filters":"Ver todos los filtros","cpx-show-more-options":"Ver m\u00e1s opciones...","cpx-show-less-options":"Ver menos opciones...","cpx-filters":"Filtros","cpx-applied-filters":"Filtros aplicados","cpx-in-cat-search":"Buscar en categor\u00eda","cpx-in-man-search":"Buscar en marca","cpx-sort-by":"Ordenar por","cpx-sort-by-cprelevance-desc":"Relevancia","cpx-sort-by-oxtitle-asc":"Nombre A-Z","cpx-sort-by-oxtitle-desc":"Nombre Z-A","cpx-sort-by-oxvarminprice-asc":"Menor Precio","cpx-sort-by-oxvarminprice-desc":"Mayor Precio","cpx-sort-by-oxstock-desc":"Disponibilidad","cpx-sort-by-oxinsert-desc":"M\u00e1s Nuevos","cpx-sort-by-oxrating-desc":"Mejor Calificaci\u00f3n","cpx-stock-alert-highlight":"Notificaci\u00f3n sobre nuevas existencias","cpx-stock-alert-text":"Este producto se encuentra temporalmente agotado, pero le enviaremos una notificaci\u00f3n a su correo electr\u00f3nico cuando est\u00e9 nuevamente disponible.","cpx-stock-alert-button":"Notificarme de Existencias","cpx-email":"E-mail","cpx-stock-alert-logged-msg":"Se ha activado la notificaci\u00f3n y recibir\u00e1s un correo cuando tengamos nuevas existencias de este art\u00edculo. ","cpx-stock-alert-logged-success-msg":"cpx-stock-alert-logged-success-msg","cpx-n-stars":"%d estrellas","cpx-from-n":"Desde %s","cpx-to-n":"Hasta %s","cpx-delete-all":"Borrar todos","cpx-price":"Precio","NO_ITEMS_FOUND":"No se encontraron resultados para","SEARCH_RECOMMENDATION_TITLE":"Consejos de b\u00fasqueda","SEARCH_RECOMMENDATION_ONE":"Intenta buscar por tipo de producto, marca o caracter\u00edstica del producto.","SEARCH_RECOMMENDATION_TWO":"Revisa la ortografia.","SEARCH_RECOMMENDATION_THREE":"Amplia tu b\u00fasqueda utilizando menos palabras o m\u00e1s generales.","SEARCH_RECOMMENDATION_FOUR":"Elimina los filtros aplicados que no consideres revelantes para tu b\u00fasqueda.","SEARCH_RECOMMENDATION_FIVE":"O da clic en el siguiente bot\u00f3n.","SEARCH_GO_TO_HOMEPAGE":"Ir a la p\u00e1gina principal","cpm_search_results_title":"%d resultados para \"%s\""}
#   </script>
#   <script>
#    window.cp = {}
#   </script>
#   <script data-cp-orig="cdn.jquery.js" src="https://cdnjs.cloudflare.com/ajax/libs/jquery/3.5.1/jquery.min.js">
#   </script>
#   <script data-cp-orig="cdn.foundation.js" src="https://cdnjs.cloudflare.com/ajax/libs/foundation/6.5.3/js/foundation.min.js">
#   </script>
#   <script data-cp-orig="cdn.knockout.js" src="https://cdnjs.cloudflare.com/ajax/libs/knockout/3.5.0/knockout-min.js">
#   </script>
#   <script data-cp-orig="cdn.moment.js" src="https://cdnjs.cloudflare.com/ajax/libs/moment.js/2.27.0/moment.min.js">
#   </script>
#   <script data-cp-orig="cdn.moment-es.js" src="https://cdnjs.cloudflare.com/ajax/libs/moment.js/2.27.0/locale/es.min.js">
#   </script>
#   <script data-cp-orig="cdn.moment-timezone.js" src="https://cdnjs.cloudflare.com/ajax/libs/moment-timezone/0.5.26/moment-timezone-with-data-10-year-range.min.js">
#   </script>
#   <script data-cp-orig="cdn.Swiper.js" src="https://cdnjs.cloudflare.com/ajax/libs/Swiper/4.3.5/js/swiper.min.js">
#   </script>
#   <script data-cp-orig="cdn.vue.js" src="https://cdnjs.cloudflare.com/ajax/libs/vue/2.7.10/vue.runtime.min.js">
#   </script>
#   <script data-cp-orig="cdn.nouislider.js" src="https://cdnjs.cloudflare.com/ajax/libs/noUiSlider/14.6.3/nouislider.min.js">
#   </script>
#   <script data-cp-orig="google.account" src="https://accounts.google.com/gsi/client">
#   </script>
#   <script data-cp-orig="apple.account" src="https://appleid.cdn-apple.com/appleauth/static/jsapi/appleid/1/es_MX/appleid.auth.js">
#   </script>
#   <script data-cp-orig="manifest.js" src="https://www.cyberpuerta.mx/out/dist/manifest.29647e8565708a590135.js">
#   </script>
#   <script data-cp-orig="cp.app.js" src="https://www.cyberpuerta.mx/out/dist/cp.app.c8e017a5689fba080c95.js">
#   </script>
#   <script data-cp-orig="cp.app.foundation.js" src="https://www.cyberpuerta.mx/out/dist/cp.app.foundation.0a5a8952f9e3dc1de013.js">
#   </script>
#   <script data-cp-orig="cp.app.legacy.js" src="https://www.cyberpuerta.mx/out/dist/cp.app.legacy.0915f10e27b62a63394f.js">
#   </script>
#   <script data-cp-orig="vendors~cp.app.js" src="https://www.cyberpuerta.mx/out/dist/vendors~cp.app.458736c1a92521caac2e.js">
#   </script>
#  </head>
#  <!-- OXID eShop Community Edition, Version 4, Shopping Cart System (c) OXID eSales AG 2003 - 2023 - http://www.oxid-esales.com -->
#  <body class="alist">
#   <!-- Google Tag Manager -->
#   <noscript>
#    <iframe height="0" src="//www.googletagmanager.com/ns.html?id=GTM-TZF4FD" style="display:none;visibility:hidden" width="0">
#    </iframe>
#   </noscript>
#   <div class="general-overlay cp-overlay1 hide">
#    <div class="cp-overlay-cnt" style="background-image:url('https://www.cyberpuerta.mx/out/cyberpuertaV5/img/loading_md.gif')">
#     <div class="inner-cnt">
#      <div class="cp-overlay-loader">
#      </div>
#      <div class="cp-overlay-title">
#      </div>
#      <div class="cp-overlay-subtitle">
#      </div>
#     </div>
#    </div>
#   </div>
#   <div data-cp-banner-place="side-left">
#   </div>
#   <div data-cp-banner-place="side-right">
#   </div>
#   <div class="cp-page-bg">
#    <div data-cp-banner-place="page-top">
#    </div>
# ...
#                 }
#             }
#         }
#
#         if (!display) {
#             $(window).on("mouseleave", cpexitintent_leave);
#         }
#     });
# /**
#      * set the cookie to be sure the popup never display
#      */
#     function cpsaldo_set_newsletter_cookie()
#     {
#         let param=$('form#cpsaldo_newsletter_cookie').serialize();
#         $.ajax({
#             type: 'POST',
#             url: 'https://www.cyberpuerta.mx/index.php?',
#             data: param,
#             cache: false,
#             dataType: "html",
#         }).done(function(data) {
#             console.log(data);
#         });
#     }
#
#
#     var cpsaldo_newslettersticker_timer;
#     $('#cpsaldo_newslettersticker').mouseenter(function () {
#         clearTimeout(cpsaldo_newslettersticker_timer);
#         if ($('#cpsaldo_newslettersticker').attr('data-open') == "0") {
#             $('#cpsaldo_newslettersticker').attr('data-open', '2');
#             $('#cpsaldo_newslettersticker .bg1').animate({top: "-=120"}, 400, function () {
#             });
#             $('#cpsaldo_newslettersticker .bg2').delay(200).animate({top: "-=120"}, 400, function () {
#                 $('#cpsaldo_newslettersticker').attr('data-open', '1');
#             });
#             $('#cpsaldo_newslettersticker .bg3').animate({top: "-=120"}, 400, function () {
#             });
#         }
#         $('#cpsaldo_newslettersticker .close').stop(true).animate({opacity: 1}, 200, function () {
#         });
#     });
#     $('#cpsaldo_newslettersticker').mouseleave(function () {
#         if ($('#cpsaldo_newslettersticker').attr('data-open') != "0") {
#             cpsaldo_newslettersticker_timer = setTimeout(function () {
#                 $('#cpsaldo_newslettersticker .bg1').animate({top: "+=120"}, 1000, function () {
#                 });
#                 $('#cpsaldo_newslettersticker .bg2').animate({top: "+=120"}, 1000, function () {
#                     $('#cpsaldo_newslettersticker').attr('data-open', '0');
#                 });
#                 $('#cpsaldo_newslettersticker .bg3').animate({top: "+=120"}, 1000, function () {
#                 });
#             }, 1500);
#         }
#         $('#cpsaldo_newslettersticker .close').stop(true).animate({opacity: 0}, 200, function () {
#         });
#     });
#     $('#cpsaldo_newslettersticker .close').click(function () {
#         $('#cpsaldo_newslettersticker').animate({
#             opacity: 0
#         });
#
#         /* set cookie */
#         cpsaldo_set_newsletter_cookie();
#     });
#     $('#cpsaldo_newslettersticker div.bg10, #cpsaldo_newslettersticker div.bg1, #cpsaldo_newslettersticker div.bg2, #cpsaldo_newslettersticker div.bg3').click(function () {
#         $('#cpsaldo_newsletter_modal_popup_link').click();
#     });
# var oxwidget_headerlogin_timeoutopen = null;
#     var oxwidget_headerlogin_timeout     = null;
#     var oxwidget_headerlogin_canclose    = true;
#     var oxwidget_headerlogin_mousehover  = false;
#     $('#oxwidget_headerlogin input').focus(function () {
#         oxwidget_headerlogin_canclose = false;
#     }).blur(function () {
#         oxwidget_headerlogin_canclose = true;
#         if (!oxwidget_headerlogin_mousehover) {
#             clearTimeout(oxwidget_headerlogin_timeoutopen);
#             oxwidget_headerlogin_timeout = setTimeout(function () {
#                 $('#oxwidget_headerlogin').removeClass('hover');
#             }, 200);
#         }
#     });
#     $('#oxwidget_headerlogin').mouseenter(function () {
#         if (oxwidget_headerlogin_timeout) {
#             clearTimeout(oxwidget_headerlogin_timeout);
#         }
#         oxwidget_headerlogin_timeoutopen = setTimeout(function () {
#             $('#oxwidget_headerlogin').addClass('hover');
#         }, 200);
#
#         oxwidget_headerlogin_mousehover = true;
#     }).mouseleave(function () {
#         oxwidget_headerlogin_mousehover = false;
#         if (oxwidget_headerlogin_canclose) {
#             clearTimeout(oxwidget_headerlogin_timeoutopen);
#             oxwidget_headerlogin_timeout = setTimeout(function () {
#                 $('#oxwidget_headerlogin').removeClass('hover');
#             }, 200);
#         }
#     });
#
#     $('#logoutBtn').click(function () {
#         if (!window.dataLayer) return;
#
#         /** GA4Event */
#         window.dataLayer.push({
#             event: 'logout'
#         });
#     });
#     $('.oxwidget_headerlogin_loginform form').on('submit', function () {
#         try{
#             let localSearches = localStorage.getItem('recentSearches');
#             let localSearchesArr = [];
#             let searchesArr = [];
#             if(localSearches) {
#
#                 localSearchesArr = JSON.parse(localSearches);
#                 localSearchesArr.forEach((e) => {
#                     if(typeof e === 'string') {
#                         searchesArr.push({
#                             'date': Math.floor((new Date().getTime() - 60000) / 1000),
#                             'keyword': e
#                         });
#                     }else {
#                         searchesArr.push(e);
#                     }
#                 });
#             }
#             if(searchesArr.length > 8) {
#                 searchesArr = searchesArr.slice(searchesArr.length - 8, searchesArr.length);
#             }
#             // Add cookie to track that search is suggested
#             const d = new Date();
#             d.setTime(d.getTime() + 8000);
#             let expires = d.toUTCString();
#             document.cookie = 'recentSearchesCookie='+JSON.stringify(searchesArr)+'; expires='+expires+'; path=/;'
#         }catch (e){console.error(e);}
#     });
# $(function () {
#         var notice = $('#oxwidget_headernotice');
#         var popup = notice.find('.oxwidget_headernotice_popup');
#         popup.find('li').on("click mouseenter", function (e) {
#             popup.find('li').removeClass('selected');
#             $(e.currentTarget).addClass('selected');
#             popup.find('.oxwidget_headernotice_products > div').css('display', 'none');
#             popup.find('.oxwidget_headernotice_products #products' + $(e.currentTarget).attr('data-id')).css('display', 'block');
#         });
#
#         notice.hoverIntent(function () {
#             notice.addClass('hover');
#             var listbox = notice.find('.oxwidget_headernotice_listsbox');
#             if (listbox.length > 0 && !notice.attr('data-checked')) {
#                 notice.attr('data-checked', '1');
#                 var h = listbox.outerHeight(true);
#                 notice.find('.oxwidget_headernotice_products > div').each(function (i, el) {
#                     h = Math.max($(el).outerHeight(true), h);
#                 });
#                 popup.css('height', (h + 2) + 'px');
#                 popup.find('li').first().trigger("click");
#             }
#         }, function () {
#             notice.removeClass('hover');
#         });
#
#     });
#     function notice_global_remove(wid, aid) {
#         $('#oxwidget_headernotice_globalremove_wid').val(wid);
#         $('#oxwidget_headernotice_globalremove_aid').val(aid);
#         $('#oxwidget_headernotice_globalremove').trigger("submit");
#     }
# $(function () {
#         var help = $('#oxwidget_headerhelp');
#         help.hoverIntent(
#             function() { help.addClass('hover'); },
#             function() {help.removeClass('hover'); }
#         );
#     });
# var oxwidget_headerminibasket_timeout = null;
# $('#oxwidget_headerminibasket').mouseenter(function() {
#     $('#oxwidget_headerminibasket').addClass('hover');
#     $('#oxwidget_headerminibasket').parent('#emheaderminibasket').addClass('hover');
#     if (oxwidget_headerminibasket_timeout) {
#
#         clearTimeout(oxwidget_headerminibasket_timeout);
#     }
# }).mouseleave(function() {
#     oxwidget_headerminibasket_timeout = setTimeout(function () {
#         $('#oxwidget_headerminibasket').removeClass('hover');
#         $('#oxwidget_headerminibasket').parent('#emheaderminibasket').removeClass('hover');
#     }, 300)
# });
# $('.cp-header-overlay').click(function(){
#     $('#oxwidget_headerminibasket').removeClass('hover');
#     $('#oxwidget_headerminibasket').parent('#emheaderminibasket').removeClass('hover');
# });
# (function(){
#                 window.cpGa = window.cpGa || {};
#                 cpGa.ecPromoImp = cpGa.ecPromoImp || []; // first stored here, then pushed to datalayer
#                 window.ecPromoImpNivoShown = window.ecPromoImpNivoShown || []; // for nivoSlider
#
#                 $('a[data-ecPromoImp]').each(function(){
#                     var self = $(this);
#                     var promoFieldObject = JSON.parse(self.attr("data-ecPromoImp"));
#                     // promotion views, preparing
#                     if (promoFieldObject.creative.substr(promoFieldObject.creative.length - 2) == "-1") {
#                         // this if is because the nivoSlider will push too. If we disable the nivoSlider to do this then we remove this if
#                         window.ecPromoImpNivoShown.push(promoFieldObject.creative); // "burn" the banner so it is not counted again
#                         cpGa.ecPromoImp.push(promoFieldObject);
#                     }
#
#                     // promotion clicks
#                     self.click(function(){
#                         dataLayer.push({
#                             'event': 'promotionClick',
#                             'ecommerce': {
#                                 'promoClick': {
#                                     'promotions':[ promoFieldObject]
#                                 }
#                             }
#                         });
#                     });
#                 });
#             })();
# function cpnosto_request(place, rai = false, slot_name = "", show = false) {
#             $('#cpnosto_place').val(place);
#             let param = $('#cpnosto_form').serialize();
#             param += rai ? "&rai=true" : "";
#             param += slot_name ? `&slot_name=${ slot_name }` : "";
#             param += show ? "&show=true" : "";
#
#             // this sections
#             let specialSections = ["detail0", "home0"];
#
#             // here will be the local storage instead to use session
#             let placeId =  getCookie("_ga") + place + '';
#             let returnDataFromLocalStorage = sessionStorage.getItem(placeId);
#
#             if( !returnDataFromLocalStorage ) {
#                 $.ajax({
#                     type: 'GET',
#                     url: 'https://www.cyberpuerta.mx/index.php?',
#                     data: param,
#                     cache: false,
#                     dataType: "html",
#                 }).done(function (returndata) {
#
#                     if (returndata) {
#                         let element = `#cpnosto_${place}_result`;
#                         element += (rai) ? ".rai" : "";
#                         $(element).html(returndata);
#
#                         if ( specialSections.includes(place) ) {
#                             sessionStorage.setItem(placeId, returndata);
#                         }
#                     }
#                 });
#             } else {
#                 let element = `#cpnosto_${place}_result`;
#                 element += (rai) ? ".rai" : "";
#                 $(element).html(returnDataFromLocalStorage);
#             }
#         }
#   </script>
#   <script>
#    var oxwidget_headercompare_timeout=null;
# var oxwidget_headercompare_timeoutdelay=null;
# var oxwidget_headercompare_timeoutopen=null;
# $('#oxwidget_headercompare').mouseenter(function() {
#     /*$('#oxwidget_headercompare').addClass('hover');*/
#     if(oxwidget_headercompare_timeoutdelay)
#     {
#         clearTimeout(oxwidget_headercompare_timeoutdelay);
#     }
#     if(oxwidget_headercompare_timeout)
#     {
#         clearTimeout(oxwidget_headercompare_timeout);
#     }
#     oxwidget_headercompare_timeoutopen=setTimeout(function() {
#         $('#oxwidget_headercompare').addClass('hover');
#     },200);
# }).mouseleave(function() {
#     if(oxwidget_headercompare_timeoutdelay)
#     {
#         clearTimeout(oxwidget_headercompare_timeoutdelay);
#     }
#     if(oxwidget_headercompare_timeoutopen)
#     {
#         clearTimeout(oxwidget_headercompare_timeoutopen);
#     }
#     oxwidget_headercompare_timeout=setTimeout(function() {
#         $('#oxwidget_headercompare').removeClass('hover');
#     },200);
# });
#
#
# function compare_global_remove(id)
# {
#     $('#oxwidget_headercompare_globalremove_aid').val(id);
#     $('#oxwidget_headercompare_globalremove').submit();
# }
#
# function compare_emstr_replace(search, replace, subject)
# {
#     return subject.split(search).join(replace);
# }
# function compare_add(id)
# {
#     $('#oxwidget_headercompare .oxwidget_headercompare_header_wait').css('display','block');
#
#     $('#compare_add'+id).css('display','none');
#     $('#compare_remove'+id).css('display','block');
#
#     var href=$('#emcomparelinkbox' + id + ' .emcomparelinkbox_link_add').attr('href');
#     href=compare_emstr_replace('&amp;','&',href);
#     href=href+'&emcomparemodule=1';
#
#     $.get(href, function(data) {
#                         var tmp='https://www.cyberpuerta.mx/index.php?cl=oxwidget_headercompare_getwidget&amp;searchparam=&amp;cnid=2f60c37a62c2a35200a845c09a3e8bf9';
#         tmp=compare_emstr_replace('&amp;','&',tmp);
#         $.get(tmp,function(data) {
#             $('#oxwidget_headercompare').html(data);
#             $("#oxwidget_headercompare img").unveil();
#
#             if(oxwidget_headercompare_timeout)
#             {
#                 clearTimeout(oxwidget_headercompare_timeout);
#             }
#             $('#oxwidget_headercompare').addClass('hover');
#             oxwidget_headercompare_timeoutdelay=setTimeout(function() {
#                 $('#oxwidget_headercompare').removeClass('hover');
#             },5000);
#         });
#     });
# }
# function compare_remove(id)
# {
#     $('#oxwidget_headercompare .oxwidget_headercompare_header_wait').css('display','block');
#
#     $('#compare_add'+id).css('display','block');
#     $('#compare_remove'+id).css('display','none');
#
#     var href=$('#emcomparelinkbox' + id + ' .emcomparelinkbox_link_remove').attr('href');
#     href = href + "&emcomparemodule=1";
#     href=compare_emstr_replace('&amp;','&',href);
#     href=href+'&emcomparemodule=1';
#
#     $.get(href, function(data) {
#                         var tmp='https://www.cyberpuerta.mx/index.php?cl=oxwidget_headercompare_getwidget&amp;searchparam=&amp;cnid=2f60c37a62c2a35200a845c09a3e8bf9';
#         tmp=compare_emstr_replace('&amp;','&',tmp);
#         $.get(tmp,function(data) {
#             $('#oxwidget_headercompare').html(data);
#         });
#     });
# }
#
# $('.emcomparelinkbox_link_add').on("click", function(e) {
#     var id = $(e.currentTarget).attr('data-id');
#     compare_add(id);
#     return false;
# });
# $('.emcomparelinkbox_link_remove').on("click", function(e) {
#     var id = $(e.currentTarget).attr('data-id');
#     compare_remove(id);
#     return false;
# });
#   </script>
#   <script type="text/javascript">
#    window.NREUM||(NREUM={});NREUM.info={"beacon":"bam.nr-data.net","licenseKey":"4879248977","applicationID":"66344412","transactionName":"MQEAbUNRXkVQAEBbVghLN0tYH19OQgZbHEkOFA==","queueTime":0,"applicationTime":659,"atts":"HUYDGwtLTUs=","errorBeacon":"bam.nr-data.net","agent":""}
#   </script>
#   <script>
#    (function(){var js = "window['__CF$cv$params']={r:'7ecf2bffda72293a'};_cpo=document.createElement('script');_cpo.nonce='',_cpo.src='/cdn-cgi/challenge-platform/scripts/invisible.js',document.getElementsByTagName('head')[0].appendChild(_cpo);";var _0xh = document.createElement('iframe');_0xh.height = 1;_0xh.width = 1;_0xh.style.position = 'absolute';_0xh.style.top = 0;_0xh.style.left = 0;_0xh.style.border = 'none';_0xh.style.visibility = 'hidden';document.body.appendChild(_0xh);function handler() {var _0xi = _0xh.contentDocument || _0xh.contentWindow.document;if (_0xi) {var _0xj = _0xi.createElement('script');_0xj.innerHTML = js;_0xi.getElementsByTagName('head')[0].appendChild(_0xj);}}if (document.readyState !== 'loading') {handler();} else if (window.addEventListener) {document.addEventListener('DOMContentLoaded', handler);} else {var prev = document.onreadystatechange || function () {};document.onreadystatechange = function (e) {prev(e);if (document.readyState !== 'loading') {document.onreadystatechange = prev;handler();}};}})();
#   </script>
#  </body>
# </html>

# %%
def obtener_contenido_pagina(pagina_web):
    reponse = requests.get(pagina_web)
    return reponse.content

# %%
def analizar_contenido_html(pagina_web):
    return BeautifulSoup(pagina_web, 'html.parser')

# %%
data = []

def procesar_pagina(soup, data):
    productos = []
    precios =[]
    ratings = []
    existencias = []
    links = []
     
    producto_items = soup.find_all('div', class_='emproduct_right')
    for items in producto_items:
        producto = items.a.text.strip()
        productos.append(producto)
               
    rating_items = soup.find_all('div', class_='cpreviews_stars_box clear')
    for item in rating_items:
        rating = item.find('div', class_='cpreviews_stars_box_percent')['style']
        stars = int(rating.strip("width: ;%"))
        stars //=  20
        ratings.append(stars)
    
    precio_items = soup.find_all('label', class_='price')
    for item in precio_items:
        precio = item.get_text(strip=True)
        precios.append(precio)
    
    existencia_items = soup.find_all('div', class_='emstock')
    for item in existencia_items:
        existencia = item.get_text(strip=True)
        existencias.append(existencia)
    
    link_items = soup.find('div', class_='emproduct_right').find_all('a')
    for item in link_items:
        links.append(item['href'])

    min_lenght = min(len(productos), len(ratings), len(precios), len(existencias), len(links))

    for i in range(min_lenght):
        data.append({
            "Producto":productos[i] if i < len(productos) else None,
            "Rating":ratings[i] if i < len(ratings) else None,
            'Precio':precios[i] if i < len(precios) else None,
            "Existencia":existencias[i] if i < len(existencias) else None,
            'Enlaces': links[i] if i < len(links) else None
        })

# %%
url_base = 'https://www.cyberpuerta.mx/Computadoras/Laptops/' #Deben ser 1088 productos

num_paginas = 69

# %%
def manejar_paginacion(url_base, num_paginas):
    for i in range(1, num_paginas + 1):
        url =  url_base + str(i) + '/'
        contenido_pagina = obtener_contenido_pagina(url)
        soup = analizar_contenido_html(contenido_pagina)
        procesar_pagina(soup, data)

manejar_paginacion(url_base, num_paginas)

# %%
data
# Out:
# [{'Producto': 'Laptop Gamer Lenovo Legion 5 15IAH7H 15.6" Full HD, Intel Core i5-12500H 3.30GHz, 8GB, 1TB SSD, NVIDIA GeForce RTX 3060, Windows 11 Home 64-bits, Español, Gris',
#   'Rating': 5,
#   'Precio': '$22,339.00',
#   'Existencia': 'Disponibles:88pzas.',
#   'Enlaces': 'https://www.cyberpuerta.mx/Computadoras/Laptops/Laptop-Gamer-Lenovo-Legion-5-15IAH7H-15-6-Full-HD-Intel-Core-i5-12500H-3-30GHz-8GB-1TB-SSD-NVIDIA-GeForce-RTX-3060-Windows-11-Home-64-bits-Espanol-Gris.html'},
#  {'Producto': 'Laptop Lenovo IdeaPad 5-14ALC05 14" Full HD, AMD Ryzen 5 5500U 2.10GHz, 8GB, 256GB SSD, Windows 11 Home 64-bit, Español, Platino',
#   'Rating': 5,
#   'Precio': '$9,549.00',
#   'Existencia': 'Disponibles:78pzas.',
#   'Enlaces': 'https://www.cyberpuerta.mx/Opiniones-sobre-Laptop-Gamer-Lenovo-Legion-5-15IAH7H-15-6-Full-HD-Intel-Core-i5-12500H-3-30GHz-8GB-1TB-SSD-NVIDIA-GeForce-RTX-3060-Windows-11-Home-64-bits-Espanol-Gris/'},
#  {'Producto': 'Laptop HP 245 G9 14" HD, AMD Ryzen 3 5425U 2.70GHz, 8GB, 512GB SSD, Windows 11 Home 64-bit, Español, Negro',
#   'Rating': 4,
#   'Precio': '$9,909.00',
#   'Existencia': 'Disponibles:38pzas.',
#   'Enlaces': 'https://www.cyberpuerta.mx/Opiniones-sobre-Laptop-Gamer-Lenovo-Legion-5-15IAH7H-15-6-Full-HD-Intel-Core-i5-12500H-3-30GHz-8GB-1TB-SSD-NVIDIA-GeForce-RTX-3060-Windows-11-Home-64-bits-Espanol-Gris/'},
#  {'Producto': 'Laptop Lenovo Thinkpad T14 Gen2 14" Full HD, Intel Core i5-1135G7 2.40GHz, 8GB, 256GB SSD, Windows 10 Pro 64-bit, Español, Negro',
#   'Rating': 4,
#   'Precio': '$16,459.00',
#   'Existencia': 'Disponibles:104pzas.',
#   'Enlaces': '#'},
#  {'Producto': 'Laptop HP 245 G9 14" HD, AMD Ryzen 3 5425U 2.70GHz, 8GB, 512GB SSD, Windows 11 Pro 64-bit, Español, Gris',
#   'Rating': 4,
#   'Precio': '$12,409.00',
#   'Existencia': 'Disponibles:22pzas.',
#   'Enlaces': 'https://www.cyberpuerta.mx/lista-de-comparacion/?cnid=4fe38c01729fc'},
#  {'Producto': 'Laptop HP 14-DQ0501LA 14" HD, Intel Celeron N4120 1.10GHz, 4GB, 256GB SSD, Windows 11 Home 64-bit, Español, Negro',
#   'Rating': 4,
#   'Precio': '$5,409.00',
#   'Existencia': 'Disponibles:\n¡1pza.!',
#   'Enlaces': '#'},
#  {'Producto': 'Laptop HP 245 G9 14" HD, AMD Ryzen 5 5625U 2.30GHz, 8GB, 512GB SSD, Windows 11 Pro 64-bit, Español, Plata',
#   'Rating': 5,
#   'Precio': '$12,929.00',
#   'Existencia': 'Disponibles:38pzas.',
#   'Enlaces': 'https://www.cyberpuerta.mx/Computadoras/Laptops/Laptop-HP-245-G9-14-HD-AMD-Ryzen-5-5625U-2-30GHz-8GB-512GB-SSD-Windows-11-Pro-64-bit-Espanol-Plata.html'},
#  {'Producto': 'Laptop Lenovo ThinkPad T14 G2 14" Full HD, Intel Core i7-1185G7 3GHz, 32GB, 512GB SSD, Windows 11 Pro 64-bit, Español, Negro',
#   'Rating': 5,
#   'Precio': '$31,109.00',
#   'Existencia': 'Disponibles:43pzas.',
#   'Enlaces': '#'},
#  {'Producto': 'Laptop Lenovo V14 G2 ALC 14" HD, AMD Ryzen 5 5500U 2.10GHz, 8GB, 256GB SSD, Windows 11 Pro 64-bit, Español, Gris',
#   'Rating': 4,
#   'Precio': '$9,679.00',
#   'Existencia': 'Disponibles:106pzas.',
#   'Enlaces': 'https://www.cyberpuerta.mx/lista-de-comparacion/?cnid=4fe38c01729fc'},
#  {'Producto': 'Laptop HP ZBook Power G9 15.6" Full HD, Intel Core i7-12800H 2.40GHz, 32GB, 1TB SSD, Nvidia RTX A2000, Windows 11 Pro 64-bit, Español, Gris',
#   'Rating': 4,
#   'Precio': '$54,779.00',
#   'Existencia': 'Disponibles:12pzas.',
#   'Enlaces': '#'},
#  {'Producto': 'Laptop Lenovo ThinkPad E14 Gen2 14" Full HD, Intel Core i7-1165G7 2.80GHz, 16GB, 512GB SSD, Windows 10 Pro 64-bit, Español, Negro',
#   'Rating': 5,
#   'Precio': '$23,039.00',
#   'Existencia': 'Disponibles:20pzas.',
#   'Enlaces': 'https://www.cyberpuerta.mx/Computadoras/Laptops/Laptop-Lenovo-ThinkPad-E14-Gen2-14-Full-HD-Intel-Core-i7-1165G7-2-80GHz-16GB-512GB-SSD-Windows-10-Pro-64-bit-Espanol-Negro-cp2-1.html'},
#  {'Producto': 'Laptop Gamer AORUS 5 SE4 15.6" Full HD, Intel Core i7-12700H 3.50GHz, 16GB, 512GB SSD, NVIDIA GeForce 3070, Windows 11 Home 64-bit, Español, Negro',
#   'Rating': 5,
#   'Precio': '$27,269.00',
#   'Existencia': 'Disponibles:16pzas.',
#   'Enlaces': '#'},
#  {'Producto': 'Laptop Gamer Acer Nitro 5 AN515-46 15.6" Full HD, AMD Ryzen 7 6800H 3.20GHz, 16GB, 512GB SSD, NVIDIA GeForce RTX 3070 Ti, Windows 11 Home 64-bit, Español, Negro',
#   'Rating': 5,
#   'Precio': '$27,809.00',
#   'Existencia': 'Disponibles:30pzas.',
#   'Enlaces': 'https://www.cyberpuerta.mx/Computadoras/Laptops/Laptop-Gamer-Acer-Nitro-5-AN515-46-15-6-Full-HD-AMD-Ryzen-7-6800H-3-20GHz-16GB-512GB-SSD-NVIDIA-GeForce-RTX-3070-Ti-Windows-11-Home-64-bit-Espanol-Negro.html'},
#  {'Producto': 'Laptop Lenovo V15 Gen 3 15.6" Full HD, AMD Ryzen 5 5625U 2.30GHz, 8GB, 512GB SSD, Windows 10 Pro 64-bit, Español, Negro',
#   'Rating': 5,
#   'Precio': '$9,169.00',
#   'Existencia': 'Disponibles:25pzas.',
#   'Enlaces': '#'},
#  {'Producto': 'Laptop ASUS ZenBook Pro Duo UX8402VV 14.5" WQXGA, Intel Core i9-13900H 4.10GHz, 32GB, 1TB SSD, Windows 11 Home 64-bit, Español, Negro ― Incluye Funda y Stylus Pen 2.0',
#   'Rating': 5,
#   'Precio': '$68,239.00',
#   'Existencia': 'Disponibles:4pzas.',
#   'Enlaces': 'https://www.cyberpuerta.mx/lista-de-comparacion/?cnid=4fe38c01729fc'},
#  {'Producto': 'Laptop Lenovo Yoga Slim 7 Pro 14IAP7 14" Quad HD, Intel Core i5-1240P 1.70GHz, 8GB, 512GB SSD, Windows 11 Home 64-bit, Español, Gris',
#   'Rating': 5,
#   'Precio': '$18,539.00',
#   'Existencia': 'Disponibles:177pzas.',
#   'Enlaces': '#'},
#  {'Producto': 'Laptop HP 240 G8 14" HD, Intel Core i5-1135G7 2.40GHz, 16GB, 500GB SSD, Windows 11 Pro 64-bit, Español, Negro ― Configuración Especial, 1 Año de Garantía',
#   'Rating': 5,
#   'Precio': '$13,249.00',
#   'Existencia': 'Disponibles:2pzas.',
#   'Enlaces': 'https://www.cyberpuerta.mx/Computadoras/Laptops/cp2-cp2-8.html'},
#  {'Producto': 'Laptop Lenovo ThinkBook 14 G2 ITL 14" Full HD, Intel Core i3-1115G4 3GHz, 8GB, 256GB SSD, Windows 10 Pro 64-bit, Español, Gris',
#   'Rating': 5,
#   'Precio': '$13,679.00',
#   'Existencia': 'Disponibles:222pzas.',
#   'Enlaces': '#'},
#  {'Producto': 'Laptop Lenovo ThinkPad T14 Gen 2 14" Full HD, AMD Ryzen 5 PRO 5650U 2.30GHz, 8GB, 512GB SSD, Windows 11 Pro 64-bit, Inglés, Negro',
#   'Rating': 4,
#   'Precio': '$18,319.00',
#   'Existencia': 'Disponibles:10pzas.',
#   'Enlaces': 'https://www.cyberpuerta.mx/lista-de-comparacion/?cnid=4fe38c01729fc'},
#  {'Producto': 'Laptop Lanix Neuron V V7 15.6" Full HD, Intel Core i5-10210U 1.60GHz, 8GB, 512GB SSD, Windows 11 Pro, Español, Negro',
#   'Rating': 4,
#   'Precio': '$14,859.00',
#   'Existencia': 'Disponibles:5pzas.',
#   'Enlaces': '#'},
#  {'Producto': 'Laptop Dell Latitude 3540 15.6" Full HD, Intel Core i5-1335U 1.30GHz, 8GB, 256GB SSD, Windows 11 Pro 64-bit, Español, Negro',
#   'Rating': 4,
#   'Precio': '$19,919.00',
#   'Existencia': 'Disponibles:480pzas.',
#   'Enlaces': 'https://www.cyberpuerta.mx/Computadoras/Laptops/cp2-cp2-3.html'},
#  {'Producto': 'Laptop HP ProBook 440 G9 14" Full HD, Intel Core i5-1235U 1.30GHz, 16GB, 512GB SSD, Windows 11 Pro 64-bit, Español, Plata',
#   'Rating': 4,
#   'Precio': '$19,689.00',
#   'Existencia': 'Disponibles:184pzas.',
#   'Enlaces': '#'},
#  {'Producto': 'Laptop HP 240 G8 14" HD, Intel Core i5-1135G7 2.40GHz, 8GB, 256GB SSD, Windows 11 Pro 64-bit, Español, Negro',
#   'Rating': 4,
#   'Precio': '$13,419.00',
#   'Existencia': 'Disponibles:956pzas.',
#   'Enlaces': 'https://www.cyberpuerta.mx/lista-de-comparacion/?cnid=4fe38c01729fc'},
#  {'Producto': 'Laptop HP 250 G8 15.6" Full HD, Intel Core i5-1135G7 2.40GHz, 16GB, 256GB SSD, Windows 11 Pro 64-bit, Español, Gris',
#   'Rating': 4,
#   'Precio': '$14,059.00',
#   'Existencia': 'Disponibles:477pzas.',
#   'Enlaces': '#'},
#  {'Producto': 'Laptop Lenovo ThinkPad L14 G1 14" HD, AMD Ryzen 3 4300U 2.70GHz, 8GB, 256GB SSD, Windows 10 Pro 64-bit, Español, Negro',
#   'Rating': 5,
#   'Precio': '$16,449.00',
#   'Existencia': 'Disponibles:25pzas.',
#   'Enlaces': 'https://www.cyberpuerta.mx/Computadoras/Laptops/Laptop-Lenovo-ThinkPad-L14-G1-14-HD-AMD-Ryzen-3-4300U-2-70GHz-8GB-256GB-SSD-Windows-10-Pro-64-bit-Espanol-Negro.html'},
#  {'Producto': "Apple MacBook Air Retina Z124 13.3'', Apple M1, 16GB, 256GB SSD, Gris Espacial",
#   'Rating': 5,
#   'Precio': '$24,439.00',
#   'Existencia': 'Disponibles:12pzas.',
#   'Enlaces': 'https://www.cyberpuerta.mx/Opiniones-sobre-Laptop-Lenovo-ThinkPad-L14-G1-14-HD-AMD-Ryzen-3-4300U-2-70GHz-8GB-256GB-SSD-Windows-10-Pro-64-bit-Espanol-Negro/'},
#  {'Producto': 'Laptop HP 245 G8 14" HD, AMD Ryzen 5 5500U 2.10GHz, 8GB, 256GB SSD, Windows 10 Home 64-bit, Español, Negro',
#   'Rating': 5,
#   'Precio': '$15,279.00',
#   'Existencia': 'Disponibles:3pzas.',
#   'Enlaces': 'https://www.cyberpuerta.mx/Opiniones-sobre-Laptop-Lenovo-ThinkPad-L14-G1-14-HD-AMD-Ryzen-3-4300U-2-70GHz-8GB-256GB-SSD-Windows-10-Pro-64-bit-Espanol-Negro/'},
#  {'Producto': 'Laptop Acer Aspire 3 A315-24P-R3XC 15.6" Full HD, AMD Ryzen 5-7520U 2.80GHz, 16GB, 512GB SSD, Windows 11 Home 64-bit, Español, Plata',
#   'Rating': 5,
#   'Precio': '$15,519.00',
#   'Existencia': 'Disponibles:8pzas.',
#   'Enlaces': '#'},
#  {'Producto': 'Laptop Gamer Dell G5 15 5515 15.6" Full HD, AMD Ryzen 7 5800H 3.20GHz, 16GB, 512GB SSD, NVIDIA GeForce RTX 3060 Windows 11 Home 64-bit, Español, Gris',
#   'Rating': 5,
#   'Precio': '$33,439.00',
#   'Existencia': 'Disponibles:21pzas.',
#   'Enlaces': 'https://www.cyberpuerta.mx/lista-de-comparacion/?cnid=4fe38c01729fc'},
#  {'Producto': 'Laptop Lanix Neuron X PRO 41539 14" Full HD, Intel Core i3-1115G4 3GHz, 8GB, 512GB SSD, Windows 11 Home 64-bit, Español, Negro',
#   'Rating': 5,
#   'Precio': '$11,679.00',
#   'Existencia': 'Disponibles:3pzas.',
#   'Enlaces': '#'},
#  {'Producto': 'Laptop HP 245 G7 14", AMD Ryzen 5 3500U 2.10GHz, 8GB, 1TB, Windows 10 Home 64-bit, Español, Negro',
#   'Rating': 4,
#   'Precio': '$16,559.00',
#   'Existencia': 'Disponibles:\n¡1pza.!',
#   'Enlaces': 'https://www.cyberpuerta.mx/Computadoras/Laptops/Laptop-HP-245-G7-14-AMD-Ryzen-5-3500U-2-10GHz-8GB-1TB-Windows-10-Home-64-bit-Espanol-Negro.html'},
#  {'Producto': 'Laptop Lenovo ThinkPad E14 Gen2 14" Full HD, AMD Ryzen 3 4300U 2.70GHz, 16GB, 256GB SSD, Windows 10 Pro 64-bit, Español, Negro',
#   'Rating': 4,
#   'Precio': '$14,049.00',
#   'Existencia': 'Disponibles:38pzas.',
#   'Enlaces': 'https://www.cyberpuerta.mx/Opiniones-sobre-Laptop-HP-245-G7-14-AMD-Ryzen-5-3500U-2-10GHz-8GB-1TB-Windows-10-Home-64-bit-Espanol-Negro/'},
#  {'Producto': 'Laptop Lenovo ThinkPad L15 Gen 3 15.6" Full HD, Intel Core i5-1235U 3.30GHz, 16GB, 512GB SSD, Windows 10 Pro 64-bit, Español, Negro',
#   'Rating': 5,
#   'Precio': '$22,449.00',
#   'Existencia': 'Disponibles:42pzas.',
#   'Enlaces': 'https://www.cyberpuerta.mx/Opiniones-sobre-Laptop-HP-245-G7-14-AMD-Ryzen-5-3500U-2-10GHz-8GB-1TB-Windows-10-Home-64-bit-Espanol-Negro/'},
#  {'Producto': 'Laptop Dell Inspiron 13 5310 13.3" Quad HD, Intel Core i7-11390H 2.90GHz, 8GB, 512GB SSD, Windows 11 Home 64-bit, Español, Plata',
#   'Rating': 5,
#   'Precio': '$17,439.00',
#   'Existencia': 'Disponibles:23pzas.',
#   'Enlaces': '#'},
#  {'Producto': 'Laptop Gamer Lenovo Legion 5 15.6" Full HD, Intel Core i5-10300H 2.50GHz, 8GB, 1TB + 128GB SSD, NVIDIA GeForce GTX 1660 Ti, Windows 10 Home 64-bit, Español, Negro',
#   'Rating': 4,
#   'Precio': '$21,559.00',
#   'Existencia': 'Disponibles:3pzas.',
#   'Enlaces': 'https://www.cyberpuerta.mx/lista-de-comparacion/?cnid=4fe38c01729fc'},
#  {'Producto': 'Laptop HP 255 G8 15.6" HD, AMD 3020e 1.20GHz, 4GB, 256GB SSD, Windows 10 Home 64-bit, Español, Negro',
#   'Rating': 4,
#   'Precio': '$7,919.00',
#   'Existencia': 'Disponibles:15pzas.',
#   'Enlaces': '#'},
#  {'Producto': 'Laptop ASUS F415EA 14" Full HD, Intel Core i3-1115G4 3GHz, 4GB, 128GB SSD, Windows 11 Home 64-bit, Español, Gris',
#   'Rating': 4,
#   'Precio': '$7,729.00',
#   'Existencia': 'Disponibles:21pzas.',
#   'Enlaces': 'https://www.cyberpuerta.mx/Computadoras/Laptops/Laptop-ASUS-F415EA-14-Full-HD-Intel-Core-i3-1115G4-3GHz-4GB-128GB-SSD-Windows-11-Home-64-bit-Espanol-Gris.html'},
#  {'Producto': 'Laptop Lenovo ThinkPad T14 Gen 2 14" Full HD, Intel Core i5-1135G7 2.40GHz, 16GB, 512GB SSD, Windows 11 Pro 64-bit, Español, Negro',
#   'Rating': 4,
#   'Precio': '$22,639.00',
#   'Existencia': 'Disponibles:45pzas.',
#   'Enlaces': '#'},
#  {'Producto': 'Laptop Lenovo IdeaPad Slim 3 15IAN8 15.6" Full HD, Intel Core i3-N305 1.80GHz, 8GB, 256GB SSD, Windows 11 Home 64-bit, Español, Azul Frío',
#   'Rating': 4,
#   'Precio': '$9,109.00',
#   'Existencia': 'Disponibles:43pzas.',
#   'Enlaces': 'https://www.cyberpuerta.mx/lista-de-comparacion/?cnid=4fe38c01729fc'},
#  {'Producto': 'Laptop ASUS Chromebook CX1 15.6" HD, Intel Celeron N4500 1.10GHz, 8GB, 128GB eMMC, Chrome OS, Español, Plata',
#   'Rating': 4,
#   'Precio': '$8,709.00',
#   'Existencia': 'Disponibles:9pzas.',
#   'Enlaces': '#'},
#  {'Producto': 'Laptop Dell Latitude 5440 14" Full HD, Intel Core i5-1335U 3.40GHz, 8GB, 256GB SSD, Windows 11 Pro 64-bit, Español, Gris',
#   'Rating': 4,
#   'Precio': '$21,449.00',
#   'Existencia': 'Disponibles:15pzas.',
#   'Enlaces': 'https://www.cyberpuerta.mx/Computadoras/Laptops/Laptop-Dell-Latitude-5440-14-Full-HD-Intel-Core-i5-1335U-3-40GHz-8GB-256GB-SSD-Windows-11-Pro-64-bit-Espanol-Gris.html'},
#  {'Producto': 'Laptop ASUS VivoBook K1703ZA-WH34 17.3" Full HD, Intel Core i3-1220P 1.10GHz, 8GB, 256GB SSD, Windows 11 Home 64-bit, Plata',
#   'Rating': 4,
#   'Precio': '$9,159.00',
#   'Existencia': 'Disponibles:27pzas.',
#   'Enlaces': '#'},
#  {'Producto': 'Laptop Lenovo IdeaPad 1 14IAU7 14" HD, Intel Core i3-1215U 3.30GHz, 8GB, 128GB SSD, Windows 11 Home S, Inglés, Gris ― Configuración Especial, 1 Año de Garantía',
#   'Rating': 4,
#   'Precio': '$7,509.00',
#   'Existencia': 'Disponibles:24pzas.',
#   'Enlaces': 'https://www.cyberpuerta.mx/lista-de-comparacion/?cnid=4fe38c01729fc'},
#  {'Producto': 'Laptop Acer Aspire 3 A315-510P-38R 15.6" Full HD, Intel Core i3-N305 1.80GHz, 8GB, 512GB SSD, Windows 11 Home 64-bit, Español, Azul',
#   'Rating': 4,
#   'Precio': '$9,199.00',
#   'Existencia': 'Disponibles:308pzas.',
#   'Enlaces': '#'},
#  {'Producto': 'Laptop HP ProBook 450 G9 15.6" Full HD, Intel Core i5-1235U 1.80GHz, 16GB, 512GB SSD, Windows 11 Pro 64-bit, Español, Plata',
#   'Rating': 4,
#   'Precio': '$18,929.00',
#   'Existencia': 'Disponibles:16pzas.',
#   'Enlaces': 'https://www.cyberpuerta.mx/Computadoras/Laptops/Laptop-HP-ProBook-450-G9-15-6-Full-HD-Intel-Core-i5-1235U-1-80GHz-16GB-512GB-SSD-Windows-11-Pro-64-bit-Espanol-Plata.html'},
#  {'Producto': 'Laptop HP 15-DW3001CA 15.6" HD, Intel Core i3-1115G4 3GHz, 8GB, 256GB SSD, Windows 10 Home 64-bit, Inglés, Gris',
#   'Rating': 4,
#   'Precio': '$8,599.00',
#   'Existencia': 'Disponibles:3pzas.',
#   'Enlaces': '#'},
#  {'Producto': 'Laptop Gamer Acer Nitro 5 15.6" Full HD, Intel Core i5-10300H 2.50GHz, 8GB, 256GB SSD, NVIDIA GeForce RTX 3050, Windows 10 Home 64-bit,  Inglés, Negro',
#   'Rating': 4,
#   'Precio': '$19,549.00',
#   'Existencia': 'Disponibles:11pzas.',
#   'Enlaces': 'https://www.cyberpuerta.mx/lista-de-comparacion/?cnid=4fe38c01729fc'},
#  {'Producto': 'Laptop Lenovo ThinkBook 14 Gen 3 14" Full HD, AMD Ryzen 5 5500U 2.10GHz, 16GB, 512GB SSD, Windows 11 Pro 64-bit, Español, Gris',
#   'Rating': 4,
#   'Precio': '$14,539.00',
#   'Existencia': 'Disponibles:21pzas.',
#   'Enlaces': '#'},
#  {'Producto': 'Laptop Gamer Dell G5 5511 15.6" Full HD, Intel Core i5-11260H 2.60GHz, 8GB, 512GB SSD, NVIDIA GeForce RTX 3050, Windows 11 Home 64-bit, Español, Gris (2021) ― Garantía Limitada por 1 Año',
#   'Rating': 4,
#   'Precio': '$17,799.00',
#   'Existencia': 'Disponibles:21pzas.',
#   'Enlaces': 'https://www.cyberpuerta.mx/Computadoras/Laptops/Laptop-Gamer-Dell-G5-5511-15-6-Full-HD-Intel-Core-i5-11260H-2-60GHz-8GB-512GB-SSD-NVIDIA-GeForce-RTX-3050-Windows-11-Home-64-bit-Espanol-Gris-2021.html'},
#  {'Producto': 'Workstation HP Power G9 15.6" Full HD, Intel Core i9-12900HK 2.50GHz, 16GB, 1TB SSD, NVIDIA RTX A2000, Windows 11 Pro 64-bit, Español, Gris ― Incluye 3 Años de Garantía \xa0(Partes, Mano de Obra, Atención en Sitio) + Active Care (Monitoreo Predictivo de',
#   'Rating': 4,
#   'Precio': '$65,129.00',
#   'Existencia': 'Disponibles:\n¡1pza.!',
#   'Enlaces': '#'},
#  {'Producto': 'Laptop Dell Latitude 7430 14" Full HD, Intel Core i7-1255U 3.50GHz, 16GB, 256GB SSD, Windows 10 Pro 64-bit, Español, Negro (2022) ― Garantía Limitada por 1 Año',
#   'Rating': 4,
#   'Precio': '$28,029.00',
#   'Existencia': 'Disponibles:\n¡1pza.!',
#   'Enlaces': 'https://www.cyberpuerta.mx/lista-de-comparacion/?cnid=4fe38c01729fc'},
#  {'Producto': 'Laptop HP EliteBook 840 G10 14" Full HD, Intel Core i7-1355U 3.70GHz, 16GB, 1TB SSD, Windows 11 Pro 64-bit, Español, Plata',
#   'Rating': 4,
#   'Precio': '$28,759.00',
#   'Existencia': 'Disponibles:54pzas.',
#   'Enlaces': '#'},
#  {'Producto': 'Laptop Dell Inspiron 3505 15.6" HD, AMD Ryzen 7 3700U 2.30GHz, 8GB, 512GB SSD, Windows 10 Home 64-bit, Español, Plata ― Garantía Limitada por 1 Año',
#   'Rating': 4,
#   'Precio': '$23,839.00',
#   'Existencia': 'Disponibles:3pzas.',
#   'Enlaces': 'https://www.cyberpuerta.mx/Computadoras/Laptops/Laptop-Dell-Inspiron-3505-15-6-HD-AMD-Ryzen-7-3700U-2-30GHz-8GB-512GB-SSD-Windows-10-Home-64-bit-Espanol-Plata.html'},
#  {'Producto': 'Laptop Dell Latitude 3410 14" Full HD, Intel Core i5-10210U 1.60GHz, 8GB, 256GB SSD, Windows 10 Pro 64-bit, Español, Negro ― Garantía Limitada por 1 Año',
#   'Rating': 4,
#   'Precio': '$19,999.00',
#   'Existencia': 'Disponibles:3pzas.',
#   'Enlaces': '#'},
#  {'Producto': 'Laptop Dell Precision Móvil 7560 15.6" Full HD, Intel Core i7-11850H 2.30GHz, 32GB, 512GB SSD, NVIDIA Quadro T1000, Windows 10 Pro 64-bit, Español, Gris (2021) ― Garantía Limitada por 1 Año',
#   'Rating': 4,
#   'Precio': '$51,199.00',
#   'Existencia': 'Disponibles:6pzas.',
#   'Enlaces': 'https://www.cyberpuerta.mx/lista-de-comparacion/?cnid=4fe38c01729fc'},
#  {'Producto': 'Laptop Dell Latitude 7430 14" Full HD, Intel Core i7-1255U 3.50GHz, 16GB, 256GB SSD, Windows 10 Pro 64-bit, Inglés, Negro ― Garantía Limitada por 1 Año',
#   'Rating': 4,
#   'Precio': '$33,439.00',
#   'Existencia': 'Disponibles:5pzas.',
#   'Enlaces': '#'},
#  {'Producto': 'Laptop ASUS Chromebook C204EE 11.6" HD, Intel Celeron N4020 1.10GHz, 4GB, 32GB eMMC, Chrome OS, Español, Gris',
#   'Rating': 4,
#   'Precio': '$7,079.00',
#   'Existencia': 'Disponibles:\n¡1pza.!',
#   'Enlaces': 'https://www.cyberpuerta.mx/Computadoras/Laptops/Laptop-ASUS-Chromebook-C204EE-11-6-HD-Intel-Celeron-N4020-1-10GHz-4GB-32GB-eMMC-Chrome-OS-Espanol-Gris.html'},
#  {'Producto': 'Laptop Gamer Lenovo IdeaPad Gaming 3 15ACH6 15.6" Full HD, AMD Ryzen 5 5600H 3.30GHz, 16GB, 1TB + 256GB SSD, NVIDIA GeForce RTX 3050 Ti, Windows 11 Home 64-bit, Inglés, Negro ― Configuración Especial, 1 Año de Garantía',
#   'Rating': 4,
#   'Precio': '$19,749.00',
#   'Existencia': 'Disponibles:24pzas.',
#   'Enlaces': 'https://www.cyberpuerta.mx/Opiniones-sobre-Laptop-ASUS-Chromebook-C204EE-11-6-HD-Intel-Celeron-N4020-1-10GHz-4GB-32GB-eMMC-Chrome-OS-Espanol-Gris/'},
#  {'Producto': 'Laptop Lenovo ThinkPad X13 G3 13.3" WUXGA, Intel Core i7-1260P 3.40GHz, 16GB, 256GB SSD, Windows 10 Pro 64-bit, Español, Negro',
#   'Rating': 4,
#   'Precio': '$27,429.00',
#   'Existencia': 'Disponibles:2pzas.',
#   'Enlaces': 'https://www.cyberpuerta.mx/Computadoras/Laptops/Laptop-Lenovo-ThinkPad-X13-G3-13-3-WUXGA-Intel-Core-i7-1260P-3-40GHz-16GB-256GB-SSD-Windows-10-Pro-64-bit-Espanol-Negro.html'},
#  {'Producto': 'Laptop Dell Latitude 3520 15,6" HD, Intel Core i5-1135G7 2.40GHz, 8GB, 256GB SSD, Windows 10 Pro 64-bit, Español, Gris',
#   'Rating': 4,
#   'Precio': '$19,139.00',
#   'Existencia': 'Disponibles:67pzas.',
#   'Enlaces': '#'},
#  {'Producto': 'Laptop Lenovo ThinkPad T14 Gen 2 14" Full HD, Intel Core i5-1135G7 2.40GHz, 16GB, 512GB SSD, Windows 10 Pro 64-bit, Español, Negro',
#   'Rating': 4,
#   'Precio': '$22,859.00',
#   'Existencia': 'Disponibles:33pzas.',
#   'Enlaces': 'https://www.cyberpuerta.mx/lista-de-comparacion/?cnid=4fe38c01729fc'},
#  {'Producto': 'Laptop HP 240 G8 79L97LT 14" HD, Intel Core i5-1135G7 2.40GHz, 8GB, 256GB SSD, Windows 11 Home 64-bit, Español, Negro',
#   'Rating': 4,
#   'Precio': '$9,189.00',
#   'Existencia': 'Disponibles:137pzas.',
#   'Enlaces': '#'},
#  {'Producto': 'Laptop HP 245 G9 14" HD, AMD Ryzen 5 5625U 2.30GHz, 8GB, 512GB SSD, Windows 11 Home 64-bit, Español, Plata',
#   'Rating': 3,
#   'Precio': '$11,349.00',
#   'Existencia': 'Disponibles:\n¡1pza.!',
#   'Enlaces': 'https://www.cyberpuerta.mx/Computadoras/Laptops/Laptop-HP-245-G9-14-HD-AMD-Ryzen-5-5625U-2-30GHz-8GB-512GB-SSD-Windows-11-Home-64-bit-Espanol-Plata.html'},
#  {'Producto': 'Laptop Dell Latitude 5430 14” Full HD, Intel Core i5-1235U 3.30GHz, 8GB, 256GB SSD, Windows 10 Pro 64-bit, Español, Gris (2022) ― Garantía Limitada por 1 Año',
#   'Rating': 3,
#   'Precio': '$27,149.00',
#   'Existencia': 'Disponibles:40pzas.',
#   'Enlaces': '#'},
#  {'Producto': 'Laptop HP EliteBook 845 G9 14" Full HD, AMD Ryzen 7 PRO 6850U 2.70GHz, 8GB, 512GB SSD, Windows 11 Pro 64-bit, Español, Plata',
#   'Rating': 3,
#   'Precio': '$25,859.00',
#   'Existencia': 'Disponibles:2pzas.',
#   'Enlaces': 'https://www.cyberpuerta.mx/Computadoras/Laptops/Laptop-HP-EliteBook-845-G9-14-Full-HD-AMD-Ryzen-7-PRO-6850U-2-70GHz-8GB-512GB-SSD-Windows-11-Pro-64-bit-Espanol-Plata.html'},
#  {'Producto': 'Apple MacBook Pro Retina MNEQ3E/A 13”, Apple M2, 8GB, 512GB SSD, Plata (Julio 2022)',
#   'Rating': 3,
#   'Precio': '$32,469.00',
#   'Existencia': 'Disponibles:32pzas.',
#   'Enlaces': '#'},
#  {'Producto': 'Laptop HP ProBook 640 G8 14" HD, Intel Core i5-1145G7 2.60GHz, 8GB, 256GB SSD, Windows 10 Pro 64-bit, Español, Plata',
#   'Rating': 3,
#   'Precio': '$22,029.00',
#   'Existencia': 'Disponibles:48pzas.',
#   'Enlaces': 'https://www.cyberpuerta.mx/Computadoras/Laptops/Laptop-HP-ProBook-640-G8-14-HD-Intel-Core-i5-1145G7-2-60GHz-8GB-256GB-SSD-Windows-10-Pro-64-bit-Espanol-Plata.html'},
#  {'Producto': 'Laptop Lenovo ThinkPad L14 G1 14" HD, AMD Ryzen 3 4300U 2.70GHz, 8GB, 512GB SSD, Windows 10 Pro 64-bit, Español, Negro',
#   'Rating': 3,
#   'Precio': '$20,929.00',
#   'Existencia': 'Disponibles:8pzas.',
#   'Enlaces': '#'},
#  {'Producto': 'Laptop Lenovo V14-ITL G2 14" HD, Intel Core i7-1165G7 2.80GHz, 16GB, 512GB SSD, Windows 10 Pro 64-bit, Español, Gris',
#   'Rating': 3,
#   'Precio': '$21,049.00',
#   'Existencia': 'Disponibles:12pzas.',
#   'Enlaces': 'https://www.cyberpuerta.mx/Computadoras/Laptops/Laptop-Lenovo-V14-ITL-G2-14-HD-Intel-Core-i7-1165G7-2-80GHz-16GB-512GB-SSD-Windows-10-Pro-64-bit-Espanol-Gris.html'},
#  {'Producto': 'Laptop Lenovo IdeaPad 3 15ITL05 15.6" HD, Intel Core i3-1115G4 3GHz, 8GB, 256GB SSD, Windows 10 Home, Inglés, Arena',
#   'Rating': 3,
#   'Precio': '$9,089.00',
#   'Existencia': 'Disponibles:6pzas.',
#   'Enlaces': '#'},
#  {'Producto': 'Laptop Dell Latitude 5420 14" Full HD, Intel Core i7-1165G7 2.80GHz, 8GB, 256GB SSD, Windows 10 Pro 64-bit, Español, Gris',
#   'Rating': 3,
#   'Precio': '$25,329.00',
#   'Existencia': 'Disponibles:46pzas.',
#   'Enlaces': 'https://www.cyberpuerta.mx/Computadoras/Laptops/Laptop-Dell-Latitude-5420-14-Full-HD-Intel-Core-i7-1165G7-2-80GHz-8GB-256GB-SSD-Windows-10-Pro-64-bit-Espanol-Gris-cp2-1.html'},
#  {'Producto': 'Laptop Lanix Neuron A V19 10650 14" HD, Intel Pentium J3710 1.60GHz, 8GB, 512GB SSD, Windows 10 Home 64-bits, Español, Negro/Gris',
#   'Rating': 3,
#   'Precio': '$4,909.00',
#   'Existencia': 'Disponibles:1825pzas.',
#   'Enlaces': '#'},
#  {'Producto': 'Laptop Acer TravelMate P6 TMP614-51-G2-50ND 14" HD, Intel Core i5-10210U 1.60GHz, 8GB, 512GB SSD, Windows 10 Pro 64-bit, Español, Negro',
#   'Rating': 3,
#   'Precio': '$18,039.00',
#   'Existencia': 'Disponibles:3pzas.',
#   'Enlaces': 'https://www.cyberpuerta.mx/Computadoras/Laptops/Laptop-Acer-TravelMate-P6-TMP614-51-G2-50ND-14-HD-Intel-Core-i5-10210U-1-60GHz-8GB-512GB-SSD-Windows-10-Pro-64-bit-Espanol-Negro.html'},
#  {'Producto': 'Laptop Lenovo IdeaPad Slim 1-14AST-05 14" HD, AMD A6-9220e 1.60GHz, 4GB, 64GB, Windows 10 Home S, Inglés, Plata',
#   'Rating': 3,
#   'Precio': '$7,699.00',
#   'Existencia': 'Disponibles:3pzas.',
#   'Enlaces': '#'},
#  {'Producto': 'Laptop Lenovo Chromebook 100E 11.6" HD, MediaTek MT8173C 2GHz, 4GB, 32GB, Chrome OS, Inglés, Negro',
#   'Rating': 4,
#   'Precio': '$2,619.00',
#   'Existencia': 'Disponibles:10pzas.',
#   'Enlaces': 'https://www.cyberpuerta.mx/lista-de-comparacion/?cnid=4fe38c01729fc'},
#  {'Producto': 'Laptop Samsung Chromebook 4+ 15.6" Full HD, Intel Celeron N4000 1.10GHz, 4GB, 32GB eMMc, Chrome OS, Inglés, Plata',
#   'Rating': 4,
#   'Precio': '$7,409.00',
#   'Existencia': 'Disponibles:\n¡1pza.!',
#   'Enlaces': '#'},
#  {'Producto': 'Laptop Lenovo IdeaPad 3 14IGL05 14” Full HD, Intel Celeron N4020 1.10GHz, 8GB, 1TB, Windows 11 Home 64-bit, Español, Azul',
#   'Rating': 5,
#   'Precio': '$6,149.00',
#   'Existencia': 'Producto agotado',
#   'Enlaces': 'https://www.cyberpuerta.mx/Computadoras/Laptops/Laptop-Lenovo-IdeaPad-3-14IGL05-14-Full-HD-Intel-Celeron-N4020-1-10GHz-8GB-1TB-Windows-11-Home-64-bit-Espanol-Azul.html'},
#  {'Producto': 'Laptop Lenovo IdeaPad 3-14ALC6 14" Full HD, AMD Ryzen 3 5300U 2.60GHz, 8GB, 512GB SSD, Windows 10 Home 64-bit, Español, Azul',
#   'Rating': 5,
#   'Precio': '$14,249.00',
#   'Existencia': 'Producto agotado',
#   'Enlaces': 'https://www.cyberpuerta.mx/Opiniones-sobre-Laptop-Lenovo-IdeaPad-3-14IGL05-14-Full-HD-Intel-Celeron-N4020-1-10GHz-8GB-1TB-Windows-11-Home-64-bit-Espanol-Azul/'},
#  {'Producto': 'Laptop Dell Precision 5570 15.6" Full HD, Intel Core i7-12800H 2.40GHz, 64GB, 512GB SSD, NVIDIA RTX A1000, Windows 11 Pro 64-bit, Español, Negro ― Garantía Limitada por 1 Año',
#   'Rating': 5,
#   'Precio': '$57,599.00',
#   'Existencia': 'Producto agotado',
#   'Enlaces': 'https://www.cyberpuerta.mx/Opiniones-sobre-Laptop-Lenovo-IdeaPad-3-14IGL05-14-Full-HD-Intel-Celeron-N4020-1-10GHz-8GB-1TB-Windows-11-Home-64-bit-Espanol-Azul/'},
#  {'Producto': 'Laptop HP 14-dq2521la 14" HD, Intel Core i3-1115G4 3GHz, 8GB, 256GB SSD, Windows 11 Home 64-bit, Español, Azul',
#   'Rating': 5,
#   'Precio': '$12,139.00',
#   'Existencia': 'Producto agotado',
#   'Enlaces': '#'},
#  {'Producto': 'Laptop Gamer Lenovo IdeaPad 3 15IHU6 15.6" Full HD, Intel Core i5-11300H 3.10GHz, 8GB, 512GB SSD, NVIDIA GeForce GTX 1650, Windows 11 Home 64-bit, Español, Negro',
#   'Rating': 5,
#   'Precio': '$16,419.00',
#   'Existencia': 'Producto agotado',
#   'Enlaces': '#'},
#  {'Producto': 'Laptop AORUS 15 XE4 15.6” Full HD, Intel Core i7-12700H  2.30GHz, 16GB, 1TB SSD, NVIDIA GeForce RTX 3070 Ti, Windows 11 Home 64-bit, Español, Negro',
#   'Rating': 5,
#   'Precio': '$26,699.00',
#   'Existencia': 'Producto agotado',
#   'Enlaces': 'https://www.cyberpuerta.mx/lista-de-comparacion/?cnid=4fe38c01729fc'},
#  {'Producto': 'Laptop HP 15-EG0500LA 15.6"HD, Intel Core i5-1135G7 2.40GHz, 8GB, 256GB SSD, Windows 11 Home 64-bit, Español, Plata',
#   'Rating': 4,
#   'Precio': '$11,189.00',
#   'Existencia': 'Producto agotado',
#   'Enlaces': '#'},
#  {'Producto': 'Laptop Gamer Lenovo IdeaPad Gaming 3i 15IMH05 15.6" Full HD, Intel Core i5-10300H 2.50GHz, 8GB, 1TB + 256GB SSD, NVIDIA GeForce GTX 1650 TI, Windows 10 Home 64-bit, Español, Azul',
#   'Rating': 4,
#   'Precio': '$16,049.00',
#   'Existencia': 'Producto agotado',
#   'Enlaces': 'https://www.cyberpuerta.mx/Computadoras/Laptops/Laptop-Gamer-Lenovo-IdeaPad-Gaming-3i-15IMH05-15-6-Full-HD-Intel-Core-i5-10300H-2-50GHz-8GB-1TB-256GB-SSD-NVIDIA-GeForce-GTX-1650-TI-Windows-10-Home-64-bit-Espanol-Azul.html'},
#  {'Producto': 'Laptop Hyundai Hybook Ereny Plus 14.1" HD, AMD A9-9400 2.4GHz, 8GB, 256GB SSD, Windows 10 Home 64-bit, Español, Gris',
#   'Rating': 4,
#   'Precio': '$4,359.00',
#   'Existencia': 'Producto agotado',
#   'Enlaces': 'https://www.cyberpuerta.mx/Opiniones-sobre-Laptop-Gamer-Lenovo-IdeaPad-Gaming-3i-15IMH05-15-6-Full-HD-Intel-Core-i5-10300H-2-50GHz-8GB-1TB-256GB-SSD-NVIDIA-GeForce-GTX-1650-TI-Windows-10-Home-64-bit-Espanol-Azul/'},
#  {'Producto': 'Laptop Lenovo Ideapad L340 15.6" Full HD, AMD Ryzen 7 3700U 2.30GHz, 8GB, 2TB, AMD Radeon RX Vega 10, Windows 10 Home 64-bit, Español, Negro',
#   'Rating': 4,
#   'Precio': '$15,629.00',
#   'Existencia': 'Producto agotado',
#   'Enlaces': 'https://www.cyberpuerta.mx/Opiniones-sobre-Laptop-Gamer-Lenovo-IdeaPad-Gaming-3i-15IMH05-15-6-Full-HD-Intel-Core-i5-10300H-2-50GHz-8GB-1TB-256GB-SSD-NVIDIA-GeForce-GTX-1650-TI-Windows-10-Home-64-bit-Espanol-Azul/'},
#  {'Producto': 'Lenovo 2 en 1 300e 2da Gen 11.6" HD, Intel Celeron N4120 1.10GHz, 4GB, 64GB, Windows 10 Pro 64-bit, Español, Negro',
#   'Rating': 4,
#   'Precio': '$5,409.00',
#   'Existencia': 'Producto agotado',
#   'Enlaces': 'https://www.cyberpuerta.mx/?cl=cpqa_writequestion&anid=b42b87d390c0db6862230b78214ac802'},
#  {'Producto': 'Laptop Gamer Dell Inspiron G15 5520 15.6" Full HD, Intel Core i7-12700H 3.50GHz, 16GB, 512GB SSD, NVIDIA GeForce RTX 3050, Windows 11 Home 64-bit, Español, Negro ― Garantía Limitada por 1 Año',
#   'Rating': 4,
#   'Precio': '$36,799.00',
#   'Existencia': 'Producto agotado',
#   'Enlaces': '#'},
#  {'Producto': 'Laptop Huawei Matebook D14 14" Full HD, Intel Core i3-10110U 2.10GHz, 8GB, 256GB SSD, Windows 10 Home 64-bit, Español, Gris',
#   'Rating': 4,
#   'Precio': '$13,819.00',
#   'Existencia': 'Producto agotado',
#   'Enlaces': '#'},
#  {'Producto': 'Laptop Lenovo IdeaPad 3 15ITL6 15.6" Full HD, Intel Core i3-1115G4 3GHz, 8GB, 256GB SSD, Windows 11 Home 64-bit, Español, Arena',
#   'Rating': 4,
#   'Precio': '$13,829.00',
#   'Existencia': 'Producto agotado',
#   'Enlaces': 'https://www.cyberpuerta.mx/lista-de-comparacion/?cnid=4fe38c01729fc'},
#  {'Producto': 'Laptop Lenovo IdeaPad 3 15ALC6 15.6" Full HD, AMD Ryzen 5 5500U 2.10GHz, 8GB, 1TB + 256GB SSD, Windows 11 Home 64-bit, Español, Azul',
#   'Rating': 4,
#   'Precio': '$12,249.00',
#   'Existencia': 'Producto agotado',
#   'Enlaces': '#'},
#  {'Producto': 'Laptop HP Elite x360 1040 G10 14" WUXGA Táctil, Intel Core i7-1365U 1.80GHz, 16GB, 1TB SSD, Windows 11 Pro, Español, Plata',
#   'Rating': 5,
#   'Precio': '$39,709.00',
#   'Existencia': 'Producto agotado',
#   'Enlaces': 'https://www.cyberpuerta.mx/Computadoras/Laptops/Laptop-HP-Elite-x360-1040-G10-14-WUXGA-Tactil-Intel-Core-i7-1365U-1-80GHz-16GB-1TB-SSD-Windows-11-Pro-Espanol-Plata.html'},
#  {'Producto': 'Apple MacBook Air Retina MGND3LA/A 13.3", Apple M1, 8GB, 256GB SSD, Oro (Noviembre 2020)',
#   'Rating': 5,
#   'Precio': '$25,209.00',
#   'Existencia': 'Producto agotado',
#   'Enlaces': '#'},
#  {'Producto': 'Apple MacBook Air Retina MGN93LA/A 13.3", Apple M1, 8GB, 256GB SSD, Plata',
#   'Rating': 5,
#   'Precio': '$19,689.00',
#   'Existencia': 'Producto agotado',
#   'Enlaces': '#'},
#  {'Producto': 'Laptop HP 15-EF2723OD 15.6" Full HD, AMD Ryzen 3 5300U 2.60GHz, 8GB, 256GB SSD, Windows 11 Home 64-bit, Inglés, Plata',
#   'Rating': 5,
#   'Precio': '$9,859.00',
#   'Existencia': 'Producto agotado',
#   'Enlaces': 'https://www.cyberpuerta.mx/lista-de-comparacion/?cnid=4fe38c01729fc'},
#  {'Producto': 'Laptop Dell Inspiron G5 5520 15.6" Full HD, Intel Core i7-12700H 3.50GHz, 16GB, 512GB SSD, NVIDIA GeForce RTX 3060, Windows 11 Home 64-bit, Español, Negro',
#   'Rating': 4,
#   'Precio': '$39,499.00',
#   'Existencia': 'Producto agotado',
#   'Enlaces': '#'},
#  {'Producto': 'Laptop Gamer MSI GF63 Thin 15.6" Full HD, Intel Core i5-11400H 2.70GHz, 8GB, 512GB SSD, NVIDIA GeForce RTX 3050, Windows 11 Home 64-bit, Inglés, Negro',
#   'Rating': 5,
#   'Precio': '$18,649.00',
#   'Existencia': 'Producto agotado',
#   'Enlaces': 'https://www.cyberpuerta.mx/Computadoras/Laptops/Laptop-Gamer-MSI-GF63-Thin-15-6-Full-HD-Intel-Core-i5-11400H-2-70GHz-8GB-512GB-SSD-NVIDIA-GeForce-RTX-3050-Windows-11-Home-64-bit-Ingles-Negro.html'},
#  {'Producto': 'Laptop Dell Vostro 3480 14" HD, Intel Core i3-8145U 2.10GHz, 8GB, 1TB, Windows 10 Pro 64-bit, Negro',
#   'Rating': 5,
#   'Precio': '$13,899.00',
#   'Existencia': 'Producto agotado',
#   'Enlaces': '#'},
#  {'Producto': 'Laptop Gamer ASUS ROG Strix SCAR 15 15.6" Full HD, Intel Core i9-12900H 3.80GHz, 16GB, 1TB SSD, NVIDIA GeForce RTX 3070 Ti, Windows 11 Home 64-bit, Inglés, Negro',
#   'Rating': 2,
#   'Precio': '$43,499.00',
#   'Existencia': 'Producto agotado',
#   'Enlaces': 'https://www.cyberpuerta.mx/Computadoras/Laptops/Laptop-Gamer-ASUS-ROG-Strix-SCAR-15-15-6-Full-HD-Intel-Core-i9-12900H-3-80GHz-16GB-1TB-SSD-NVIDIA-GeForce-RTX-3070-Ti-Windows-11-Home-64-bit-Ingles-Negro.html'},
#  {'Producto': 'Laptop Dell Inspiron 5510 15.6" Full HD, Intel Core i5-11320H 3.20GHz, 12GB, 512GB SSD, Windows 10 Pro 64-bit, Español, Plata (2021) ― Garantía Limitada por 1 Año',
#   'Rating': 2,
#   'Precio': '$22,239.00',
#   'Existencia': 'Producto agotado',
#   'Enlaces': 'https://www.cyberpuerta.mx/Opiniones-sobre-Laptop-Gamer-ASUS-ROG-Strix-SCAR-15-15-6-Full-HD-Intel-Core-i9-12900H-3-80GHz-16GB-1TB-SSD-NVIDIA-GeForce-RTX-3070-Ti-Windows-11-Home-64-bit-Ingles-Negro/'},
#  {'Producto': 'Laptop Lenovo ThinkPad T15 G2 15.6" Full HD, Intel Core i5-1135G7 2.40GHz, 16GB, 512GB SSD, Windows 10 Pro 64-bit, Español, Negro',
#   'Rating': 3,
#   'Precio': '$22,239.00',
#   'Existencia': 'Producto agotado',
#   'Enlaces': 'https://www.cyberpuerta.mx/Computadoras/Laptops/Laptop-Lenovo-ThinkPad-T15-G2-15-6-Full-HD-Intel-Core-i5-1135G7-2-40GHz-16GB-512GB-SSD-Windows-10-Pro-64-bit-Espanol-Negro.html'},
#  {'Producto': 'Laptop Dell Inspiron 5415 14" Full HD, AMD Ryzen 7 5700U 1.80GHz, 16GB, 512GB SSD, Windows 10 Home 64-bit, Español, Platino ― Configuración Especial, 1 Año de Garantía',
#   'Rating': 3,
#   'Precio': '$18,109.00',
#   'Existencia': 'Producto agotado',
#   'Enlaces': '#'},
#  {'Producto': 'Laptop Lenovo IdeaPad 5-14ARE05 14" HD, AMD Ryzen 3 4300U 2.70GHz, 8GB, 256GB SSD, Windows 10 Home 64-bit, Español, Azul',
#   'Rating': 2,
#   'Precio': '$7,709.00',
#   'Existencia': 'Producto agotado',
#   'Enlaces': 'https://www.cyberpuerta.mx/Computadoras/Laptops/Laptop-Lenovo-IdeaPad-5-14ARE05-14-HD-AMD-Ryzen-3-4300U-2-70GHz-8GB-256GB-SSD-Windows-10-Home-64-bit-Espanol-Azul.html'},
#  {'Producto': 'Laptop Lenovo IdeaPad 3 15IML05 15.6" HD, Intel Core i3-10110U 2.10GHz, 8GB, 1TB, Windows 10 Home 64-bit, Español, Plata',
#   'Rating': 2,
#   'Precio': '$11,599.00',
#   'Existencia': 'Producto agotado',
#   'Enlaces': '#'},
#  {'Producto': "Laptop HP 240 G8 14'' HD, Intel Core i5-1035G1 1GHz, 8GB, 1TB, Windows 10 Home 64-bit, Español, Gris Oscuro",
#   'Rating': 3,
#   'Precio': '$29,439.00',
#   'Existencia': 'Producto agotado',
#   'Enlaces': 'https://www.cyberpuerta.mx/Computadoras/Laptops/Laptop-HP-240-G8-14-HD-Intel-Core-i5-1035G1-1GHz-8GB-1TB-Windows-10-Home-64-bit-Espanol-Gris-Oscuro.html'},
#  {'Producto': 'Laptop Gamer MSI GF63 Thin 15.6" Full HD, Intel Core i5-10300H 2.50GHz, 16GB, 256GB SSD, NVIDIA GeForce GTX 1650 Max-Q, Windows 10 Home, Inglés, Negro',
#   'Rating': 3,
#   'Precio': '$14,909.00',
#   'Existencia': 'Producto agotado',
#   'Enlaces': '#'},
#  {'Producto': 'Laptop Gamer Lenovo Legion 5 15IAH7H 15.6" Full HD, Intel Core i5-12500H 3.30GHz, 8GB, 1TB SSD, NVIDIA GeForce RTX 3060, Windows 11 Home 64-bits, Español, Gris',
#   'Rating': 5,
#   'Precio': '$22,339.00',
#   'Existencia': 'Disponibles:88pzas.',
#   'Enlaces': 'https://www.cyberpuerta.mx/Computadoras/Laptops/Laptop-Gamer-Lenovo-Legion-5-15IAH7H-15-6-Full-HD-Intel-Core-i5-12500H-3-30GHz-8GB-1TB-SSD-NVIDIA-GeForce-RTX-3060-Windows-11-Home-64-bits-Espanol-Gris.html'},
#  {'Producto': 'Laptop Lenovo IdeaPad 5-14ALC05 14" Full HD, AMD Ryzen 5 5500U 2.10GHz, 8GB, 256GB SSD, Windows 11 Home 64-bit, Español, Platino',
#   'Rating': 5,
#   'Precio': '$9,549.00',
#   'Existencia': 'Disponibles:78pzas.',
#   'Enlaces': 'https://www.cyberpuerta.mx/Opiniones-sobre-Laptop-Gamer-Lenovo-Legion-5-15IAH7H-15-6-Full-HD-Intel-Core-i5-12500H-3-30GHz-8GB-1TB-SSD-NVIDIA-GeForce-RTX-3060-Windows-11-Home-64-bits-Espanol-Gris/'},
#  {'Producto': 'Laptop HP 245 G9 14" HD, AMD Ryzen 3 5425U 2.70GHz, 8GB, 512GB SSD, Windows 11 Home 64-bit, Español, Negro',
#   'Rating': 4,
#   'Precio': '$9,909.00',
#   'Existencia': 'Disponibles:38pzas.',
#   'Enlaces': 'https://www.cyberpuerta.mx/Opiniones-sobre-Laptop-Gamer-Lenovo-Legion-5-15IAH7H-15-6-Full-HD-Intel-Core-i5-12500H-3-30GHz-8GB-1TB-SSD-NVIDIA-GeForce-RTX-3060-Windows-11-Home-64-bits-Espanol-Gris/'},
#  {'Producto': 'Laptop Lenovo Thinkpad T14 Gen2 14" Full HD, Intel Core i5-1135G7 2.40GHz, 8GB, 256GB SSD, Windows 10 Pro 64-bit, Español, Negro',
#   'Rating': 4,
#   'Precio': '$16,459.00',
#   'Existencia': 'Disponibles:104pzas.',
#   'Enlaces': '#'},
#  {'Producto': 'Laptop HP 245 G9 14" HD, AMD Ryzen 3 5425U 2.70GHz, 8GB, 512GB SSD, Windows 11 Pro 64-bit, Español, Gris',
#   'Rating': 4,
#   'Precio': '$12,409.00',
#   'Existencia': 'Disponibles:22pzas.',
#   'Enlaces': 'https://www.cyberpuerta.mx/lista-de-comparacion/?cnid=4fe38c01729fc'},
#  {'Producto': 'Laptop HP 14-DQ0501LA 14" HD, Intel Celeron N4120 1.10GHz, 4GB, 256GB SSD, Windows 11 Home 64-bit, Español, Negro',
#   'Rating': 4,
#   'Precio': '$5,409.00',
#   'Existencia': 'Disponibles:\n¡1pza.!',
#   'Enlaces': '#'},
#  {'Producto': 'Laptop HP 245 G9 14" HD, AMD Ryzen 5 5625U 2.30GHz, 8GB, 512GB SSD, Windows 11 Pro 64-bit, Español, Plata',
#   'Rating': 5,
#   'Precio': '$12,929.00',
#   'Existencia': 'Disponibles:38pzas.',
#   'Enlaces': 'https://www.cyberpuerta.mx/Computadoras/Laptops/Laptop-HP-245-G9-14-HD-AMD-Ryzen-5-5625U-2-30GHz-8GB-512GB-SSD-Windows-11-Pro-64-bit-Espanol-Plata.html'},
#  {'Producto': 'Laptop Lenovo ThinkPad T14 G2 14" Full HD, Intel Core i7-1185G7 3GHz, 32GB, 512GB SSD, Windows 11 Pro 64-bit, Español, Negro',
#   'Rating': 5,
#   'Precio': '$31,109.00',
#   'Existencia': 'Disponibles:43pzas.',
#   'Enlaces': '#'},
#  {'Producto': 'Laptop Lenovo V14 G2 ALC 14" HD, AMD Ryzen 5 5500U 2.10GHz, 8GB, 256GB SSD, Windows 11 Pro 64-bit, Español, Gris',
#   'Rating': 4,
#   'Precio': '$9,679.00',
#   'Existencia': 'Disponibles:106pzas.',
#   'Enlaces': 'https://www.cyberpuerta.mx/lista-de-comparacion/?cnid=4fe38c01729fc'},
#  {'Producto': 'Laptop HP ZBook Power G9 15.6" Full HD, Intel Core i7-12800H 2.40GHz, 32GB, 1TB SSD, Nvidia RTX A2000, Windows 11 Pro 64-bit, Español, Gris',
#   'Rating': 4,
#   'Precio': '$54,779.00',
#   'Existencia': 'Disponibles:12pzas.',
#   'Enlaces': '#'},
#  {'Producto': 'Laptop Lenovo ThinkPad E14 Gen2 14" Full HD, Intel Core i7-1165G7 2.80GHz, 16GB, 512GB SSD, Windows 10 Pro 64-bit, Español, Negro',
#   'Rating': 5,
#   'Precio': '$23,039.00',
#   'Existencia': 'Disponibles:20pzas.',
#   'Enlaces': 'https://www.cyberpuerta.mx/Computadoras/Laptops/Laptop-Lenovo-ThinkPad-E14-Gen2-14-Full-HD-Intel-Core-i7-1165G7-2-80GHz-16GB-512GB-SSD-Windows-10-Pro-64-bit-Espanol-Negro-cp2-1.html'},
#  {'Producto': 'Laptop Gamer AORUS 5 SE4 15.6" Full HD, Intel Core i7-12700H 3.50GHz, 16GB, 512GB SSD, NVIDIA GeForce 3070, Windows 11 Home 64-bit, Español, Negro',
#   'Rating': 5,
#   'Precio': '$27,269.00',
#   'Existencia': 'Disponibles:16pzas.',
#   'Enlaces': '#'},
#  {'Producto': 'Laptop Gamer Acer Nitro 5 AN515-46 15.6" Full HD, AMD Ryzen 7 6800H 3.20GHz, 16GB, 512GB SSD, NVIDIA GeForce RTX 3070 Ti, Windows 11 Home 64-bit, Español, Negro',
#   'Rating': 5,
#   'Precio': '$27,809.00',
#   'Existencia': 'Disponibles:30pzas.',
#   'Enlaces': 'https://www.cyberpuerta.mx/Computadoras/Laptops/Laptop-Gamer-Acer-Nitro-5-AN515-46-15-6-Full-HD-AMD-Ryzen-7-6800H-3-20GHz-16GB-512GB-SSD-NVIDIA-GeForce-RTX-3070-Ti-Windows-11-Home-64-bit-Espanol-Negro.html'},
#  {'Producto': 'Laptop Lenovo V15 Gen 3 15.6" Full HD, AMD Ryzen 5 5625U 2.30GHz, 8GB, 512GB SSD, Windows 10 Pro 64-bit, Español, Negro',
#   'Rating': 5,
#   'Precio': '$9,169.00',
#   'Existencia': 'Disponibles:25pzas.',
#   'Enlaces': '#'},
#  {'Producto': 'Laptop ASUS ZenBook Pro Duo UX8402VV 14.5" WQXGA, Intel Core i9-13900H 4.10GHz, 32GB, 1TB SSD, Windows 11 Home 64-bit, Español, Negro ― Incluye Funda y Stylus Pen 2.0',
#   'Rating': 5,
#   'Precio': '$68,239.00',
#   'Existencia': 'Disponibles:4pzas.',
#   'Enlaces': 'https://www.cyberpuerta.mx/lista-de-comparacion/?cnid=4fe38c01729fc'},
#  {'Producto': 'Laptop Lenovo Yoga Slim 7 Pro 14IAP7 14" Quad HD, Intel Core i5-1240P 1.70GHz, 8GB, 512GB SSD, Windows 11 Home 64-bit, Español, Gris',
#   'Rating': 5,
#   'Precio': '$18,539.00',
#   'Existencia': 'Disponibles:177pzas.',
#   'Enlaces': '#'},
#  {'Producto': 'Laptop HP 240 G8 14" HD, Intel Core i5-1135G7 2.40GHz, 16GB, 500GB SSD, Windows 11 Pro 64-bit, Español, Negro ― Configuración Especial, 1 Año de Garantía',
#   'Rating': 5,
#   'Precio': '$13,249.00',
#   'Existencia': 'Disponibles:2pzas.',
#   'Enlaces': 'https://www.cyberpuerta.mx/Computadoras/Laptops/cp2-cp2-8.html'},
#  {'Producto': 'Laptop Lenovo ThinkBook 14 G2 ITL 14" Full HD, Intel Core i3-1115G4 3GHz, 8GB, 256GB SSD, Windows 10 Pro 64-bit, Español, Gris',
#   'Rating': 5,
#   'Precio': '$13,679.00',
#   'Existencia': 'Disponibles:222pzas.',
#   'Enlaces': '#'},
#  {'Producto': 'Laptop Lenovo ThinkPad T14 Gen 2 14" Full HD, AMD Ryzen 5 PRO 5650U 2.30GHz, 8GB, 512GB SSD, Windows 11 Pro 64-bit, Inglés, Negro',
#   'Rating': 4,
#   'Precio': '$18,319.00',
#   'Existencia': 'Disponibles:10pzas.',
#   'Enlaces': 'https://www.cyberpuerta.mx/lista-de-comparacion/?cnid=4fe38c01729fc'},
#  {'Producto': 'Laptop Lanix Neuron V V7 15.6" Full HD, Intel Core i5-10210U 1.60GHz, 8GB, 512GB SSD, Windows 11 Pro, Español, Negro',
#   'Rating': 4,
#   'Precio': '$14,859.00',
#   'Existencia': 'Disponibles:5pzas.',
#   'Enlaces': '#'},
#  {'Producto': 'Laptop Dell Latitude 3540 15.6" Full HD, Intel Core i5-1335U 1.30GHz, 8GB, 256GB SSD, Windows 11 Pro 64-bit, Español, Negro',
#   'Rating': 4,
#   'Precio': '$19,919.00',
#   'Existencia': 'Disponibles:480pzas.',
#   'Enlaces': 'https://www.cyberpuerta.mx/Computadoras/Laptops/cp2-cp2-3.html'},
#  {'Producto': 'Laptop HP ProBook 440 G9 14" Full HD, Intel Core i5-1235U 1.30GHz, 16GB, 512GB SSD, Windows 11 Pro 64-bit, Español, Plata',
#   'Rating': 4,
#   'Precio': '$19,689.00',
#   'Existencia': 'Disponibles:184pzas.',
#   'Enlaces': '#'},
#  {'Producto': 'Laptop HP 240 G8 14" HD, Intel Core i5-1135G7 2.40GHz, 8GB, 256GB SSD, Windows 11 Pro 64-bit, Español, Negro',
#   'Rating': 4,
#   'Precio': '$13,419.00',
#   'Existencia': 'Disponibles:956pzas.',
#   'Enlaces': 'https://www.cyberpuerta.mx/lista-de-comparacion/?cnid=4fe38c01729fc'},
#  {'Producto': 'Laptop HP 250 G8 15.6" Full HD, Intel Core i5-1135G7 2.40GHz, 16GB, 256GB SSD, Windows 11 Pro 64-bit, Español, Gris',
#   'Rating': 4,
#   'Precio': '$14,059.00',
#   'Existencia': 'Disponibles:477pzas.',
#   'Enlaces': '#'},
#  {'Producto': 'Laptop Lenovo ThinkPad L14 G1 14" HD, AMD Ryzen 3 4300U 2.70GHz, 8GB, 256GB SSD, Windows 10 Pro 64-bit, Español, Negro',
#   'Rating': 5,
#   'Precio': '$16,449.00',
#   'Existencia': 'Disponibles:25pzas.',
#   'Enlaces': 'https://www.cyberpuerta.mx/Computadoras/Laptops/Laptop-Lenovo-ThinkPad-L14-G1-14-HD-AMD-Ryzen-3-4300U-2-70GHz-8GB-256GB-SSD-Windows-10-Pro-64-bit-Espanol-Negro.html'},
#  {'Producto': "Apple MacBook Air Retina Z124 13.3'', Apple M1, 16GB, 256GB SSD, Gris Espacial",
#   'Rating': 5,
#   'Precio': '$24,439.00',
#   'Existencia': 'Disponibles:12pzas.',
#   'Enlaces': 'https://www.cyberpuerta.mx/Opiniones-sobre-Laptop-Lenovo-ThinkPad-L14-G1-14-HD-AMD-Ryzen-3-4300U-2-70GHz-8GB-256GB-SSD-Windows-10-Pro-64-bit-Espanol-Negro/'},
#  {'Producto': 'Laptop HP 245 G8 14" HD, AMD Ryzen 5 5500U 2.10GHz, 8GB, 256GB SSD, Windows 10 Home 64-bit, Español, Negro',
#   'Rating': 5,
#   'Precio': '$15,279.00',
#   'Existencia': 'Disponibles:3pzas.',
#   'Enlaces': 'https://www.cyberpuerta.mx/Opiniones-sobre-Laptop-Lenovo-ThinkPad-L14-G1-14-HD-AMD-Ryzen-3-4300U-2-70GHz-8GB-256GB-SSD-Windows-10-Pro-64-bit-Espanol-Negro/'},
#  {'Producto': 'Laptop Acer Aspire 3 A315-24P-R3XC 15.6" Full HD, AMD Ryzen 5-7520U 2.80GHz, 16GB, 512GB SSD, Windows 11 Home 64-bit, Español, Plata',
#   'Rating': 5,
#   'Precio': '$15,519.00',
#   'Existencia': 'Disponibles:8pzas.',
#   'Enlaces': '#'},
#  {'Producto': 'Laptop Gamer Dell G5 15 5515 15.6" Full HD, AMD Ryzen 7 5800H 3.20GHz, 16GB, 512GB SSD, NVIDIA GeForce RTX 3060 Windows 11 Home 64-bit, Español, Gris',
#   'Rating': 5,
#   'Precio': '$33,439.00',
#   'Existencia': 'Disponibles:21pzas.',
#   'Enlaces': 'https://www.cyberpuerta.mx/lista-de-comparacion/?cnid=4fe38c01729fc'},
#  {'Producto': 'Laptop Lanix Neuron X PRO 41539 14" Full HD, Intel Core i3-1115G4 3GHz, 8GB, 512GB SSD, Windows 11 Home 64-bit, Español, Negro',
#   'Rating': 5,
#   'Precio': '$11,679.00',
#   'Existencia': 'Disponibles:3pzas.',
#   'Enlaces': '#'},
#  {'Producto': 'Laptop HP 245 G7 14", AMD Ryzen 5 3500U 2.10GHz, 8GB, 1TB, Windows 10 Home 64-bit, Español, Negro',
#   'Rating': 4,
#   'Precio': '$16,559.00',
#   'Existencia': 'Disponibles:\n¡1pza.!',
#   'Enlaces': 'https://www.cyberpuerta.mx/Computadoras/Laptops/Laptop-HP-245-G7-14-AMD-Ryzen-5-3500U-2-10GHz-8GB-1TB-Windows-10-Home-64-bit-Espanol-Negro.html'},
#  {'Producto': 'Laptop Lenovo ThinkPad E14 Gen2 14" Full HD, AMD Ryzen 3 4300U 2.70GHz, 16GB, 256GB SSD, Windows 10 Pro 64-bit, Español, Negro',
#   'Rating': 4,
#   'Precio': '$14,049.00',
#   'Existencia': 'Disponibles:38pzas.',
#   'Enlaces': 'https://www.cyberpuerta.mx/Opiniones-sobre-Laptop-HP-245-G7-14-AMD-Ryzen-5-3500U-2-10GHz-8GB-1TB-Windows-10-Home-64-bit-Espanol-Negro/'},
#  {'Producto': 'Laptop Lenovo ThinkPad L15 Gen 3 15.6" Full HD, Intel Core i5-1235U 3.30GHz, 16GB, 512GB SSD, Windows 10 Pro 64-bit, Español, Negro',
#   'Rating': 5,
#   'Precio': '$22,449.00',
#   'Existencia': 'Disponibles:42pzas.',
#   'Enlaces': 'https://www.cyberpuerta.mx/Opiniones-sobre-Laptop-HP-245-G7-14-AMD-Ryzen-5-3500U-2-10GHz-8GB-1TB-Windows-10-Home-64-bit-Espanol-Negro/'},
#  {'Producto': 'Laptop Dell Inspiron 13 5310 13.3" Quad HD, Intel Core i7-11390H 2.90GHz, 8GB, 512GB SSD, Windows 11 Home 64-bit, Español, Plata',
#   'Rating': 5,
#   'Precio': '$17,439.00',
#   'Existencia': 'Disponibles:23pzas.',
#   'Enlaces': '#'},
#  {'Producto': 'Laptop Gamer Lenovo Legion 5 15.6" Full HD, Intel Core i5-10300H 2.50GHz, 8GB, 1TB + 128GB SSD, NVIDIA GeForce GTX 1660 Ti, Windows 10 Home 64-bit, Español, Negro',
#   'Rating': 4,
#   'Precio': '$21,559.00',
#   'Existencia': 'Disponibles:3pzas.',
#   'Enlaces': 'https://www.cyberpuerta.mx/lista-de-comparacion/?cnid=4fe38c01729fc'},
#  {'Producto': 'Laptop HP 255 G8 15.6" HD, AMD 3020e 1.20GHz, 4GB, 256GB SSD, Windows 10 Home 64-bit, Español, Negro',
#   'Rating': 4,
#   'Precio': '$7,919.00',
#   'Existencia': 'Disponibles:15pzas.',
#   'Enlaces': '#'},
#  {'Producto': 'Laptop ASUS F415EA 14" Full HD, Intel Core i3-1115G4 3GHz, 4GB, 128GB SSD, Windows 11 Home 64-bit, Español, Gris',
#   'Rating': 4,
#   'Precio': '$7,729.00',
#   'Existencia': 'Disponibles:21pzas.',
#   'Enlaces': 'https://www.cyberpuerta.mx/Computadoras/Laptops/Laptop-ASUS-F415EA-14-Full-HD-Intel-Core-i3-1115G4-3GHz-4GB-128GB-SSD-Windows-11-Home-64-bit-Espanol-Gris.html'},
#  {'Producto': 'Laptop Lenovo ThinkPad T14 Gen 2 14" Full HD, Intel Core i5-1135G7 2.40GHz, 16GB, 512GB SSD, Windows 11 Pro 64-bit, Español, Negro',
#   'Rating': 4,
#   'Precio': '$22,639.00',
#   'Existencia': 'Disponibles:45pzas.',
#   'Enlaces': '#'},
#  {'Producto': 'Laptop Lenovo IdeaPad Slim 3 15IAN8 15.6" Full HD, Intel Core i3-N305 1.80GHz, 8GB, 256GB SSD, Windows 11 Home 64-bit, Español, Azul Frío',
#   'Rating': 4,
#   'Precio': '$9,109.00',
#   'Existencia': 'Disponibles:43pzas.',
#   'Enlaces': 'https://www.cyberpuerta.mx/lista-de-comparacion/?cnid=4fe38c01729fc'},
#  {'Producto': 'Laptop ASUS Chromebook CX1 15.6" HD, Intel Celeron N4500 1.10GHz, 8GB, 128GB eMMC, Chrome OS, Español, Plata',
#   'Rating': 4,
#   'Precio': '$8,709.00',
#   'Existencia': 'Disponibles:9pzas.',
#   'Enlaces': '#'},
#  {'Producto': 'Laptop Dell Latitude 5440 14" Full HD, Intel Core i5-1335U 3.40GHz, 8GB, 256GB SSD, Windows 11 Pro 64-bit, Español, Gris',
#   'Rating': 4,
#   'Precio': '$21,449.00',
#   'Existencia': 'Disponibles:15pzas.',
#   'Enlaces': 'https://www.cyberpuerta.mx/Computadoras/Laptops/Laptop-Dell-Latitude-5440-14-Full-HD-Intel-Core-i5-1335U-3-40GHz-8GB-256GB-SSD-Windows-11-Pro-64-bit-Espanol-Gris.html'},
#  {'Producto': 'Laptop ASUS VivoBook K1703ZA-WH34 17.3" Full HD, Intel Core i3-1220P 1.10GHz, 8GB, 256GB SSD, Windows 11 Home 64-bit, Plata',
#   'Rating': 4,
#   'Precio': '$9,159.00',
#   'Existencia': 'Disponibles:27pzas.',
#   'Enlaces': '#'},
#  {'Producto': 'Laptop Lenovo IdeaPad 1 14IAU7 14" HD, Intel Core i3-1215U 3.30GHz, 8GB, 128GB SSD, Windows 11 Home S, Inglés, Gris ― Configuración Especial, 1 Año de Garantía',
#   'Rating': 4,
#   'Precio': '$7,509.00',
#   'Existencia': 'Disponibles:24pzas.',
#   'Enlaces': 'https://www.cyberpuerta.mx/lista-de-comparacion/?cnid=4fe38c01729fc'},
#  {'Producto': 'Laptop Acer Aspire 3 A315-510P-38R 15.6" Full HD, Intel Core i3-N305 1.80GHz, 8GB, 512GB SSD, Windows 11 Home 64-bit, Español, Azul',
#   'Rating': 4,
#   'Precio': '$9,199.00',
#   'Existencia': 'Disponibles:308pzas.',
#   'Enlaces': '#'},
# ...
#   'Rating': 4,
#   'Precio': '$19,749.00',
#   'Existencia': 'Disponibles:24pzas.',
#   'Enlaces': 'https://www.cyberpuerta.mx/Opiniones-sobre-Laptop-ASUS-Chromebook-C204EE-11-6-HD-Intel-Celeron-N4020-1-10GHz-4GB-32GB-eMMC-Chrome-OS-Espanol-Gris/'},
#  {'Producto': 'Laptop Lenovo ThinkPad X13 G3 13.3" WUXGA, Intel Core i7-1260P 3.40GHz, 16GB, 256GB SSD, Windows 10 Pro 64-bit, Español, Negro',
#   'Rating': 4,
#   'Precio': '$27,429.00',
#   'Existencia': 'Disponibles:2pzas.',
#   'Enlaces': 'https://www.cyberpuerta.mx/Computadoras/Laptops/Laptop-Lenovo-ThinkPad-X13-G3-13-3-WUXGA-Intel-Core-i7-1260P-3-40GHz-16GB-256GB-SSD-Windows-10-Pro-64-bit-Espanol-Negro.html'},
#  {'Producto': 'Laptop Dell Latitude 3520 15,6" HD, Intel Core i5-1135G7 2.40GHz, 8GB, 256GB SSD, Windows 10 Pro 64-bit, Español, Gris',
#   'Rating': 4,
#   'Precio': '$19,139.00',
#   'Existencia': 'Disponibles:67pzas.',
#   'Enlaces': '#'},
#  {'Producto': 'Laptop Lenovo ThinkPad T14 Gen 2 14" Full HD, Intel Core i5-1135G7 2.40GHz, 16GB, 512GB SSD, Windows 10 Pro 64-bit, Español, Negro',
#   'Rating': 4,
#   'Precio': '$22,859.00',
#   'Existencia': 'Disponibles:33pzas.',
#   'Enlaces': 'https://www.cyberpuerta.mx/lista-de-comparacion/?cnid=4fe38c01729fc'},
#  {'Producto': 'Laptop HP 240 G8 79L97LT 14" HD, Intel Core i5-1135G7 2.40GHz, 8GB, 256GB SSD, Windows 11 Home 64-bit, Español, Negro',
#   'Rating': 4,
#   'Precio': '$9,189.00',
#   'Existencia': 'Disponibles:137pzas.',
#   'Enlaces': '#'},
#  {'Producto': 'Laptop HP 245 G9 14" HD, AMD Ryzen 5 5625U 2.30GHz, 8GB, 512GB SSD, Windows 11 Home 64-bit, Español, Plata',
#   'Rating': 3,
#   'Precio': '$11,349.00',
#   'Existencia': 'Disponibles:\n¡1pza.!',
#   'Enlaces': 'https://www.cyberpuerta.mx/Computadoras/Laptops/Laptop-HP-245-G9-14-HD-AMD-Ryzen-5-5625U-2-30GHz-8GB-512GB-SSD-Windows-11-Home-64-bit-Espanol-Plata.html'},
#  {'Producto': 'Laptop Dell Latitude 5430 14” Full HD, Intel Core i5-1235U 3.30GHz, 8GB, 256GB SSD, Windows 10 Pro 64-bit, Español, Gris (2022) ― Garantía Limitada por 1 Año',
#   'Rating': 3,
#   'Precio': '$27,149.00',
#   'Existencia': 'Disponibles:40pzas.',
#   'Enlaces': '#'},
#  {'Producto': 'Laptop HP EliteBook 845 G9 14" Full HD, AMD Ryzen 7 PRO 6850U 2.70GHz, 8GB, 512GB SSD, Windows 11 Pro 64-bit, Español, Plata',
#   'Rating': 3,
#   'Precio': '$25,859.00',
#   'Existencia': 'Disponibles:2pzas.',
#   'Enlaces': 'https://www.cyberpuerta.mx/Computadoras/Laptops/Laptop-HP-EliteBook-845-G9-14-Full-HD-AMD-Ryzen-7-PRO-6850U-2-70GHz-8GB-512GB-SSD-Windows-11-Pro-64-bit-Espanol-Plata.html'},
#  {'Producto': 'Apple MacBook Pro Retina MNEQ3E/A 13”, Apple M2, 8GB, 512GB SSD, Plata (Julio 2022)',
#   'Rating': 3,
#   'Precio': '$32,469.00',
#   'Existencia': 'Disponibles:32pzas.',
#   'Enlaces': '#'},
#  {'Producto': 'Laptop HP ProBook 640 G8 14" HD, Intel Core i5-1145G7 2.60GHz, 8GB, 256GB SSD, Windows 10 Pro 64-bit, Español, Plata',
#   'Rating': 3,
#   'Precio': '$22,029.00',
#   'Existencia': 'Disponibles:48pzas.',
#   'Enlaces': 'https://www.cyberpuerta.mx/Computadoras/Laptops/Laptop-HP-ProBook-640-G8-14-HD-Intel-Core-i5-1145G7-2-60GHz-8GB-256GB-SSD-Windows-10-Pro-64-bit-Espanol-Plata.html'},
#  {'Producto': 'Laptop Lenovo ThinkPad L14 G1 14" HD, AMD Ryzen 3 4300U 2.70GHz, 8GB, 512GB SSD, Windows 10 Pro 64-bit, Español, Negro',
#   'Rating': 3,
#   'Precio': '$20,929.00',
#   'Existencia': 'Disponibles:8pzas.',
#   'Enlaces': '#'},
#  {'Producto': 'Laptop Lenovo V14-ITL G2 14" HD, Intel Core i7-1165G7 2.80GHz, 16GB, 512GB SSD, Windows 10 Pro 64-bit, Español, Gris',
#   'Rating': 3,
#   'Precio': '$21,049.00',
#   'Existencia': 'Disponibles:12pzas.',
#   'Enlaces': 'https://www.cyberpuerta.mx/Computadoras/Laptops/Laptop-Lenovo-V14-ITL-G2-14-HD-Intel-Core-i7-1165G7-2-80GHz-16GB-512GB-SSD-Windows-10-Pro-64-bit-Espanol-Gris.html'},
#  {'Producto': 'Laptop Lenovo IdeaPad 3 15ITL05 15.6" HD, Intel Core i3-1115G4 3GHz, 8GB, 256GB SSD, Windows 10 Home, Inglés, Arena',
#   'Rating': 3,
#   'Precio': '$9,089.00',
#   'Existencia': 'Disponibles:6pzas.',
#   'Enlaces': '#'},
#  {'Producto': 'Laptop Dell Latitude 5420 14" Full HD, Intel Core i7-1165G7 2.80GHz, 8GB, 256GB SSD, Windows 10 Pro 64-bit, Español, Gris',
#   'Rating': 3,
#   'Precio': '$25,329.00',
#   'Existencia': 'Disponibles:46pzas.',
#   'Enlaces': 'https://www.cyberpuerta.mx/Computadoras/Laptops/Laptop-Dell-Latitude-5420-14-Full-HD-Intel-Core-i7-1165G7-2-80GHz-8GB-256GB-SSD-Windows-10-Pro-64-bit-Espanol-Gris-cp2-1.html'},
#  {'Producto': 'Laptop Lanix Neuron A V19 10650 14" HD, Intel Pentium J3710 1.60GHz, 8GB, 512GB SSD, Windows 10 Home 64-bits, Español, Negro/Gris',
#   'Rating': 3,
#   'Precio': '$4,909.00',
#   'Existencia': 'Disponibles:1825pzas.',
#   'Enlaces': '#'},
#  {'Producto': 'Laptop Acer TravelMate P6 TMP614-51-G2-50ND 14" HD, Intel Core i5-10210U 1.60GHz, 8GB, 512GB SSD, Windows 10 Pro 64-bit, Español, Negro',
#   'Rating': 3,
#   'Precio': '$18,039.00',
#   'Existencia': 'Disponibles:3pzas.',
#   'Enlaces': 'https://www.cyberpuerta.mx/Computadoras/Laptops/Laptop-Acer-TravelMate-P6-TMP614-51-G2-50ND-14-HD-Intel-Core-i5-10210U-1-60GHz-8GB-512GB-SSD-Windows-10-Pro-64-bit-Espanol-Negro.html'},
#  {'Producto': 'Laptop Lenovo IdeaPad Slim 1-14AST-05 14" HD, AMD A6-9220e 1.60GHz, 4GB, 64GB, Windows 10 Home S, Inglés, Plata',
#   'Rating': 3,
#   'Precio': '$7,699.00',
#   'Existencia': 'Disponibles:3pzas.',
#   'Enlaces': '#'},
#  {'Producto': 'Laptop Lenovo Chromebook 100E 11.6" HD, MediaTek MT8173C 2GHz, 4GB, 32GB, Chrome OS, Inglés, Negro',
#   'Rating': 4,
#   'Precio': '$2,619.00',
#   'Existencia': 'Disponibles:10pzas.',
#   'Enlaces': 'https://www.cyberpuerta.mx/lista-de-comparacion/?cnid=4fe38c01729fc'},
#  {'Producto': 'Laptop Samsung Chromebook 4+ 15.6" Full HD, Intel Celeron N4000 1.10GHz, 4GB, 32GB eMMc, Chrome OS, Inglés, Plata',
#   'Rating': 4,
#   'Precio': '$7,409.00',
#   'Existencia': 'Disponibles:\n¡1pza.!',
#   'Enlaces': '#'},
#  {'Producto': 'Laptop Lenovo IdeaPad 3 14IGL05 14” Full HD, Intel Celeron N4020 1.10GHz, 8GB, 1TB, Windows 11 Home 64-bit, Español, Azul',
#   'Rating': 5,
#   'Precio': '$6,149.00',
#   'Existencia': 'Producto agotado',
#   'Enlaces': 'https://www.cyberpuerta.mx/Computadoras/Laptops/Laptop-Lenovo-IdeaPad-3-14IGL05-14-Full-HD-Intel-Celeron-N4020-1-10GHz-8GB-1TB-Windows-11-Home-64-bit-Espanol-Azul.html'},
#  {'Producto': 'Laptop Lenovo IdeaPad 3-14ALC6 14" Full HD, AMD Ryzen 3 5300U 2.60GHz, 8GB, 512GB SSD, Windows 10 Home 64-bit, Español, Azul',
#   'Rating': 5,
#   'Precio': '$14,249.00',
#   'Existencia': 'Producto agotado',
#   'Enlaces': 'https://www.cyberpuerta.mx/Opiniones-sobre-Laptop-Lenovo-IdeaPad-3-14IGL05-14-Full-HD-Intel-Celeron-N4020-1-10GHz-8GB-1TB-Windows-11-Home-64-bit-Espanol-Azul/'},
#  {'Producto': 'Laptop Dell Precision 5570 15.6" Full HD, Intel Core i7-12800H 2.40GHz, 64GB, 512GB SSD, NVIDIA RTX A1000, Windows 11 Pro 64-bit, Español, Negro ― Garantía Limitada por 1 Año',
#   'Rating': 5,
#   'Precio': '$57,599.00',
#   'Existencia': 'Producto agotado',
#   'Enlaces': 'https://www.cyberpuerta.mx/Opiniones-sobre-Laptop-Lenovo-IdeaPad-3-14IGL05-14-Full-HD-Intel-Celeron-N4020-1-10GHz-8GB-1TB-Windows-11-Home-64-bit-Espanol-Azul/'},
#  {'Producto': 'Laptop HP 14-dq2521la 14" HD, Intel Core i3-1115G4 3GHz, 8GB, 256GB SSD, Windows 11 Home 64-bit, Español, Azul',
#   'Rating': 5,
#   'Precio': '$12,139.00',
#   'Existencia': 'Producto agotado',
#   'Enlaces': '#'},
#  {'Producto': 'Laptop Gamer Lenovo IdeaPad 3 15IHU6 15.6" Full HD, Intel Core i5-11300H 3.10GHz, 8GB, 512GB SSD, NVIDIA GeForce GTX 1650, Windows 11 Home 64-bit, Español, Negro',
#   'Rating': 5,
#   'Precio': '$16,419.00',
#   'Existencia': 'Producto agotado',
#   'Enlaces': '#'},
#  {'Producto': 'Laptop AORUS 15 XE4 15.6” Full HD, Intel Core i7-12700H  2.30GHz, 16GB, 1TB SSD, NVIDIA GeForce RTX 3070 Ti, Windows 11 Home 64-bit, Español, Negro',
#   'Rating': 5,
#   'Precio': '$26,699.00',
#   'Existencia': 'Producto agotado',
#   'Enlaces': 'https://www.cyberpuerta.mx/lista-de-comparacion/?cnid=4fe38c01729fc'},
#  {'Producto': 'Laptop HP 15-EG0500LA 15.6"HD, Intel Core i5-1135G7 2.40GHz, 8GB, 256GB SSD, Windows 11 Home 64-bit, Español, Plata',
#   'Rating': 4,
#   'Precio': '$11,189.00',
#   'Existencia': 'Producto agotado',
#   'Enlaces': '#'},
#  {'Producto': 'Laptop Gamer Lenovo IdeaPad Gaming 3i 15IMH05 15.6" Full HD, Intel Core i5-10300H 2.50GHz, 8GB, 1TB + 256GB SSD, NVIDIA GeForce GTX 1650 TI, Windows 10 Home 64-bit, Español, Azul',
#   'Rating': 4,
#   'Precio': '$16,049.00',
#   'Existencia': 'Producto agotado',
#   'Enlaces': 'https://www.cyberpuerta.mx/Computadoras/Laptops/Laptop-Gamer-Lenovo-IdeaPad-Gaming-3i-15IMH05-15-6-Full-HD-Intel-Core-i5-10300H-2-50GHz-8GB-1TB-256GB-SSD-NVIDIA-GeForce-GTX-1650-TI-Windows-10-Home-64-bit-Espanol-Azul.html'},
#  {'Producto': 'Laptop Hyundai Hybook Ereny Plus 14.1" HD, AMD A9-9400 2.4GHz, 8GB, 256GB SSD, Windows 10 Home 64-bit, Español, Gris',
#   'Rating': 4,
#   'Precio': '$4,359.00',
#   'Existencia': 'Producto agotado',
#   'Enlaces': 'https://www.cyberpuerta.mx/Opiniones-sobre-Laptop-Gamer-Lenovo-IdeaPad-Gaming-3i-15IMH05-15-6-Full-HD-Intel-Core-i5-10300H-2-50GHz-8GB-1TB-256GB-SSD-NVIDIA-GeForce-GTX-1650-TI-Windows-10-Home-64-bit-Espanol-Azul/'},
#  {'Producto': 'Laptop Lenovo Ideapad L340 15.6" Full HD, AMD Ryzen 7 3700U 2.30GHz, 8GB, 2TB, AMD Radeon RX Vega 10, Windows 10 Home 64-bit, Español, Negro',
#   'Rating': 4,
#   'Precio': '$15,629.00',
#   'Existencia': 'Producto agotado',
#   'Enlaces': 'https://www.cyberpuerta.mx/Opiniones-sobre-Laptop-Gamer-Lenovo-IdeaPad-Gaming-3i-15IMH05-15-6-Full-HD-Intel-Core-i5-10300H-2-50GHz-8GB-1TB-256GB-SSD-NVIDIA-GeForce-GTX-1650-TI-Windows-10-Home-64-bit-Espanol-Azul/'},
#  {'Producto': 'Lenovo 2 en 1 300e 2da Gen 11.6" HD, Intel Celeron N4120 1.10GHz, 4GB, 64GB, Windows 10 Pro 64-bit, Español, Negro',
#   'Rating': 4,
#   'Precio': '$5,409.00',
#   'Existencia': 'Producto agotado',
#   'Enlaces': 'https://www.cyberpuerta.mx/?cl=cpqa_writequestion&anid=b42b87d390c0db6862230b78214ac802'},
#  {'Producto': 'Laptop Gamer Dell Inspiron G15 5520 15.6" Full HD, Intel Core i7-12700H 3.50GHz, 16GB, 512GB SSD, NVIDIA GeForce RTX 3050, Windows 11 Home 64-bit, Español, Negro ― Garantía Limitada por 1 Año',
#   'Rating': 4,
#   'Precio': '$36,799.00',
#   'Existencia': 'Producto agotado',
#   'Enlaces': '#'},
#  {'Producto': 'Laptop Huawei Matebook D14 14" Full HD, Intel Core i3-10110U 2.10GHz, 8GB, 256GB SSD, Windows 10 Home 64-bit, Español, Gris',
#   'Rating': 4,
#   'Precio': '$13,819.00',
#   'Existencia': 'Producto agotado',
#   'Enlaces': '#'},
#  {'Producto': 'Laptop Lenovo IdeaPad 3 15ITL6 15.6" Full HD, Intel Core i3-1115G4 3GHz, 8GB, 256GB SSD, Windows 11 Home 64-bit, Español, Arena',
#   'Rating': 4,
#   'Precio': '$13,829.00',
#   'Existencia': 'Producto agotado',
#   'Enlaces': 'https://www.cyberpuerta.mx/lista-de-comparacion/?cnid=4fe38c01729fc'},
#  {'Producto': 'Laptop Lenovo IdeaPad 3 15ALC6 15.6" Full HD, AMD Ryzen 5 5500U 2.10GHz, 8GB, 1TB + 256GB SSD, Windows 11 Home 64-bit, Español, Azul',
#   'Rating': 4,
#   'Precio': '$12,249.00',
#   'Existencia': 'Producto agotado',
#   'Enlaces': '#'},
#  {'Producto': 'Laptop HP Elite x360 1040 G10 14" WUXGA Táctil, Intel Core i7-1365U 1.80GHz, 16GB, 1TB SSD, Windows 11 Pro, Español, Plata',
#   'Rating': 5,
#   'Precio': '$39,709.00',
#   'Existencia': 'Producto agotado',
#   'Enlaces': 'https://www.cyberpuerta.mx/Computadoras/Laptops/Laptop-HP-Elite-x360-1040-G10-14-WUXGA-Tactil-Intel-Core-i7-1365U-1-80GHz-16GB-1TB-SSD-Windows-11-Pro-Espanol-Plata.html'},
#  {'Producto': 'Apple MacBook Air Retina MGND3LA/A 13.3", Apple M1, 8GB, 256GB SSD, Oro (Noviembre 2020)',
#   'Rating': 5,
#   'Precio': '$25,209.00',
#   'Existencia': 'Producto agotado',
#   'Enlaces': '#'},
#  {'Producto': 'Apple MacBook Air Retina MGN93LA/A 13.3", Apple M1, 8GB, 256GB SSD, Plata',
#   'Rating': 5,
#   'Precio': '$19,689.00',
#   'Existencia': 'Producto agotado',
#   'Enlaces': '#'},
#  {'Producto': 'Laptop HP 15-EF2723OD 15.6" Full HD, AMD Ryzen 3 5300U 2.60GHz, 8GB, 256GB SSD, Windows 11 Home 64-bit, Inglés, Plata',
#   'Rating': 5,
#   'Precio': '$9,859.00',
#   'Existencia': 'Producto agotado',
#   'Enlaces': 'https://www.cyberpuerta.mx/lista-de-comparacion/?cnid=4fe38c01729fc'},
#  {'Producto': 'Laptop Dell Inspiron G5 5520 15.6" Full HD, Intel Core i7-12700H 3.50GHz, 16GB, 512GB SSD, NVIDIA GeForce RTX 3060, Windows 11 Home 64-bit, Español, Negro',
#   'Rating': 4,
#   'Precio': '$39,499.00',
#   'Existencia': 'Producto agotado',
#   'Enlaces': '#'},
#  {'Producto': 'Laptop Gamer MSI GF63 Thin 15.6" Full HD, Intel Core i5-11400H 2.70GHz, 8GB, 512GB SSD, NVIDIA GeForce RTX 3050, Windows 11 Home 64-bit, Inglés, Negro',
#   'Rating': 5,
#   'Precio': '$18,649.00',
#   'Existencia': 'Producto agotado',
#   'Enlaces': 'https://www.cyberpuerta.mx/Computadoras/Laptops/Laptop-Gamer-MSI-GF63-Thin-15-6-Full-HD-Intel-Core-i5-11400H-2-70GHz-8GB-512GB-SSD-NVIDIA-GeForce-RTX-3050-Windows-11-Home-64-bit-Ingles-Negro.html'},
#  {'Producto': 'Laptop Dell Vostro 3480 14" HD, Intel Core i3-8145U 2.10GHz, 8GB, 1TB, Windows 10 Pro 64-bit, Negro',
#   'Rating': 5,
#   'Precio': '$13,899.00',
#   'Existencia': 'Producto agotado',
#   'Enlaces': '#'},
#  {'Producto': 'Laptop Gamer ASUS ROG Strix SCAR 15 15.6" Full HD, Intel Core i9-12900H 3.80GHz, 16GB, 1TB SSD, NVIDIA GeForce RTX 3070 Ti, Windows 11 Home 64-bit, Inglés, Negro',
#   'Rating': 2,
#   'Precio': '$43,499.00',
#   'Existencia': 'Producto agotado',
#   'Enlaces': 'https://www.cyberpuerta.mx/Computadoras/Laptops/Laptop-Gamer-ASUS-ROG-Strix-SCAR-15-15-6-Full-HD-Intel-Core-i9-12900H-3-80GHz-16GB-1TB-SSD-NVIDIA-GeForce-RTX-3070-Ti-Windows-11-Home-64-bit-Ingles-Negro.html'},
#  {'Producto': 'Laptop Dell Inspiron 5510 15.6" Full HD, Intel Core i5-11320H 3.20GHz, 12GB, 512GB SSD, Windows 10 Pro 64-bit, Español, Plata (2021) ― Garantía Limitada por 1 Año',
#   'Rating': 2,
#   'Precio': '$22,239.00',
#   'Existencia': 'Producto agotado',
#   'Enlaces': 'https://www.cyberpuerta.mx/Opiniones-sobre-Laptop-Gamer-ASUS-ROG-Strix-SCAR-15-15-6-Full-HD-Intel-Core-i9-12900H-3-80GHz-16GB-1TB-SSD-NVIDIA-GeForce-RTX-3070-Ti-Windows-11-Home-64-bit-Ingles-Negro/'},
#  {'Producto': 'Laptop Lenovo ThinkPad T15 G2 15.6" Full HD, Intel Core i5-1135G7 2.40GHz, 16GB, 512GB SSD, Windows 10 Pro 64-bit, Español, Negro',
#   'Rating': 3,
#   'Precio': '$22,239.00',
#   'Existencia': 'Producto agotado',
#   'Enlaces': 'https://www.cyberpuerta.mx/Computadoras/Laptops/Laptop-Lenovo-ThinkPad-T15-G2-15-6-Full-HD-Intel-Core-i5-1135G7-2-40GHz-16GB-512GB-SSD-Windows-10-Pro-64-bit-Espanol-Negro.html'},
#  {'Producto': 'Laptop Dell Inspiron 5415 14" Full HD, AMD Ryzen 7 5700U 1.80GHz, 16GB, 512GB SSD, Windows 10 Home 64-bit, Español, Platino ― Configuración Especial, 1 Año de Garantía',
#   'Rating': 3,
#   'Precio': '$18,109.00',
#   'Existencia': 'Producto agotado',
#   'Enlaces': '#'},
#  {'Producto': 'Laptop Lenovo IdeaPad 5-14ARE05 14" HD, AMD Ryzen 3 4300U 2.70GHz, 8GB, 256GB SSD, Windows 10 Home 64-bit, Español, Azul',
#   'Rating': 2,
#   'Precio': '$7,709.00',
#   'Existencia': 'Producto agotado',
#   'Enlaces': 'https://www.cyberpuerta.mx/Computadoras/Laptops/Laptop-Lenovo-IdeaPad-5-14ARE05-14-HD-AMD-Ryzen-3-4300U-2-70GHz-8GB-256GB-SSD-Windows-10-Home-64-bit-Espanol-Azul.html'},
#  {'Producto': 'Laptop Lenovo IdeaPad 3 15IML05 15.6" HD, Intel Core i3-10110U 2.10GHz, 8GB, 1TB, Windows 10 Home 64-bit, Español, Plata',
#   'Rating': 2,
#   'Precio': '$11,599.00',
#   'Existencia': 'Producto agotado',
#   'Enlaces': '#'},
#  {'Producto': "Laptop HP 240 G8 14'' HD, Intel Core i5-1035G1 1GHz, 8GB, 1TB, Windows 10 Home 64-bit, Español, Gris Oscuro",
#   'Rating': 3,
#   'Precio': '$29,439.00',
#   'Existencia': 'Producto agotado',
#   'Enlaces': 'https://www.cyberpuerta.mx/Computadoras/Laptops/Laptop-HP-240-G8-14-HD-Intel-Core-i5-1035G1-1GHz-8GB-1TB-Windows-10-Home-64-bit-Espanol-Gris-Oscuro.html'},
#  {'Producto': 'Laptop Gamer MSI GF63 Thin 15.6" Full HD, Intel Core i5-10300H 2.50GHz, 16GB, 256GB SSD, NVIDIA GeForce GTX 1650 Max-Q, Windows 10 Home, Inglés, Negro',
#   'Rating': 3,
#   'Precio': '$14,909.00',
#   'Existencia': 'Producto agotado',
#   'Enlaces': '#'}]

# %%
print(len(data))
# Out:
# 212

# %%
import pandas as pd

df =  pd.DataFrame(data)

df
# Out:
#                                               Producto  Rating      Precio  \
# 0    Laptop Gamer Lenovo Legion 5 15IAH7H 15.6" Ful...       5  $22,339.00
# 1    Laptop Lenovo IdeaPad 5-14ALC05 14" Full HD, A...       5   $9,549.00
# 2    Laptop HP 245 G9 14" HD, AMD Ryzen 3 5425U 2.7...       4   $9,909.00
# 3    Laptop Lenovo Thinkpad T14 Gen2 14" Full HD, I...       4  $16,459.00
# 4    Laptop HP 245 G9 14" HD, AMD Ryzen 3 5425U 2.7...       4  $12,409.00
# ..                                                 ...     ...         ...
# 207  Laptop Dell Inspiron 5415 14" Full HD, AMD Ryz...       3  $18,109.00
# 208  Laptop Lenovo IdeaPad 5-14ARE05 14" HD, AMD Ry...       2   $7,709.00
# 209  Laptop Lenovo IdeaPad 3 15IML05 15.6" HD, Inte...       2  $11,599.00
# 210  Laptop HP 240 G8 14'' HD, Intel Core i5-1035G1...       3  $29,439.00
# 211  Laptop Gamer MSI GF63 Thin 15.6" Full HD, Inte...       3  $14,909.00
#
#                Existencia                                            Enlaces
# 0     Disponibles:88pzas.  https://www.cyberpuerta.mx/Computadoras/Laptop...
# 1     Disponibles:78pzas.  https://www.cyberpuerta.mx/Opiniones-sobre-Lap...
# 2     Disponibles:38pzas.  https://www.cyberpuerta.mx/Opiniones-sobre-Lap...
# 3    Disponibles:104pzas.                                                  #
# 4     Disponibles:22pzas.  https://www.cyberpuerta.mx/lista-de-comparacio...
# ..                    ...                                                ...
# 207      Producto agotado                                                  #
# 208      Producto agotado  https://www.cyberpuerta.mx/Computadoras/Laptop...
# 209      Producto agotado                                                  #
# 210      Producto agotado  https://www.cyberpuerta.mx/Computadoras/Laptop...
# 211      Producto agotado                                                  #
#
# [212 rows x 5 columns]

# %%
import datetime

fecha_actual = datetime.datetime.now().strftime('%d-%m-%Y')

df.to_csv(f'./WebScrapping/Cyberpuerta-WebScrap-{fecha_actual}.csv', index=False)
